# %% [markdown]
# ## Final Project Submission

# %%
# Your code here - remember to use markdown cells for comments as well!

# %%
import pandas as pd # data analysis
import requests # get url
from bs4 import BeautifulSoup as bs # data scraping
import matplotlib.pyplot as plt # Data visualisation
import datetime # Check week number
import time

# %%
url = "https://www.boxofficemojo.com/chart/ww_top_lifetime_gross/?area=XWW&ref_=bo_cso_ac"
r = requests.get(url)
soup = bs(r.content, "html.parser")
print(soup.prettify)
# Out:
# <bound method Tag.prettify of <!DOCTYPE doctype html>
# <html class="a-no-js" data-19ax5a9jf="dingo"><head><script>var aPageStart = (new Date()).getTime();</script><meta charset="utf-8"/><meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <meta charset="utf-8"/>
# <title dir="ltr">Top Lifetime Grosses - Box Office Mojo</title><meta content="Top Lifetime Grosses" name="title"/>
# <meta content="Box Office Mojo" property="og:site_name"/>
# <meta content="telephone=no" name="format-detection"/>
# <link href="https://m.media-amazon.com/images/G/01/boxofficemojo/v2/favicon._CB448965889_.ico" rel="icon" type="image/x-icon"/>
# ...

# %%
movie_list1 = []
row_list = []
for record in soup.findAll("tr"):
    for data in record.findAll("td"):
        row_list.append(data.text)
    if row_list == []:
        pass
    else:
        movie_list1.append(row_list)
        row_list = []
print(movie_list1)
# Out:
# [['1', 'Avengers: Endgame', '$2,797,800,564', '$858,373,000', '30.7%', '$1,939,427,564', '69.3%', '2019'], ['2', 'Avatar', '$2,790,439,000', '$760,507,625', '27.2%', '$2,029,931,375', '72.8%', '2009'], ['3', 'Titanic', '$2,194,439,542', '$659,363,944', '30%', '$1,535,075,598', '70%', '1997'], ['4', 'Star Wars: Episode VII - The Force Awakens', '$2,068,223,624', '$936,662,225', '45.3%', '$1,131,561,399', '54.7%', '2015'], ['5', 'Avengers: Infinity War', '$2,048,359,754', '$678,815,482', '33.1%', '$1,369,544,272', '66.9%', '2018'], ['6', 'Jurassic World', '$1,670,400,637', '$652,270,625', '39%', '$1,018,130,012', '61%', '2015'], ['7', 'The Lion King', '$1,656,943,394', '$543,638,043', '32.8%', '$1,113,305,351', '67.2%', '2019'], ['8', 'The Avengers', '$1,518,812,988', '$623,357,910', '41%', '$895,455,078', '59%', '2012'], ['9', 'Furious 7', '$1,515,047,671', '$353,007,020', '23.3%', '$1,162,040,651', '76.7%', '2015'], ['10', 'Frozen II', '$1,448,824,988', '$477,045,566', '32.9%', '$971
# ...

# %%
# mov_list1 = []
# for record in soup.findAll("tr"):
#    # print(record.findAll("td"))
#     row = [x.text for x in record.findAll("td")]
#     #print(row)
#     for a in record.findAll('a', href=True):
#         if a['href'].startswith('/title/'):
#             row.append(a['href'][7:16])
#     mov_list1.append(row)
# print(mov_list1)
# Out:
# [[], ['1', 'Avengers: Endgame', '$2,797,800,564', '$858,373,000', '30.7%', '$1,939,427,564', '69.3%', '2019', 'tt4154796'], ['2', 'Avatar', '$2,790,439,000', '$760,507,625', '27.2%', '$2,029,931,375', '72.8%', '2009', 'tt0499549'], ['3', 'Titanic', '$2,194,439,542', '$659,363,944', '30%', '$1,535,075,598', '70%', '1997', 'tt0120338'], ['4', 'Star Wars: Episode VII - The Force Awakens', '$2,068,223,624', '$936,662,225', '45.3%', '$1,131,561,399', '54.7%', '2015', 'tt2488496'], ['5', 'Avengers: Infinity War', '$2,048,359,754', '$678,815,482', '33.1%', '$1,369,544,272', '66.9%', '2018', 'tt4154756'], ['6', 'Jurassic World', '$1,670,400,637', '$652,270,625', '39%', '$1,018,130,012', '61%', '2015', 'tt0369610'], ['7', 'The Lion King', '$1,656,943,394', '$543,638,043', '32.8%', '$1,113,305,351', '67.2%', '2019', 'tt6105098'], ['8', 'The Avengers', '$1,518,812,988', '$623,357,910', '41%', '$895,455,078', '59%', '2012', 'tt0848228'], ['9', 'Furious 7', '$1,515,047,671', '$353,007,020', '23.3
# ...

# %%
movie_ids1 = []
for a in soup.findAll('a', href=True):
    if a['href'].startswith('/title/'):
        movie_ids1.append(a['href'][7:16])
print(len(movie_ids1))
# Out:
# 200

# %%
url = "https://www.boxofficemojo.com/chart/ww_top_lifetime_gross/?area=XWW&offset=200"
r = requests.get(url)
soup2 = bs(r.content, "html.parser")
print(soup.prettify)
# Out:
# <bound method Tag.prettify of <!DOCTYPE doctype html>
# <html class="a-no-js" data-19ax5a9jf="dingo"><head><script>var aPageStart = (new Date()).getTime();</script><meta charset="utf-8"/><meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <meta charset="utf-8"/>
# <title dir="ltr">Top Lifetime Grosses - Box Office Mojo</title><meta content="Top Lifetime Grosses" name="title"/>
# <meta content="Box Office Mojo" property="og:site_name"/>
# <meta content="telephone=no" name="format-detection"/>
# <link href="https://m.media-amazon.com/images/G/01/boxofficemojo/v2/favicon._CB448965889_.ico" rel="icon" type="image/x-icon"/>
# ...

# %%
movie_list2 = []
row_list = []
for record in soup2.findAll("tr"):
    for data in record.findAll("td"):
        row_list.append(data.text)
    if row_list == []:
        pass
    else:
        movie_list2.append(row_list)
        row_list = []
movie_list2
# Out:
# [['201',
#   'Dunkirk',
#   '$526,940,665',
#   '$189,740,665',
#   '36%',
#   '$337,200,000',
#   '64%',
#   '2017'],
#  ['202',
#   'Godzilla',
#   '$524,976,069',
#   '$200,676,069',
#   '38.2%',
#   '$324,300,000',
#   '61.8%',
#   '2014'],
#  ['203',
#   'Sherlock Holmes',
#   '$524,028,679',
#   '$209,028,679',
#   '39.9%',
#   '$315,000,000',
#   '60.1%',
#   '2009'],
#  ['204',
#   'Meet the Fockers',
#   '$522,657,936',
#   '$279,261,160',
#   '53.4%',
#   '$243,396,776',
#   '46.6%',
#   '2004'],
#  ['205',
#   'How to Train Your Dragon: The Hidden World',
#   '$521,799,505',
#   '$160,799,505',
#   '30.8%',
#   '$361,000,000',
#   '69.2%',
#   '2019'],
#  ['206',
#   'WALL·E',
#   '$521,311,860',
#   '$223,808,164',
#   '42.9%',
#   '$297,503,696',
#   '57.1%',
#   '2008'],
#  ['207',
#   'Kung Fu Panda 3',
#   '$521,170,825',
#   '$143,528,619',
#   '27.5%',
#   '$377,642,206',
#   '72.5%',
#   '2016'],
#  ['208',
#   'Terminator 2: Judgment Day',
#   '$520,884,847',
# ...

# %%
movie_ids2 = []
for a in soup2.findAll('a', href=True):
    if a['href'].startswith('/title/'):
        movie_ids2.append(a['href'][7:16])
print(movie_ids2)
# Out:
# ['tt5013056', 'tt0831387', 'tt0988045', 'tt0290002', 'tt2386490', 'tt0910970', 'tt2267968', 'tt0103064', 'tt0478970', 'tt2709692', 'tt0099653', 'tt0103639', 'tt2357291', 'tt0332452', 'tt0120363', 'tt0892769', 'tt0117998', 'tt1623205', 'tt0800320', 'tt4777008', 'tt3450958', 'tt0356910', 'tt0808151', 'tt1291150', 'tt0315327', 'tt0126029', 'tt1436562', 'tt0120815', 'tt1318514', 'tt0099785', 'tt0086190', 'tt0367594', 'tt2510894', 'tt0097576', 'tt2126355', 'tt7349950', 'tt1772341', 'tt0073195', 'tt1119646', 'tt1490017', 'tt4701182', 'tt1408101', 'tt0133093', 'tt0100405', 'tt0317219', 'tt0172495', 'tt0376994', 'tt0465234', 'tt2872732', 'tt0117060', 'tt0416449', 'tt0325710', 'tt7362036', 'tt0240772', 'tt1014738', 'tt0800369', 'tt0213149', 'tt0120855', 'tt3783958', 'tt0120912', 'tt0440963', 'tt0209163', 'tt1231580', 'tt1707386', 'tt0070047', 'tt0107614', 'tt1340138', 'tt0101414', 'tt0803096', 'tt1517451', 'tt1485796', 'tt0181852', 'tt5884052', 'tt0246460', 'tt5113040', 'tt0162222', 'tt223146
# ...

# %%
url = "https://www.boxofficemojo.com/chart/ww_top_lifetime_gross/?offset=400&area=XWW"
r = requests.get(url)
soup3 = bs(r.content, "html.parser")
print(soup3.prettify)
# Out:
# <bound method Tag.prettify of <!DOCTYPE doctype html>
# <html class="a-no-js" data-19ax5a9jf="dingo"><head><script>var aPageStart = (new Date()).getTime();</script><meta charset="utf-8"/><meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <meta charset="utf-8"/>
# <title dir="ltr">Top Lifetime Grosses - Box Office Mojo</title><meta content="Top Lifetime Grosses" name="title"/>
# <meta content="Box Office Mojo" property="og:site_name"/>
# <meta content="telephone=no" name="format-detection"/>
# <link href="https://m.media-amazon.com/images/G/01/boxofficemojo/v2/favicon._CB448965889_.ico" rel="icon" type="image/x-icon"/>
# ...

# %%
movie_list3 = []
row_list = []
for record in soup3.findAll("tr"):
    for data in record.findAll("td"):
        row_list.append(data.text)
    if row_list == []:
        pass
    else:
        movie_list3.append(row_list)
        row_list = []
movie_list3
# Out:
# [['402',
#   'Rush Hour 2',
#   '$347,325,802',
#   '$226,164,286',
#   '65.1%',
#   '$121,161,516',
#   '34.9%',
#   '2001'],
#  ['403',
#   'Trolls',
#   '$346,864,462',
#   '$153,707,064',
#   '44.3%',
#   '$193,157,398',
#   '55.7%',
#   '2016'],
#  ['404',
#   'xXx: Return of Xander Cage',
#   '$346,118,277',
#   '$44,898,413',
#   '13%',
#   '$301,219,864',
#   '87%',
#   '2017'],
#  ['405',
#   'Pocahontas',
#   '$346,079,773',
#   '$141,579,773',
#   '40.9%',
#   '$204,500,000',
#   '59.1%',
#   '1995'],
#  ['406',
#   'How the Grinch Stole Christmas',
#   '$345,141,403',
#   '$260,044,825',
#   '75.3%',
#   '$85,096,578',
#   '24.7%',
#   '2000'],
#  ['407',
#   'Star Trek Beyond',
#   '$343,471,816',
#   '$158,848,340',
#   '46.2%',
#   '$184,623,476',
#   '53.8%',
#   '2016'],
#  ['408',
#   'Alvin and the Chipmunks: Chipwrecked',
#   '$342,695,435',
#   '$133,110,742',
#   '38.8%',
#   '$209,584,693',
#   '61.2%',
#   '2011'],
#  ['409',
#   'Wanted',
#   '$342,463,063',
# ...

# %%
movie_ids3 = []
for a in soup3.findAll('a', href=True):
    if a['href'].startswith('/title/'):
        movie_ids3.append(a['href'][7:16])
print(movie_ids3)
# Out:
# ['tt0266915', 'tt1679335', 'tt1293847', 'tt0114148', 'tt0170016', 'tt2660888', 'tt1615918', 'tt0493464', 'tt0109813', 'tt6644200', 'tt0461770', 'tt0327084', 'tt1253863', 'tt0112462', 'tt0473075', 'tt0096874', 'tt0421715', 'tt1397514', 'tt0117500', 'tt2034800', 'tt3110958', 'tt0120667', 'tt0087469', 'tt0120347', 'tt1979388', 'tt2294449', 'tt0212338', 'tt0096438', 'tt6966692', 'tt0947798', 'tt0177971', 'tt0090555', 'tt0458352', 'tt0114369', 'tt6146586', 'tt2446042', 'tt0116583', 'tt1067106', 'tt2279373', 'tt0108052', 'tt1001526', 'tt0104714', 'tt1142988', 'tt0955308', 'tt0361748', 'tt0115433', 'tt3065204', 'tt0093010', 'tt0938283', 'tt1457767', 'tt1041829', 'tt0268978', 'tt0086960', 'tt0118571', 'tt1764651', 'tt0371606', 'tt0119822', 'tt0338348', 'tt4046784', 'tt2592614', 'tt0145660', 'tt4116284', 'tt0496806', 'tt0970866', 'tt0397892', 'tt0117438', 'tt0163187', 'tt0878804', 'tt8946378', 'tt7830888', 'tt2582846', 'tt0454921', 'tt1446192', 'tt0075860', 'tt0299658', 'tt5140878', 'tt254347
# ...

# %%
url = "https://www.boxofficemojo.com/chart/ww_top_lifetime_gross/?area=XWW&offset=600"
r = requests.get(url)
soup4 = bs(r.content, "html.parser")
print(soup4.prettify)
# Out:
# <bound method Tag.prettify of <!DOCTYPE doctype html>
# <html class="a-no-js" data-19ax5a9jf="dingo"><head><script>var aPageStart = (new Date()).getTime();</script><meta charset="utf-8"/><meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <meta charset="utf-8"/>
# <title dir="ltr">Top Lifetime Grosses - Box Office Mojo</title><meta content="Top Lifetime Grosses" name="title"/>
# <meta content="Box Office Mojo" property="og:site_name"/>
# <meta content="telephone=no" name="format-detection"/>
# <link href="https://m.media-amazon.com/images/G/01/boxofficemojo/v2/favicon._CB448965889_.ico" rel="icon" type="image/x-icon"/>
# ...

# %%
movie_list4 = []
row_list = []
for record in soup4.findAll("tr"):
    for data in record.findAll("td"):
        row_list.append(data.text)
    if row_list == []:
        pass
    else:
        movie_list4.append(row_list)
        row_list = []
movie_list4
# Out:
# [['605',
#   'Wild Hogs',
#   '$253,625,427',
#   '$168,273,550',
#   '66.4%',
#   '$85,351,877',
#   '33.6%',
#   '2007'],
#  ['606',
#   'High School Musical 3',
#   '$252,909,177',
#   '$90,559,416',
#   '35.8%',
#   '$162,349,761',
#   '64.2%',
#   '2008'],
#  ['607',
#   'Hercules',
#   '$252,712,101',
#   '$99,112,101',
#   '39.2%',
#   '$153,600,000',
#   '60.8%',
#   '1997'],
#  ['608',
#   'X-Men: Dark Phoenix',
#   '$252,442,974',
#   '$65,845,974',
#   '26.1%',
#   '$186,597,000',
#   '73.9%',
#   '2019'],
#  ['609',
#   'True Grit',
#   '$252,276,927',
#   '$171,243,005',
#   '67.9%',
#   '$81,033,922',
#   '32.1%',
#   '2010'],
#  ['610',
#   'Bean',
#   '$251,212,670',
#   '$45,319,423',
#   '18%',
#   '$205,893,247',
#   '82%',
#   '1997'],
#  ['611',
#   'American Hustle',
#   '$251,171,807',
#   '$150,117,807',
#   '59.8%',
#   '$101,054,000',
#   '40.2%',
#   '2013'],
#  ['612',
#   'Enemy of the State',
#   '$250,849,789',
#   '$111,549,836',
#   '44.5%',
# ...

# %%
movie_ids4 = []
for a in soup4.findAll('a', href=True):
    if a['href'].startswith('/title/'):
        movie_ids4.append(a['href'][7:16])
print(movie_ids4)
# Out:
# ['tt0486946', 'tt0962726', 'tt0119282', 'tt6565702', 'tt1403865', 'tt0118689', 'tt1800241', 'tt0120660', 'tt0128853', 'tt0449010', 'tt0328880', 'tt0120746', 'tt0298130', 'tt0185937', 'tt0217869', 'tt5273624', 'tt0109686', 'tt6823368', 'tt2191701', 'tt2452042', 'tt0099088', 'tt0068646', 'tt1192628', 'tt0109831', 'tt0119094', 'tt3949660', 'tt1077368', 'tt0286716', 'tt1021867', 'tt0314331', 'tt2120120', 'tt1267297', 'tt0120812', 'tt0373051', 'tt1815862', 'tt0104257', 'tt0844471', 'tt0298203', 'tt1528854', 'tt1234721', 'tt0116213', 'tt2316204', 'tt3263904', 'tt2094766', 'tt0389860', 'tt0099423', 'tt1855325', 'tt0092493', 'tt1691917', 'tt3104988', 'tt0118688', 'tt1320261', 'tt0187078', 'tt0076666', 'tt1045658', 'tt0322259', 'tt0347149', 'tt4846340', 'tt0212720', 'tt0097165', 'tt3079380', 'tt0163651', 'tt1605630', 'tt0142342', 'tt2974918', 'tt2084970', 'tt0970416', 'tt0328828', 'tt1568346', 'tt0467406', 'tt1024648', 'tt0453451', 'tt6751668', 'tt0116209', 'tt0105417', 'tt8350360', 'tt036048
# ...

# %%
url = "https://www.boxofficemojo.com/chart/ww_top_lifetime_gross/?area=XWW&offset=800"
r = requests.get(url)
soup5 = bs(r.content, "html.parser")
print(soup5.prettify)
# Out:
# <bound method Tag.prettify of <!DOCTYPE doctype html>
# <html class="a-no-js" data-19ax5a9jf="dingo"><head><script>var aPageStart = (new Date()).getTime();</script><meta charset="utf-8"/><meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <meta charset="utf-8"/>
# <title dir="ltr">Top Lifetime Grosses - Box Office Mojo</title><meta content="Top Lifetime Grosses" name="title"/>
# <meta content="Box Office Mojo" property="og:site_name"/>
# <meta content="telephone=no" name="format-detection"/>
# <link href="https://m.media-amazon.com/images/G/01/boxofficemojo/v2/favicon._CB448965889_.ico" rel="icon" type="image/x-icon"/>
# ...

# %%
movie_list5 = []
row_list = []
for record in soup5.findAll("tr"):
    for data in record.findAll("td"):
        row_list.append(data.text)
    if row_list == []:
        pass
    else:
        movie_list5.append(row_list)
        row_list = []
movie_list5
# Out:
# [['808',
#   'Garfield',
#   '$203,172,417',
#   '$75,369,589',
#   '37.1%',
#   '$127,802,828',
#   '62.9%',
#   '2004'],
#  ['809',
#   'Little Women',
#   '$203,074,701',
#   '$107,674,701',
#   '53%',
#   '$95,400,000',
#   '47%',
#   '2019'],
#  ['810',
#   'The Addams Family',
#   '$203,044,905',
#   '$100,044,905',
#   '49.3%',
#   '$103,000,000',
#   '50.7%',
#   '2019'],
#  ['811',
#   'Patch Adams',
#   '$202,292,902',
#   '$135,026,902',
#   '66.8%',
#   '$67,266,000',
#   '33.2%',
#   '1998'],
#  ['812',
#   'Teenage Mutant Ninja Turtles',
#   '$201,965,915',
#   '$135,265,915',
#   '67%',
#   '$66,700,000',
#   '33%',
#   '1990'],
#  ['813',
#   'Kindergarten Cop',
#   '$201,957,688',
#   '$91,457,688',
#   '45.3%',
#   '$110,500,000',
#   '54.7%',
#   '1990'],
#  ['814',
#   'Straight Outta Compton',
#   '$201,634,991',
#   '$161,197,785',
#   '80%',
#   '$40,437,206',
#   '20%',
#   '2015'],
#  ['815',
#   '21 Jump Street',
#   '$201,585,328',
#   '$138,447,667',
# ...

# %%
movie_ids5 = []
for a in soup5.findAll('a', href=True):
    if a['href'].startswith('/title/'):
        movie_ids5.append(a['href'][7:16])
print(movie_ids5)
# Out:
# ['tt0356634', 'tt3281548', 'tt1620981', 'tt0129290', 'tt0100758', 'tt0099938', 'tt1398426', 'tt1232829', 'tt0985699', 'tt0400717', 'tt0239395', 'tt0099810', 'tt1854564', 'tt0313737', 'tt1245526', 'tt0120632', 'tt0395699', 'tt0343660', 'tt1386703', 'tt8755316', 'tt1649419', 'tt2459022', 'tt4575576', 'tt1351685', 'tt2398241', 'tt0338459', 'tt0258000', 'tt2203939', 'tt0111282', 'tt0442933', 'tt1606389', 'tt0305224', 'tt0942385', 'tt5580390', 'tt0107798', 'tt3691740', 'tt2066051', 'tt2361509', 'tt6398184', 'tt0312004', 'tt0377981', 'tt0164184', 'tt0217505', 'tt4591310', 'tt1179904', 'tt0455944', 'tt3513498', 'tt0101272', 'tt0398165', 'tt0349205', 'tt3766354', 'tt0164052', 'tt0114069', 'tt0111070', 'tt6324278', 'tt8239806', 'tt0120902', 'tt3890264', 'tt0095956', 'tt7713068', 'tt0359950', 'tt0077766', 'tt2024544', 'tt0113277', 'tt1396218', 'tt0391198', 'tt0762107', 'tt9426210', 'tt0119314', 'tt0358273', 'tt0283426', 'tt1144884', 'tt0230011', 'tt0454848', 'tt0120484', 'tt0970179', 'tt476528
# ...

# %%
print(len(movie_ids1))
print(len(movie_ids2))
print(len(movie_ids3))
print(len(movie_ids4))
print(len(movie_ids5))
# Out:
# 200
# 200
# 200
# 200
# 200

# %%
all_movie_ids = movie_ids1 + movie_ids2 + movie_ids3 + movie_ids4 + movie_ids5
print(all_movie_ids)
# Out:
# ['tt4154796', 'tt0499549', 'tt0120338', 'tt2488496', 'tt4154756', 'tt0369610', 'tt6105098', 'tt0848228', 'tt2820852', 'tt4520988', 'tt2395427', 'tt1825683', 'tt1201607', 'tt2527336', 'tt4881806', 'tt2294629', 'tt2771200', 'tt3606756', 'tt4630562', 'tt1300854', 'tt2293640', 'tt3498820', 'tt1477834', 'tt0167260', 'tt6320628', 'tt4154664', 'tt1399103', 'tt1074638', 'tt2109248', 'tt1345836', 'tt7286456', 'tt1979376', 'tt2527338', 'tt0435761', 'tt0383574', 'tt3748528', 'tt6139732', 'tt1298650', 'tt3469046', 'tt0107290', 'tt2277860', 'tt0120915', 'tt1014759', 'tt2948356', 'tt0903624', 'tt0468569', 'tt0241527', 'tt0926084', 'tt1690953', 'tt0110357', 'tt3040964', 'tt2283362', 'tt0449088', 'tt1170358', 'tt2310332', 'tt0167261', 'tt0373889', 'tt0266543', 'tt0417741', 'tt0298148', 'tt1727824', 'tt0330373', 'tt0413300', 'tt0120737', 'tt1080016', 'tt2379713', 'tt2250912', 'tt0295297', 'tt1667889', 'tt2709768', 'tt2975590', 'tt7131870', 'tt0121766', 'tt1951264', 'tt3896198', 'tt2096673', 'tt127079
# ...

# %%
import json
import time
import requests
# api_key = [‘3aeb17b2290cbbffede9813c8fe450e7’]
# url = "https://api.themoviedb.org/3/movie/" + mov_id + "?api_key=3aeb17b2290cbbffede9813c8fe450e7&language=en-US"

List_of_responses = []
for id in all_movie_ids:
    response = requests.get("https://api.themoviedb.org/3/movie/" + id + "?api_key=3aeb17b2290cbbffede9813c8fe450e7&language=en-US")
    data = response.json()
    time.sleep(.5)
    List_of_responses.append(data)
print(List_of_responses)
    
# i = 0
# sizeofList = len(wordList) 
# while i < sizeofList :
#     print(wordList[i]) 
#     i += 1
# Out:
# [{'adult': False, 'backdrop_path': '/7RyHsO4yDXtBv1zUU3mTpHeQ0d5.jpg', 'belongs_to_collection': {'id': 86311, 'name': 'The Avengers Collection', 'poster_path': '/yFSIUVTCvgYrpalUktulvk3Gi5Y.jpg', 'backdrop_path': '/zuW6fOiusv4X9nnW3paHGfXcSll.jpg'}, 'budget': 356000000, 'genres': [{'id': 12, 'name': 'Adventure'}, {'id': 878, 'name': 'Science Fiction'}, {'id': 28, 'name': 'Action'}], 'homepage': 'https://www.marvel.com/movies/avengers-endgame', 'id': 299534, 'imdb_id': 'tt4154796', 'original_language': 'en', 'original_title': 'Avengers: Endgame', 'overview': "After the devastating events of Avengers: Infinity War, the universe is in ruins due to the efforts of the Mad Titan, Thanos. With the help of remaining allies, the Avengers must assemble once more in order to undo Thanos' actions and restore order to the universe once and for all, no matter what consequences may be in store.", 'popularity': 38.57, 'poster_path': '/or06FN3Dka5tukK1e9sl16pB3iy.jpg', 'production_companies': [{'id':
# ...

# %%
print(len(List_of_responses))
# Out:
# 1000

# %%
highest_grossing = movie_list1 + movie_list2 + movie_list3 + movie_list4 + movie_list5
len(highest_grossing)
highest_grossing
# Out:
# [['1',
#   'Avengers: Endgame',
#   '$2,797,800,564',
#   '$858,373,000',
#   '30.7%',
#   '$1,939,427,564',
#   '69.3%',
#   '2019'],
#  ['2',
#   'Avatar',
#   '$2,790,439,000',
#   '$760,507,625',
#   '27.2%',
#   '$2,029,931,375',
#   '72.8%',
#   '2009'],
#  ['3',
#   'Titanic',
#   '$2,194,439,542',
#   '$659,363,944',
#   '30%',
#   '$1,535,075,598',
#   '70%',
#   '1997'],
#  ['4',
#   'Star Wars: Episode VII - The Force Awakens',
#   '$2,068,223,624',
#   '$936,662,225',
#   '45.3%',
#   '$1,131,561,399',
#   '54.7%',
#   '2015'],
#  ['5',
#   'Avengers: Infinity War',
#   '$2,048,359,754',
#   '$678,815,482',
#   '33.1%',
#   '$1,369,544,272',
#   '66.9%',
#   '2018'],
#  ['6',
#   'Jurassic World',
#   '$1,670,400,637',
#   '$652,270,625',
#   '39%',
#   '$1,018,130,012',
#   '61%',
#   '2015'],
#  ['7',
#   'The Lion King',
#   '$1,656,943,394',
#   '$543,638,043',
#   '32.8%',
#   '$1,113,305,351',
#   '67.2%',
#   '2019'],
#  ['8',
#   'The Avengers',
# ...

# %%
for header in soup.findAll("th"):
    print(header.text)
# Out:
# Rank
#
# Title
#
# Worldwide Lifetime Gross
#
# Domestic Lifetime Gross
#
# Domestic %
#
# Foreign Lifetime Gross
#
# Foreign %
#
# Year

# %%
https://www.boxofficemojo.com/chart/ww_top_lifetime_gross/?area=XWW&offset=200
