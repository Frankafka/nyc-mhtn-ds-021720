# %% [markdown]
# ## Final Project Submission

# %%
# Your code here - remember to use markdown cells for comments as well!

# %%
import pandas as pd # data analysis
import requests # get url
from bs4 import BeautifulSoup as bs # data scraping
import matplotlib.pyplot as plt # Data visualisation
import datetime # Check week number
import time

# %%
url = "https://www.boxofficemojo.com/chart/ww_top_lifetime_gross/?area=XWW&ref_=bo_cso_ac"
r = requests.get(url)
soup = bs(r.content, "html.parser")
print(soup.prettify)
# Out:
# <bound method Tag.prettify of <!DOCTYPE doctype html>
# <html class="a-no-js" data-19ax5a9jf="dingo"><head><script>var aPageStart = (new Date()).getTime();</script><meta charset="utf-8"/><meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <meta charset="utf-8"/>
# <title dir="ltr">Top Lifetime Grosses - Box Office Mojo</title><meta content="Top Lifetime Grosses" name="title"/>
# <meta content="Box Office Mojo" property="og:site_name"/>
# <meta content="telephone=no" name="format-detection"/>
# <link href="https://m.media-amazon.com/images/G/01/boxofficemojo/v2/favicon._CB448965889_.ico" rel="icon" type="image/x-icon"/>
# <link href="https://images-na.ssl-images-amazon.com/images/I/51tax7M48-L._RC|516fcOUE-HL.css,01evdoiemkL.css,01K+Ps1DeEL.css,31pdJv9iSzL.css,01VszOUTO6L.css,11UGC+GXOPL.css,21LK7jaicML.css,11L58Qpo0GL.css,21kyTi1FabL.css,01ruG+gDPFL.css,01YhS3Cs-hL.css,21GwE3cR-yL.css,019SHZnt8RL.css,01wAWQRgXzL.css,21bWcRJYNIL.css,11WgRxUdJRL.css,01dU8+SPlFL.css,11ocrgKoE-L.css,01SHjPML6tL.css,111-D2qRjiL.css,01QrWuRrZ-L.css,310Imb6LqFL.css,01piEq-AdwL.css,11Z1a0FxSIL.css,01cbS3UK11L.css,21mOLw+nYYL.css,01L8Y-JFEhL.css_.css?AUIClients/AmazonUI#us.not-trident" rel="stylesheet"/>
# <link href="https://images-na.ssl-images-amazon.com/images/I/41jxT1zINDL.css?AUIClients/IMDbMojoSiteAssets" rel="stylesheet"/>
# <script>
# (function(f,h,Q,A){function G(a){v&&v.tag&&v.tag(q(":","aui",a))}function x(a,b){v&&v.count&&v.count("aui:"+a,0===b?0:b||(v.count("aui:"+a)||0)+1)}function l(a){try{return a.test(navigator.userAgent)}catch(b){return!1}}function y(a,b,c){a.addEventListener?a.addEventListener(b,c,!1):a.attachEvent&&a.attachEvent("on"+b,c)}function q(a,b,c,e){b=b&&c?b+a+c:b||c;return e?q(a,b,e):b}function H(a,b,c){try{Object.defineProperty(a,b,{value:c,writable:!1})}catch(e){a[b]=c}return c}function ta(a,b){var c=a.length,
# e=c,g=function(){e--||(R.push(b),S||(setTimeout(T,0),S=!0))};for(g();c--;)ca[a[c]]?g():(B[a[c]]=B[a[c]]||[]).push(g)}function ua(a,b,c,e,g){var d=h.createElement(a?"script":"link");y(d,"error",e);g&&y(d,"load",g);a?(d.type="text/javascript",d.async=!0,c&&/AUIClients|images[/]I/.test(b)&&d.setAttribute("crossorigin","anonymous"),d.src=b):(d.rel="stylesheet",d.href=b);h.getElementsByTagName("head")[0].appendChild(d)}function da(a,b){function c(c,e){function g(){ua(b,c,h,function(b){!I&&h?(h=!1,x("resource_retry"),
# g()):(x("resource_error"),a.log("Asset failed to load: "+c,I?"WARN":A));b&&b.stopPropagation?b.stopPropagation():f.event&&(f.event.cancelBubble=!0)},e)}if(ea[c])return!1;ea[c]=!0;x("resource_count");var h=!0;return!g()}if(b){var e=0,g=0;c.andConfirm=function(a,b){return c(a,function(){e++;b&&b.apply(this,arguments)})};c.confirm=function(){g++};c.getCsriCounters=function(){return{reqs:e,full:g}}}return c}function va(a,b,c){for(var e={name:a,guard:function(c){return b.guardFatal(a,c)},logError:function(c,
# d,e){b.logError(c,d,e,a)}},g=[],d=0;d<c.length;d++)J.hasOwnProperty(c[d])&&(g[d]=U.hasOwnProperty(c[d])?U[c[d]](J[c[d]],e):J[c[d]]);return g}function C(a,b,c,e,g){return function(d,h){function m(){var a=null;e?a=h:"function"===typeof h&&(p.start=D(),a=h.apply(f,va(d,k,l)),p.end=D());if(b){J[d]=a;a=d;for(ca[a]=!0;(B[a]||[]).length;)B[a].shift()();delete B[a]}p.done=!0}var k=g||this;"function"===typeof d&&(h=d,d=A);b&&(d=d?d.replace(fa,""):"__NONAME__",V.hasOwnProperty(d)&&k.error(q(", reregistered by ",
# q(" by ",d+" already registered",V[d]),k.attribution),d),V[d]=k.attribution);for(var l=[],n=0;n<a.length;n++)l[n]=a[n].replace(fa,"");var p=ga[d||"anon"+ ++wa]={depend:l,registered:D(),namespace:k.namespace};c?m():ta(l,k.guardFatal(d,m));return{decorate:function(a){U[d]=k.guardFatal(d,a)}}}}function ha(a){return function(){var b=Array.prototype.slice.call(arguments);return{execute:C(b,!1,a,!1,this),register:C(b,!0,a,!1,this)}}}function W(a,b){return function(c,e){e||(e=c,c=A);var g=this.attribution;
# return function(){z.push(b||{attribution:g,name:c,logLevel:a});var d=e.apply(this,arguments);z.pop();return d}}}function K(a,b){this.load={js:da(this,!0),css:da(this)};H(this,"namespace",b);H(this,"attribution",a)}function ia(){h.body?p.trigger("a-bodyBegin"):setTimeout(ia,20)}function E(a,b){a.className=X(a,b)+" "+b}function X(a,b){return(" "+a.className+" ").split(" "+b+" ").join(" ").replace(/^ | $/g,"")}function ja(a){try{return a()}catch(b){return!1}}function L(){if(M){var a={w:f.innerWidth||
# m.clientWidth,h:f.innerHeight||m.clientHeight};5<Math.abs(a.w-Y.w)||50<a.h-Y.h?(Y=a,N=4,(a=k.mobile||k.tablet?450<a.w&&a.w>a.h:1250<=a.w)?E(m,"a-ws"):m.className=X(m,"a-ws")):0<N&&(N--,ka=setTimeout(L,16))}}function xa(a){(M=a===A?!M:!!a)&&L()}function ya(){return M}function r(a,b){return"sw:"+(b||"")+":"+a+":"}function la(){ma.forEach(function(a){G(a)})}function n(a){ma.push(a)}function na(a,b,c,e){if(c){b=l(/Chrome/i)&&!l(/Edge/i)&&!l(/OPR/i)&&!a.capabilities.isAmazonApp&&!l(new RegExp(Z+"bwv"+
# Z+"b"));var g=r(e,"browser"),d=r(e,"prod_mshop"),f=r(e,"beta_mshop");!a.capabilities.isAmazonApp&&c.browser&&b&&(n(g+"supported"),c.browser.action(g,e));!b&&c.browser&&n(g+"unsupported");c.prodMshop&&n(d+"unsupported");c.betaMshop&&n(f+"unsupported")}}"use strict";var O=Q.now=Q.now||function(){return+new Q},D=function(a){return a&&a.now?a.now.bind(a):O}(f.performance),za=D(),t=f.AmazonUIPageJS||f.P;if(t&&t.when&&t.register)throw Error("A copy of P has already been loaded on this page.");var v=f.ue;
# G();G("aui_build_date:3.20.1-2020-02-28");var R=[],S=!1,T;T=function(){for(var a=setTimeout(T,0),b=O();R.length;)if(R.shift()(),50<O()-b)return;clearTimeout(a);S=!1};var ca={},B={},ea={},I=!1;y(f,"beforeunload",function(){I=!0;setTimeout(function(){I=!1},1E4)});var fa=/^prv:/,V={},J={},U={},ga={},wa=0,Z=String.fromCharCode(92),F,z=[],oa=f.onerror;f.onerror=function(a,b,c,e,g){g&&"object"===typeof g||(g=Error(a,b,c),g.columnNumber=e,g.stack=b||c||e?q(Z,g.message,"at "+q(":",b,c,e)):A);var d=z.pop()||
# {};g.attribution=q(":",g.attribution||d.attribution,d.name);g.logLevel=d.logLevel;g.attribution&&console&&console.log&&console.log([g.logLevel||"ERROR",a,"thrown by",g.attribution].join(" "));z=[];oa&&(d=[].slice.call(arguments),d[4]=g,oa.apply(f,d))};K.prototype={logError:function(a,b,c,e){b={message:b,logLevel:c||"ERROR",attribution:q(":",this.attribution,e)};if(f.ueLogError)return f.ueLogError(a||b,a?b:null),!0;console&&console.error&&(console.log(b),console.error(a));return!1},error:function(a,
# b,c,e){a=Error(q(":",e,a,c));a.attribution=q(":",this.attribution,b);throw a;},guardError:W(),guardFatal:W("FATAL"),guardCurrent:function(a){var b=z[z.length-1];return b?W(b.logLevel,b).call(this,a):a},log:function(a,b,c){return this.logError(null,a,b,c)},declare:C([],!0,!0,!0),register:C([],!0),execute:C([]),AUI_BUILD_DATE:"3.20.1-2020-02-28",when:ha(),now:ha(!0),trigger:function(a,b,c){var e=O();this.declare(a,{data:b,pageElapsedTime:e-(f.aPageStart||NaN),triggerTime:e});c&&c.instrument&&F.when("prv:a-logTrigger").execute(function(b){b(a)})},
# handleTriggers:function(){this.log("handleTriggers deprecated")},attributeErrors:function(a){return new K(a)},_namespace:function(a,b){return new K(a,b)}};var p=H(f,"AmazonUIPageJS",new K);F=p._namespace("PageJS","AmazonUI");F.declare("prv:p-debug",ga);p.declare("p-recorder-events",[]);p.declare("p-recorder-stop",function(){});H(f,"P",p);ia();if(h.addEventListener){var pa;h.addEventListener("DOMContentLoaded",pa=function(){p.trigger("a-domready");h.removeEventListener("DOMContentLoaded",pa,!1)},!1)}var m=
# h.documentElement,aa=function(){var a=["O","ms","Moz","Webkit"],b=h.createElement("div");return{testGradients:function(){b.style.cssText="background-image:-webkit-gradient(linear,left top,right bottom,from(#1E4),to(white));background-image:-webkit-linear-gradient(left top,#1E4,white);background-image:linear-gradient(left top,#1E4,white);";return~b.style.backgroundImage.indexOf("gradient")},test:function(c){var e=c.charAt(0).toUpperCase()+c.substr(1);c=(a.join(e+" ")+e+" "+c).split(" ");for(e=c.length;e--;)if(""===
# b.style[c[e]])return!0;return!1},testTransform3d:function(){var a=!1;f.matchMedia&&(a=f.matchMedia("(-webkit-transform-3d)").matches);return a}}}(),t=m.className,qa=/(^| )a-mobile( |$)/.test(t),ra=/(^| )a-tablet( |$)/.test(t),k={audio:function(){return!!h.createElement("audio").canPlayType},video:function(){return!!h.createElement("video").canPlayType},canvas:function(){return!!h.createElement("canvas").getContext},svg:function(){return!!h.createElementNS&&!!h.createElementNS("http://www.w3.org/2000/svg",
# "svg").createSVGRect},offline:function(){return navigator.hasOwnProperty&&navigator.hasOwnProperty("onLine")&&navigator.onLine},dragDrop:function(){return"draggable"in h.createElement("span")},geolocation:function(){return!!navigator.geolocation},history:function(){return!(!f.history||!f.history.pushState)},webworker:function(){return!!f.Worker},autofocus:function(){return"autofocus"in h.createElement("input")},inputPlaceholder:function(){return"placeholder"in h.createElement("input")},textareaPlaceholder:function(){return"placeholder"in
# h.createElement("textarea")},localStorage:function(){return"localStorage"in f&&null!==f.localStorage},orientation:function(){return"orientation"in f},touch:function(){return"ontouchend"in h},gradients:function(){return aa.testGradients()},hires:function(){var a=f.devicePixelRatio&&1.5<=f.devicePixelRatio||f.matchMedia&&f.matchMedia("(min-resolution:144dpi)").matches;x("hiRes"+(qa?"Mobile":ra?"Tablet":"Desktop"),a?1:0);return a},transform3d:function(){return aa.testTransform3d()},touchScrolling:function(){return l(/Windowshop|android|OS ([5-9]|[1-9][0-9]+)(_[0-9]{1,2})+ like Mac OS X|Chrome|Silk|Firefox|Trident.+?; Touch/i)},
# ios:function(){return l(/OS [1-9][0-9]*(_[0-9]*)+ like Mac OS X/i)&&!l(/trident|Edge/i)},android:function(){return l(/android.([1-9]|[L-Z])/i)&&!l(/trident|Edge/i)},mobile:function(){return qa},tablet:function(){return ra},rtl:function(){return"rtl"===m.dir}},u;for(u in k)k.hasOwnProperty(u)&&(k[u]=ja(k[u]));for(var ba="textShadow textStroke boxShadow borderRadius borderImage opacity transform transition".split(" "),P=0;P<ba.length;P++)k[ba[P]]=ja(function(){return aa.test(ba[P])});var M=!0,ka=0,
# Y={w:0,h:0},N=4;L();y(f,"resize",function(){clearTimeout(ka);N=4;L()});var sa={getItem:function(a){try{return f.localStorage.getItem(a)}catch(b){}},setItem:function(a,b){try{return f.localStorage.setItem(a,b)}catch(c){}}};m.className=X(m,"a-no-js");E(m,"a-js");!l(/OS [1-8](_[0-9]*)+ like Mac OS X/i)||f.navigator.standalone||l(/safari/i)||E(m,"a-ember");t=[];for(u in k)k.hasOwnProperty(u)&&k[u]&&t.push("a-"+u.replace(/([A-Z])/g,function(a){return"-"+a.toLowerCase()}));E(m,t.join(" "));m.setAttribute("data-aui-build-date",
# "3.20.1-2020-02-28");p.register("p-detect",function(){return{capabilities:k,localStorage:k.localStorage&&sa,toggleResponsiveGrid:xa,responsiveGridEnabled:ya}});l(/UCBrowser/i)||k.localStorage&&E(m,sa.getItem("a-font-class"));p.declare("a-event-revised-handling",!1);var w;try{w=navigator.serviceWorker}catch(a){G("sw:nav_err")}w&&(y(w,"message",function(a){a&&a.data&&x(a.data.k,a.data.v)}),w.controller&&w.controller.postMessage("MSG-RDY"));var ma=[];(function(a){var b=a.reg,c=a.unreg;w&&w.getRegistrations?
# (F.when("A","a-util").execute(function(a,b){na(a,b,c,"unregister")}),y(f,"load",function(){F.when("A","a-util").execute(function(a,c){na(a,c,b,"register");la()})})):(b&&(b.browser&&n(r("register","browser")+"unsupported"),b.prodMshop&&n(r("register","prod_mshop")+"unsupported"),b.betaMshop&&n(r("register","beta_mshop")+"unsupported")),c&&(c.browser&&n(r("unregister","browser")+"unsupported"),c.prodMshop&&n(r("unregister","prod_mshop")+"unsupported"),c.betaMshop&&n(r("unregister","beta_mshop")+"unsupported")),
# la())})({reg:{},unreg:{}});p.declare("a-fix-event-off",!1);x("pagejs:pkgExecTime",D()-za)})(window,document,Date);
#   (window.AmazonUIPageJS ? AmazonUIPageJS : P).load.js('https://images-na.ssl-images-amazon.com/images/I/61-6nKPKyWL._RC|11-BZEJ8lnL.js,61GQ9IdK7HL.js,21Of0-9HPCL.js,012FVc3131L.js,11S5WBtBslL.js,51CF7BmbF2L.js,11AHlQhPRjL.js,016iHgpF74L.js,11aNYFFS5hL.js,116tgw9TSaL.js,211-p4GRUCL.js,01PoLXBDXWL.js,618UAEWDpaL.js,01ezj5Rkz1L.js,11BOgvnnntL.js,31UWuPgtTtL.js,01rpauTep4L.js,01iyxuSGj4L.js,01nZw0IOzSL.js_.js?AUIClients/AmazonUI');
#   (window.AmazonUIPageJS ? AmazonUIPageJS : P).load.js('https://images-na.ssl-images-amazon.com/images/I/51voyzpfdCL.js?AUIClients/IMDbMojoSiteAssets');
# </script>
# </head><body class="mojo-page-id-cso a-m-us a-aui_157141-c a-aui_72554-c a-aui_dropdown_187959-c a-aui_pci_risk_banner_210084-c a-aui_perf_130093-c a-aui_tnr_v2_180836-c a-aui_ux_145937-c" id="body"><div id="a-page"><script data-a-state='{"key":"a-wlab-states"}' type="a-state">{}</script><div class="a-section a-spacing-none mojo-navigation mojo-header mojo-flex mojo-flex-h"><div class="a-section mojo-logo"><a class="a-link-normal" href="/?ref_=bo_nb_cso_mojologo"></a></div><div class="a-section a-spacing-none mojo-nav-elements mojo-flex mojo-flex-h mojo-flex-1"><div class="a-section a-spacing-none mojo-search-bar mojo-flex mojo-flex-h"><div class="a-section a-spacing-none mojo-search"><form action="/search">
# <input id="mojo-search-text-input" name="q" placeholder="Search for Titles" required="true" type="search"/>
# <input class="mojo-inline-button" id="mojo-search-button" type="submit" value=""/>
# </form>
# </div></div><div class="a-section a-spacing-none mojo-mobile-options"><span class="a-declarative" data-a-popover='{"closeButton":"false","inlineContent":"\u003cspan class=\"a-size-medium\"&gt;\u003ca href=\"https://pro.imdb.com/?ref_=mojo_nb_cso_pro&amp;amp;rf=mojo_nb_cso_pro\" class=\"a-touch-link a-box a-touch-link-noborder\"&gt;\u003cdiv class=\"a-box-inner\"&gt;\u003ci class=\"a-icon a-icon-touch-link\"&gt;\u003c\/i&gt;IMDbPro\u003c\/div&gt;\u003c\/a&gt;\u003ca href=\"https://www.facebook.com/BoxOfficeMojo/\" class=\"a-touch-link a-box a-touch-link-noborder\"&gt;\u003cdiv class=\"a-box-inner\"&gt;\u003ci class=\"a-icon a-icon-touch-link\"&gt;\u003c\/i&gt;Facebook\u003c\/div&gt;\u003c\/a&gt;\u003ca href=\"https://twitter.com/boxofficemojo\" class=\"a-touch-link a-box a-touch-link-noborder\"&gt;\u003cdiv class=\"a-box-inner\"&gt;\u003ci class=\"a-icon a-icon-touch-link\"&gt;\u003c\/i&gt;Twitter\u003c\/div&gt;\u003c\/a&gt;\u003ca href=\"https://help.imdb.com/article/imdbpro/industry-research/box-office-mojo-by-imdbpro-faq/GCWTV4MQKGWRAUAP?ref_=mojo_ftr_help\" class=\"a-touch-link a-box a-touch-link-noborder\"&gt;\u003cdiv class=\"a-box-inner\"&gt;\u003ci class=\"a-icon a-icon-touch-link\"&gt;\u003c\/i&gt;Help\u003c\/div&gt;\u003c\/a&gt;\u003c\/span&gt;"}' data-action="a-popover"><a class="a-popover-trigger a-declarative" href="javascript:void(0)"><span class="mobile-menu-popover-trigger"></span>
# <i class="a-icon a-icon-popover"></i></a></span></div><div class="a-section a-spacing-none mojo-options mojo-flex"><div class="a-popover-preload" id="a-popover-mojoRollover"><a class="a-link-normal mojo-rollover-image" href="https://pro.imdb.com/login/ap?u=%2Flogin%2Flwa&amp;imdbPageAction=signUp&amp;ref_=mojo_nb_cso_rollover&amp;rf=mojo_nb_cso_rollover"><img alt="" src="https://m.media-amazon.com/images/G/01/IMDbPro/images/MI_121919_NYNY2020_Engagement_rollover_2x._CB1578336809_.png"/></a></div><span class="a-declarative" data-a-popover='{"padding":"none","closeButton":"false","dataStrategy":"preload","name":"mojoRollover","width":"500","position":"triggerBottom","height":"200"}' data-action="a-popover"><a class="a-popover-trigger a-declarative" href="javascript:void(0)"><span class="imdb-pro-logo"></span><i class="a-icon a-icon-popover"></i></a></span><span class="mojo-logo-delimiter"></span><a class="a-link-normal mojo-fb-logo" href="https://www.facebook.com/BoxOfficeMojo/" rel="noopener" target="_blank"></a><a class="a-link-normal mojo-tw-logo" href="https://twitter.com/boxofficemojo" rel="noopener" target="_blank"></a></div></div><div class="a-section a-spacing-none mojo-link-bar mojo-flex mojo-flex-h"><div class="a-section a-spacing-none mojo-tab-container"><a class="a-size-medium a-link-normal mojo-navigation-tab" href="/date/?ref_=bo_nb_cso_tab">Domestic</a><a class="a-size-medium a-link-normal mojo-navigation-tab" href="/intl/?ref_=bo_nb_cso_tab">International</a><a class="a-size-medium a-link-normal mojo-navigation-tab" href="/year/world/?ref_=bo_nb_cso_tab">Worldwide</a><a class="a-size-medium a-link-normal mojo-navigation-tab" href="/calendar/?ref_=bo_nb_cso_tab">Calendar</a><a class="a-size-medium a-link-normal mojo-navigation-tab mojo-navigation-tab-active" href="/charts/overall/?ref_=bo_nb_cso_tab">All Time</a><a class="a-size-medium a-link-normal mojo-navigation-tab" href="/showdown/?ref_=bo_nb_cso_tab">Showdowns</a><a class="a-size-medium a-link-normal mojo-navigation-tab" href="/news/?ref_=bo_nb_cso_tab">News</a></div></div><div class="a-section a-spacing-none mojo-link-bar-secondary mojo-flex mojo-flex-h"><div class="a-section a-spacing-base mojo-tab-container"><a class="a-size-medium a-link-normal mojo-navigation-tab mojo-navigation-tab-active" href="/charts/overall/?ref_=bo_nb_cso_secondarytab"><h2 class="a-size-medium a-text-normal">Overall</h2></a><a class="a-size-medium a-link-normal mojo-navigation-tab" href="/charts/weekend/?ref_=bo_nb_cso_secondarytab">Weekend Records</a><a class="a-size-medium a-link-normal mojo-navigation-tab" href="/charts/daily/?ref_=bo_nb_cso_secondarytab">Daily Records</a><a class="a-size-medium a-link-normal mojo-navigation-tab" href="/charts/misc/?ref_=bo_nb_cso_secondarytab">Miscellaneous Records</a></div></div><div class="a-section a-spacing-none mojo-link-bar-fade"><span class="a-letter-space"></span></div></div><main>
# <div class="a-section mojo-body aok-relative"><div class="a-section a-spacing-none"><h1 class="mojo-gutter">Top Lifetime Grosses</h1><div class="a-section mojo-gutter-sides"></div><div class="mojo-refiner mojo-override-gutter">
# <div class="mojo-refinement mojo-refinement-dropdown">
# <span class="mojo-dropdown-clear">
# <form action="" autocomplete="off" class="a-spacing-none" method="post"><span class="a-dropdown-container"><select autocomplete="off" class="a-native-dropdown" id="area-navSelector" name="area-navSelector" tabindex="-1"><option value="/chart/top_lifetime_gross/">Domestic</option><option selected="" value="/chart/ww_top_lifetime_gross/?area=XWW">Worldwide</option></select><span class="a-button a-button-dropdown" tabindex="-1"><span class="a-button-inner"><span aria-hidden="true" class="a-button-text a-declarative" data-action="a-dropdown-button" role="button" tabindex="0"><span class="a-dropdown-prompt"></span></span><i class="a-icon a-icon-dropdown"></i></span></span></span></form></span>
# </div>
# </div>
# <div class="a-text-center mojo-pagination"><ul class="a-pagination"><li class="a-disabled">←<span class="a-letter-space"></span><span class="a-letter-space"></span>Previous page</li><li class="a-selected mojo-pagination-button-center"><a href="#">1-200 of 1,000</a></li><li class="a-last"><a href="/chart/ww_top_lifetime_gross/?area=XWW&amp;offset=200">Next page<span class="a-letter-space"></span><span class="a-letter-space"></span>→</a></li></ul></div><style>
# table.a-bordered.mojo-body-table-compact td,
# table.a-bordered.mojo-body-table-compact th {
#     padding: 5px;
# }
# table.mojo-body-table tr.mojo-group-label th {
#     background: linear-gradient(to bottom, #f8f8f8, #eee);
# }
# </style>
# <div class="a-section imdb-scroll-table mojo-gutter-sides" id="table"><div class="a-section imdb-scroll-table-inner"><table class="a-bordered a-horizontal-stripes a-size-base a-span12 mojo-body-table mojo-table-annotated"><tr><th class="a-text-right mojo-field-type-rank a-nowrap"><span title="Rank">Rank</span>
# </th><th class="a-text-left mojo-field-type-title a-nowrap"><span title="Title">Title</span>
# </th><th class="a-text-right mojo-field-type-money a-nowrap"><span title="Worldwide Lifetime Gross">Worldwide Lifetime Gross</span>
# </th><th class="a-text-right mojo-field-type-money a-nowrap"><span title="Domestic Lifetime Gross">Domestic Lifetime Gross</span>
# </th><th class="a-text-right mojo-field-type-percent a-nowrap"><span title="Domestic %">Domestic %</span>
# </th><th class="a-text-right mojo-field-type-money a-nowrap"><span title="Foreign Lifetime Gross">Foreign Lifetime Gross</span>
# </th><th class="a-text-right mojo-field-type-percent a-nowrap"><span title="Foreign %">Foreign %</span>
# </th><th class="a-text-left mojo-field-type-year a-nowrap"><span title="Year">Year</span>
# </th></tr><tr><td class="a-text-right mojo-header-column mojo-truncate mojo-field-type-rank">1</td><td class="a-text-left mojo-field-type-title"><a class="a-link-normal" href="/title/tt4154796/?ref_=bo_cso_table_1">Avengers: Endgame</a></td><td class="a-text-right mojo-field-type-money">$2,797,800,564</td><td class="a-text-right mojo-field-type-money">$858,373,000</td><td class="a-text-right mojo-field-type-percent">30.7%</td><td class="a-text-right mojo-field-type-money">$1,939,427,564</td><td class="a-text-right mojo-field-type-percent">69.3%</td><td class="a-text-left mojo-field-type-year"><a class="a-link-normal" href="/year/world/2019/?ref_=bo_cso_table_1">2019</a></td></tr><tr><td class="a-text-right mojo-header-column mojo-truncate mojo-field-type-rank">2</td><td class="a-text-left mojo-field-type-title"><a class="a-link-normal" href="/title/tt0499549/?ref_=bo_cso_table_2">Avatar</a></td><td class="a-text-right mojo-field-type-money">$2,790,439,000</td><td class="a-text-right mojo-field-type-money">$760,507,625</td><td class="a-text-right mojo-field-type-percent">27.2%</td><td class="a-text-right mojo-field-type-money">$2,029,931,375</td><td class="a-text-right mojo-field-type-percent">72.8%</td><td class="a-text-left mojo-field-type-year"><a class="a-link-normal" href="/year/world/2009/?ref_=bo_cso_table_2">2009</a></td></tr><tr><td class="a-text-right mojo-header-column mojo-truncate mojo-field-type-rank">3</td><td class="a-text-left mojo-field-type-title"><a class="a-link-normal" href="/title/tt0120338/?ref_=bo_cso_table_3">Titanic</a></td><td class="a-text-right mojo-field-type-money">$2,194,439,542</td><td class="a-text-right mojo-field-type-money">$659,363,944</td><td class="a-text-right mojo-field-type-percent">30%</td><td class="a-text-right mojo-field-type-money">$1,535,075,598</td><td class="a-text-right mojo-field-type-percent">70%</td><td class="a-text-left mojo-field-type-year"><a class="a-link-normal" href="/year/world/1997/?ref_=bo_cso_table_3">1997</a></td></tr><tr><td class="a-text-right mojo-header-column mojo-truncate mojo-field-type-rank">4</td><td class="a-text-left mojo-field-type-title"><a class="a-link-normal" href="/title/tt2488496/?ref_=bo_cso_table_4">Star Wars: Episode VII - The Force Awakens</a></td><td class="a-text-right mojo-field-type-money">$2,068,223,624</td><td class="a-text-right mojo-field-type-money">$936,662,225</td><td class="a-text-right mojo-field-type-percent">45.3%</td><td class="a-text-right mojo-field-type-money">$1,131,561,399</td><td class="a-text-right mojo-field-type-percent">54.7%</td><td class="a-text-left mojo-field-type-year"><a class="a-link-normal" href="/year/world/2015/?ref_=bo_cso_table_4">2015</a></td></tr><tr><td class="a-text-right mojo-header-column mojo-truncate mojo-field-type-rank">5</td><td class="a-text-left mojo-field-type-title"><a class="a-link-normal" href="/title/tt4154756/?ref_=bo_cso_table_5">Avengers: Infinity War</a></td><td class="a-text-right mojo-field-type-money">$2,048,359,754</td><td class="a-text-right mojo-field-type-money">$678,815,482</td><td class="a-text-right mojo-field-type-percent">33.1%</td><td class="a-text-right mojo-field-type-money">$1,369,544,272</td><td class="a-text-right mojo-field-type-percent">66.9%</td><td class="a-text-left mojo-field-type-year"><a class="a-link-normal" href="/year/world/2018/?ref_=bo_cso_table_5">2018</a></td></tr><tr><td class="a-text-right mojo-header-column mojo-truncate mojo-field-type-rank">6</td><td class="a-text-left mojo-field-type-title"><a class="a-link-normal" href="/title/tt0369610/?ref_=bo_cso_table_6">Jurassic World</a></td><td class="a-text-right mojo-field-type-money">$1,670,400,637</td><td class="a-text-right mojo-field-type-money">$652,270,625</td><td class="a-text-right mojo-field-type-percent">39%</td><td class="a-text-right mojo-field-type-money">$1,018,130,012</td><td class="a-text-right mojo-field-type-percent">61%</td><td class="a-text-left mojo-field-type-year"><a class="a- ...
# <div class="a-section a-spacing-none mojo-navigation-frame"><div class="a-section a-spacing-none mojo-navigation mojo-footer"><a class="a-link-normal imdb-pro-logo" href="https://pro.imdb.com/?ref_=mojo_ft_cso_prologo&amp;rf=mojo_ft_cso_prologo"></a><p>
#             Latest Updates:
#             <a class="a-link-normal" href="/news/?ref_=bo_ft_cso_news">News</a> |
#             <a class="a-link-normal" href="/daily/?ref_=bo_ft_cso_daily">Daily</a> |
#             <a class="a-link-normal" href="/weekend/?ref_=bo_ft_cso_weekend">Weekend</a> |
#             <a class="a-link-normal" href="/charts/?ref_=bo_ft_cso_charts">All Time</a> |
#             <a class="a-link-normal" href="/intl/?ref_=bo_ft_cso_intl">International</a> |
#             <a class="a-link-normal" href="/showdown/?ref_=bo_ft_cso_showdown">Showdowns</a></p><p><a class="a-link-normal" href="https://help.imdb.com/article/imdbpro/industry-research/box-office-mojo-by-imdbpro-faq/GCWTV4MQKGWRAUAP?ref_=mojo_ftr_help" rel="noopener" target="_blank">Help</a></p><p>
#             BoxOfficeMojo.com by IMDbPro - an
#             <a class="a-link-normal" href="http://www.imdb.com/" rel="noopener" target="_blank">IMDb</a>
#             company.
#         </p><p>
#             © IMDb.com, Inc. or its affiliates. All rights reserved.
#             Box Office Mojo and IMDb are trademarks or registered trademarks of IMDb.com, Inc. or its affiliates.
#             <a class="a-link-normal" href="/conditions/?ref_=bo_ft_cso_conditions">Conditions of Use</a>
#              and
#              <a class="a-link-normal" href="/privacy/?ref_=bo_ft_cso_privacy">Privacy Policy</a>
#             under which this service is provided to you.
#         </p></div></div></div></body></html>>

# %%
movie_list1 = []
row_list = []
for record in soup.findAll("tr"):
    for data in record.findAll("td"):
        row_list.append(data.text)
    if row_list == []:
        pass
    else:
        movie_list1.append(row_list)
        row_list = []
movie_list1
# Out:
# [['1',
#   'Avengers: Endgame',
#   '$2,797,800,564',
#   '$858,373,000',
#   '30.7%',
#   '$1,939,427,564',
#   '69.3%',
#   '2019'],
#  ['2',
#   'Avatar',
#   '$2,790,439,000',
#   '$760,507,625',
#   '27.2%',
#   '$2,029,931,375',
#   '72.8%',
#   '2009'],
#  ['3',
#   'Titanic',
#   '$2,194,439,542',
#   '$659,363,944',
#   '30%',
#   '$1,535,075,598',
#   '70%',
#   '1997'],
#  ['4',
#   'Star Wars: Episode VII - The Force Awakens',
#   '$2,068,223,624',
#   '$936,662,225',
#   '45.3%',
#   '$1,131,561,399',
#   '54.7%',
#   '2015'],
#  ['5',
#   'Avengers: Infinity War',
#   '$2,048,359,754',
#   '$678,815,482',
#   '33.1%',
#   '$1,369,544,272',
#   '66.9%',
#   '2018'],
#  ['6',
#   'Jurassic World',
#   '$1,670,400,637',
#   '$652,270,625',
#   '39%',
#   '$1,018,130,012',
#   '61%',
#   '2015'],
#  ['7',
#   'The Lion King',
#   '$1,656,943,394',
#   '$543,638,043',
#   '32.8%',
#   '$1,113,305,351',
#   '67.2%',
#   '2019'],
#  ['8',
#   'The Avengers',
#   '$1,518,812,988',
#   '$623,357,910',
#   '41%',
#   '$895,455,078',
#   '59%',
#   '2012'],
#  ['9',
#   'Furious 7',
#   '$1,515,047,671',
#   '$353,007,020',
#   '23.3%',
#   '$1,162,040,651',
#   '76.7%',
#   '2015'],
#  ['10',
#   'Frozen II',
#   '$1,448,824,988',
#   '$477,045,566',
#   '32.9%',
#   '$971,779,422',
#   '67.1%',
#   '2019'],
#  ['11',
#   'Avengers: Age of Ultron',
#   '$1,402,805,868',
#   '$459,005,868',
#   '32.7%',
#   '$943,800,000',
#   '67.3%',
#   '2015'],
#  ['12',
#   'Black Panther',
#   '$1,346,913,161',
#   '$700,059,566',
#   '52%',
#   '$646,853,595',
#   '48%',
#   '2018'],
#  ['13',
#   'Harry Potter and the Deathly Hallows: Part 2',
#   '$1,341,932,398',
#   '$381,409,310',
#   '28.4%',
#   '$960,523,088',
#   '71.6%',
#   '2011'],
#  ['14',
#   'Star Wars: Episode VIII - The Last Jedi',
#   '$1,332,539,889',
#   '$620,181,382',
#   '46.5%',
#   '$712,358,507',
#   '53.5%',
#   '2017'],
#  ['15',
#   'Jurassic World: Fallen Kingdom',
#   '$1,308,467,944',
#   '$417,719,760',
#   '31.9%',
#   '$890,748,184',
#   '68.1%',
#   '2018'],
#  ['16',
#   'Frozen',
#   '$1,280,802,282',
#   '$400,738,009',
#   '31.3%',
#   '$880,064,273',
#   '68.7%',
#   '2013'],
#  ['17',
#   'Beauty and the Beast',
#   '$1,263,521,126',
#   '$504,014,165',
#   '39.9%',
#   '$759,506,961',
#   '60.1%',
#   '2017'],
#  ['18',
#   'Incredibles 2',
#   '$1,242,805,359',
#   '$608,581,744',
#   '49%',
#   '$634,223,615',
#   '51%',
#   '2018'],
#  ['19',
#   'The Fate of the Furious',
#   '$1,236,005,118',
#   '$226,008,385',
#   '18.3%',
#   '$1,009,996,733',
#   '81.7%',
#   '2017'],
#  ['20',
#   'Iron Man 3',
#   '$1,214,811,252',
#   '$409,013,994',
#   '33.7%',
#   '$805,797,258',
#   '66.3%',
#   '2013'],
#  ['21',
#   'Minions',
#   '$1,159,398,397',
#   '$336,045,770',
#   '29%',
#   '$823,352,627',
#   '71%',
#   '2015'],
#  ['22',
#   'Captain America: Civil War',
#   '$1,153,296,293',
#   '$408,084,349',
#   '35.4%',
#   '$745,211,944',
#   '64.6%',
#   '2016'],
#  ['23',
#   'Aquaman',
#   '$1,148,461,807',
#   '$335,061,807',
#   '29.2%',
#   '$813,400,000',
#   '70.8%',
#   '2018'],
#  ['24',
#   'The Lord of the Rings: The Return of the King',
#   '$1,142,219,401',
#   '$377,845,905',
#   '33.1%',
#   '$764,373,496',
#   '66.9%',
#   '2003'],
#  ['25',
#   'Spider-Man: Far from Home',
#   '$1,131,927,996',
#   '$390,532,085',
#   '34.5%',
#   '$741,395,911',
#   '65.5%',
#   '2019'],
#  ['26',
#   'Captain Marvel',
#   '$1,128,274,794',
#   '$426,829,839',
#   '37.8%',
#   '$701,444,955',
#   '62.2%',
#   '2019'],
#  ['27',
#   'Transformers: Dark of the Moon',
#   '$1,123,794,079',
#   '$352,390,543',
#   '31.4%',
#   '$771,403,536',
#   '68.6%',
#   '2011'],
#  ['28',
#   'Skyfall',
#   '$1,108,561,013',
#   '$304,360,277',
#   '27.5%',
#   '$804,200,736',
#   '72.5%',
#   '2012'],
#  ['29',
#   'Transformers: Age of Extinction',
#   '$1,104,054,072',
#   '$245,439,076',
#   '22.2%',
#   '$858,614,996',
#   '77.8%',
#   '2014'],
#  ['30',
#   'The Dark Knight Rises',
#   '$1,081,041,287',
#   '$448,139,099',
#   '41.4%',
#   '$632,902,188',
#   '58.6%',
#   '2012'],
#  ['31',
#   'Joker',
#   '$1,073,943,334',
#   '$335,443,334',
#   '31.2%',
#   '$738,500,000',
#   '68.8%',
#   '2019'],
#  ['32',
#   'Toy Story 4',
#   '$1,073,394,593',
#   '$434,038,008',
#   '40.4%',
#   '$639,356,585',
#   '59.6%',
#   '2019'],
#  ['33',
#   'Star Wars: Episode IX - The Rise of Skywalker',
#   '$1,073,294,598',
#   '$514,718,318',
#   '48%',
#   '$558,576,280',
#   '52%',
#   '2019'],
#  ['34',
#   'Toy Story 3',
#   '$1,066,969,703',
#   '$415,004,880',
#   '38.9%',
#   '$651,964,823',
#   '61.1%',
#   '2010'],
#  ['35',
#   "Pirates of the Caribbean: Dead Man's Chest",
#   '$1,066,179,725',
#   '$423,315,812',
#   '39.7%',
#   '$642,863,913',
#   '60.3%',
#   '2006'],
#  ['36',
#   'Rogue One: A Star Wars Story',
#   '$1,056,057,273',
#   '$532,177,324',
#   '50.4%',
#   '$523,879,949',
#   '49.6%',
#   '2016'],
#  ['37',
#   'Aladdin',
#   '$1,050,693,953',
#   '$355,559,216',
#   '33.8%',
#   '$695,134,737',
#   '66.2%',
#   '2019'],
#  ['38',
#   'Pirates of the Caribbean: On Stranger Tides',
#   '$1,045,713,802',
#   '$241,071,802',
#   '23%',
#   '$804,642,000',
#   '77%',
#   '2011'],
#  ['39',
#   'Despicable Me 3',
#   '$1,034,799,409',
#   '$264,624,300',
#   '25.6%',
#   '$770,175,109',
#   '74.4%',
#   '2017'],
#  ['40',
#   'Jurassic Park',
#   '$1,032,020,521',
#   '$402,828,120',
#   '39%',
#   '$629,192,401',
#   '61%',
#   '1993'],
#  ['41',
#   'Finding Dory',
#   '$1,028,570,889',
#   '$486,295,561',
#   '47.3%',
#   '$542,275,328',
#   '52.7%',
#   '2016'],
#  ['42',
#   'Star Wars: Episode I - The Phantom Menace',
#   '$1,027,082,707',
#   '$474,544,677',
#   '46.2%',
#   '$552,538,030',
#   '53.8%',
#   '1999'],
#  ['43',
#   'Alice in Wonderland',
#   '$1,025,467,110',
#   '$334,191,110',
#   '32.6%',
#   '$691,276,000',
#   '67.4%',
#   '2010'],
#  ['44',
#   'Zootopia',
#   '$1,023,784,195',
#   '$341,268,248',
#   '33.3%',
#   '$682,515,947',
#   '66.7%',
#   '2016'],
#  ['45',
#   'The Hobbit: An Unexpected Journey',
#   '$1,017,003,568',
#   '$303,003,568',
#   '29.8%',
#   '$714,000,000',
#   '70.2%',
#   '2012'],
#  ['46',
#   'The Dark Knight',
#   '$1,004,934,033',
#   '$535,234,033',
#   '53.3%',
#   '$469,700,000',
#   '46.7%',
#   '2008'],
#  ['47',
#   "Harry Potter and the Sorcerer's Stone",
#   '$978,087,613',
#   '$318,087,620',
#   '32.5%',
#   '$659,999,993',
#   '67.5%',
#   '2001'],
#  ['48',
#   'Harry Potter and the Deathly Hallows: Part 1',
#   '$976,920,103',
#   '$296,347,721',
#   '30.3%',
#   '$680,572,382',
#   '69.7%',
#   '2010'],
#  ['49',
#   'Despicable Me 2',
#   '$970,766,005',
#   '$368,065,385',
#   '37.9%',
#   '$602,700,620',
#   '62.1%',
#   '2013'],
#  ['50',
#   'The Lion King',
#   '$968,511,805',
#   '$422,783,777',
#   '43.6%',
#   '$545,728,028',
#   '56.4%',
#   '1994'],
#  ['51',
#   'The Jungle Book',
#   '$966,550,600',
#   '$364,001,123',
#   '37.7%',
#   '$602,549,477',
#   '62.3%',
#   '2016'],
#  ['52',
#   'Jumanji: Welcome to the Jungle',
#   '$962,102,237',
#   '$404,540,171',
#   '42%',
#   '$557,562,066',
#   '58%',
#   '2017'],
#  ['53',
#   "Pirates of the Caribbean: At World's End",
#   '$960,996,492',
#   '$309,420,425',
#   '32.2%',
#   '$651,576,067',
#   '67.8%',
#   '2007'],
#  ['54',
#   'The Hobbit: The Desolation of Smaug',
#   '$958,366,855',
#   '$258,366,855',
#   '27%',
#   '$700,000,000',
#   '73%',
#   '2013'],
#  ['55',
#   'The Hobbit: The Battle of the Five Armies',
#   '$956,019,788',
#   '$255,119,788',
#   '26.7%',
#   '$700,900,000',
#   '73.3%',
#   '2014'],
#  ['56',
#   'The Lord of the Rings: The Two Towers',
#   '$951,208,089',
#   '$342,551,365',
#   '36%',
#   '$608,656,724',
#   '64%',
#   '2002'],
#  ['57',
#   'Harry Potter and the Order of the Phoenix',
#   '$942,044,510',
#   '$292,353,413',
#   '31%',
#   '$649,691,097',
#   '69%',
#   '2007'],
#  ['58',
#   'Finding Nemo',
#   '$940,343,261',
#   '$380,843,261',
#   '40.5%',
#   '$559,500,000',
#   '59.5%',
#   '2003'],
#  ['59',
#   'Harry Potter and the Half-Blood Prince',
#   '$934,326,396',
#   '$302,305,431',
#   '32.4%',
#   '$632,020,965',
#   '67.6%',
#   '2009'],
#  ['60',
#   'Shrek 2',
#   '$928,760,770',
#   '$441,226,247',
#   '47.5%',
#   '$487,534,523',
#   '52.5%',
#   '2004'],
#  ['61',
#   'Bohemian Rhapsody',
#   '$903,655,259',
#   '$216,428,042',
#   '24%',
#   '$687,227,217',
#   '76%',
#   '2018'],
#  ['62',
#   'Harry Potter and the Goblet of Fire',
#   '$896,346,229',
#   '$290,417,905',
#   '32.4%',
#   '$605,928,324',
#   '67.6%',
#   '2005'],
#  ['63',
#   'Spider-Man 3',
#   '$894,983,373',
#   '$336,530,303',
#   '37.6%',
#   '$558,453,070',
#   '62.4%',
#   '2007'],
#  ['64',
#   'The Lord of the Rings: The Fellowship of the Ring',
#   '$887,832,826',
#   '$315,544,750',
#   '35.5%',
#   '$572,288,076',
#   '64.5%',
#   '2001'],
#  ['65',
#   'Ice Age: Dawn of the Dinosaurs',
#   '$886,686,817',
#   '$196,573,705',
#   '22.2%',
#   '$690,113,112',
#   '77.8%',
#   '2009'],
#  ['66',
#   'Spectre',
#   '$880,674,609',
#   '$200,074,609',
#   '22.7%',
#   '$680,600,000',
#   '77.3%',
#   '2015'],
#  ['67',
#   'Spider-Man: Homecoming',
#   '$880,166,924',
#   '$334,201,140',
#   '38%',
#   '$545,965,784',
#   '62%',
#   '2017'],
#  ['68',
#   'Harry Potter and the Chamber of Secrets',
#   '$879,465,594',
#   '$262,450,136',
#   '29.8%',
#   '$617,015,458',
#   '70.2%',
#   '2002'],
#  ['69',
#   'Ice Age: Continental Drift',
#   '$877,244,782',
#   '$161,321,843',
#   '18.4%',
#   '$715,922,939',
#   '81.6%',
#   '2012'],
#  ['70',
#   'The Secret Life of Pets',
#   '$875,457,937',
#   '$368,384,330',
#   '42.1%',
#   '$507,073,607',
#   '57.9%',
#   '2016'],
#  ['71',
#   'Batman v Superman: Dawn of Justice',
#   '$873,634,919',
#   '$330,360,194',
#   '37.8%',
#   '$543,274,725',
#   '62.2%',
#   '2016'],
#  ['72',
#   'Wolf Warrior 2',
#   '$870,325,439',
#   '$2,721,100',
#   '0.3%',
#   '$867,604,339',
#   '99.7%',
#   '2017'],
#  ['73',
#   'Star Wars: Episode III - Revenge of the Sith',
#   '$868,390,560',
#   '$380,270,577',
#   '43.8%',
#   '$488,119,983',
#   '56.2%',
#   '2005'],
#  ['74',
#   'The Hunger Games: Catching Fire',
#   '$865,011,746',
#   '$424,668,047',
#   '49.1%',
#   '$440,343,699',
#   '50.9%',
#   '2013'],
#  ['75',
#   'Guardians of the Galaxy Vol. 2',
#   '$863,756,051',
#   '$389,813,101',
#   '45.1%',
#   '$473,942,950',
#   '54.9%',
#   '2017'],
#  ['76',
#   'Inside Out',
#   '$857,611,174',
#   '$356,461,711',
#   '41.6%',
#   '$501,149,463',
#   '58.4%',
#   '2015'],
#  ['77',
#   'Venom',
#   '$856,085,151',
#   '$213,515,506',
#   '24.9%',
#   '$642,569,645',
#   '75.1%',
#   '2018'],
#  ['78',
#   'Thor: Ragnarok',
#   '$853,977,126',
#   '$315,058,289',
#   '36.9%',
#   '$538,918,837',
#   '63.1%',
#   '2017'],
#  ['79',
#   'Transformers: Revenge of the Fallen',
#   '$836,303,693',
#   '$402,111,870',
#   '48.1%',
#   '$434,191,823',
#   '51.9%',
#   '2009'],
#  ['80',
#   'Inception',
#   '$829,895,144',
#   '$292,576,195',
#   '35.2%',
#   '$537,318,949',
#   '64.8%',
#   '2010'],
#  ['81',
#   'The Twilight Saga: Breaking Dawn - Part 2',
#   '$829,746,820',
#   '$292,324,737',
#   '35.2%',
#   '$537,422,083',
#   '64.8%',
#   '2012'],
#  ['82',
#   'Spider-Man',
#   '$825,025,036',
#   '$407,022,860',
#   '49.3%',
#   '$418,002,176',
#   '50.7%',
#   '2002'],
#  ['83',
#   'Wonder Woman',
#   '$821,847,012',
#   '$412,563,408',
#   '50.2%',
#   '$409,283,604',
#   '49.8%',
#   '2017'],
#  ['84',
#   'Independence Day',
#   '$817,400,891',
#   '$306,169,268',
#   '37.5%',
#   '$511,231,623',
#   '62.5%',
#   '1996'],
#  ['85',
#   'Fantastic Beasts and Where to Find Them',
#   '$814,037,575',
#   '$234,037,575',
#   '28.8%',
#   '$580,000,000',
#   '71.2%',
#   '2016'],
#  ['86',
#   'Shrek the Third',
#   '$813,367,380',
#   '$322,719,944',
#   '39.7%',
#   '$490,647,436',
#   '60.3%',
#   '2007'],
#  ['87',
#   'Coco',
#   '$807,082,196',
#   '$209,726,015',
#   '26%',
#   '$597,356,181',
#   '74%',
#   '2017'],
#  ['88',
#   'Harry Potter and the Prisoner of Azkaban',
#   '$796,093,802',
#   '$249,975,996',
#   '31.4%',
#   '$546,117,806',
#   '68.6%',
#   '2004'],
#  ['89',
#   'Pirates of the Caribbean: Dead Men Tell No Tales',
#   '$794,861,794',
#   '$172,558,876',
#   '21.7%',
#   '$622,302,918',
#   '78.3%',
#   '2017'],
#  ['90',
#   'E.T. the Extra-Terrestrial',
#   '$793,482,178',
#   '$435,110,554',
#   '54.8%',
#   '$358,371,624',
#   '45.2%',
#   '1982'],
#  ['91',
#   '2012',
#   '$791,217,826',
#   '$166,112,167',
#   '21%',
#   '$625,105,659',
#   '79%',
#   '2009'],
#  ['92',
#   'Mission: Impossible - Fallout',
#   '$791,115,104',
#   '$220,159,104',
#   '27.8%',
#   '$570,956,000',
#   '72.2%',
#   '2018'],
#  ['93',
#   'Jumanji: The Next Level',
#   '$791,086,138',
#   '$313,943,814',
#   '39.7%',
#   '$477,142,324',
#   '60.3%',
#   '2019'],
#  ['94',
#   'Indiana Jones and the Kingdom of the Crystal Skull',
#   '$790,653,942',
#   '$317,101,119',
#   '40.1%',
#   '$473,552,823',
#   '59.9%',
#   '2008'],
#  ['95',
#   'Spider-Man 2',
#   '$788,976,453',
#   '$373,585,825',
#   '47.4%',
#   '$415,390,628',
#   '52.6%',
#   '2004'],
#  ['96',
#   'Fast & Furious 6',
#   '$788,679,850',
#   '$238,679,850',
#   '30.3%',
#   '$550,000,000',
#   '69.7%',
#   '2013'],
#  ['97',
#   'Deadpool 2',
#   '$785,794,179',
#   '$324,591,735',
#   '41.3%',
#   '$461,202,444',
#   '58.7%',
#   '2018'],
#  ['98',
#   'Deadpool',
#   '$782,612,155',
#   '$363,070,709',
#   '46.4%',
#   '$419,541,446',
#   '53.6%',
#   '2016'],
#  ['99',
#   'Star Wars: Episode IV - A New Hope',
#   '$775,512,064',
#   '$460,998,507',
#   '59.4%',
#   '$314,513,557',
#   '40.6%',
#   '1977'],
#  ['100',
#   'Guardians of the Galaxy',
#   '$772,776,600',
#   '$333,176,600',
#   '43.1%',
#   '$439,600,000',
#   '56.9%',
#   '2014'],
#  ['101',
#   'The Da Vinci Code',
#   '$760,006,945',
#   '$217,536,138',
#   '28.6%',
#   '$542,470,807',
#   '71.4%',
#   '2006'],
#  ['102',
#   'Fast & Furious Presents: Hobbs & Shaw',
#   '$759,056,935',
#   '$173,956,935',
#   '22.9%',
#   '$585,100,000',
#   '77.1%',
#   '2019'],
#  ['103',
#   'Maleficent',
#   '$758,410,378',
#   '$241,410,378',
#   '31.8%',
#   '$517,000,000',
#   '68.2%',
#   '2014'],
#  ['104',
#   'The Amazing Spider-Man',
#   '$757,930,663',
#   '$262,030,663',
#   '34.6%',
#   '$495,900,000',
#   '65.4%',
#   '2012'],
#  ['105',
#   'The Hunger Games: Mockingjay - Part 1',
#   '$755,356,711',
#   '$337,135,885',
#   '44.6%',
#   '$418,220,826',
#   '55.4%',
#   '2014'],
#  ['106',
#   'Shrek Forever After',
#   '$752,600,867',
#   '$238,736,787',
#   '31.7%',
#   '$513,864,080',
#   '68.3%',
#   '2010'],
#  ['107',
#   "Madagascar 3: Europe's Most Wanted",
#   '$746,921,274',
#   '$216,391,482',
#   '29%',
#   '$530,529,792',
#   '71%',
#   '2012'],
#  ['108',
#   'Suicide Squad',
#   '$746,846,894',
#   '$325,100,054',
#   '43.5%',
#   '$421,746,840',
#   '56.5%',
#   '2016'],
#  ['109',
#   'X-Men: Days of Future Past',
#   '$746,045,700',
#   '$233,921,534',
#   '31.4%',
#   '$512,124,166',
#   '68.6%',
#   '2014'],
#  ['110',
#   'The Chronicles of Narnia: The Lion, the Witch and the Wardrobe',
#   '$745,013,115',
#   '$291,710,957',
#   '39.2%',
#   '$453,302,158',
#   '60.8%',
#   '2005'],
#  ['111',
#   'Monsters University',
#   '$743,559,607',
#   '$268,492,764',
#   '36.1%',
#   '$475,066,843',
#   '63.9%',
#   '2013'],
#  ['112',
#   'The Matrix Reloaded',
#   '$741,846,459',
#   '$281,576,461',
#   '38%',
#   '$460,269,998',
#   '62%',
#   '2003'],
#  ['113',
#   'Up',
#   '$735,099,082',
#   '$293,004,164',
#   '39.9%',
#   '$442,094,918',
#   '60.1%',
#   '2009'],
#  ['114',
#   'Ne Zha',
#   '$726,063,471',
#   '$3,695,533',
#   '0.5%',
#   '$722,367,938',
#   '99.5%',
#   '2019'],
#  ['115',
#   'Gravity',
#   '$723,192,705',
#   '$274,092,705',
#   '37.9%',
#   '$449,100,000',
#   '62.1%',
#   '2013'],
#  ['116',
#   'Captain America: The Winter Soldier',
#   '$714,421,503',
#   '$259,766,572',
#   '36.4%',
#   '$454,654,931',
#   '63.6%',
#   '2014'],
#  ['117',
#   'The Twilight Saga: Breaking Dawn - Part 1',
#   '$712,205,856',
#   '$281,287,133',
#   '39.5%',
#   '$430,918,723',
#   '60.5%',
#   '2011'],
#  ['118',
#   'The Twilight Saga: New Moon',
#   '$711,020,081',
#   '$297,816,253',
#   '41.9%',
#   '$413,203,828',
#   '58.1%',
#   '2009'],
#  ['119',
#   'Dawn of the Planet of the Apes',
#   '$710,644,566',
#   '$208,545,589',
#   '29.4%',
#   '$502,098,977',
#   '70.6%',
#   '2014'],
#  ['120',
#   'Transformers',
#   '$709,709,780',
#   '$319,246,193',
#   '45%',
#   '$390,463,587',
#   '55%',
#   '2007'],
#  ['121',
#   'The Amazing Spider-Man 2',
#   '$708,982,323',
#   '$202,853,933',
#   '28.6%',
#   '$506,128,390',
#   '71.4%',
#   '2014'],
#  ['122',
#   'It',
#   '$701,796,444',
#   '$328,828,874',
#   '46.9%',
#   '$372,967,570',
#   '53.1%',
#   '2017'],
#  ['123',
#   'The Wandering Earth',
#   '$699,760,773',
#   '$5,875,487',
#   '0.8%',
#   '$693,885,286',
#   '99.2%',
#   '2019'],
#  ['124',
#   'The Twilight Saga: Eclipse',
#   '$698,491,347',
#   '$300,531,751',
#   '43%',
#   '$397,959,596',
#   '57%',
#   '2010'],
#  ['125',
#   'Mission: Impossible - Ghost Protocol',
#   '$694,713,380',
#   '$209,397,903',
#   '30.1%',
#   '$485,315,477',
#   '69.9%',
#   '2011'],
#  ['126',
#   'The Hunger Games',
#   '$694,394,724',
#   '$408,010,692',
#   '58.8%',
#   '$286,384,032',
#   '41.2%',
#   '2012'],
#  ['127',
#   'Moana',
#   '$690,845,539',
#   '$248,757,044',
#   '36%',
#   '$442,088,495',
#   '64%',
#   '2016'],
#  ['128',
#   'Mission: Impossible - Rogue Nation',
#   '$682,714,267',
#   '$195,042,377',
#   '28.6%',
#   '$487,671,890',
#   '71.4%',
#   '2015'],
#  ['129',
#   'Forrest Gump',
#   '$678,194,565',
#   '$330,455,270',
#   '48.7%',
#   '$347,739,295',
#   '51.3%',
#   '1994'],
#  ['130',
#   'Doctor Strange',
#   '$677,718,395',
#   '$232,641,920',
#   '34.3%',
#   '$445,076,475',
#   '65.7%',
#   '2016'],
#  ['131',
#   'Interstellar',
#   '$677,471,339',
#   '$188,020,017',
#   '27.8%',
#   '$489,451,322',
#   '72.2%',
#   '2014'],
#  ['132',
#   'The Sixth Sense',
#   '$672,806,292',
#   '$293,506,292',
#   '43.6%',
#   '$379,300,000',
#   '56.4%',
#   '1999'],
#  ['133',
#   'Man of Steel',
#   '$668,045,518',
#   '$291,045,518',
#   '43.6%',
#   '$377,000,000',
#   '56.4%',
#   '2013'],
#  ['134',
#   'Ice Age: The Meltdown',
#   '$667,094,506',
#   '$195,330,621',
#   '29.3%',
#   '$471,763,885',
#   '70.7%',
#   '2006'],
#  ['135',
#   'Kung Fu Panda 2',
#   '$665,692,281',
#   '$165,249,063',
#   '24.8%',
#   '$500,443,218',
#   '75.2%',
#   '2011'],
#  ['136',
#   'The Hunger Games: Mockingjay - Part 2',
#   '$658,344,137',
#   '$281,723,902',
#   '42.8%',
#   '$376,620,235',
#   '57.2%',
#   '2015'],
#  ['137',
#   'Justice League',
#   '$657,924,295',
#   '$229,024,295',
#   '34.8%',
#   '$428,900,000',
#   '65.2%',
#   '2017'],
#  ['138',
#   'Big Hero 6',
#   '$657,827,828',
#   '$222,527,828',
#   '33.8%',
#   '$435,300,000',
#   '66.2%',
#   '2014'],
#  ['139',
#   'Fantastic Beasts: The Crimes of Grindelwald',
#   '$654,855,901',
#   '$159,555,901',
#   '24.4%',
#   '$495,300,000',
#   '75.6%',
#   '2018'],
#  ['140',
#   'Pirates of the Caribbean: The Curse of the Black Pearl',
#   '$654,264,015',
#   '$305,413,918',
#   '46.7%',
#   '$348,850,097',
#   '53.3%',
#   '2003'],
#  ['141',
#   'Star Wars: Episode II - Attack of the Clones',
#   '$653,779,970',
#   '$310,676,740',
#   '47.5%',
#   '$343,103,230',
#   '52.5%',
#   '2002'],
#  ['142',
#   'Thor: The Dark World',
#   '$644,783,140',
#   '$206,362,140',
#   '32%',
#   '$438,421,000',
#   '68%',
#   '2013'],
#  ['143',
#   'Sing',
#   '$634,151,679',
#   '$270,395,425',
#   '42.6%',
#   '$363,756,254',
#   '57.4%',
#   '2016'],
#  ['144',
#   'Monsters, Inc.',
#   '$632,316,649',
#   '$289,916,256',
#   '45.8%',
#   '$342,400,393',
#   '54.2%',
#   '2001'],
#  ['145',
#   'Kung Fu Panda',
#   '$631,746,197',
#   '$215,434,591',
#   '34.1%',
#   '$416,311,606',
#   '65.9%',
#   '2008'],
#  ['146',
#   'The Incredibles',
#   '$631,606,713',
#   '$261,441,092',
#   '41.4%',
#   '$370,165,621',
#   '58.6%',
#   '2004'],
#  ['147',
#   'The Martian',
#   '$630,161,890',
#   '$228,433,663',
#   '36.2%',
#   '$401,728,227',
#   '63.8%',
#   '2015'],
#  ['148',
#   'Hancock',
#   '$629,443,428',
#   '$227,946,274',
#   '36.2%',
#   '$401,497,154',
#   '63.8%',
#   '2008'],
#  ['149',
#   'Fast Five',
#   '$626,137,675',
#   '$209,837,675',
#   '33.5%',
#   '$416,300,000',
#   '66.5%',
#   '2011'],
#  ['150',
#   'Men in Black 3',
#   '$624,026,776',
#   '$179,020,854',
#   '28.7%',
#   '$445,005,922',
#   '71.3%',
#   '2012'],
#  ['151',
#   'Iron Man 2',
#   '$623,933,331',
#   '$312,433,331',
#   '50.1%',
#   '$311,500,000',
#   '49.9%',
#   '2010'],
#  ['152',
#   'Ratatouille',
#   '$623,726,085',
#   '$206,445,654',
#   '33.1%',
#   '$417,280,431',
#   '66.9%',
#   '2007'],
#  ['153',
#   'Ant-Man and the Wasp',
#   '$622,674,139',
#   '$216,648,740',
#   '34.8%',
#   '$406,025,399',
#   '65.2%',
#   '2018'],
#  ['154',
#   'How to Train Your Dragon 2',
#   '$621,537,519',
#   '$177,002,924',
#   '28.5%',
#   '$444,534,595',
#   '71.5%',
#   '2014'],
#  ['155',
#   'Logan',
#   '$619,021,436',
#   '$226,277,068',
#   '36.6%',
#   '$392,744,368',
#   '63.4%',
#   '2017'],
#  ['156',
#   'The Lost World: Jurassic Park',
#   '$618,638,999',
#   '$229,086,679',
#   '37%',
#   '$389,552,320',
#   '63%',
#   '1997'],
#  ['157',
#   'Casino Royale',
#   '$616,501,619',
#   '$167,445,960',
#   '27.2%',
#   '$449,055,659',
#   '72.8%',
#   '2006'],
#  ['158',
#   'The Passion of the Christ',
#   '$612,054,428',
#   '$370,782,930',
#   '60.6%',
#   '$241,271,498',
#   '39.4%',
#   '2004'],
#  ['159',
#   'Mamma Mia!',
#   '$609,896,805',
#   '$144,169,664',
#   '23.6%',
#   '$465,727,141',
#   '76.4%',
#   '2008'],
#  ['160',
#   'Life of Pi',
#   '$609,016,565',
#   '$124,987,023',
#   '20.5%',
#   '$484,029,542',
#   '79.5%',
#   '2012'],
#  ['161',
#   'Transformers: The Last Knight',
#   '$605,425,157',
#   '$130,168,683',
#   '21.5%',
#   '$475,256,474',
#   '78.5%',
#   '2017'],
#  ['162',
#   'Madagascar: Escape 2 Africa',
#   '$603,900,354',
#   '$180,010,950',
#   '29.8%',
#   '$423,889,404',
#   '70.2%',
#   '2008'],
#  ['163',
#   'War of the Worlds',
#   '$603,873,119',
#   '$234,280,354',
#   '38.8%',
#   '$369,592,765',
#   '61.2%',
#   '2005'],
#  ['164',
#   'Tangled',
#   '$592,461,732',
#   '$200,821,936',
#   '33.9%',
#   '$391,639,796',
#   '66.1%',
#   '2010'],
#  ['165',
#   'Quantum of Solace',
#   '$589,580,482',
#   '$168,368,427',
#   '28.6%',
#   '$421,212,055',
#   '71.4%',
#   '2008'],
#  ['166',
#   'Men in Black',
#   '$589,390,539',
#   '$250,690,539',
#   '42.5%',
#   '$338,700,000',
#   '57.5%',
#   '1997'],
#  ['167',
#   'The Croods',
#   '$587,204,668',
#   '$187,168,425',
#   '31.9%',
#   '$400,036,243',
#   '68.1%',
#   '2013'],
#  ['168',
#   'The Hangover Part II',
#   '$586,764,305',
#   '$254,464,305',
#   '43.4%',
#   '$332,300,000',
#   '56.6%',
#   '2011'],
#  ['169',
#   'I Am Legend',
#   '$585,410,052',
#   '$256,393,010',
#   '43.8%',
#   '$329,017,042',
#   '56.2%',
#   '2007'],
#  ['170',
#   'Iron Man',
#   '$585,366,247',
#   '$318,604,126',
#   '54.4%',
#   '$266,762,121',
#   '45.6%',
#   '2008'],
#  ['171',
#   'Ready Player One',
#   '$582,890,172',
#   '$137,690,172',
#   '23.6%',
#   '$445,200,000',
#   '76.4%',
#   '2018'],
#  ['172',
#   'Operation Red Sea',
#   '$579,330,426',
#   '$1,543,547',
#   '0.3%',
#   '$577,786,879',
#   '99.7%',
#   '2018'],
#  ['173',
#   'Night at the Museum',
#   '$574,480,841',
#   '$250,863,268',
#   '43.7%',
#   '$323,617,573',
#   '56.3%',
#   '2006'],
#  ['174',
#   'Fifty Shades of Grey',
#   '$569,651,467',
#   '$166,167,230',
#   '29.2%',
#   '$403,484,237',
#   '70.8%',
#   '2015'],
#  ['175',
#   'Kong: Skull Island',
#   '$566,652,812',
#   '$168,052,812',
#   '29.7%',
#   '$398,600,000',
#   '70.3%',
#   '2017'],
#  ['176',
#   'The Smurfs',
#   '$563,749,323',
#   '$142,614,158',
#   '25.3%',
#   '$421,135,165',
#   '74.7%',
#   '2011'],
#  ['177',
#   'King Kong',
#   '$562,363,449',
#   '$218,080,025',
#   '38.8%',
#   '$344,283,424',
#   '61.2%',
#   '2005'],
#  ['178',
#   'Cars 2',
#   '$559,852,396',
#   '$191,452,396',
#   '34.2%',
#   '$368,400,000',
#   '65.8%',
#   '2011'],
#  ['179',
#   'Puss in Boots',
#   '$554,987,477',
#   '$149,260,504',
#   '26.9%',
#   '$405,726,973',
#   '73.1%',
#   '2011'],
#  ['180',
#   'The Mermaid',
#   '$553,810,228',
#   '$3,232,685',
#   '0.6%',
#   '$550,577,543',
#   '99.4%',
#   '2016'],
#  ['181',
#   'Armageddon',
#   '$553,709,788',
#   '$201,578,182',
#   '36.4%',
#   '$352,131,606',
#   '63.6%',
#   '1998'],
#  ['182',
#   'The Day After Tomorrow',
#   '$552,639,571',
#   '$186,740,799',
#   '33.8%',
#   '$365,898,772',
#   '66.2%',
#   '2004'],
#  ['183',
#   'Ted',
#   '$549,368,315',
#   '$218,815,487',
#   '39.8%',
#   '$330,552,828',
#   '60.2%',
#   '2012'],
#  ['184',
#   'Star Wars: Episode V - The Empire Strikes Back',
#   '$547,897,454',
#   '$290,271,960',
#   '53%',
#   '$257,625,494',
#   '47%',
#   '1980'],
#  ['185',
#   'American Sniper',
#   '$547,426,372',
#   '$350,126,372',
#   '64%',
#   '$197,300,000',
#   '36%',
#   '2014'],
#  ['186',
#   'Mission: Impossible II',
#   '$546,388,108',
#   '$215,409,889',
#   '39.4%',
#   '$330,978,219',
#   '60.6%',
#   '2000'],
#  ['187',
#   'Detective Chinatown 2',
#   '$544,185,156',
#   '$1,983,984',
#   '0.4%',
#   '$542,201,172',
#   '99.6%',
#   '2018'],
#  ['188',
#   'X-Men: Apocalypse',
#   '$543,934,105',
#   '$155,442,489',
#   '28.6%',
#   '$388,491,616',
#   '71.4%',
#   '2016'],
#  ['189',
#   'Sherlock Holmes: A Game of Shadows',
#   '$543,848,418',
#   '$186,848,418',
#   '34.4%',
#   '$357,000,000',
#   '65.6%',
#   '2011'],
#  ['190',
#   'Despicable Me',
#   '$543,113,985',
#   '$251,513,985',
#   '46.3%',
#   '$291,600,000',
#   '53.7%',
#   '2010'],
#  ['191',
#   'Cinderella',
#   '$542,351,353',
#   '$201,151,353',
#   '37.1%',
#   '$341,200,000',
#   '62.9%',
#   '2015'],
#  ['192',
#   'Madagascar',
#   '$542,063,846',
#   '$193,595,521',
#   '35.7%',
#   '$348,468,325',
#   '64.3%',
#   '2005'],
#  ['193',
#   'World War Z',
#   '$540,007,876',
#   '$202,359,711',
#   '37.5%',
#   '$337,648,165',
#   '62.5%',
#   '2013'],
#  ['194',
#   'Brave',
#   '$538,983,207',
#   '$237,283,207',
#   '44%',
#   '$301,700,000',
#   '56%',
#   '2012'],
#  ['195',
#   'The Simpsons Movie',
#   '$536,414,270',
#   '$183,135,014',
#   '34.1%',
#   '$353,279,256',
#   '65.9%',
#   '2007'],
#  ['196',
#   'The Revenant',
#   '$532,950,503',
#   '$183,637,894',
#   '34.5%',
#   '$349,312,609',
#   '65.5%',
#   '2015'],
#  ['197',
#   'The Meg',
#   '$530,243,742',
#   '$145,443,742',
#   '27.4%',
#   '$384,800,000',
#   '72.6%',
#   '2018'],
#  ['198',
#   'Ralph Breaks the Internet',
#   '$529,323,962',
#   '$201,091,711',
#   '38%',
#   '$328,232,251',
#   '62%',
#   '2018'],
#  ['199',
#   'Hotel Transylvania 3: Summer Vacation',
#   '$528,583,774',
#   '$167,510,016',
#   '31.7%',
#   '$361,073,758',
#   '68.3%',
#   '2018'],
#  ['200',
#   'The Boss Baby',
#   '$527,965,936',
#   '$175,003,033',
#   '33.2%',
#   '$352,962,903',
#   '66.8%',
#   '2017']]

# %%
# movie_list1 = []
# row_list = []

# for a in soup.findAll('a', href=True):
#     if a['href'].startswith('/title/'):
#         row_list.append(a['href'][7:16])
result = []
for record in soup.findAll("tr"):
   # print(record.findAll("td"))
    row = [x.text for x in record.findAll("td")]
    #print(row)
    for a in record.findAll('a', href=True):
        if a['href'].startswith('/title/'):
            row.append(a['href'][7:16])
    result.append(row)
print(result)
        
#     for data in record.findAll("td"):
#         row_list.append(data.text)
#     if row_list == []:
#         pass
#     else:
#         movie_list1.append(row_list)
#         row_list = []
# movie_list1
# Out:
# [[], ['1', 'Avengers: Endgame', '$2,797,800,564', '$858,373,000', '30.7%', '$1,939,427,564', '69.3%', '2019', 'tt4154796'], ['2', 'Avatar', '$2,790,439,000', '$760,507,625', '27.2%', '$2,029,931,375', '72.8%', '2009', 'tt0499549'], ['3', 'Titanic', '$2,194,439,542', '$659,363,944', '30%', '$1,535,075,598', '70%', '1997', 'tt0120338'], ['4', 'Star Wars: Episode VII - The Force Awakens', '$2,068,223,624', '$936,662,225', '45.3%', '$1,131,561,399', '54.7%', '2015', 'tt2488496'], ['5', 'Avengers: Infinity War', '$2,048,359,754', '$678,815,482', '33.1%', '$1,369,544,272', '66.9%', '2018', 'tt4154756'], ['6', 'Jurassic World', '$1,670,400,637', '$652,270,625', '39%', '$1,018,130,012', '61%', '2015', 'tt0369610'], ['7', 'The Lion King', '$1,656,943,394', '$543,638,043', '32.8%', '$1,113,305,351', '67.2%', '2019', 'tt6105098'], ['8', 'The Avengers', '$1,518,812,988', '$623,357,910', '41%', '$895,455,078', '59%', '2012', 'tt0848228'], ['9', 'Furious 7', '$1,515,047,671', '$353,007,020', '23.3%', '$1,162,040,651', '76.7%', '2015', 'tt2820852'], ['10', 'Frozen II', '$1,448,824,988', '$477,045,566', '32.9%', '$971,779,422', '67.1%', '2019', 'tt4520988'], ['11', 'Avengers: Age of Ultron', '$1,402,805,868', '$459,005,868', '32.7%', '$943,800,000', '67.3%', '2015', 'tt2395427'], ['12', 'Black Panther', '$1,346,913,161', '$700,059,566', '52%', '$646,853,595', '48%', '2018', 'tt1825683'], ['13', 'Harry Potter and the Deathly Hallows: Part 2', '$1,341,932,398', '$381,409,310', '28.4%', '$960,523,088', '71.6%', '2011', 'tt1201607'], ['14', 'Star Wars: Episode VIII - The Last Jedi', '$1,332,539,889', '$620,181,382', '46.5%', '$712,358,507', '53.5%', '2017', 'tt2527336'], ['15', 'Jurassic World: Fallen Kingdom', '$1,308,467,944', '$417,719,760', '31.9%', '$890,748,184', '68.1%', '2018', 'tt4881806'], ['16', 'Frozen', '$1,280,802,282', '$400,738,009', '31.3%', '$880,064,273', '68.7%', '2013', 'tt2294629'], ['17', 'Beauty and the Beast', '$1,263,521,126', '$504,014,165', '39.9%', '$759,506,961', '60.1%', '2017', 'tt2771200'], ['18', 'Incredibles 2', '$1,242,805,359', '$608,581,744', '49%', '$634,223,615', '51%', '2018', 'tt3606756'], ['19', 'The Fate of the Furious', '$1,236,005,118', '$226,008,385', '18.3%', '$1,009,996,733', '81.7%', '2017', 'tt4630562'], ['20', 'Iron Man 3', '$1,214,811,252', '$409,013,994', '33.7%', '$805,797,258', '66.3%', '2013', 'tt1300854'], ['21', 'Minions', '$1,159,398,397', '$336,045,770', '29%', '$823,352,627', '71%', '2015', 'tt2293640'], ['22', 'Captain America: Civil War', '$1,153,296,293', '$408,084,349', '35.4%', '$745,211,944', '64.6%', '2016', 'tt3498820'], ['23', 'Aquaman', '$1,148,461,807', '$335,061,807', '29.2%', '$813,400,000', '70.8%', '2018', 'tt1477834'], ['24', 'The Lord of the Rings: The Return of the King', '$1,142,219,401', '$377,845,905', '33.1%', '$764,373,496', '66.9%', '2003', 'tt0167260'], ['25', 'Spider-Man: Far from Home', '$1,131,927,996', '$390,532,085', '34.5%', '$741,395,911', '65.5%', '2019', 'tt6320628'], ['26', 'Captain Marvel', '$1,128,274,794', '$426,829,839', '37.8%', '$701,444,955', '62.2%', '2019', 'tt4154664'], ['27', 'Transformers: Dark of the Moon', '$1,123,794,079', '$352,390,543', '31.4%', '$771,403,536', '68.6%', '2011', 'tt1399103'], ['28', 'Skyfall', '$1,108,561,013', '$304,360,277', '27.5%', '$804,200,736', '72.5%', '2012', 'tt1074638'], ['29', 'Transformers: Age of Extinction', '$1,104,054,072', '$245,439,076', '22.2%', '$858,614,996', '77.8%', '2014', 'tt2109248'], ['30', 'The Dark Knight Rises', '$1,081,041,287', '$448,139,099', '41.4%', '$632,902,188', '58.6%', '2012', 'tt1345836'], ['31', 'Joker', '$1,073,943,334', '$335,443,334', '31.2%', '$738,500,000', '68.8%', '2019', 'tt7286456'], ['32', 'Toy Story 4', '$1,073,394,593', '$434,038,008', '40.4%', '$639,356,585', '59.6%', '2019', 'tt1979376'], ['33', 'Star Wars: Episode IX - The Rise of Skywalker', '$1,073,294,598', '$514,718,318', '48%', '$558,576,280', '52%', '2019', 'tt2527338'], ['34', 'Toy Story 3', '$1,066,969,7 ...

# %%
movie_list1 = []
row_list = []

for a in soup.findAll('a', href=True):
    if a['href'].startswith('/title/'):
        row_list.append(a['href'][7:16])
for record in soup.findAll("tr"):
    for data in record.findAll("td"):
        row_list.append(data.text)
    if row_list == []:
        pass
    else:
        movie_list1.append(row_list)
        row_list = []
movie_list1

# for a in soup.findAll('a', href=True):
#     for record in soup.findAll("tr"):
#         for data in record.findAll("td"):
#             row_list.append(data.text)
#         if row_list == []:
#             pass
#         else:
#             movie_list1.append(row_list)
#             row_list = []
#     if a['href'].startswith('/title/'):
#         row_list.append(a['href'][7:16])

# movie_list1

# for a in soup.findAll('a', href=True):
#     if a['href'].startswith('/title/'):
#         ids.append(a['href'][7:16])
# Out:
# [['tt4154796',
#   'tt0499549',
#   'tt0120338',
#   'tt2488496',
#   'tt4154756',
#   'tt0369610',
#   'tt6105098',
#   'tt0848228',
#   'tt2820852',
#   'tt4520988',
#   'tt2395427',
#   'tt1825683',
#   'tt1201607',
#   'tt2527336',
#   'tt4881806',
#   'tt2294629',
#   'tt2771200',
#   'tt3606756',
#   'tt4630562',
#   'tt1300854',
#   'tt2293640',
#   'tt3498820',
#   'tt1477834',
#   'tt0167260',
#   'tt6320628',
#   'tt4154664',
#   'tt1399103',
#   'tt1074638',
#   'tt2109248',
#   'tt1345836',
#   'tt7286456',
#   'tt1979376',
#   'tt2527338',
#   'tt0435761',
#   'tt0383574',
#   'tt3748528',
#   'tt6139732',
#   'tt1298650',
#   'tt3469046',
#   'tt0107290',
#   'tt2277860',
#   'tt0120915',
#   'tt1014759',
#   'tt2948356',
#   'tt0903624',
#   'tt0468569',
#   'tt0241527',
#   'tt0926084',
#   'tt1690953',
#   'tt0110357',
#   'tt3040964',
#   'tt2283362',
#   'tt0449088',
#   'tt1170358',
#   'tt2310332',
#   'tt0167261',
#   'tt0373889',
#   'tt0266543',
#   'tt0417741',
#   'tt0298148',
#   'tt1727824',
#   'tt0330373',
#   'tt0413300',
#   'tt0120737',
#   'tt1080016',
#   'tt2379713',
#   'tt2250912',
#   'tt0295297',
#   'tt1667889',
#   'tt2709768',
#   'tt2975590',
#   'tt7131870',
#   'tt0121766',
#   'tt1951264',
#   'tt3896198',
#   'tt2096673',
#   'tt1270797',
#   'tt3501632',
#   'tt1055369',
#   'tt1375666',
#   'tt1673434',
#   'tt0145487',
#   'tt0451279',
#   'tt0116629',
#   'tt3183660',
#   'tt0413267',
#   'tt2380307',
#   'tt0304141',
#   'tt1790809',
#   'tt0083866',
#   'tt1190080',
#   'tt4912910',
#   'tt7975244',
#   'tt0367882',
#   'tt0316654',
#   'tt1905041',
#   'tt5463162',
#   'tt1431045',
#   'tt0076759',
#   'tt2015381',
#   'tt0382625',
#   'tt6806448',
#   'tt1587310',
#   'tt0948470',
#   'tt1951265',
#   'tt0892791',
#   'tt1277953',
#   'tt1386697',
#   'tt1877832',
#   'tt0363771',
#   'tt1453405',
#   'tt0234215',
#   'tt1049413',
#   'tt1062772',
#   'tt1454468',
#   'tt1843866',
#   'tt1324999',
#   'tt1259571',
#   'tt2103281',
#   'tt0418279',
#   'tt1872181',
#   'tt1396484',
#   'tt7605074',
#   'tt1325004',
#   'tt1229238',
#   'tt1392170',
#   'tt3521164',
#   'tt2381249',
#   'tt0109830',
#   'tt1211837',
#   'tt0816692',
#   'tt0167404',
#   'tt0770828',
#   'tt0438097',
#   'tt1302011',
#   'tt1951266',
#   'tt0974015',
#   'tt2245084',
#   'tt4123430',
#   'tt0325980',
#   'tt0121765',
#   'tt1981115',
#   'tt3470600',
#   'tt0198781',
#   'tt0441773',
#   'tt0317705',
#   'tt3659388',
#   'tt0448157',
#   'tt1596343',
#   'tt1409024',
#   'tt1228705',
#   'tt0382932',
#   'tt5095030',
#   'tt1646971',
#   'tt3315342',
#   'tt0119567',
#   'tt0381061',
#   'tt0335345',
#   'tt0795421',
#   'tt0454876',
#   'tt3371366',
#   'tt0479952',
#   'tt0407304',
#   'tt0398286',
#   'tt0830515',
#   'tt0119654',
#   'tt0481499',
#   'tt1411697',
#   'tt0480249',
#   'tt0371746',
#   'tt1677720',
#   'tt6878882',
#   'tt0477347',
#   'tt2322441',
#   'tt3731562',
#   'tt0472181',
#   'tt0360717',
#   'tt1216475',
#   'tt0448694',
#   'tt4701660',
#   'tt0120591',
#   'tt0319262',
#   'tt1637725',
#   'tt0080684',
#   'tt2179136',
#   'tt0120755',
#   'tt7752454',
#   'tt3385516',
#   'tt1515091',
#   'tt1323594',
#   'tt1661199',
#   'tt0351283',
#   'tt0816711',
#   'tt1217209',
#   'tt0462538',
#   'tt1663202',
#   'tt4779682',
#   'tt5848272',
#   'tt5220122',
#   'tt3874544'],
#  ['1',
#   'Avengers: Endgame',
#   '$2,797,800,564',
#   '$858,373,000',
#   '30.7%',
#   '$1,939,427,564',
#   '69.3%',
#   '2019'],
#  ['2',
#   'Avatar',
#   '$2,790,439,000',
#   '$760,507,625',
#   '27.2%',
#   '$2,029,931,375',
#   '72.8%',
#   '2009'],
#  ['3',
#   'Titanic',
#   '$2,194,439,542',
#   '$659,363,944',
#   '30%',
#   '$1,535,075,598',
#   '70%',
#   '1997'],
#  ['4',
#   'Star Wars: Episode VII - The Force Awakens',
#   '$2,068,223,624',
#   '$936,662,225',
#   '45.3%',
#   '$1,131,561,399',
#   '54.7%',
#   '2015'],
#  ['5',
#   'Avengers: Infinity War',
#   '$2,048,359,754',
#   '$678,815,482',
#   '33.1%',
#   '$1,369,544,272',
#   '66.9%',
#   '2018'],
#  ['6',
#   'Jurassic World',
#   '$1,670,400,637',
#   '$652,270,625',
#   '39%',
#   '$1,018,130,012',
#   '61%',
#   '2015'],
#  ['7',
#   'The Lion King',
#   '$1,656,943,394',
#   '$543,638,043',
#   '32.8%',
#   '$1,113,305,351',
#   '67.2%',
#   '2019'],
#  ['8',
#   'The Avengers',
#   '$1,518,812,988',
#   '$623,357,910',
#   '41%',
#   '$895,455,078',
#   '59%',
#   '2012'],
#  ['9',
#   'Furious 7',
#   '$1,515,047,671',
#   '$353,007,020',
#   '23.3%',
#   '$1,162,040,651',
#   '76.7%',
#   '2015'],
#  ['10',
#   'Frozen II',
#   '$1,448,824,988',
#   '$477,045,566',
#   '32.9%',
#   '$971,779,422',
#   '67.1%',
#   '2019'],
#  ['11',
#   'Avengers: Age of Ultron',
#   '$1,402,805,868',
#   '$459,005,868',
#   '32.7%',
#   '$943,800,000',
#   '67.3%',
#   '2015'],
#  ['12',
#   'Black Panther',
#   '$1,346,913,161',
#   '$700,059,566',
#   '52%',
#   '$646,853,595',
#   '48%',
#   '2018'],
#  ['13',
#   'Harry Potter and the Deathly Hallows: Part 2',
#   '$1,341,932,398',
#   '$381,409,310',
#   '28.4%',
#   '$960,523,088',
#   '71.6%',
#   '2011'],
#  ['14',
#   'Star Wars: Episode VIII - The Last Jedi',
#   '$1,332,539,889',
#   '$620,181,382',
#   '46.5%',
#   '$712,358,507',
#   '53.5%',
#   '2017'],
#  ['15',
#   'Jurassic World: Fallen Kingdom',
#   '$1,308,467,944',
#   '$417,719,760',
#   '31.9%',
#   '$890,748,184',
#   '68.1%',
#   '2018'],
#  ['16',
#   'Frozen',
#   '$1,280,802,282',
#   '$400,738,009',
#   '31.3%',
#   '$880,064,273',
#   '68.7%',
#   '2013'],
#  ['17',
#   'Beauty and the Beast',
#   '$1,263,521,126',
#   '$504,014,165',
#   '39.9%',
#   '$759,506,961',
#   '60.1%',
#   '2017'],
#  ['18',
#   'Incredibles 2',
#   '$1,242,805,359',
#   '$608,581,744',
#   '49%',
#   '$634,223,615',
#   '51%',
#   '2018'],
#  ['19',
#   'The Fate of the Furious',
#   '$1,236,005,118',
#   '$226,008,385',
#   '18.3%',
#   '$1,009,996,733',
#   '81.7%',
#   '2017'],
#  ['20',
#   'Iron Man 3',
#   '$1,214,811,252',
#   '$409,013,994',
#   '33.7%',
#   '$805,797,258',
#   '66.3%',
#   '2013'],
#  ['21',
#   'Minions',
#   '$1,159,398,397',
#   '$336,045,770',
#   '29%',
#   '$823,352,627',
#   '71%',
#   '2015'],
#  ['22',
#   'Captain America: Civil War',
#   '$1,153,296,293',
#   '$408,084,349',
#   '35.4%',
#   '$745,211,944',
#   '64.6%',
#   '2016'],
#  ['23',
#   'Aquaman',
#   '$1,148,461,807',
#   '$335,061,807',
#   '29.2%',
#   '$813,400,000',
#   '70.8%',
#   '2018'],
#  ['24',
#   'The Lord of the Rings: The Return of the King',
#   '$1,142,219,401',
#   '$377,845,905',
#   '33.1%',
#   '$764,373,496',
#   '66.9%',
#   '2003'],
#  ['25',
#   'Spider-Man: Far from Home',
#   '$1,131,927,996',
#   '$390,532,085',
#   '34.5%',
#   '$741,395,911',
#   '65.5%',
#   '2019'],
#  ['26',
#   'Captain Marvel',
#   '$1,128,274,794',
#   '$426,829,839',
#   '37.8%',
#   '$701,444,955',
#   '62.2%',
#   '2019'],
#  ['27',
#   'Transformers: Dark of the Moon',
#   '$1,123,794,079',
#   '$352,390,543',
#   '31.4%',
#   '$771,403,536',
#   '68.6%',
#   '2011'],
#  ['28',
#   'Skyfall',
#   '$1,108,561,013',
#   '$304,360,277',
#   '27.5%',
#   '$804,200,736',
#   '72.5%',
#   '2012'],
#  ['29',
#   'Transformers: Age of Extinction',
#   '$1,104,054,072',
#   '$245,439,076',
#   '22.2%',
#   '$858,614,996',
#   '77.8%',
#   '2014'],
#  ['30',
#   'The Dark Knight Rises',
#   '$1,081,041,287',
#   '$448,139,099',
#   '41.4%',
#   '$632,902,188',
#   '58.6%',
#   '2012'],
#  ['31',
#   'Joker',
#   '$1,073,943,334',
#   '$335,443,334',
#   '31.2%',
#   '$738,500,000',
#   '68.8%',
#   '2019'],
#  ['32',
#   'Toy Story 4',
#   '$1,073,394,593',
#   '$434,038,008',
#   '40.4%',
#   '$639,356,585',
#   '59.6%',
#   '2019'],
#  ['33',
#   'Star Wars: Episode IX - The Rise of Skywalker',
#   '$1,073,294,598',
#   '$514,718,318',
#   '48%',
#   '$558,576,280',
#   '52%',
#   '2019'],
#  ['34',
#   'Toy Story 3',
#   '$1,066,969,703',
#   '$415,004,880',
#   '38.9%',
#   '$651,964,823',
#   '61.1%',
#   '2010'],
#  ['35',
#   "Pirates of the Caribbean: Dead Man's Chest",
#   '$1,066,179,725',
#   '$423,315,812',
#   '39.7%',
#   '$642,863,913',
#   '60.3%',
#   '2006'],
#  ['36',
#   'Rogue One: A Star Wars Story',
#   '$1,056,057,273',
#   '$532,177,324',
#   '50.4%',
#   '$523,879,949',
#   '49.6%',
#   '2016'],
#  ['37',
#   'Aladdin',
#   '$1,050,693,953',
#   '$355,559,216',
#   '33.8%',
#   '$695,134,737',
#   '66.2%',
#   '2019'],
#  ['38',
#   'Pirates of the Caribbean: On Stranger Tides',
#   '$1,045,713,802',
#   '$241,071,802',
#   '23%',
#   '$804,642,000',
#   '77%',
#   '2011'],
#  ['39',
#   'Despicable Me 3',
#   '$1,034,799,409',
#   '$264,624,300',
#   '25.6%',
#   '$770,175,109',
#   '74.4%',
#   '2017'],
#  ['40',
#   'Jurassic Park',
#   '$1,032,020,521',
#   '$402,828,120',
#   '39%',
#   '$629,192,401',
#   '61%',
#   '1993'],
#  ['41',
#   'Finding Dory',
#   '$1,028,570,889',
#   '$486,295,561',
#   '47.3%',
#   '$542,275,328',
#   '52.7%',
#   '2016'],
#  ['42',
#   'Star Wars: Episode I - The Phantom Menace',
#   '$1,027,082,707',
#   '$474,544,677',
#   '46.2%',
#   '$552,538,030',
#   '53.8%',
#   '1999'],
#  ['43',
#   'Alice in Wonderland',
#   '$1,025,467,110',
#   '$334,191,110',
#   '32.6%',
#   '$691,276,000',
#   '67.4%',
#   '2010'],
#  ['44',
#   'Zootopia',
#   '$1,023,784,195',
#   '$341,268,248',
#   '33.3%',
#   '$682,515,947',
#   '66.7%',
#   '2016'],
#  ['45',
#   'The Hobbit: An Unexpected Journey',
#   '$1,017,003,568',
#   '$303,003,568',
#   '29.8%',
#   '$714,000,000',
#   '70.2%',
#   '2012'],
#  ['46',
#   'The Dark Knight',
#   '$1,004,934,033',
#   '$535,234,033',
#   '53.3%',
#   '$469,700,000',
#   '46.7%',
#   '2008'],
#  ['47',
#   "Harry Potter and the Sorcerer's Stone",
#   '$978,087,613',
#   '$318,087,620',
#   '32.5%',
#   '$659,999,993',
#   '67.5%',
#   '2001'],
#  ['48',
#   'Harry Potter and the Deathly Hallows: Part 1',
#   '$976,920,103',
#   '$296,347,721',
#   '30.3%',
#   '$680,572,382',
#   '69.7%',
#   '2010'],
#  ['49',
#   'Despicable Me 2',
#   '$970,766,005',
#   '$368,065,385',
#   '37.9%',
#   '$602,700,620',
#   '62.1%',
#   '2013'],
#  ['50',
#   'The Lion King',
#   '$968,511,805',
#   '$422,783,777',
#   '43.6%',
#   '$545,728,028',
#   '56.4%',
#   '1994'],
#  ['51',
#   'The Jungle Book',
#   '$966,550,600',
#   '$364,001,123',
#   '37.7%',
#   '$602,549,477',
#   '62.3%',
#   '2016'],
#  ['52',
#   'Jumanji: Welcome to the Jungle',
#   '$962,102,237',
#   '$404,540,171',
#   '42%',
#   '$557,562,066',
#   '58%',
#   '2017'],
#  ['53',
#   "Pirates of the Caribbean: At World's End",
#   '$960,996,492',
#   '$309,420,425',
#   '32.2%',
#   '$651,576,067',
#   '67.8%',
#   '2007'],
#  ['54',
#   'The Hobbit: The Desolation of Smaug',
#   '$958,366,855',
#   '$258,366,855',
#   '27%',
#   '$700,000,000',
#   '73%',
#   '2013'],
#  ['55',
#   'The Hobbit: The Battle of the Five Armies',
#   '$956,019,788',
#   '$255,119,788',
#   '26.7%',
#   '$700,900,000',
#   '73.3%',
#   '2014'],
#  ['56',
#   'The Lord of the Rings: The Two Towers',
#   '$951,208,089',
#   '$342,551,365',
#   '36%',
#   '$608,656,724',
#   '64%',
#   '2002'],
#  ['57',
#   'Harry Potter and the Order of the Phoenix',
#   '$942,044,510',
#   '$292,353,413',
#   '31%',
#   '$649,691,097',
#   '69%',
#   '2007'],
#  ['58',
#   'Finding Nemo',
#   '$940,343,261',
#   '$380,843,261',
#   '40.5%',
#   '$559,500,000',
#   '59.5%',
#   '2003'],
#  ['59',
#   'Harry Potter and the Half-Blood Prince',
#   '$934,326,396',
#   '$302,305,431',
#   '32.4%',
#   '$632,020,965',
#   '67.6%',
#   '2009'],
#  ['60',
#   'Shrek 2',
#   '$928,760,770',
#   '$441,226,247',
#   '47.5%',
#   '$487,534,523',
#   '52.5%',
#   '2004'],
#  ['61',
#   'Bohemian Rhapsody',
#   '$903,655,259',
#   '$216,428,042',
#   '24%',
#   '$687,227,217',
#   '76%',
#   '2018'],
#  ['62',
#   'Harry Potter and the Goblet of Fire',
#   '$896,346,229',
#   '$290,417,905',
#   '32.4%',
#   '$605,928,324',
#   '67.6%',
#   '2005'],
#  ['63',
#   'Spider-Man 3',
#   '$894,983,373',
#   '$336,530,303',
#   '37.6%',
#   '$558,453,070',
#   '62.4%',
#   '2007'],
#  ['64',
#   'The Lord of the Rings: The Fellowship of the Ring',
#   '$887,832,826',
#   '$315,544,750',
#   '35.5%',
#   '$572,288,076',
#   '64.5%',
#   '2001'],
#  ['65',
#   'Ice Age: Dawn of the Dinosaurs',
#   '$886,686,817',
#   '$196,573,705',
#   '22.2%',
#   '$690,113,112',
#   '77.8%',
#   '2009'],
#  ['66',
#   'Spectre',
#   '$880,674,609',
#   '$200,074,609',
#   '22.7%',
#   '$680,600,000',
#   '77.3%',
#   '2015'],
#  ['67',
#   'Spider-Man: Homecoming',
#   '$880,166,924',
#   '$334,201,140',
#   '38%',
#   '$545,965,784',
#   '62%',
#   '2017'],
#  ['68',
#   'Harry Potter and the Chamber of Secrets',
#   '$879,465,594',
#   '$262,450,136',
#   '29.8%',
#   '$617,015,458',
#   '70.2%',
#   '2002'],
#  ['69',
#   'Ice Age: Continental Drift',
#   '$877,244,782',
#   '$161,321,843',
#   '18.4%',
#   '$715,922,939',
#   '81.6%',
#   '2012'],
#  ['70',
#   'The Secret Life of Pets',
#   '$875,457,937',
#   '$368,384,330',
#   '42.1%',
#   '$507,073,607',
#   '57.9%',
#   '2016'],
#  ['71',
#   'Batman v Superman: Dawn of Justice',
#   '$873,634,919',
#   '$330,360,194',
#   '37.8%',
#   '$543,274,725',
#   '62.2%',
#   '2016'],
#  ['72',
#   'Wolf Warrior 2',
#   '$870,325,439',
#   '$2,721,100',
#   '0.3%',
#   '$867,604,339',
#   '99.7%',
#   '2017'],
#  ['73',
#   'Star Wars: Episode III - Revenge of the Sith',
#   '$868,390,560',
#   '$380,270,577',
#   '43.8%',
#   '$488,119,983',
#   '56.2%',
#   '2005'],
#  ['74',
#   'The Hunger Games: Catching Fire',
#   '$865,011,746',
#   '$424,668,047',
#   '49.1%',
#   '$440,343,699',
#   '50.9%',
#   '2013'],
#  ['75',
#   'Guardians of the Galaxy Vol. 2',
#   '$863,756,051',
#   '$389,813,101',
#   '45.1%',
#   '$473,942,950',
#   '54.9%',
#   '2017'],
#  ['76',
#   'Inside Out',
#   '$857,611,174',
#   '$356,461,711',
#   '41.6%',
#   '$501,149,463',
#   '58.4%',
#   '2015'],
#  ['77',
#   'Venom',
#   '$856,085,151',
#   '$213,515,506',
#   '24.9%',
#   '$642,569,645',
#   '75.1%',
#   '2018'],
#  ['78',
#   'Thor: Ragnarok',
#   '$853,977,126',
#   '$315,058,289',
#   '36.9%',
#   '$538,918,837',
#   '63.1%',
#   '2017'],
#  ['79',
#   'Transformers: Revenge of the Fallen',
#   '$836,303,693',
#   '$402,111,870',
#   '48.1%',
#   '$434,191,823',
#   '51.9%',
#   '2009'],
#  ['80',
#   'Inception',
#   '$829,895,144',
#   '$292,576,195',
#   '35.2%',
#   '$537,318,949',
#   '64.8%',
#   '2010'],
#  ['81',
#   'The Twilight Saga: Breaking Dawn - Part 2',
#   '$829,746,820',
#   '$292,324,737',
#   '35.2%',
#   '$537,422,083',
#   '64.8%',
#   '2012'],
#  ['82',
#   'Spider-Man',
#   '$825,025,036',
#   '$407,022,860',
#   '49.3%',
#   '$418,002,176',
#   '50.7%',
#   '2002'],
#  ['83',
#   'Wonder Woman',
#   '$821,847,012',
#   '$412,563,408',
#   '50.2%',
#   '$409,283,604',
#   '49.8%',
#   '2017'],
#  ['84',
#   'Independence Day',
#   '$817,400,891',
#   '$306,169,268',
#   '37.5%',
#   '$511,231,623',
#   '62.5%',
#   '1996'],
#  ['85',
#   'Fantastic Beasts and Where to Find Them',
#   '$814,037,575',
#   '$234,037,575',
#   '28.8%',
#   '$580,000,000',
#   '71.2%',
#   '2016'],
#  ['86',
#   'Shrek the Third',
#   '$813,367,380',
#   '$322,719,944',
#   '39.7%',
#   '$490,647,436',
#   '60.3%',
#   '2007'],
#  ['87',
#   'Coco',
#   '$807,082,196',
#   '$209,726,015',
#   '26%',
#   '$597,356,181',
#   '74%',
#   '2017'],
#  ['88',
#   'Harry Potter and the Prisoner of Azkaban',
#   '$796,093,802',
#   '$249,975,996',
#   '31.4%',
#   '$546,117,806',
#   '68.6%',
#   '2004'],
#  ['89',
#   'Pirates of the Caribbean: Dead Men Tell No Tales',
#   '$794,861,794',
#   '$172,558,876',
#   '21.7%',
#   '$622,302,918',
#   '78.3%',
#   '2017'],
#  ['90',
#   'E.T. the Extra-Terrestrial',
#   '$793,482,178',
#   '$435,110,554',
#   '54.8%',
#   '$358,371,624',
#   '45.2%',
#   '1982'],
#  ['91',
#   '2012',
#   '$791,217,826',
#   '$166,112,167',
#   '21%',
#   '$625,105,659',
#   '79%',
#   '2009'],
#  ['92',
#   'Mission: Impossible - Fallout',
#   '$791,115,104',
#   '$220,159,104',
#   '27.8%',
#   '$570,956,000',
#   '72.2%',
#   '2018'],
#  ['93',
#   'Jumanji: The Next Level',
#   '$791,086,138',
#   '$313,943,814',
#   '39.7%',
#   '$477,142,324',
#   '60.3%',
#   '2019'],
#  ['94',
#   'Indiana Jones and the Kingdom of the Crystal Skull',
#   '$790,653,942',
#   '$317,101,119',
#   '40.1%',
#   '$473,552,823',
#   '59.9%',
#   '2008'],
#  ['95',
#   'Spider-Man 2',
#   '$788,976,453',
#   '$373,585,825',
#   '47.4%',
#   '$415,390,628',
#   '52.6%',
#   '2004'],
#  ['96',
#   'Fast & Furious 6',
#   '$788,679,850',
#   '$238,679,850',
#   '30.3%',
#   '$550,000,000',
#   '69.7%',
#   '2013'],
#  ['97',
#   'Deadpool 2',
#   '$785,794,179',
#   '$324,591,735',
#   '41.3%',
#   '$461,202,444',
#   '58.7%',
#   '2018'],
#  ['98',
#   'Deadpool',
#   '$782,612,155',
#   '$363,070,709',
#   '46.4%',
#   '$419,541,446',
#   '53.6%',
#   '2016'],
#  ['99',
#   'Star Wars: Episode IV - A New Hope',
#   '$775,512,064',
#   '$460,998,507',
#   '59.4%',
#   '$314,513,557',
#   '40.6%',
#   '1977'],
#  ['100',
#   'Guardians of the Galaxy',
#   '$772,776,600',
#   '$333,176,600',
#   '43.1%',
#   '$439,600,000',
#   '56.9%',
#   '2014'],
#  ['101',
#   'The Da Vinci Code',
#   '$760,006,945',
#   '$217,536,138',
#   '28.6%',
#   '$542,470,807',
#   '71.4%',
#   '2006'],
#  ['102',
#   'Fast & Furious Presents: Hobbs & Shaw',
#   '$759,056,935',
#   '$173,956,935',
#   '22.9%',
#   '$585,100,000',
#   '77.1%',
#   '2019'],
#  ['103',
#   'Maleficent',
#   '$758,410,378',
#   '$241,410,378',
#   '31.8%',
#   '$517,000,000',
#   '68.2%',
#   '2014'],
#  ['104',
#   'The Amazing Spider-Man',
#   '$757,930,663',
#   '$262,030,663',
#   '34.6%',
#   '$495,900,000',
#   '65.4%',
#   '2012'],
#  ['105',
#   'The Hunger Games: Mockingjay - Part 1',
#   '$755,356,711',
#   '$337,135,885',
#   '44.6%',
#   '$418,220,826',
#   '55.4%',
#   '2014'],
#  ['106',
#   'Shrek Forever After',
#   '$752,600,867',
#   '$238,736,787',
#   '31.7%',
#   '$513,864,080',
#   '68.3%',
#   '2010'],
#  ['107',
#   "Madagascar 3: Europe's Most Wanted",
#   '$746,921,274',
#   '$216,391,482',
#   '29%',
#   '$530,529,792',
#   '71%',
#   '2012'],
#  ['108',
#   'Suicide Squad',
#   '$746,846,894',
#   '$325,100,054',
#   '43.5%',
#   '$421,746,840',
#   '56.5%',
#   '2016'],
#  ['109',
#   'X-Men: Days of Future Past',
#   '$746,045,700',
#   '$233,921,534',
#   '31.4%',
#   '$512,124,166',
#   '68.6%',
#   '2014'],
#  ['110',
#   'The Chronicles of Narnia: The Lion, the Witch and the Wardrobe',
#   '$745,013,115',
#   '$291,710,957',
#   '39.2%',
#   '$453,302,158',
#   '60.8%',
#   '2005'],
#  ['111',
#   'Monsters University',
#   '$743,559,607',
#   '$268,492,764',
#   '36.1%',
#   '$475,066,843',
#   '63.9%',
#   '2013'],
#  ['112',
#   'The Matrix Reloaded',
#   '$741,846,459',
#   '$281,576,461',
#   '38%',
#   '$460,269,998',
#   '62%',
#   '2003'],
#  ['113',
#   'Up',
#   '$735,099,082',
#   '$293,004,164',
#   '39.9%',
#   '$442,094,918',
#   '60.1%',
#   '2009'],
#  ['114',
#   'Ne Zha',
#   '$726,063,471',
#   '$3,695,533',
#   '0.5%',
#   '$722,367,938',
#   '99.5%',
#   '2019'],
#  ['115',
#   'Gravity',
#   '$723,192,705',
#   '$274,092,705',
#   '37.9%',
#   '$449,100,000',
#   '62.1%',
#   '2013'],
#  ['116',
#   'Captain America: The Winter Soldier',
#   '$714,421,503',
#   '$259,766,572',
#   '36.4%',
#   '$454,654,931',
#   '63.6%',
#   '2014'],
#  ['117',
#   'The Twilight Saga: Breaking Dawn - Part 1',
#   '$712,205,856',
#   '$281,287,133',
#   '39.5%',
#   '$430,918,723',
#   '60.5%',
#   '2011'],
#  ['118',
#   'The Twilight Saga: New Moon',
#   '$711,020,081',
#   '$297,816,253',
#   '41.9%',
#   '$413,203,828',
#   '58.1%',
#   '2009'],
#  ['119',
#   'Dawn of the Planet of the Apes',
#   '$710,644,566',
#   '$208,545,589',
#   '29.4%',
#   '$502,098,977',
#   '70.6%',
#   '2014'],
#  ['120',
#   'Transformers',
#   '$709,709,780',
#   '$319,246,193',
#   '45%',
#   '$390,463,587',
#   '55%',
#   '2007'],
#  ['121',
#   'The Amazing Spider-Man 2',
#   '$708,982,323',
#   '$202,853,933',
#   '28.6%',
#   '$506,128,390',
#   '71.4%',
#   '2014'],
#  ['122',
#   'It',
#   '$701,796,444',
#   '$328,828,874',
#   '46.9%',
#   '$372,967,570',
#   '53.1%',
#   '2017'],
#  ['123',
#   'The Wandering Earth',
#   '$699,760,773',
#   '$5,875,487',
#   '0.8%',
#   '$693,885,286',
#   '99.2%',
#   '2019'],
#  ['124',
#   'The Twilight Saga: Eclipse',
#   '$698,491,347',
#   '$300,531,751',
#   '43%',
#   '$397,959,596',
#   '57%',
#   '2010'],
#  ['125',
#   'Mission: Impossible - Ghost Protocol',
#   '$694,713,380',
#   '$209,397,903',
#   '30.1%',
#   '$485,315,477',
#   '69.9%',
#   '2011'],
#  ['126',
#   'The Hunger Games',
#   '$694,394,724',
#   '$408,010,692',
#   '58.8%',
#   '$286,384,032',
#   '41.2%',
#   '2012'],
#  ['127',
#   'Moana',
#   '$690,845,539',
#   '$248,757,044',
#   '36%',
#   '$442,088,495',
#   '64%',
#   '2016'],
#  ['128',
#   'Mission: Impossible - Rogue Nation',
#   '$682,714,267',
#   '$195,042,377',
#   '28.6%',
#   '$487,671,890',
#   '71.4%',
#   '2015'],
#  ['129',
#   'Forrest Gump',
#   '$678,194,565',
#   '$330,455,270',
#   '48.7%',
#   '$347,739,295',
#   '51.3%',
#   '1994'],
#  ['130',
#   'Doctor Strange',
#   '$677,718,395',
#   '$232,641,920',
#   '34.3%',
#   '$445,076,475',
#   '65.7%',
#   '2016'],
#  ['131',
#   'Interstellar',
#   '$677,471,339',
#   '$188,020,017',
#   '27.8%',
#   '$489,451,322',
#   '72.2%',
#   '2014'],
#  ['132',
#   'The Sixth Sense',
#   '$672,806,292',
#   '$293,506,292',
#   '43.6%',
#   '$379,300,000',
#   '56.4%',
#   '1999'],
#  ['133',
#   'Man of Steel',
#   '$668,045,518',
#   '$291,045,518',
#   '43.6%',
#   '$377,000,000',
#   '56.4%',
#   '2013'],
#  ['134',
#   'Ice Age: The Meltdown',
#   '$667,094,506',
#   '$195,330,621',
#   '29.3%',
#   '$471,763,885',
#   '70.7%',
#   '2006'],
#  ['135',
#   'Kung Fu Panda 2',
#   '$665,692,281',
#   '$165,249,063',
#   '24.8%',
#   '$500,443,218',
#   '75.2%',
#   '2011'],
#  ['136',
#   'The Hunger Games: Mockingjay - Part 2',
#   '$658,344,137',
#   '$281,723,902',
#   '42.8%',
#   '$376,620,235',
#   '57.2%',
#   '2015'],
#  ['137',
#   'Justice League',
#   '$657,924,295',
#   '$229,024,295',
#   '34.8%',
#   '$428,900,000',
#   '65.2%',
#   '2017'],
#  ['138',
#   'Big Hero 6',
#   '$657,827,828',
#   '$222,527,828',
#   '33.8%',
#   '$435,300,000',
#   '66.2%',
#   '2014'],
#  ['139',
#   'Fantastic Beasts: The Crimes of Grindelwald',
#   '$654,855,901',
#   '$159,555,901',
#   '24.4%',
#   '$495,300,000',
#   '75.6%',
#   '2018'],
#  ['140',
#   'Pirates of the Caribbean: The Curse of the Black Pearl',
#   '$654,264,015',
#   '$305,413,918',
#   '46.7%',
#   '$348,850,097',
#   '53.3%',
#   '2003'],
#  ['141',
#   'Star Wars: Episode II - Attack of the Clones',
#   '$653,779,970',
#   '$310,676,740',
#   '47.5%',
#   '$343,103,230',
#   '52.5%',
#   '2002'],
#  ['142',
#   'Thor: The Dark World',
#   '$644,783,140',
#   '$206,362,140',
#   '32%',
#   '$438,421,000',
#   '68%',
#   '2013'],
#  ['143',
#   'Sing',
#   '$634,151,679',
#   '$270,395,425',
#   '42.6%',
#   '$363,756,254',
#   '57.4%',
#   '2016'],
#  ['144',
#   'Monsters, Inc.',
#   '$632,316,649',
#   '$289,916,256',
#   '45.8%',
#   '$342,400,393',
#   '54.2%',
#   '2001'],
#  ['145',
#   'Kung Fu Panda',
#   '$631,746,197',
#   '$215,434,591',
#   '34.1%',
#   '$416,311,606',
#   '65.9%',
#   '2008'],
#  ['146',
#   'The Incredibles',
#   '$631,606,713',
#   '$261,441,092',
#   '41.4%',
#   '$370,165,621',
#   '58.6%',
#   '2004'],
#  ['147',
#   'The Martian',
#   '$630,161,890',
#   '$228,433,663',
#   '36.2%',
#   '$401,728,227',
#   '63.8%',
#   '2015'],
#  ['148',
#   'Hancock',
#   '$629,443,428',
#   '$227,946,274',
#   '36.2%',
#   '$401,497,154',
#   '63.8%',
#   '2008'],
#  ['149',
#   'Fast Five',
#   '$626,137,675',
#   '$209,837,675',
#   '33.5%',
#   '$416,300,000',
#   '66.5%',
#   '2011'],
#  ['150',
#   'Men in Black 3',
#   '$624,026,776',
#   '$179,020,854',
#   '28.7%',
#   '$445,005,922',
#   '71.3%',
#   '2012'],
#  ['151',
#   'Iron Man 2',
#   '$623,933,331',
#   '$312,433,331',
#   '50.1%',
#   '$311,500,000',
#   '49.9%',
#   '2010'],
#  ['152',
#   'Ratatouille',
#   '$623,726,085',
#   '$206,445,654',
#   '33.1%',
#   '$417,280,431',
#   '66.9%',
#   '2007'],
#  ['153',
#   'Ant-Man and the Wasp',
#   '$622,674,139',
#   '$216,648,740',
#   '34.8%',
#   '$406,025,399',
#   '65.2%',
#   '2018'],
#  ['154',
#   'How to Train Your Dragon 2',
#   '$621,537,519',
#   '$177,002,924',
#   '28.5%',
#   '$444,534,595',
#   '71.5%',
#   '2014'],
#  ['155',
#   'Logan',
#   '$619,021,436',
#   '$226,277,068',
#   '36.6%',
#   '$392,744,368',
#   '63.4%',
#   '2017'],
#  ['156',
#   'The Lost World: Jurassic Park',
#   '$618,638,999',
#   '$229,086,679',
#   '37%',
#   '$389,552,320',
#   '63%',
#   '1997'],
#  ['157',
#   'Casino Royale',
#   '$616,501,619',
#   '$167,445,960',
#   '27.2%',
#   '$449,055,659',
#   '72.8%',
#   '2006'],
#  ['158',
#   'The Passion of the Christ',
#   '$612,054,428',
#   '$370,782,930',
#   '60.6%',
#   '$241,271,498',
#   '39.4%',
#   '2004'],
#  ['159',
#   'Mamma Mia!',
#   '$609,896,805',
#   '$144,169,664',
#   '23.6%',
#   '$465,727,141',
#   '76.4%',
#   '2008'],
#  ['160',
#   'Life of Pi',
#   '$609,016,565',
#   '$124,987,023',
#   '20.5%',
#   '$484,029,542',
#   '79.5%',
#   '2012'],
#  ['161',
#   'Transformers: The Last Knight',
#   '$605,425,157',
#   '$130,168,683',
#   '21.5%',
#   '$475,256,474',
#   '78.5%',
#   '2017'],
#  ['162',
#   'Madagascar: Escape 2 Africa',
#   '$603,900,354',
#   '$180,010,950',
#   '29.8%',
#   '$423,889,404',
#   '70.2%',
#   '2008'],
#  ['163',
#   'War of the Worlds',
#   '$603,873,119',
#   '$234,280,354',
#   '38.8%',
#   '$369,592,765',
#   '61.2%',
#   '2005'],
#  ['164',
#   'Tangled',
#   '$592,461,732',
#   '$200,821,936',
#   '33.9%',
#   '$391,639,796',
#   '66.1%',
#   '2010'],
#  ['165',
#   'Quantum of Solace',
#   '$589,580,482',
#   '$168,368,427',
#   '28.6%',
#   '$421,212,055',
#   '71.4%',
#   '2008'],
#  ['166',
#   'Men in Black',
#   '$589,390,539',
#   '$250,690,539',
#   '42.5%',
#   '$338,700,000',
#   '57.5%',
#   '1997'],
#  ['167',
#   'The Croods',
#   '$587,204,668',
#   '$187,168,425',
#   '31.9%',
#   '$400,036,243',
#   '68.1%',
#   '2013'],
#  ['168',
#   'The Hangover Part II',
#   '$586,764,305',
#   '$254,464,305',
#   '43.4%',
#   '$332,300,000',
#   '56.6%',
#   '2011'],
#  ['169',
#   'I Am Legend',
#   '$585,410,052',
#   '$256,393,010',
#   '43.8%',
#   '$329,017,042',
#   '56.2%',
#   '2007'],
#  ['170',
#   'Iron Man',
#   '$585,366,247',
#   '$318,604,126',
#   '54.4%',
#   '$266,762,121',
#   '45.6%',
#   '2008'],
#  ['171',
#   'Ready Player One',
#   '$582,890,172',
#   '$137,690,172',
#   '23.6%',
#   '$445,200,000',
#   '76.4%',
#   '2018'],
#  ['172',
#   'Operation Red Sea',
#   '$579,330,426',
#   '$1,543,547',
#   '0.3%',
#   '$577,786,879',
#   '99.7%',
#   '2018'],
#  ['173',
#   'Night at the Museum',
#   '$574,480,841',
#   '$250,863,268',
#   '43.7%',
#   '$323,617,573',
#   '56.3%',
#   '2006'],
#  ['174',
#   'Fifty Shades of Grey',
#   '$569,651,467',
#   '$166,167,230',
#   '29.2%',
#   '$403,484,237',
#   '70.8%',
#   '2015'],
#  ['175',
#   'Kong: Skull Island',
#   '$566,652,812',
#   '$168,052,812',
#   '29.7%',
#   '$398,600,000',
#   '70.3%',
#   '2017'],
#  ['176',
#   'The Smurfs',
#   '$563,749,323',
#   '$142,614,158',
#   '25.3%',
#   '$421,135,165',
#   '74.7%',
#   '2011'],
#  ['177',
#   'King Kong',
#   '$562,363,449',
#   '$218,080,025',
#   '38.8%',
#   '$344,283,424',
#   '61.2%',
#   '2005'],
#  ['178',
#   'Cars 2',
#   '$559,852,396',
#   '$191,452,396',
#   '34.2%',
#   '$368,400,000',
#   '65.8%',
#   '2011'],
#  ['179',
#   'Puss in Boots',
#   '$554,987,477',
#   '$149,260,504',
#   '26.9%',
#   '$405,726,973',
#   '73.1%',
#   '2011'],
#  ['180',
#   'The Mermaid',
#   '$553,810,228',
#   '$3,232,685',
#   '0.6%',
#   '$550,577,543',
#   '99.4%',
#   '2016'],
#  ['181',
#   'Armageddon',
#   '$553,709,788',
#   '$201,578,182',
#   '36.4%',
#   '$352,131,606',
#   '63.6%',
#   '1998'],
#  ['182',
#   'The Day After Tomorrow',
#   '$552,639,571',
#   '$186,740,799',
#   '33.8%',
#   '$365,898,772',
#   '66.2%',
#   '2004'],
#  ['183',
#   'Ted',
#   '$549,368,315',
#   '$218,815,487',
#   '39.8%',
#   '$330,552,828',
#   '60.2%',
#   '2012'],
#  ['184',
#   'Star Wars: Episode V - The Empire Strikes Back',
#   '$547,897,454',
#   '$290,271,960',
#   '53%',
#   '$257,625,494',
#   '47%',
#   '1980'],
#  ['185',
#   'American Sniper',
#   '$547,426,372',
#   '$350,126,372',
#   '64%',
#   '$197,300,000',
#   '36%',
#   '2014'],
#  ['186',
#   'Mission: Impossible II',
#   '$546,388,108',
#   '$215,409,889',
#   '39.4%',
#   '$330,978,219',
#   '60.6%',
#   '2000'],
#  ['187',
#   'Detective Chinatown 2',
#   '$544,185,156',
#   '$1,983,984',
#   '0.4%',
#   '$542,201,172',
#   '99.6%',
#   '2018'],
#  ['188',
#   'X-Men: Apocalypse',
#   '$543,934,105',
#   '$155,442,489',
#   '28.6%',
#   '$388,491,616',
#   '71.4%',
#   '2016'],
#  ['189',
#   'Sherlock Holmes: A Game of Shadows',
#   '$543,848,418',
#   '$186,848,418',
#   '34.4%',
#   '$357,000,000',
#   '65.6%',
#   '2011'],
#  ['190',
#   'Despicable Me',
#   '$543,113,985',
#   '$251,513,985',
#   '46.3%',
#   '$291,600,000',
#   '53.7%',
#   '2010'],
#  ['191',
#   'Cinderella',
#   '$542,351,353',
#   '$201,151,353',
#   '37.1%',
#   '$341,200,000',
#   '62.9%',
#   '2015'],
#  ['192',
#   'Madagascar',
#   '$542,063,846',
#   '$193,595,521',
#   '35.7%',
#   '$348,468,325',
#   '64.3%',
#   '2005'],
#  ['193',
#   'World War Z',
#   '$540,007,876',
#   '$202,359,711',
#   '37.5%',
#   '$337,648,165',
#   '62.5%',
#   '2013'],
#  ['194',
#   'Brave',
#   '$538,983,207',
#   '$237,283,207',
#   '44%',
#   '$301,700,000',
#   '56%',
#   '2012'],
#  ['195',
#   'The Simpsons Movie',
#   '$536,414,270',
#   '$183,135,014',
#   '34.1%',
#   '$353,279,256',
#   '65.9%',
#   '2007'],
#  ['196',
#   'The Revenant',
#   '$532,950,503',
#   '$183,637,894',
#   '34.5%',
#   '$349,312,609',
#   '65.5%',
#   '2015'],
#  ['197',
#   'The Meg',
#   '$530,243,742',
#   '$145,443,742',
#   '27.4%',
#   '$384,800,000',
#   '72.6%',
#   '2018'],
#  ['198',
#   'Ralph Breaks the Internet',
#   '$529,323,962',
#   '$201,091,711',
#   '38%',
#   '$328,232,251',
#   '62%',
#   '2018'],
#  ['199',
#   'Hotel Transylvania 3: Summer Vacation',
#   '$528,583,774',
#   '$167,510,016',
#   '31.7%',
#   '$361,073,758',
#   '68.3%',
#   '2018'],
#  ['200',
#   'The Boss Baby',
#   '$527,965,936',
#   '$175,003,033',
#   '33.2%',
#   '$352,962,903',
#   '66.8%',
#   '2017']]

# %%
row_list = []
for record in soup.findAll("td", class_='a-text-left mojo-field-type-title'):
    record == a['href'][6:17].startswith('/tt')
        row_list.append(a['href'][7:16])
row_list
# Out:
#   File "<ipython-input-148-004ba191a400>", line 4
#     row_list.append(a['href'][7:16])
#     ^
# IndentationError: unexpected indent

# %%
movie_id_list1 = []
row_list = []
for record in soup.findAll("td", class_='a-text-left mojo-field-type-title'):
    if a['href'][6:17].startswith('/tt'):
        row_list.append(a['href'][7:16])
#     if 
#         row_list.append(data.text)
#     if 
# #         for a in data.findAll('a', href=True):
# #             if a['href'][6:17].startswith('/tt'):
# #                 row_list.append(a['href'][7:16])
    if row_list == []:
        pass
    else:
        movie_id_list1.append(row_list)
        row_list = []
movie_id_list1
# Out:
# []

# %%
movie_id_list1 = []
row_list = []
for record in soup.findAll("tr"):
    for data in record.findAll("td"):
    if 
        row_list.append(data.text)
    if 
#         for a in data.findAll('a', href=True):
#             if a['href'][6:17].startswith('/tt'):
#                 row_list.append(a['href'][7:16])
    if row_list == []:
        pass
    else:
        movie_id_list1.append(row_list)
        row_list = []
movie_id_list1
# Out:
#   File "<ipython-input-97-5767c4c640aa>", line 5
#     if
#      ^
# IndentationError: expected an indented block

# %%
title = [a.find('href').attrs['title'][6:17] for a in soup.findAll('a')]
print(len(title), title[:5])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-98-7371c3202a42> in <module>
# ----> 1 title = [a.find('href').attrs['title'][6:17] for a in soup.findAll('a')]
#       2 print(len(title), title[:5])
#       3
#
# <ipython-input-98-7371c3202a42> in <listcomp>(.0)
# ----> 1 title = [a.find('href').attrs['title'][6:17] for a in soup.findAll('a')]
#       2 print(len(title), title[:5])
#       3
#
# AttributeError: 'NoneType' object has no attribute 'attrs'

# %%
for a in soup.findAll('a', href=True):
    if a['href'][6:17].startswith('/tt'):
        print(a['href'][7:16])

# %%
ids = []
for a in soup.findAll('a', href=True):
    if a['href'].startswith('/title/'):
        ids.append(a['href'][7:16])
len(ids)
ids
# Out:
# ['tt4154796',
#  'tt0499549',
#  'tt0120338',
#  'tt2488496',
#  'tt4154756',
#  'tt0369610',
#  'tt6105098',
#  'tt0848228',
#  'tt2820852',
#  'tt4520988',
#  'tt2395427',
#  'tt1825683',
#  'tt1201607',
#  'tt2527336',
#  'tt4881806',
#  'tt2294629',
#  'tt2771200',
#  'tt3606756',
#  'tt4630562',
#  'tt1300854',
#  'tt2293640',
#  'tt3498820',
#  'tt1477834',
#  'tt0167260',
#  'tt6320628',
#  'tt4154664',
#  'tt1399103',
#  'tt1074638',
#  'tt2109248',
#  'tt1345836',
#  'tt7286456',
#  'tt1979376',
#  'tt2527338',
#  'tt0435761',
#  'tt0383574',
#  'tt3748528',
#  'tt6139732',
#  'tt1298650',
#  'tt3469046',
#  'tt0107290',
#  'tt2277860',
#  'tt0120915',
#  'tt1014759',
#  'tt2948356',
#  'tt0903624',
#  'tt0468569',
#  'tt0241527',
#  'tt0926084',
#  'tt1690953',
#  'tt0110357',
#  'tt3040964',
#  'tt2283362',
#  'tt0449088',
#  'tt1170358',
#  'tt2310332',
#  'tt0167261',
#  'tt0373889',
#  'tt0266543',
#  'tt0417741',
#  'tt0298148',
#  'tt1727824',
#  'tt0330373',
#  'tt0413300',
#  'tt0120737',
#  'tt1080016',
#  'tt2379713',
#  'tt2250912',
#  'tt0295297',
#  'tt1667889',
#  'tt2709768',
#  'tt2975590',
#  'tt7131870',
#  'tt0121766',
#  'tt1951264',
#  'tt3896198',
#  'tt2096673',
#  'tt1270797',
#  'tt3501632',
#  'tt1055369',
#  'tt1375666',
#  'tt1673434',
#  'tt0145487',
#  'tt0451279',
#  'tt0116629',
#  'tt3183660',
#  'tt0413267',
#  'tt2380307',
#  'tt0304141',
#  'tt1790809',
#  'tt0083866',
#  'tt1190080',
#  'tt4912910',
#  'tt7975244',
#  'tt0367882',
#  'tt0316654',
#  'tt1905041',
#  'tt5463162',
#  'tt1431045',
#  'tt0076759',
#  'tt2015381',
#  'tt0382625',
#  'tt6806448',
#  'tt1587310',
#  'tt0948470',
#  'tt1951265',
#  'tt0892791',
#  'tt1277953',
#  'tt1386697',
#  'tt1877832',
#  'tt0363771',
#  'tt1453405',
#  'tt0234215',
#  'tt1049413',
#  'tt1062772',
#  'tt1454468',
#  'tt1843866',
#  'tt1324999',
#  'tt1259571',
#  'tt2103281',
#  'tt0418279',
#  'tt1872181',
#  'tt1396484',
#  'tt7605074',
#  'tt1325004',
#  'tt1229238',
#  'tt1392170',
#  'tt3521164',
#  'tt2381249',
#  'tt0109830',
#  'tt1211837',
#  'tt0816692',
#  'tt0167404',
#  'tt0770828',
#  'tt0438097',
#  'tt1302011',
#  'tt1951266',
#  'tt0974015',
#  'tt2245084',
#  'tt4123430',
#  'tt0325980',
#  'tt0121765',
#  'tt1981115',
#  'tt3470600',
#  'tt0198781',
#  'tt0441773',
#  'tt0317705',
#  'tt3659388',
#  'tt0448157',
#  'tt1596343',
#  'tt1409024',
#  'tt1228705',
#  'tt0382932',
#  'tt5095030',
#  'tt1646971',
#  'tt3315342',
#  'tt0119567',
#  'tt0381061',
#  'tt0335345',
#  'tt0795421',
#  'tt0454876',
#  'tt3371366',
#  'tt0479952',
#  'tt0407304',
#  'tt0398286',
#  'tt0830515',
#  'tt0119654',
#  'tt0481499',
#  'tt1411697',
#  'tt0480249',
#  'tt0371746',
#  'tt1677720',
#  'tt6878882',
#  'tt0477347',
#  'tt2322441',
#  'tt3731562',
#  'tt0472181',
#  'tt0360717',
#  'tt1216475',
#  'tt0448694',
#  'tt4701660',
#  'tt0120591',
#  'tt0319262',
#  'tt1637725',
#  'tt0080684',
#  'tt2179136',
#  'tt0120755',
#  'tt7752454',
#  'tt3385516',
#  'tt1515091',
#  'tt1323594',
#  'tt1661199',
#  'tt0351283',
#  'tt0816711',
#  'tt1217209',
#  'tt0462538',
#  'tt1663202',
#  'tt4779682',
#  'tt5848272',
#  'tt5220122',
#  'tt3874544']

# %%
list_of_ids =[]
for a in soup.findAll('a', href=True):
    if a['href'][6:17].startswith('/tt'):
        print(a['href'][7:16])
        
#list_of_ids
    #print(a['href'][6:17])
    #for title in a:
      #  print(title[7:16])
    
    #list_of_links.append(title[7:16])
    #list_of_links.append(a)
    #print(a[7:16])
    #for title in a:
       # list_of_links.append(title[7:16])

#list_of_links

#         if title.startswith("/title/"):
# Out:
# tt4154796
# tt0499549
# tt0120338
# tt2488496
# tt4154756
# tt0369610
# tt6105098
# tt0848228
# tt2820852
# tt4520988
# tt2395427
# tt1825683
# tt1201607
# tt2527336
# tt4881806
# tt2294629
# tt2771200
# tt3606756
# tt4630562
# tt1300854
# tt2293640
# tt3498820
# tt1477834
# tt0167260
# tt6320628
# tt4154664
# tt1399103
# tt1074638
# tt2109248
# tt1345836
# tt7286456
# tt1979376
# tt2527338
# tt0435761
# tt0383574
# tt3748528
# tt6139732
# tt1298650
# tt3469046
# tt0107290
# tt2277860
# tt0120915
# tt1014759
# tt2948356
# tt0903624
# tt0468569
# tt0241527
# tt0926084
# tt1690953
# tt0110357
# tt3040964
# tt2283362
# tt0449088
# tt1170358
# tt2310332
# tt0167261
# tt0373889
# tt0266543
# tt0417741
# tt0298148
# tt1727824
# tt0330373
# tt0413300
# tt0120737
# tt1080016
# tt2379713
# tt2250912
# tt0295297
# tt1667889
# tt2709768
# tt2975590
# tt7131870
# tt0121766
# tt1951264
# tt3896198
# tt2096673
# tt1270797
# tt3501632
# tt1055369
# tt1375666
# tt1673434
# tt0145487
# tt0451279
# tt0116629
# tt3183660
# tt0413267
# tt2380307
# tt0304141
# tt1790809
# tt0083866
# tt1190080
# tt4912910
# tt7975244
# tt0367882
# tt0316654
# tt1905041
# tt5463162
# tt1431045
# tt0076759
# tt2015381
# tt0382625
# tt6806448
# tt1587310
# tt0948470
# tt1951265
# tt0892791
# tt1277953
# tt1386697
# tt1877832
# tt0363771
# tt1453405
# tt0234215
# tt1049413
# tt1062772
# tt1454468
# tt1843866
# tt1324999
# tt1259571
# tt2103281
# tt0418279
# tt1872181
# tt1396484
# tt7605074
# tt1325004
# tt1229238
# tt1392170
# tt3521164
# tt2381249
# tt0109830
# tt1211837
# tt0816692
# tt0167404
# tt0770828
# tt0438097
# tt1302011
# tt1951266
# tt0974015
# tt2245084
# tt4123430
# tt0325980
# tt0121765
# tt1981115
# tt3470600
# tt0198781
# tt0441773
# tt0317705
# tt3659388
# tt0448157
# tt1596343
# tt1409024
# tt1228705
# tt0382932
# tt5095030
# tt1646971
# tt3315342
# tt0119567
# tt0381061
# tt0335345
# tt0795421
# tt0454876
# tt3371366
# tt0479952
# tt0407304
# tt0398286
# tt0830515
# tt0119654
# tt0481499
# tt1411697
# tt0480249
# tt0371746
# tt1677720
# tt6878882
# tt0477347
# tt2322441
# tt3731562
# tt0472181
# tt0360717
# tt1216475
# tt0448694
# tt4701660
# tt0120591
# tt0319262
# tt1637725
# tt0080684
# tt2179136
# tt0120755
# tt7752454
# tt3385516
# tt1515091
# tt1323594
# tt1661199
# tt0351283
# tt0816711
# tt1217209
# tt0462538
# tt1663202
# tt4779682
# tt5848272
# tt5220122
# tt3874544

# %%
mm = [link.split('/') for link in list_of_links]
mm
# Out:
# [['javascript:void(0)'],
#  ['javascript:void(0)'],
#  ['javascript:void(0)'],
#  ['https:',
#   '',
#   'pro.imdb.com',
#   'login',
#   'ap?u=%2Flogin%2Flwa&imdbPageAction=signUp&ref_=mojo_nb_cso_rollover&rf=mojo_nb_cso_rollover'],
#  ['javascript:void(0)'],
#  ['javascript:void(0)'],
#  ['', 'date', '?ref_=bo_nb_cso_tab'],
#  ['', 'intl', '?ref_=bo_nb_cso_tab'],
#  ['', 'year', 'world', '?ref_=bo_nb_cso_tab'],
#  ['', 'calendar', '?ref_=bo_nb_cso_tab'],
#  ['', 'charts', 'overall', '?ref_=bo_nb_cso_tab'],
#  ['', 'showdown', '?ref_=bo_nb_cso_tab'],
#  ['', 'news', '?ref_=bo_nb_cso_tab'],
#  ['', 'charts', 'overall', '?ref_=bo_nb_cso_secondarytab'],
#  ['', 'charts', 'weekend', '?ref_=bo_nb_cso_secondarytab'],
#  ['', 'charts', 'daily', '?ref_=bo_nb_cso_secondarytab'],
#  ['', 'charts', 'misc', '?ref_=bo_nb_cso_secondarytab'],
#  ['#'],
#  ['', 'chart', 'ww_top_lifetime_gross', '?area=XWW&offset=200'],
#  ['', 'chart', 'ww_top_lifetime_gross', '?area=XWW&offset=200'],
#  ['', 'chart', 'ww_top_lifetime_gross', '?area=XWW&offset=200'],
#  ['', 'chart', 'ww_top_lifetime_gross', '?area=XWW&offset=200'],
#  ['', 'title', 'tt4154796', '?ref_=bo_cso_table_1'],
#  ['', 'year', 'world', '2019', '?ref_=bo_cso_table_1'],
#  ['', 'title', 'tt0499549', '?ref_=bo_cso_table_2'],
#  ['', 'year', 'world', '2009', '?ref_=bo_cso_table_2'],
#  ['', 'title', 'tt0120338', '?ref_=bo_cso_table_3'],
#  ['', 'year', 'world', '1997', '?ref_=bo_cso_table_3'],
#  ['', 'title', 'tt2488496', '?ref_=bo_cso_table_4'],
#  ['', 'year', 'world', '2015', '?ref_=bo_cso_table_4'],
#  ['', 'title', 'tt4154756', '?ref_=bo_cso_table_5'],
#  ['', 'year', 'world', '2018', '?ref_=bo_cso_table_5'],
#  ['', 'title', 'tt0369610', '?ref_=bo_cso_table_6'],
#  ['', 'year', 'world', '2015', '?ref_=bo_cso_table_6'],
#  ['', 'title', 'tt6105098', '?ref_=bo_cso_table_7'],
#  ['', 'year', 'world', '2019', '?ref_=bo_cso_table_7'],
#  ['', 'title', 'tt0848228', '?ref_=bo_cso_table_8'],
#  ['', 'year', 'world', '2012', '?ref_=bo_cso_table_8'],
#  ['', 'title', 'tt2820852', '?ref_=bo_cso_table_9'],
#  ['', 'year', 'world', '2015', '?ref_=bo_cso_table_9'],
#  ['', 'title', 'tt4520988', '?ref_=bo_cso_table_10'],
#  ['', 'year', 'world', '2019', '?ref_=bo_cso_table_10'],
#  ['', 'title', 'tt2395427', '?ref_=bo_cso_table_11'],
#  ['', 'year', 'world', '2015', '?ref_=bo_cso_table_11'],
#  ['', 'title', 'tt1825683', '?ref_=bo_cso_table_12'],
#  ['', 'year', 'world', '2018', '?ref_=bo_cso_table_12'],
#  ['', 'title', 'tt1201607', '?ref_=bo_cso_table_13'],
#  ['', 'year', 'world', '2011', '?ref_=bo_cso_table_13'],
#  ['', 'title', 'tt2527336', '?ref_=bo_cso_table_14'],
#  ['', 'year', 'world', '2017', '?ref_=bo_cso_table_14'],
#  ['', 'title', 'tt4881806', '?ref_=bo_cso_table_15'],
#  ['', 'year', 'world', '2018', '?ref_=bo_cso_table_15'],
#  ['', 'title', 'tt2294629', '?ref_=bo_cso_table_16'],
#  ['', 'year', 'world', '2013', '?ref_=bo_cso_table_16'],
#  ['', 'title', 'tt2771200', '?ref_=bo_cso_table_17'],
#  ['', 'year', 'world', '2017', '?ref_=bo_cso_table_17'],
#  ['', 'title', 'tt3606756', '?ref_=bo_cso_table_18'],
#  ['', 'year', 'world', '2018', '?ref_=bo_cso_table_18'],
#  ['', 'title', 'tt4630562', '?ref_=bo_cso_table_19'],
#  ['', 'year', 'world', '2017', '?ref_=bo_cso_table_19'],
#  ['', 'title', 'tt1300854', '?ref_=bo_cso_table_20'],
#  ['', 'year', 'world', '2013', '?ref_=bo_cso_table_20'],
#  ['', 'title', 'tt2293640', '?ref_=bo_cso_table_21'],
#  ['', 'year', 'world', '2015', '?ref_=bo_cso_table_21'],
#  ['', 'title', 'tt3498820', '?ref_=bo_cso_table_22'],
#  ['', 'year', 'world', '2016', '?ref_=bo_cso_table_22'],
#  ['', 'title', 'tt1477834', '?ref_=bo_cso_table_23'],
#  ['', 'year', 'world', '2018', '?ref_=bo_cso_table_23'],
#  ['', 'title', 'tt0167260', '?ref_=bo_cso_table_24'],
#  ['', 'year', 'world', '2003', '?ref_=bo_cso_table_24'],
#  ['', 'title', 'tt6320628', '?ref_=bo_cso_table_25'],
#  ['', 'year', 'world', '2019', '?ref_=bo_cso_table_25'],
#  ['', 'title', 'tt4154664', '?ref_=bo_cso_table_26'],
#  ['', 'year', 'world', '2019', '?ref_=bo_cso_table_26'],
#  ['', 'title', 'tt1399103', '?ref_=bo_cso_table_27'],
#  ['', 'year', 'world', '2011', '?ref_=bo_cso_table_27'],
#  ['', 'title', 'tt1074638', '?ref_=bo_cso_table_28'],
#  ['', 'year', 'world', '2012', '?ref_=bo_cso_table_28'],
#  ['', 'title', 'tt2109248', '?ref_=bo_cso_table_29'],
#  ['', 'year', 'world', '2014', '?ref_=bo_cso_table_29'],
#  ['', 'title', 'tt1345836', '?ref_=bo_cso_table_30'],
#  ['', 'year', 'world', '2012', '?ref_=bo_cso_table_30'],
#  ['', 'title', 'tt7286456', '?ref_=bo_cso_table_31'],
#  ['', 'year', 'world', '2019', '?ref_=bo_cso_table_31'],
#  ['', 'title', 'tt1979376', '?ref_=bo_cso_table_32'],
#  ['', 'year', 'world', '2019', '?ref_=bo_cso_table_32'],
#  ['', 'title', 'tt2527338', '?ref_=bo_cso_table_33'],
#  ['', 'year', 'world', '2019', '?ref_=bo_cso_table_33'],
#  ['', 'title', 'tt0435761', '?ref_=bo_cso_table_34'],
#  ['', 'year', 'world', '2010', '?ref_=bo_cso_table_34'],
#  ['', 'title', 'tt0383574', '?ref_=bo_cso_table_35'],
#  ['', 'year', 'world', '2006', '?ref_=bo_cso_table_35'],
#  ['', 'title', 'tt3748528', '?ref_=bo_cso_table_36'],
#  ['', 'year', 'world', '2016', '?ref_=bo_cso_table_36'],
#  ['', 'title', 'tt6139732', '?ref_=bo_cso_table_37'],
#  ['', 'year', 'world', '2019', '?ref_=bo_cso_table_37'],
#  ['', 'title', 'tt1298650', '?ref_=bo_cso_table_38'],
#  ['', 'year', 'world', '2011', '?ref_=bo_cso_table_38'],
#  ['', 'title', 'tt3469046', '?ref_=bo_cso_table_39'],
#  ['', 'year', 'world', '2017', '?ref_=bo_cso_table_39'],
#  ['', 'title', 'tt0107290', '?ref_=bo_cso_table_40'],
#  ['', 'year', 'world', '1993', '?ref_=bo_cso_table_40'],
#  ['', 'title', 'tt2277860', '?ref_=bo_cso_table_41'],
#  ['', 'year', 'world', '2016', '?ref_=bo_cso_table_41'],
#  ['', 'title', 'tt0120915', '?ref_=bo_cso_table_42'],
#  ['', 'year', 'world', '1999', '?ref_=bo_cso_table_42'],
#  ['', 'title', 'tt1014759', '?ref_=bo_cso_table_43'],
#  ['', 'year', 'world', '2010', '?ref_=bo_cso_table_43'],
#  ['', 'title', 'tt2948356', '?ref_=bo_cso_table_44'],
#  ['', 'year', 'world', '2016', '?ref_=bo_cso_table_44'],
#  ['', 'title', 'tt0903624', '?ref_=bo_cso_table_45'],
#  ['', 'year', 'world', '2012', '?ref_=bo_cso_table_45'],
#  ['', 'title', 'tt0468569', '?ref_=bo_cso_table_46'],
#  ['', 'year', 'world', '2008', '?ref_=bo_cso_table_46'],
#  ['', 'title', 'tt0241527', '?ref_=bo_cso_table_47'],
#  ['', 'year', 'world', '2001', '?ref_=bo_cso_table_47'],
#  ['', 'title', 'tt0926084', '?ref_=bo_cso_table_48'],
#  ['', 'year', 'world', '2010', '?ref_=bo_cso_table_48'],
#  ['', 'title', 'tt1690953', '?ref_=bo_cso_table_49'],
#  ['', 'year', 'world', '2013', '?ref_=bo_cso_table_49'],
#  ['', 'title', 'tt0110357', '?ref_=bo_cso_table_50'],
#  ['', 'year', 'world', '1994', '?ref_=bo_cso_table_50'],
#  ['', 'title', 'tt3040964', '?ref_=bo_cso_table_51'],
#  ['', 'year', 'world', '2016', '?ref_=bo_cso_table_51'],
#  ['', 'title', 'tt2283362', '?ref_=bo_cso_table_52'],
#  ['', 'year', 'world', '2017', '?ref_=bo_cso_table_52'],
#  ['', 'title', 'tt0449088', '?ref_=bo_cso_table_53'],
#  ['', 'year', 'world', '2007', '?ref_=bo_cso_table_53'],
#  ['', 'title', 'tt1170358', '?ref_=bo_cso_table_54'],
#  ['', 'year', 'world', '2013', '?ref_=bo_cso_table_54'],
#  ['', 'title', 'tt2310332', '?ref_=bo_cso_table_55'],
#  ['', 'year', 'world', '2014', '?ref_=bo_cso_table_55'],
#  ['', 'title', 'tt0167261', '?ref_=bo_cso_table_56'],
#  ['', 'year', 'world', '2002', '?ref_=bo_cso_table_56'],
#  ['', 'title', 'tt0373889', '?ref_=bo_cso_table_57'],
#  ['', 'year', 'world', '2007', '?ref_=bo_cso_table_57'],
#  ['', 'title', 'tt0266543', '?ref_=bo_cso_table_58'],
#  ['', 'year', 'world', '2003', '?ref_=bo_cso_table_58'],
#  ['', 'title', 'tt0417741', '?ref_=bo_cso_table_59'],
#  ['', 'year', 'world', '2009', '?ref_=bo_cso_table_59'],
#  ['', 'title', 'tt0298148', '?ref_=bo_cso_table_60'],
#  ['', 'year', 'world', '2004', '?ref_=bo_cso_table_60'],
#  ['', 'title', 'tt1727824', '?ref_=bo_cso_table_61'],
#  ['', 'year', 'world', '2018', '?ref_=bo_cso_table_61'],
#  ['', 'title', 'tt0330373', '?ref_=bo_cso_table_62'],
#  ['', 'year', 'world', '2005', '?ref_=bo_cso_table_62'],
#  ['', 'title', 'tt0413300', '?ref_=bo_cso_table_63'],
#  ['', 'year', 'world', '2007', '?ref_=bo_cso_table_63'],
#  ['', 'title', 'tt0120737', '?ref_=bo_cso_table_64'],
#  ['', 'year', 'world', '2001', '?ref_=bo_cso_table_64'],
#  ['', 'title', 'tt1080016', '?ref_=bo_cso_table_65'],
#  ['', 'year', 'world', '2009', '?ref_=bo_cso_table_65'],
#  ['', 'title', 'tt2379713', '?ref_=bo_cso_table_66'],
#  ['', 'year', 'world', '2015', '?ref_=bo_cso_table_66'],
#  ['', 'title', 'tt2250912', '?ref_=bo_cso_table_67'],
#  ['', 'year', 'world', '2017', '?ref_=bo_cso_table_67'],
#  ['', 'title', 'tt0295297', '?ref_=bo_cso_table_68'],
#  ['', 'year', 'world', '2002', '?ref_=bo_cso_table_68'],
#  ['', 'title', 'tt1667889', '?ref_=bo_cso_table_69'],
#  ['', 'year', 'world', '2012', '?ref_=bo_cso_table_69'],
#  ['', 'title', 'tt2709768', '?ref_=bo_cso_table_70'],
#  ['', 'year', 'world', '2016', '?ref_=bo_cso_table_70'],
#  ['', 'title', 'tt2975590', '?ref_=bo_cso_table_71'],
#  ['', 'year', 'world', '2016', '?ref_=bo_cso_table_71'],
#  ['', 'title', 'tt7131870', '?ref_=bo_cso_table_72'],
#  ['', 'year', 'world', '2017', '?ref_=bo_cso_table_72'],
#  ['', 'title', 'tt0121766', '?ref_=bo_cso_table_73'],
#  ['', 'year', 'world', '2005', '?ref_=bo_cso_table_73'],
#  ['', 'title', 'tt1951264', '?ref_=bo_cso_table_74'],
#  ['', 'year', 'world', '2013', '?ref_=bo_cso_table_74'],
#  ['', 'title', 'tt3896198', '?ref_=bo_cso_table_75'],
#  ['', 'year', 'world', '2017', '?ref_=bo_cso_table_75'],
#  ['', 'title', 'tt2096673', '?ref_=bo_cso_table_76'],
#  ['', 'year', 'world', '2015', '?ref_=bo_cso_table_76'],
#  ['', 'title', 'tt1270797', '?ref_=bo_cso_table_77'],
#  ['', 'year', 'world', '2018', '?ref_=bo_cso_table_77'],
#  ['', 'title', 'tt3501632', '?ref_=bo_cso_table_78'],
#  ['', 'year', 'world', '2017', '?ref_=bo_cso_table_78'],
#  ['', 'title', 'tt1055369', '?ref_=bo_cso_table_79'],
#  ['', 'year', 'world', '2009', '?ref_=bo_cso_table_79'],
#  ['', 'title', 'tt1375666', '?ref_=bo_cso_table_80'],
#  ['', 'year', 'world', '2010', '?ref_=bo_cso_table_80'],
#  ['', 'title', 'tt1673434', '?ref_=bo_cso_table_81'],
#  ['', 'year', 'world', '2012', '?ref_=bo_cso_table_81'],
#  ['', 'title', 'tt0145487', '?ref_=bo_cso_table_82'],
#  ['', 'year', 'world', '2002', '?ref_=bo_cso_table_82'],
#  ['', 'title', 'tt0451279', '?ref_=bo_cso_table_83'],
#  ['', 'year', 'world', '2017', '?ref_=bo_cso_table_83'],
#  ['', 'title', 'tt0116629', '?ref_=bo_cso_table_84'],
#  ['', 'year', 'world', '1996', '?ref_=bo_cso_table_84'],
#  ['', 'title', 'tt3183660', '?ref_=bo_cso_table_85'],
#  ['', 'year', 'world', '2016', '?ref_=bo_cso_table_85'],
#  ['', 'title', 'tt0413267', '?ref_=bo_cso_table_86'],
#  ['', 'year', 'world', '2007', '?ref_=bo_cso_table_86'],
#  ['', 'title', 'tt2380307', '?ref_=bo_cso_table_87'],
#  ['', 'year', 'world', '2017', '?ref_=bo_cso_table_87'],
#  ['', 'title', 'tt0304141', '?ref_=bo_cso_table_88'],
#  ['', 'year', 'world', '2004', '?ref_=bo_cso_table_88'],
#  ['', 'title', 'tt1790809', '?ref_=bo_cso_table_89'],
#  ['', 'year', 'world', '2017', '?ref_=bo_cso_table_89'],
#  ['', 'title', 'tt0083866', '?ref_=bo_cso_table_90'],
#  ['', 'year', 'world', '1982', '?ref_=bo_cso_table_90'],
#  ['', 'title', 'tt1190080', '?ref_=bo_cso_table_91'],
#  ['', 'year', 'world', '2009', '?ref_=bo_cso_table_91'],
#  ['', 'title', 'tt4912910', '?ref_=bo_cso_table_92'],
#  ['', 'year', 'world', '2018', '?ref_=bo_cso_table_92'],
#  ['', 'title', 'tt7975244', '?ref_=bo_cso_table_93'],
#  ['', 'year', 'world', '2019', '?ref_=bo_cso_table_93'],
#  ['', 'title', 'tt0367882', '?ref_=bo_cso_table_94'],
#  ['', 'year', 'world', '2008', '?ref_=bo_cso_table_94'],
#  ['', 'title', 'tt0316654', '?ref_=bo_cso_table_95'],
#  ['', 'year', 'world', '2004', '?ref_=bo_cso_table_95'],
#  ['', 'title', 'tt1905041', '?ref_=bo_cso_table_96'],
#  ['', 'year', 'world', '2013', '?ref_=bo_cso_table_96'],
#  ['', 'title', 'tt5463162', '?ref_=bo_cso_table_97'],
#  ['', 'year', 'world', '2018', '?ref_=bo_cso_table_97'],
#  ['', 'title', 'tt1431045', '?ref_=bo_cso_table_98'],
#  ['', 'year', 'world', '2016', '?ref_=bo_cso_table_98'],
#  ['', 'title', 'tt0076759', '?ref_=bo_cso_table_99'],
#  ['', 'year', 'world', '1977', '?ref_=bo_cso_table_99'],
#  ['', 'title', 'tt2015381', '?ref_=bo_cso_table_100'],
#  ['', 'year', 'world', '2014', '?ref_=bo_cso_table_100'],
#  ['', 'title', 'tt0382625', '?ref_=bo_cso_table_101'],
#  ['', 'year', 'world', '2006', '?ref_=bo_cso_table_101'],
#  ['', 'title', 'tt6806448', '?ref_=bo_cso_table_102'],
#  ['', 'year', 'world', '2019', '?ref_=bo_cso_table_102'],
#  ['', 'title', 'tt1587310', '?ref_=bo_cso_table_103'],
#  ['', 'year', 'world', '2014', '?ref_=bo_cso_table_103'],
#  ['', 'title', 'tt0948470', '?ref_=bo_cso_table_104'],
#  ['', 'year', 'world', '2012', '?ref_=bo_cso_table_104'],
#  ['', 'title', 'tt1951265', '?ref_=bo_cso_table_105'],
#  ['', 'year', 'world', '2014', '?ref_=bo_cso_table_105'],
#  ['', 'title', 'tt0892791', '?ref_=bo_cso_table_106'],
#  ['', 'year', 'world', '2010', '?ref_=bo_cso_table_106'],
#  ['', 'title', 'tt1277953', '?ref_=bo_cso_table_107'],
#  ['', 'year', 'world', '2012', '?ref_=bo_cso_table_107'],
#  ['', 'title', 'tt1386697', '?ref_=bo_cso_table_108'],
#  ['', 'year', 'world', '2016', '?ref_=bo_cso_table_108'],
#  ['', 'title', 'tt1877832', '?ref_=bo_cso_table_109'],
#  ['', 'year', 'world', '2014', '?ref_=bo_cso_table_109'],
#  ['', 'title', 'tt0363771', '?ref_=bo_cso_table_110'],
#  ['', 'year', 'world', '2005', '?ref_=bo_cso_table_110'],
#  ['', 'title', 'tt1453405', '?ref_=bo_cso_table_111'],
#  ['', 'year', 'world', '2013', '?ref_=bo_cso_table_111'],
#  ['', 'title', 'tt0234215', '?ref_=bo_cso_table_112'],
#  ['', 'year', 'world', '2003', '?ref_=bo_cso_table_112'],
#  ['', 'title', 'tt1049413', '?ref_=bo_cso_table_113'],
#  ['', 'year', 'world', '2009', '?ref_=bo_cso_table_113'],
#  ['', 'title', 'tt10627720', '?ref_=bo_cso_table_114'],
#  ['', 'year', 'world', '2019', '?ref_=bo_cso_table_114'],
#  ['', 'title', 'tt1454468', '?ref_=bo_cso_table_115'],
#  ['', 'year', 'world', '2013', '?ref_=bo_cso_table_115'],
#  ['', 'title', 'tt1843866', '?ref_=bo_cso_table_116'],
#  ['', 'year', 'world', '2014', '?ref_=bo_cso_table_116'],
#  ['', 'title', 'tt1324999', '?ref_=bo_cso_table_117'],
#  ['', 'year', 'world', '2011', '?ref_=bo_cso_table_117'],
#  ['', 'title', 'tt1259571', '?ref_=bo_cso_table_118'],
#  ['', 'year', 'world', '2009', '?ref_=bo_cso_table_118'],
#  ['', 'title', 'tt2103281', '?ref_=bo_cso_table_119'],
#  ['', 'year', 'world', '2014', '?ref_=bo_cso_table_119'],
#  ['', 'title', 'tt0418279', '?ref_=bo_cso_table_120'],
#  ['', 'year', 'world', '2007', '?ref_=bo_cso_table_120'],
#  ['', 'title', 'tt1872181', '?ref_=bo_cso_table_121'],
#  ['', 'year', 'world', '2014', '?ref_=bo_cso_table_121'],
#  ['', 'title', 'tt1396484', '?ref_=bo_cso_table_122'],
#  ['', 'year', 'world', '2017', '?ref_=bo_cso_table_122'],
#  ['', 'title', 'tt7605074', '?ref_=bo_cso_table_123'],
#  ['', 'year', 'world', '2019', '?ref_=bo_cso_table_123'],
#  ['', 'title', 'tt1325004', '?ref_=bo_cso_table_124'],
#  ['', 'year', 'world', '2010', '?ref_=bo_cso_table_124'],
#  ['', 'title', 'tt1229238', '?ref_=bo_cso_table_125'],
#  ['', 'year', 'world', '2011', '?ref_=bo_cso_table_125'],
#  ['', 'title', 'tt1392170', '?ref_=bo_cso_table_126'],
#  ['', 'year', 'world', '2012', '?ref_=bo_cso_table_126'],
#  ['', 'title', 'tt3521164', '?ref_=bo_cso_table_127'],
#  ['', 'year', 'world', '2016', '?ref_=bo_cso_table_127'],
#  ['', 'title', 'tt2381249', '?ref_=bo_cso_table_128'],
#  ['', 'year', 'world', '2015', '?ref_=bo_cso_table_128'],
#  ['', 'title', 'tt0109830', '?ref_=bo_cso_table_129'],
#  ['', 'year', 'world', '1994', '?ref_=bo_cso_table_129'],
#  ['', 'title', 'tt1211837', '?ref_=bo_cso_table_130'],
#  ['', 'year', 'world', '2016', '?ref_=bo_cso_table_130'],
#  ['', 'title', 'tt0816692', '?ref_=bo_cso_table_131'],
#  ['', 'year', 'world', '2014', '?ref_=bo_cso_table_131'],
#  ['', 'title', 'tt0167404', '?ref_=bo_cso_table_132'],
#  ['', 'year', 'world', '1999', '?ref_=bo_cso_table_132'],
#  ['', 'title', 'tt0770828', '?ref_=bo_cso_table_133'],
#  ['', 'year', 'world', '2013', '?ref_=bo_cso_table_133'],
#  ['', 'title', 'tt0438097', '?ref_=bo_cso_table_134'],
#  ['', 'year', 'world', '2006', '?ref_=bo_cso_table_134'],
#  ['', 'title', 'tt1302011', '?ref_=bo_cso_table_135'],
#  ['', 'year', 'world', '2011', '?ref_=bo_cso_table_135'],
#  ['', 'title', 'tt1951266', '?ref_=bo_cso_table_136'],
#  ['', 'year', 'world', '2015', '?ref_=bo_cso_table_136'],
#  ['', 'title', 'tt0974015', '?ref_=bo_cso_table_137'],
#  ['', 'year', 'world', '2017', '?ref_=bo_cso_table_137'],
#  ['', 'title', 'tt2245084', '?ref_=bo_cso_table_138'],
#  ['', 'year', 'world', '2014', '?ref_=bo_cso_table_138'],
#  ['', 'title', 'tt4123430', '?ref_=bo_cso_table_139'],
#  ['', 'year', 'world', '2018', '?ref_=bo_cso_table_139'],
#  ['', 'title', 'tt0325980', '?ref_=bo_cso_table_140'],
#  ['', 'year', 'world', '2003', '?ref_=bo_cso_table_140'],
#  ['', 'title', 'tt0121765', '?ref_=bo_cso_table_141'],
#  ['', 'year', 'world', '2002', '?ref_=bo_cso_table_141'],
#  ['', 'title', 'tt1981115', '?ref_=bo_cso_table_142'],
#  ['', 'year', 'world', '2013', '?ref_=bo_cso_table_142'],
#  ['', 'title', 'tt3470600', '?ref_=bo_cso_table_143'],
#  ['', 'year', 'world', '2016', '?ref_=bo_cso_table_143'],
#  ['', 'title', 'tt0198781', '?ref_=bo_cso_table_144'],
#  ['', 'year', 'world', '2001', '?ref_=bo_cso_table_144'],
#  ['', 'title', 'tt0441773', '?ref_=bo_cso_table_145'],
#  ['', 'year', 'world', '2008', '?ref_=bo_cso_table_145'],
#  ['', 'title', 'tt0317705', '?ref_=bo_cso_table_146'],
#  ['', 'year', 'world', '2004', '?ref_=bo_cso_table_146'],
#  ['', 'title', 'tt3659388', '?ref_=bo_cso_table_147'],
#  ['', 'year', 'world', '2015', '?ref_=bo_cso_table_147'],
#  ['', 'title', 'tt0448157', '?ref_=bo_cso_table_148'],
#  ['', 'year', 'world', '2008', '?ref_=bo_cso_table_148'],
#  ['', 'title', 'tt1596343', '?ref_=bo_cso_table_149'],
#  ['', 'year', 'world', '2011', '?ref_=bo_cso_table_149'],
#  ['', 'title', 'tt1409024', '?ref_=bo_cso_table_150'],
#  ['', 'year', 'world', '2012', '?ref_=bo_cso_table_150'],
#  ['', 'title', 'tt1228705', '?ref_=bo_cso_table_151'],
#  ['', 'year', 'world', '2010', '?ref_=bo_cso_table_151'],
#  ['', 'title', 'tt0382932', '?ref_=bo_cso_table_152'],
#  ['', 'year', 'world', '2007', '?ref_=bo_cso_table_152'],
#  ['', 'title', 'tt5095030', '?ref_=bo_cso_table_153'],
#  ['', 'year', 'world', '2018', '?ref_=bo_cso_table_153'],
#  ['', 'title', 'tt1646971', '?ref_=bo_cso_table_154'],
#  ['', 'year', 'world', '2014', '?ref_=bo_cso_table_154'],
#  ['', 'title', 'tt3315342', '?ref_=bo_cso_table_155'],
#  ['', 'year', 'world', '2017', '?ref_=bo_cso_table_155'],
#  ['', 'title', 'tt0119567', '?ref_=bo_cso_table_156'],
#  ['', 'year', 'world', '1997', '?ref_=bo_cso_table_156'],
#  ['', 'title', 'tt0381061', '?ref_=bo_cso_table_157'],
#  ['', 'year', 'world', '2006', '?ref_=bo_cso_table_157'],
#  ['', 'title', 'tt0335345', '?ref_=bo_cso_table_158'],
#  ['', 'year', 'world', '2004', '?ref_=bo_cso_table_158'],
#  ['', 'title', 'tt0795421', '?ref_=bo_cso_table_159'],
#  ['', 'year', 'world', '2008', '?ref_=bo_cso_table_159'],
#  ['', 'title', 'tt0454876', '?ref_=bo_cso_table_160'],
#  ['', 'year', 'world', '2012', '?ref_=bo_cso_table_160'],
#  ['', 'title', 'tt3371366', '?ref_=bo_cso_table_161'],
#  ['', 'year', 'world', '2017', '?ref_=bo_cso_table_161'],
#  ['', 'title', 'tt0479952', '?ref_=bo_cso_table_162'],
#  ['', 'year', 'world', '2008', '?ref_=bo_cso_table_162'],
#  ['', 'title', 'tt0407304', '?ref_=bo_cso_table_163'],
#  ['', 'year', 'world', '2005', '?ref_=bo_cso_table_163'],
#  ['', 'title', 'tt0398286', '?ref_=bo_cso_table_164'],
#  ['', 'year', 'world', '2010', '?ref_=bo_cso_table_164'],
#  ['', 'title', 'tt0830515', '?ref_=bo_cso_table_165'],
#  ['', 'year', 'world', '2008', '?ref_=bo_cso_table_165'],
#  ['', 'title', 'tt0119654', '?ref_=bo_cso_table_166'],
#  ['', 'year', 'world', '1997', '?ref_=bo_cso_table_166'],
#  ['', 'title', 'tt0481499', '?ref_=bo_cso_table_167'],
#  ['', 'year', 'world', '2013', '?ref_=bo_cso_table_167'],
#  ['', 'title', 'tt1411697', '?ref_=bo_cso_table_168'],
#  ['', 'year', 'world', '2011', '?ref_=bo_cso_table_168'],
#  ['', 'title', 'tt0480249', '?ref_=bo_cso_table_169'],
#  ['', 'year', 'world', '2007', '?ref_=bo_cso_table_169'],
#  ['', 'title', 'tt0371746', '?ref_=bo_cso_table_170'],
#  ['', 'year', 'world', '2008', '?ref_=bo_cso_table_170'],
#  ['', 'title', 'tt1677720', '?ref_=bo_cso_table_171'],
#  ['', 'year', 'world', '2018', '?ref_=bo_cso_table_171'],
#  ['', 'title', 'tt6878882', '?ref_=bo_cso_table_172'],
#  ['', 'year', 'world', '2018', '?ref_=bo_cso_table_172'],
#  ['', 'title', 'tt0477347', '?ref_=bo_cso_table_173'],
#  ['', 'year', 'world', '2006', '?ref_=bo_cso_table_173'],
#  ['', 'title', 'tt2322441', '?ref_=bo_cso_table_174'],
#  ['', 'year', 'world', '2015', '?ref_=bo_cso_table_174'],
#  ['', 'title', 'tt3731562', '?ref_=bo_cso_table_175'],
#  ['', 'year', 'world', '2017', '?ref_=bo_cso_table_175'],
#  ['', 'title', 'tt0472181', '?ref_=bo_cso_table_176'],
#  ['', 'year', 'world', '2011', '?ref_=bo_cso_table_176'],
#  ['', 'title', 'tt0360717', '?ref_=bo_cso_table_177'],
#  ['', 'year', 'world', '2005', '?ref_=bo_cso_table_177'],
#  ['', 'title', 'tt1216475', '?ref_=bo_cso_table_178'],
#  ['', 'year', 'world', '2011', '?ref_=bo_cso_table_178'],
#  ['', 'title', 'tt0448694', '?ref_=bo_cso_table_179'],
#  ['', 'year', 'world', '2011', '?ref_=bo_cso_table_179'],
#  ['', 'title', 'tt4701660', '?ref_=bo_cso_table_180'],
#  ['', 'year', 'world', '2016', '?ref_=bo_cso_table_180'],
#  ['', 'title', 'tt0120591', '?ref_=bo_cso_table_181'],
#  ['', 'year', 'world', '1998', '?ref_=bo_cso_table_181'],
#  ['', 'title', 'tt0319262', '?ref_=bo_cso_table_182'],
#  ['', 'year', 'world', '2004', '?ref_=bo_cso_table_182'],
#  ['', 'title', 'tt1637725', '?ref_=bo_cso_table_183'],
#  ['', 'year', 'world', '2012', '?ref_=bo_cso_table_183'],
#  ['', 'title', 'tt0080684', '?ref_=bo_cso_table_184'],
#  ['', 'year', 'world', '1980', '?ref_=bo_cso_table_184'],
#  ['', 'title', 'tt2179136', '?ref_=bo_cso_table_185'],
#  ['', 'year', 'world', '2014', '?ref_=bo_cso_table_185'],
#  ['', 'title', 'tt0120755', '?ref_=bo_cso_table_186'],
#  ['', 'year', 'world', '2000', '?ref_=bo_cso_table_186'],
#  ['', 'title', 'tt7752454', '?ref_=bo_cso_table_187'],
#  ['', 'year', 'world', '2018', '?ref_=bo_cso_table_187'],
#  ['', 'title', 'tt3385516', '?ref_=bo_cso_table_188'],
#  ['', 'year', 'world', '2016', '?ref_=bo_cso_table_188'],
#  ['', 'title', 'tt1515091', '?ref_=bo_cso_table_189'],
#  ['', 'year', 'world', '2011', '?ref_=bo_cso_table_189'],
#  ['', 'title', 'tt1323594', '?ref_=bo_cso_table_190'],
#  ['', 'year', 'world', '2010', '?ref_=bo_cso_table_190'],
#  ['', 'title', 'tt1661199', '?ref_=bo_cso_table_191'],
#  ['', 'year', 'world', '2015', '?ref_=bo_cso_table_191'],
#  ['', 'title', 'tt0351283', '?ref_=bo_cso_table_192'],
#  ['', 'year', 'world', '2005', '?ref_=bo_cso_table_192'],
#  ['', 'title', 'tt0816711', '?ref_=bo_cso_table_193'],
#  ['', 'year', 'world', '2013', '?ref_=bo_cso_table_193'],
#  ['', 'title', 'tt1217209', '?ref_=bo_cso_table_194'],
#  ['', 'year', 'world', '2012', '?ref_=bo_cso_table_194'],
#  ['', 'title', 'tt0462538', '?ref_=bo_cso_table_195'],
#  ['', 'year', 'world', '2007', '?ref_=bo_cso_table_195'],
#  ['', 'title', 'tt1663202', '?ref_=bo_cso_table_196'],
#  ['', 'year', 'world', '2015', '?ref_=bo_cso_table_196'],
#  ['', 'title', 'tt4779682', '?ref_=bo_cso_table_197'],
#  ['', 'year', 'world', '2018', '?ref_=bo_cso_table_197'],
#  ['', 'title', 'tt5848272', '?ref_=bo_cso_table_198'],
#  ['', 'year', 'world', '2018', '?ref_=bo_cso_table_198'],
#  ['', 'title', 'tt5220122', '?ref_=bo_cso_table_199'],
#  ['', 'year', 'world', '2018', '?ref_=bo_cso_table_199'],
#  ['', 'title', 'tt3874544', '?ref_=bo_cso_table_200'],
#  ['', 'year', 'world', '2017', '?ref_=bo_cso_table_200'],
#  ['', 'news', '?ref_=bo_ft_cso_news'],
#  ['', 'daily', '?ref_=bo_ft_cso_daily'],
#  ['', 'weekend', '?ref_=bo_ft_cso_weekend'],
#  ['', 'charts', '?ref_=bo_ft_cso_charts'],
#  ['', 'intl', '?ref_=bo_ft_cso_intl'],
#  ['', 'showdown', '?ref_=bo_ft_cso_showdown'],
#  ['https:',
#   '',
#   'help.imdb.com',
#   'article',
#   'imdbpro',
#   'industry-research',
#   'box-office-mojo-by-imdbpro-faq',
#   'GCWTV4MQKGWRAUAP?ref_=mojo_ftr_help'],
#  ['http:', '', 'www.imdb.com', ''],
#  ['', 'conditions', '?ref_=bo_ft_cso_conditions'],
#  ['', 'privacy', '?ref_=bo_ft_cso_privacy']]

# %%
def find_tt(list_of_str):
    clean_list =[]
    for count,item in enumerate(list_of_str):
        if item[count][:2] == 'tt':
            clean_list.append(item)
    return clean_list
find_tt(mm)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-77-bc104d1b2334> in <module>
#       5             clean_list.append(item)
#       6     return clean_list
# ----> 7 find_tt(mm)
#
# <ipython-input-77-bc104d1b2334> in find_tt(list_of_str)
#       2     clean_list =[]
#       3     for count,item in enumerate(list_of_str):
# ----> 4         if item[count][:2] == 'tt':
#       5             clean_list.append(item)
#       6     return clean_list
#
# IndexError: list index out of range

# %%
title_id = soup.find("td", class_="a-link-normal")
print(title_id)
# Out:
# None

# %%
url = "https://www.boxofficemojo.com/chart/ww_top_lifetime_gross/?area=XWW&offset=200"
r = requests.get(url)
soup = bs(r.content, "html.parser")
print(soup.prettify)
# Out:
# <bound method Tag.prettify of <!DOCTYPE doctype html>
# <html class="a-no-js" data-19ax5a9jf="dingo"><head><script>var aPageStart = (new Date()).getTime();</script><meta charset="utf-8"/><meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <meta charset="utf-8"/>
# <title dir="ltr">Top Lifetime Grosses - Box Office Mojo</title><meta content="Top Lifetime Grosses" name="title"/>
# <meta content="Box Office Mojo" property="og:site_name"/>
# <meta content="telephone=no" name="format-detection"/>
# <link href="https://m.media-amazon.com/images/G/01/boxofficemojo/v2/favicon._CB448965889_.ico" rel="icon" type="image/x-icon"/>
# <link href="https://images-na.ssl-images-amazon.com/images/I/51tax7M48-L._RC|516fcOUE-HL.css,01evdoiemkL.css,01K+Ps1DeEL.css,31pdJv9iSzL.css,01VszOUTO6L.css,11UGC+GXOPL.css,21LK7jaicML.css,11L58Qpo0GL.css,21kyTi1FabL.css,01ruG+gDPFL.css,01YhS3Cs-hL.css,21GwE3cR-yL.css,019SHZnt8RL.css,01wAWQRgXzL.css,21bWcRJYNIL.css,11WgRxUdJRL.css,01dU8+SPlFL.css,11ocrgKoE-L.css,01SHjPML6tL.css,111-D2qRjiL.css,01QrWuRrZ-L.css,310Imb6LqFL.css,01piEq-AdwL.css,11Z1a0FxSIL.css,01cbS3UK11L.css,21mOLw+nYYL.css,01L8Y-JFEhL.css_.css?AUIClients/AmazonUI#us.not-trident" rel="stylesheet"/>
# <link href="https://images-na.ssl-images-amazon.com/images/I/41jxT1zINDL.css?AUIClients/IMDbMojoSiteAssets" rel="stylesheet"/>
# <script>
# (function(f,h,Q,A){function G(a){v&&v.tag&&v.tag(q(":","aui",a))}function x(a,b){v&&v.count&&v.count("aui:"+a,0===b?0:b||(v.count("aui:"+a)||0)+1)}function l(a){try{return a.test(navigator.userAgent)}catch(b){return!1}}function y(a,b,c){a.addEventListener?a.addEventListener(b,c,!1):a.attachEvent&&a.attachEvent("on"+b,c)}function q(a,b,c,e){b=b&&c?b+a+c:b||c;return e?q(a,b,e):b}function H(a,b,c){try{Object.defineProperty(a,b,{value:c,writable:!1})}catch(e){a[b]=c}return c}function ta(a,b){var c=a.length,
# e=c,g=function(){e--||(R.push(b),S||(setTimeout(T,0),S=!0))};for(g();c--;)ca[a[c]]?g():(B[a[c]]=B[a[c]]||[]).push(g)}function ua(a,b,c,e,g){var d=h.createElement(a?"script":"link");y(d,"error",e);g&&y(d,"load",g);a?(d.type="text/javascript",d.async=!0,c&&/AUIClients|images[/]I/.test(b)&&d.setAttribute("crossorigin","anonymous"),d.src=b):(d.rel="stylesheet",d.href=b);h.getElementsByTagName("head")[0].appendChild(d)}function da(a,b){function c(c,e){function g(){ua(b,c,h,function(b){!I&&h?(h=!1,x("resource_retry"),
# g()):(x("resource_error"),a.log("Asset failed to load: "+c,I?"WARN":A));b&&b.stopPropagation?b.stopPropagation():f.event&&(f.event.cancelBubble=!0)},e)}if(ea[c])return!1;ea[c]=!0;x("resource_count");var h=!0;return!g()}if(b){var e=0,g=0;c.andConfirm=function(a,b){return c(a,function(){e++;b&&b.apply(this,arguments)})};c.confirm=function(){g++};c.getCsriCounters=function(){return{reqs:e,full:g}}}return c}function va(a,b,c){for(var e={name:a,guard:function(c){return b.guardFatal(a,c)},logError:function(c,
# d,e){b.logError(c,d,e,a)}},g=[],d=0;d<c.length;d++)J.hasOwnProperty(c[d])&&(g[d]=U.hasOwnProperty(c[d])?U[c[d]](J[c[d]],e):J[c[d]]);return g}function C(a,b,c,e,g){return function(d,h){function m(){var a=null;e?a=h:"function"===typeof h&&(p.start=D(),a=h.apply(f,va(d,k,l)),p.end=D());if(b){J[d]=a;a=d;for(ca[a]=!0;(B[a]||[]).length;)B[a].shift()();delete B[a]}p.done=!0}var k=g||this;"function"===typeof d&&(h=d,d=A);b&&(d=d?d.replace(fa,""):"__NONAME__",V.hasOwnProperty(d)&&k.error(q(", reregistered by ",
# q(" by ",d+" already registered",V[d]),k.attribution),d),V[d]=k.attribution);for(var l=[],n=0;n<a.length;n++)l[n]=a[n].replace(fa,"");var p=ga[d||"anon"+ ++wa]={depend:l,registered:D(),namespace:k.namespace};c?m():ta(l,k.guardFatal(d,m));return{decorate:function(a){U[d]=k.guardFatal(d,a)}}}}function ha(a){return function(){var b=Array.prototype.slice.call(arguments);return{execute:C(b,!1,a,!1,this),register:C(b,!0,a,!1,this)}}}function W(a,b){return function(c,e){e||(e=c,c=A);var g=this.attribution;
# return function(){z.push(b||{attribution:g,name:c,logLevel:a});var d=e.apply(this,arguments);z.pop();return d}}}function K(a,b){this.load={js:da(this,!0),css:da(this)};H(this,"namespace",b);H(this,"attribution",a)}function ia(){h.body?p.trigger("a-bodyBegin"):setTimeout(ia,20)}function E(a,b){a.className=X(a,b)+" "+b}function X(a,b){return(" "+a.className+" ").split(" "+b+" ").join(" ").replace(/^ | $/g,"")}function ja(a){try{return a()}catch(b){return!1}}function L(){if(M){var a={w:f.innerWidth||
# m.clientWidth,h:f.innerHeight||m.clientHeight};5<Math.abs(a.w-Y.w)||50<a.h-Y.h?(Y=a,N=4,(a=k.mobile||k.tablet?450<a.w&&a.w>a.h:1250<=a.w)?E(m,"a-ws"):m.className=X(m,"a-ws")):0<N&&(N--,ka=setTimeout(L,16))}}function xa(a){(M=a===A?!M:!!a)&&L()}function ya(){return M}function r(a,b){return"sw:"+(b||"")+":"+a+":"}function la(){ma.forEach(function(a){G(a)})}function n(a){ma.push(a)}function na(a,b,c,e){if(c){b=l(/Chrome/i)&&!l(/Edge/i)&&!l(/OPR/i)&&!a.capabilities.isAmazonApp&&!l(new RegExp(Z+"bwv"+
# Z+"b"));var g=r(e,"browser"),d=r(e,"prod_mshop"),f=r(e,"beta_mshop");!a.capabilities.isAmazonApp&&c.browser&&b&&(n(g+"supported"),c.browser.action(g,e));!b&&c.browser&&n(g+"unsupported");c.prodMshop&&n(d+"unsupported");c.betaMshop&&n(f+"unsupported")}}"use strict";var O=Q.now=Q.now||function(){return+new Q},D=function(a){return a&&a.now?a.now.bind(a):O}(f.performance),za=D(),t=f.AmazonUIPageJS||f.P;if(t&&t.when&&t.register)throw Error("A copy of P has already been loaded on this page.");var v=f.ue;
# G();G("aui_build_date:3.20.1-2020-02-28");var R=[],S=!1,T;T=function(){for(var a=setTimeout(T,0),b=O();R.length;)if(R.shift()(),50<O()-b)return;clearTimeout(a);S=!1};var ca={},B={},ea={},I=!1;y(f,"beforeunload",function(){I=!0;setTimeout(function(){I=!1},1E4)});var fa=/^prv:/,V={},J={},U={},ga={},wa=0,Z=String.fromCharCode(92),F,z=[],oa=f.onerror;f.onerror=function(a,b,c,e,g){g&&"object"===typeof g||(g=Error(a,b,c),g.columnNumber=e,g.stack=b||c||e?q(Z,g.message,"at "+q(":",b,c,e)):A);var d=z.pop()||
# {};g.attribution=q(":",g.attribution||d.attribution,d.name);g.logLevel=d.logLevel;g.attribution&&console&&console.log&&console.log([g.logLevel||"ERROR",a,"thrown by",g.attribution].join(" "));z=[];oa&&(d=[].slice.call(arguments),d[4]=g,oa.apply(f,d))};K.prototype={logError:function(a,b,c,e){b={message:b,logLevel:c||"ERROR",attribution:q(":",this.attribution,e)};if(f.ueLogError)return f.ueLogError(a||b,a?b:null),!0;console&&console.error&&(console.log(b),console.error(a));return!1},error:function(a,
# b,c,e){a=Error(q(":",e,a,c));a.attribution=q(":",this.attribution,b);throw a;},guardError:W(),guardFatal:W("FATAL"),guardCurrent:function(a){var b=z[z.length-1];return b?W(b.logLevel,b).call(this,a):a},log:function(a,b,c){return this.logError(null,a,b,c)},declare:C([],!0,!0,!0),register:C([],!0),execute:C([]),AUI_BUILD_DATE:"3.20.1-2020-02-28",when:ha(),now:ha(!0),trigger:function(a,b,c){var e=O();this.declare(a,{data:b,pageElapsedTime:e-(f.aPageStart||NaN),triggerTime:e});c&&c.instrument&&F.when("prv:a-logTrigger").execute(function(b){b(a)})},
# handleTriggers:function(){this.log("handleTriggers deprecated")},attributeErrors:function(a){return new K(a)},_namespace:function(a,b){return new K(a,b)}};var p=H(f,"AmazonUIPageJS",new K);F=p._namespace("PageJS","AmazonUI");F.declare("prv:p-debug",ga);p.declare("p-recorder-events",[]);p.declare("p-recorder-stop",function(){});H(f,"P",p);ia();if(h.addEventListener){var pa;h.addEventListener("DOMContentLoaded",pa=function(){p.trigger("a-domready");h.removeEventListener("DOMContentLoaded",pa,!1)},!1)}var m=
# h.documentElement,aa=function(){var a=["O","ms","Moz","Webkit"],b=h.createElement("div");return{testGradients:function(){b.style.cssText="background-image:-webkit-gradient(linear,left top,right bottom,from(#1E4),to(white));background-image:-webkit-linear-gradient(left top,#1E4,white);background-image:linear-gradient(left top,#1E4,white);";return~b.style.backgroundImage.indexOf("gradient")},test:function(c){var e=c.charAt(0).toUpperCase()+c.substr(1);c=(a.join(e+" ")+e+" "+c).split(" ");for(e=c.length;e--;)if(""===
# b.style[c[e]])return!0;return!1},testTransform3d:function(){var a=!1;f.matchMedia&&(a=f.matchMedia("(-webkit-transform-3d)").matches);return a}}}(),t=m.className,qa=/(^| )a-mobile( |$)/.test(t),ra=/(^| )a-tablet( |$)/.test(t),k={audio:function(){return!!h.createElement("audio").canPlayType},video:function(){return!!h.createElement("video").canPlayType},canvas:function(){return!!h.createElement("canvas").getContext},svg:function(){return!!h.createElementNS&&!!h.createElementNS("http://www.w3.org/2000/svg",
# "svg").createSVGRect},offline:function(){return navigator.hasOwnProperty&&navigator.hasOwnProperty("onLine")&&navigator.onLine},dragDrop:function(){return"draggable"in h.createElement("span")},geolocation:function(){return!!navigator.geolocation},history:function(){return!(!f.history||!f.history.pushState)},webworker:function(){return!!f.Worker},autofocus:function(){return"autofocus"in h.createElement("input")},inputPlaceholder:function(){return"placeholder"in h.createElement("input")},textareaPlaceholder:function(){return"placeholder"in
# h.createElement("textarea")},localStorage:function(){return"localStorage"in f&&null!==f.localStorage},orientation:function(){return"orientation"in f},touch:function(){return"ontouchend"in h},gradients:function(){return aa.testGradients()},hires:function(){var a=f.devicePixelRatio&&1.5<=f.devicePixelRatio||f.matchMedia&&f.matchMedia("(min-resolution:144dpi)").matches;x("hiRes"+(qa?"Mobile":ra?"Tablet":"Desktop"),a?1:0);return a},transform3d:function(){return aa.testTransform3d()},touchScrolling:function(){return l(/Windowshop|android|OS ([5-9]|[1-9][0-9]+)(_[0-9]{1,2})+ like Mac OS X|Chrome|Silk|Firefox|Trident.+?; Touch/i)},
# ios:function(){return l(/OS [1-9][0-9]*(_[0-9]*)+ like Mac OS X/i)&&!l(/trident|Edge/i)},android:function(){return l(/android.([1-9]|[L-Z])/i)&&!l(/trident|Edge/i)},mobile:function(){return qa},tablet:function(){return ra},rtl:function(){return"rtl"===m.dir}},u;for(u in k)k.hasOwnProperty(u)&&(k[u]=ja(k[u]));for(var ba="textShadow textStroke boxShadow borderRadius borderImage opacity transform transition".split(" "),P=0;P<ba.length;P++)k[ba[P]]=ja(function(){return aa.test(ba[P])});var M=!0,ka=0,
# Y={w:0,h:0},N=4;L();y(f,"resize",function(){clearTimeout(ka);N=4;L()});var sa={getItem:function(a){try{return f.localStorage.getItem(a)}catch(b){}},setItem:function(a,b){try{return f.localStorage.setItem(a,b)}catch(c){}}};m.className=X(m,"a-no-js");E(m,"a-js");!l(/OS [1-8](_[0-9]*)+ like Mac OS X/i)||f.navigator.standalone||l(/safari/i)||E(m,"a-ember");t=[];for(u in k)k.hasOwnProperty(u)&&k[u]&&t.push("a-"+u.replace(/([A-Z])/g,function(a){return"-"+a.toLowerCase()}));E(m,t.join(" "));m.setAttribute("data-aui-build-date",
# "3.20.1-2020-02-28");p.register("p-detect",function(){return{capabilities:k,localStorage:k.localStorage&&sa,toggleResponsiveGrid:xa,responsiveGridEnabled:ya}});l(/UCBrowser/i)||k.localStorage&&E(m,sa.getItem("a-font-class"));p.declare("a-event-revised-handling",!1);var w;try{w=navigator.serviceWorker}catch(a){G("sw:nav_err")}w&&(y(w,"message",function(a){a&&a.data&&x(a.data.k,a.data.v)}),w.controller&&w.controller.postMessage("MSG-RDY"));var ma=[];(function(a){var b=a.reg,c=a.unreg;w&&w.getRegistrations?
# (F.when("A","a-util").execute(function(a,b){na(a,b,c,"unregister")}),y(f,"load",function(){F.when("A","a-util").execute(function(a,c){na(a,c,b,"register");la()})})):(b&&(b.browser&&n(r("register","browser")+"unsupported"),b.prodMshop&&n(r("register","prod_mshop")+"unsupported"),b.betaMshop&&n(r("register","beta_mshop")+"unsupported")),c&&(c.browser&&n(r("unregister","browser")+"unsupported"),c.prodMshop&&n(r("unregister","prod_mshop")+"unsupported"),c.betaMshop&&n(r("unregister","beta_mshop")+"unsupported")),
# la())})({reg:{},unreg:{}});p.declare("a-fix-event-off",!1);x("pagejs:pkgExecTime",D()-za)})(window,document,Date);
#   (window.AmazonUIPageJS ? AmazonUIPageJS : P).load.js('https://images-na.ssl-images-amazon.com/images/I/61-6nKPKyWL._RC|11-BZEJ8lnL.js,61GQ9IdK7HL.js,21Of0-9HPCL.js,012FVc3131L.js,11S5WBtBslL.js,51CF7BmbF2L.js,11AHlQhPRjL.js,016iHgpF74L.js,11aNYFFS5hL.js,116tgw9TSaL.js,211-p4GRUCL.js,01PoLXBDXWL.js,618UAEWDpaL.js,01ezj5Rkz1L.js,11BOgvnnntL.js,31UWuPgtTtL.js,01rpauTep4L.js,01iyxuSGj4L.js,01nZw0IOzSL.js_.js?AUIClients/AmazonUI');
#   (window.AmazonUIPageJS ? AmazonUIPageJS : P).load.js('https://images-na.ssl-images-amazon.com/images/I/51voyzpfdCL.js?AUIClients/IMDbMojoSiteAssets');
# </script>
# </head><body class="mojo-page-id-cso a-m-us a-aui_157141-c a-aui_72554-c a-aui_dropdown_187959-c a-aui_pci_risk_banner_210084-c a-aui_perf_130093-c a-aui_tnr_v2_180836-c a-aui_ux_145937-c" id="body"><div id="a-page"><script data-a-state='{"key":"a-wlab-states"}' type="a-state">{}</script><div class="a-section a-spacing-none mojo-navigation mojo-header mojo-flex mojo-flex-h"><div class="a-section mojo-logo"><a class="a-link-normal" href="/?ref_=bo_nb_cso_mojologo"></a></div><div class="a-section a-spacing-none mojo-nav-elements mojo-flex mojo-flex-h mojo-flex-1"><div class="a-section a-spacing-none mojo-search-bar mojo-flex mojo-flex-h"><div class="a-section a-spacing-none mojo-search"><form action="/search">
# <input id="mojo-search-text-input" name="q" placeholder="Search for Titles" required="true" type="search"/>
# <input class="mojo-inline-button" id="mojo-search-button" type="submit" value=""/>
# </form>
# </div></div><div class="a-section a-spacing-none mojo-mobile-options"><span class="a-declarative" data-a-popover='{"closeButton":"false","inlineContent":"\u003cspan class=\"a-size-medium\"&gt;\u003ca href=\"https://pro.imdb.com/?ref_=mojo_nb_cso_pro&amp;amp;rf=mojo_nb_cso_pro\" class=\"a-touch-link a-box a-touch-link-noborder\"&gt;\u003cdiv class=\"a-box-inner\"&gt;\u003ci class=\"a-icon a-icon-touch-link\"&gt;\u003c\/i&gt;IMDbPro\u003c\/div&gt;\u003c\/a&gt;\u003ca href=\"https://www.facebook.com/BoxOfficeMojo/\" class=\"a-touch-link a-box a-touch-link-noborder\"&gt;\u003cdiv class=\"a-box-inner\"&gt;\u003ci class=\"a-icon a-icon-touch-link\"&gt;\u003c\/i&gt;Facebook\u003c\/div&gt;\u003c\/a&gt;\u003ca href=\"https://twitter.com/boxofficemojo\" class=\"a-touch-link a-box a-touch-link-noborder\"&gt;\u003cdiv class=\"a-box-inner\"&gt;\u003ci class=\"a-icon a-icon-touch-link\"&gt;\u003c\/i&gt;Twitter\u003c\/div&gt;\u003c\/a&gt;\u003ca href=\"https://help.imdb.com/article/imdbpro/industry-research/box-office-mojo-by-imdbpro-faq/GCWTV4MQKGWRAUAP?ref_=mojo_ftr_help\" class=\"a-touch-link a-box a-touch-link-noborder\"&gt;\u003cdiv class=\"a-box-inner\"&gt;\u003ci class=\"a-icon a-icon-touch-link\"&gt;\u003c\/i&gt;Help\u003c\/div&gt;\u003c\/a&gt;\u003c\/span&gt;"}' data-action="a-popover"><a class="a-popover-trigger a-declarative" href="javascript:void(0)"><span class="mobile-menu-popover-trigger"></span>
# <i class="a-icon a-icon-popover"></i></a></span></div><div class="a-section a-spacing-none mojo-options mojo-flex"><div class="a-popover-preload" id="a-popover-mojoRollover"><a class="a-link-normal mojo-rollover-image" href="https://pro.imdb.com/login/ap?u=%2Flogin%2Flwa&amp;imdbPageAction=signUp&amp;ref_=mojo_nb_cso_rollover&amp;rf=mojo_nb_cso_rollover"><img alt="" src="https://m.media-amazon.com/images/G/01/IMDbPro/images/MI_121919_NYNY2020_Engagement_rollover_2x._CB1578336809_.png"/></a></div><span class="a-declarative" data-a-popover='{"padding":"none","closeButton":"false","dataStrategy":"preload","name":"mojoRollover","width":"500","position":"triggerBottom","height":"200"}' data-action="a-popover"><a class="a-popover-trigger a-declarative" href="javascript:void(0)"><span class="imdb-pro-logo"></span><i class="a-icon a-icon-popover"></i></a></span><span class="mojo-logo-delimiter"></span><a class="a-link-normal mojo-fb-logo" href="https://www.facebook.com/BoxOfficeMojo/" rel="noopener" target="_blank"></a><a class="a-link-normal mojo-tw-logo" href="https://twitter.com/boxofficemojo" rel="noopener" target="_blank"></a></div></div><div class="a-section a-spacing-none mojo-link-bar mojo-flex mojo-flex-h"><div class="a-section a-spacing-none mojo-tab-container"><a class="a-size-medium a-link-normal mojo-navigation-tab" href="/date/?ref_=bo_nb_cso_tab">Domestic</a><a class="a-size-medium a-link-normal mojo-navigation-tab" href="/intl/?ref_=bo_nb_cso_tab">International</a><a class="a-size-medium a-link-normal mojo-navigation-tab" href="/year/world/?ref_=bo_nb_cso_tab">Worldwide</a><a class="a-size-medium a-link-normal mojo-navigation-tab" href="/calendar/?ref_=bo_nb_cso_tab">Calendar</a><a class="a-size-medium a-link-normal mojo-navigation-tab mojo-navigation-tab-active" href="/charts/overall/?ref_=bo_nb_cso_tab">All Time</a><a class="a-size-medium a-link-normal mojo-navigation-tab" href="/showdown/?ref_=bo_nb_cso_tab">Showdowns</a><a class="a-size-medium a-link-normal mojo-navigation-tab" href="/news/?ref_=bo_nb_cso_tab">News</a></div></div><div class="a-section a-spacing-none mojo-link-bar-secondary mojo-flex mojo-flex-h"><div class="a-section a-spacing-base mojo-tab-container"><a class="a-size-medium a-link-normal mojo-navigation-tab mojo-navigation-tab-active" href="/charts/overall/?ref_=bo_nb_cso_secondarytab"><h2 class="a-size-medium a-text-normal">Overall</h2></a><a class="a-size-medium a-link-normal mojo-navigation-tab" href="/charts/weekend/?ref_=bo_nb_cso_secondarytab">Weekend Records</a><a class="a-size-medium a-link-normal mojo-navigation-tab" href="/charts/daily/?ref_=bo_nb_cso_secondarytab">Daily Records</a><a class="a-size-medium a-link-normal mojo-navigation-tab" href="/charts/misc/?ref_=bo_nb_cso_secondarytab">Miscellaneous Records</a></div></div><div class="a-section a-spacing-none mojo-link-bar-fade"><span class="a-letter-space"></span></div></div><main>
# <div class="a-section mojo-body aok-relative"><div class="a-section a-spacing-none"><h1 class="mojo-gutter">Top Lifetime Grosses</h1><div class="a-section mojo-gutter-sides"></div><div class="mojo-refiner mojo-override-gutter">
# <div class="mojo-refinement mojo-refinement-dropdown">
# <span class="mojo-dropdown-clear">
# <form action="" autocomplete="off" class="a-spacing-none" method="post"><span class="a-dropdown-container"><select autocomplete="off" class="a-native-dropdown" id="area-navSelector" name="area-navSelector" tabindex="-1"><option value="/chart/top_lifetime_gross/">Domestic</option><option selected="" value="/chart/ww_top_lifetime_gross/?area=XWW">Worldwide</option></select><span class="a-button a-button-dropdown" tabindex="-1"><span class="a-button-inner"><span aria-hidden="true" class="a-button-text a-declarative" data-action="a-dropdown-button" role="button" tabindex="0"><span class="a-dropdown-prompt"></span></span><i class="a-icon a-icon-dropdown"></i></span></span></span></form></span>
# </div>
# </div>
# <div class="a-text-center mojo-pagination"><ul class="a-pagination"><li><a href="/chart/ww_top_lifetime_gross/?area=XWW">←<span class="a-letter-space"></span><span class="a-letter-space"></span>Previous page</a></li><li class="a-selected mojo-pagination-button-center"><a href="#">201-400 of 1,000</a></li><li class="a-last"><a href="/chart/ww_top_lifetime_gross/?area=XWW&amp;offset=400">Next page<span class="a-letter-space"></span><span class="a-letter-space"></span>→</a></li></ul></div><style>
# table.a-bordered.mojo-body-table-compact td,
# table.a-bordered.mojo-body-table-compact th {
#     padding: 5px;
# }
# table.mojo-body-table tr.mojo-group-label th {
#     background: linear-gradient(to bottom, #f8f8f8, #eee);
# }
# </style>
# <div class="a-section imdb-scroll-table mojo-gutter-sides" id="table"><div class="a-section imdb-scroll-table-inner"><table class="a-bordered a-horizontal-stripes a-size-base a-span12 mojo-body-table mojo-table-annotated"><tr><th class="a-text-right mojo-field-type-rank a-nowrap"><span title="Rank">Rank</span>
# </th><th class="a-text-left mojo-field-type-title a-nowrap"><span title="Title">Title</span>
# </th><th class="a-text-right mojo-field-type-money a-nowrap"><span title="Worldwide Lifetime Gross">Worldwide Lifetime Gross</span>
# </th><th class="a-text-right mojo-field-type-money a-nowrap"><span title="Domestic Lifetime Gross">Domestic Lifetime Gross</span>
# </th><th class="a-text-right mojo-field-type-percent a-nowrap"><span title="Domestic %">Domestic %</span>
# </th><th class="a-text-right mojo-field-type-money a-nowrap"><span title="Foreign Lifetime Gross">Foreign Lifetime Gross</span>
# </th><th class="a-text-right mojo-field-type-percent a-nowrap"><span title="Foreign %">Foreign %</span>
# </th><th class="a-text-left mojo-field-type-year a-nowrap"><span title="Year">Year</span>
# </th></tr><tr><td class="a-text-right mojo-header-column mojo-truncate mojo-field-type-rank">201</td><td class="a-text-left mojo-field-type-title"><a class="a-link-normal" href="/title/tt5013056/?ref_=bo_cso_table_1">Dunkirk</a></td><td class="a-text-right mojo-field-type-money">$526,940,665</td><td class="a-text-right mojo-field-type-money">$189,740,665</td><td class="a-text-right mojo-field-type-percent">36%</td><td class="a-text-right mojo-field-type-money">$337,200,000</td><td class="a-text-right mojo-field-type-percent">64%</td><td class="a-text-left mojo-field-type-year"><a class="a-link-normal" href="/year/world/2017/?ref_=bo_cso_table_1">2017</a></td></tr><tr><td class="a-text-right mojo-header-column mojo-truncate mojo-field-type-rank">202</td><td class="a-text-left mojo-field-type-title"><a class="a-link-normal" href="/title/tt0831387/?ref_=bo_cso_table_2">Godzilla</a></td><td class="a-text-right mojo-field-type-money">$524,976,069</td><td class="a-text-right mojo-field-type-money">$200,676,069</td><td class="a-text-right mojo-field-type-percent">38.2%</td><td class="a-text-right mojo-field-type-money">$324,300,000</td><td class="a-text-right mojo-field-type-percent">61.8%</td><td class="a-text-left mojo-field-type-year"><a class="a-link-normal" href="/year/world/2014/?ref_=bo_cso_table_2">2014</a></td></tr><tr><td class="a-text-right mojo-header-column mojo-truncate mojo-field-type-rank">203</td><td class="a-text-left mojo-field-type-title"><a class="a-link-normal" href="/title/tt0988045/?ref_=bo_cso_table_3">Sherlock Holmes</a></td><td class="a-text-right mojo-field-type-money">$524,028,679</td><td class="a-text-right mojo-field-type-money">$209,028,679</td><td class="a-text-right mojo-field-type-percent">39.9%</td><td class="a-text-right mojo-field-type-money">$315,000,000</td><td class="a-text-right mojo-field-type-percent">60.1%</td><td class="a-text-left mojo-field-type-year"><a class="a-link-normal" href="/year/world/2009/?ref_=bo_cso_table_3">2009</a></td></tr><tr><td class="a-text-right mojo-header-column mojo-truncate mojo-field-type-rank">204</td><td class="a-text-left mojo-field-type-title"><a class="a-link-normal" href="/title/tt0290002/?ref_=bo_cso_table_4">Meet the Fockers</a></td><td class="a-text-right mojo-field-type-money">$522,657,936</td><td class="a-text-right mojo-field-type-money">$279,261,160</td><td class="a-text-right mojo-field-type-percent">53.4%</td><td class="a-text-right mojo-field-type-money">$243,396,776</td><td class="a-text-right mojo-field-type-percent">46.6%</td><td class="a-text-left mojo-field-type-year"><a class="a-link-normal" href="/year/world/2004/?ref_=bo_cso_table_4">2004</a></td></tr><tr><td class="a-text-right mojo-header-column mojo-truncate mojo-field-type-rank">205</td><td class="a-text-left mojo-field-type-title"><a class="a-link-normal" href="/title/tt2386490/?ref_=bo_cso_table_5">How to Train Your Dragon: The Hidden World</a></td><td class="a-text-right mojo-field-type-money">$521,799,505</td><td class="a-text-right mojo-field-type-money">$160,799,505</td><td class="a-text-right mojo-field-type-percent">30.8%</td><td class="a-text-right mojo-field-type-money">$361,000,000</td><td class="a-text-right mojo-field-type-percent">69.2%</td><td class="a-text-left mojo-field-type-year"><a class="a-link-normal" href="/year/world/2019/?ref_=bo_cso_table_5">2019</a></td></tr><tr><td class="a-text-right mojo-header-column mojo-truncate mojo-field-type-rank">206</td><td class="a-text-left mojo-field-type-title"><a class="a-link-normal" href="/title/tt0910970/?ref_=bo_cso_table_6">WALL·E</a></td><td class="a-text-right mojo-field-type-money">$521,311,860</td><td class="a-text-right mojo-field-type-money">$223,808,164</td><td class="a-text-right mojo-field-type-percent">42.9%</td><td class="a-text-right mojo-field-type-money">$297,503,696</td><td class="a-text-right mojo-field-type-percent">57.1%</td><td class="a-text-left mojo-field-type-year"><a class="a-link-normal" href="/ye ...
# <div class="a-section a-spacing-none mojo-navigation-frame"><div class="a-section a-spacing-none mojo-navigation mojo-footer"><a class="a-link-normal imdb-pro-logo" href="https://pro.imdb.com/?ref_=mojo_ft_cso_prologo&amp;rf=mojo_ft_cso_prologo"></a><p>
#             Latest Updates:
#             <a class="a-link-normal" href="/news/?ref_=bo_ft_cso_news">News</a> |
#             <a class="a-link-normal" href="/daily/?ref_=bo_ft_cso_daily">Daily</a> |
#             <a class="a-link-normal" href="/weekend/?ref_=bo_ft_cso_weekend">Weekend</a> |
#             <a class="a-link-normal" href="/charts/?ref_=bo_ft_cso_charts">All Time</a> |
#             <a class="a-link-normal" href="/intl/?ref_=bo_ft_cso_intl">International</a> |
#             <a class="a-link-normal" href="/showdown/?ref_=bo_ft_cso_showdown">Showdowns</a></p><p><a class="a-link-normal" href="https://help.imdb.com/article/imdbpro/industry-research/box-office-mojo-by-imdbpro-faq/GCWTV4MQKGWRAUAP?ref_=mojo_ftr_help" rel="noopener" target="_blank">Help</a></p><p>
#             BoxOfficeMojo.com by IMDbPro - an
#             <a class="a-link-normal" href="http://www.imdb.com/" rel="noopener" target="_blank">IMDb</a>
#             company.
#         </p><p>
#             © IMDb.com, Inc. or its affiliates. All rights reserved.
#             Box Office Mojo and IMDb are trademarks or registered trademarks of IMDb.com, Inc. or its affiliates.
#             <a class="a-link-normal" href="/conditions/?ref_=bo_ft_cso_conditions">Conditions of Use</a>
#              and
#              <a class="a-link-normal" href="/privacy/?ref_=bo_ft_cso_privacy">Privacy Policy</a>
#             under which this service is provided to you.
#         </p></div></div></div></body></html>>

# %%
movie_list2 = []
row_list = []
for record in soup.findAll("tr"):
    for data in record.findAll("td"):
        row_list.append(data.text)
    if row_list == []:
        pass
    else:
        movie_list2.append(row_list)
        row_list = []
movie_list2
# Out:
# [['201',
#   'Dunkirk',
#   '$526,940,665',
#   '$189,740,665',
#   '36%',
#   '$337,200,000',
#   '64%',
#   '2017'],
#  ['202',
#   'Godzilla',
#   '$524,976,069',
#   '$200,676,069',
#   '38.2%',
#   '$324,300,000',
#   '61.8%',
#   '2014'],
#  ['203',
#   'Sherlock Holmes',
#   '$524,028,679',
#   '$209,028,679',
#   '39.9%',
#   '$315,000,000',
#   '60.1%',
#   '2009'],
#  ['204',
#   'Meet the Fockers',
#   '$522,657,936',
#   '$279,261,160',
#   '53.4%',
#   '$243,396,776',
#   '46.6%',
#   '2004'],
#  ['205',
#   'How to Train Your Dragon: The Hidden World',
#   '$521,799,505',
#   '$160,799,505',
#   '30.8%',
#   '$361,000,000',
#   '69.2%',
#   '2019'],
#  ['206',
#   'WALL·E',
#   '$521,311,860',
#   '$223,808,164',
#   '42.9%',
#   '$297,503,696',
#   '57.1%',
#   '2008'],
#  ['207',
#   'Kung Fu Panda 3',
#   '$521,170,825',
#   '$143,528,619',
#   '27.5%',
#   '$377,642,206',
#   '72.5%',
#   '2016'],
#  ['208',
#   'Terminator 2: Judgment Day',
#   '$520,884,847',
#   '$205,881,154',
#   '39.5%',
#   '$315,003,693',
#   '60.5%',
#   '1991'],
#  ['209',
#   'Ant-Man',
#   '$519,311,965',
#   '$180,202,163',
#   '34.7%',
#   '$339,109,802',
#   '65.3%',
#   '2015'],
#  ['210',
#   "Dr. Seuss' The Grinch",
#   '$511,595,957',
#   '$270,620,950',
#   '52.9%',
#   '$240,975,007',
#   '47.1%',
#   '2018'],
#  ['211',
#   'Ghost',
#   '$505,809,505',
#   '$217,631,306',
#   '43%',
#   '$288,178,199',
#   '57%',
#   '1990'],
#  ['212',
#   'Aladdin',
#   '$504,050,219',
#   '$217,350,219',
#   '43.1%',
#   '$286,700,000',
#   '56.9%',
#   '1992'],
#  ['213',
#   'Rio 2',
#   '$498,781,117',
#   '$131,538,435',
#   '26.4%',
#   '$367,242,682',
#   '73.6%',
#   '2014'],
#  ['214',
#   'Troy',
#   '$497,409,852',
#   '$133,378,256',
#   '26.8%',
#   '$364,031,596',
#   '73.2%',
#   '2004'],
#  ['215',
#   'Toy Story 2',
#   '$497,374,776',
#   '$245,852,179',
#   '49.4%',
#   '$251,522,597',
#   '50.6%',
#   '1999'],
#  ['216',
#   'How to Train Your Dragon',
#   '$494,878,759',
#   '$217,581,231',
#   '44%',
#   '$277,297,528',
#   '56%',
#   '2010'],
#  ['217',
#   'Twister',
#   '$494,471,524',
#   '$241,721,524',
#   '48.9%',
#   '$252,750,000',
#   '51.1%',
#   '1996'],
#  ['218',
#   'Oz the Great and Powerful',
#   '$493,311,825',
#   '$234,911,825',
#   '47.6%',
#   '$258,400,000',
#   '52.4%',
#   '2013'],
#  ['219',
#   'Clash of the Titans',
#   '$493,214,993',
#   '$163,214,888',
#   '33.1%',
#   '$330,000,105',
#   '66.9%',
#   '2010'],
#  ['220',
#   'Maleficent: Mistress of Evil',
#   '$491,730,089',
#   '$113,929,605',
#   '23.2%',
#   '$377,800,484',
#   '76.8%',
#   '2019'],
#  ['221',
#   'War for the Planet of the Apes',
#   '$490,719,763',
#   '$146,880,162',
#   '29.9%',
#   '$343,839,601',
#   '70.1%',
#   '2017'],
#  ['222',
#   'Mr. & Mrs. Smith',
#   '$487,287,646',
#   '$186,336,279',
#   '38.2%',
#   '$300,951,367',
#   '61.8%',
#   '2005'],
#  ['223',
#   'Angels & Demons',
#   '$485,930,816',
#   '$133,375,846',
#   '27.4%',
#   '$352,554,970',
#   '72.6%',
#   '2009'],
#  ['224',
#   'Teenage Mutant Ninja Turtles',
#   '$485,004,754',
#   '$191,204,754',
#   '39.4%',
#   '$293,800,000',
#   '60.6%',
#   '2014'],
#  ['225',
#   'Bruce Almighty',
#   '$484,592,874',
#   '$242,829,261',
#   '50.1%',
#   '$241,763,613',
#   '49.9%',
#   '2003'],
#  ['226',
#   'Shrek',
#   '$484,409,218',
#   '$267,665,011',
#   '55.3%',
#   '$216,744,207',
#   '44.7%',
#   '2001'],
#  ['227',
#   'Rio',
#   '$483,866,518',
#   '$143,619,809',
#   '29.7%',
#   '$340,246,709',
#   '70.3%',
#   '2011'],
#  ['228',
#   'Saving Private Ryan',
#   '$482,349,603',
#   '$217,049,603',
#   '45%',
#   '$265,300,000',
#   '55%',
#   '1998'],
#  ['229',
#   'Rise of the Planet of the Apes',
#   '$481,800,873',
#   '$176,760,185',
#   '36.7%',
#   '$305,040,688',
#   '63.3%',
#   '2011'],
#  ['230',
#   'Home Alone',
#   '$477,063,114',
#   '$285,761,243',
#   '59.9%',
#   '$191,301,871',
#   '40.1%',
#   '1990'],
#  ['231',
#   'Star Wars: Episode VI - Return of the Jedi',
#   '$475,347,111',
#   '$309,306,177',
#   '65.1%',
#   '$166,040,934',
#   '34.9%',
#   '1983'],
#  ['232',
#   'Charlie and the Chocolate Factory',
#   '$474,968,763',
#   '$206,459,076',
#   '43.5%',
#   '$268,509,687',
#   '56.5%',
#   '2005'],
#  ['233',
#   'Hotel Transylvania 2',
#   '$474,800,000',
#   '$169,700,110',
#   '35.7%',
#   '$305,099,890',
#   '64.3%',
#   '2015'],
#  ['234',
#   'Indiana Jones and the Last Crusade',
#   '$474,310,887',
#   '$197,171,806',
#   '41.6%',
#   '$277,139,081',
#   '58.4%',
#   '1989'],
#  ['235',
#   'San Andreas',
#   '$473,990,832',
#   '$155,190,832',
#   '32.7%',
#   '$318,800,000',
#   '67.3%',
#   '2015'],
#  ['236',
#   'It Chapter Two',
#   '$473,093,228',
#   '$211,593,228',
#   '44.7%',
#   '$261,500,000',
#   '55.3%',
#   '2019'],
#  ['237',
#   'Wreck-It Ralph',
#   '$471,222,889',
#   '$189,422,889',
#   '40.2%',
#   '$281,800,000',
#   '59.8%',
#   '2012'],
#  ['238',
#   'Jaws',
#   '$471,203,004',
#   '$260,000,000',
#   '55.2%',
#   '$211,203,004',
#   '44.8%',
#   '1975'],
#  ['239',
#   'The Hangover',
#   '$469,310,836',
#   '$277,322,503',
#   '59.1%',
#   '$191,988,333',
#   '40.9%',
#   '2009'],
#  ['240',
#   'The Lego Movie',
#   '$468,060,692',
#   '$257,760,692',
#   '55.1%',
#   '$210,300,000',
#   '44.9%',
#   '2014'],
#  ['241',
#   'Bumblebee',
#   '$467,989,645',
#   '$127,195,589',
#   '27.2%',
#   '$340,794,056',
#   '72.8%',
#   '2018'],
#  ['242',
#   'Star Trek Into Darkness',
#   '$467,365,246',
#   '$228,778,661',
#   '49%',
#   '$238,586,585',
#   '51%',
#   '2013'],
#  ['243',
#   'The Matrix',
#   '$465,343,787',
#   '$171,479,930',
#   '36.8%',
#   '$293,863,857',
#   '63.2%',
#   '1999'],
#  ['244',
#   'Pretty Woman',
#   '$463,406,268',
#   '$178,406,268',
#   '38.5%',
#   '$285,000,000',
#   '61.5%',
#   '1990'],
#  ['245',
#   'Cars',
#   '$461,983,149',
#   '$244,082,982',
#   '52.8%',
#   '$217,900,167',
#   '47.2%',
#   '2006'],
#  ['246',
#   'Gladiator',
#   '$460,583,960',
#   '$187,705,427',
#   '40.8%',
#   '$272,878,533',
#   '59.2%',
#   '2000'],
#  ['247',
#   'X-Men: The Last Stand',
#   '$460,435,291',
#   '$234,362,462',
#   '50.9%',
#   '$226,072,829',
#   '49.1%',
#   '2006'],
#  ['248',
#   'National Treasure: Book of Secrets',
#   '$459,242,249',
#   '$219,964,115',
#   '47.9%',
#   '$239,278,134',
#   '52.1%',
#   '2007'],
#  ['249',
#   'Lucy',
#   '$458,863,600',
#   '$126,663,600',
#   '27.6%',
#   '$332,200,000',
#   '72.4%',
#   '2014'],
#  ['250',
#   'Mission: Impossible',
#   '$457,731,198',
#   '$180,981,856',
#   '39.5%',
#   '$276,749,342',
#   '60.5%',
#   '1996'],
#  ['251',
#   '300',
#   '$456,068,181',
#   '$210,614,939',
#   '46.2%',
#   '$245,453,242',
#   '53.8%',
#   '2007'],
#  ['252',
#   'The Last Samurai',
#   '$454,627,263',
#   '$111,127,263',
#   '24.4%',
#   '$343,500,000',
#   '75.6%',
#   '2003'],
#  ['253',
#   'Dying to Survive',
#   '$451,183,391',
#   '$6,752',
#   '-',
#   '$451,176,639',
#   '100%',
#   '2018'],
#  ['254',
#   "Ocean's Eleven",
#   '$450,717,150',
#   '$183,417,150',
#   '40.7%',
#   '$267,300,000',
#   '59.3%',
#   '2001'],
#  ['255',
#   'My People, My Country',
#   '$450,064,993',
#   '$2,356,683',
#   '0.5%',
#   '$447,708,310',
#   '99.5%',
#   '2019'],
#  ['256',
#   'Thor',
#   '$449,326,618',
#   '$181,030,624',
#   '40.3%',
#   '$268,295,994',
#   '59.7%',
#   '2011'],
#  ['257',
#   'Pearl Harbor',
#   '$449,220,945',
#   '$198,542,554',
#   '44.2%',
#   '$250,678,391',
#   '55.8%',
#   '2001'],
#  ['258',
#   'Tarzan',
#   '$448,191,819',
#   '$171,091,819',
#   '38.2%',
#   '$277,100,000',
#   '61.8%',
#   '1999'],
#  ['259',
#   'La La Land',
#   '$446,171,671',
#   '$151,101,803',
#   '33.9%',
#   '$295,069,868',
#   '66.1%',
#   '2016'],
#  ['260',
#   'Men in Black II',
#   '$445,135,288',
#   '$193,735,288',
#   '43.5%',
#   '$251,400,000',
#   '56.5%',
#   '2002'],
#  ['261',
#   'The Bourne Ultimatum',
#   '$444,100,035',
#   '$227,471,070',
#   '51.2%',
#   '$216,628,965',
#   '48.8%',
#   '2007'],
#  ['262',
#   'The Mummy Returns',
#   '$443,280,904',
#   '$202,019,785',
#   '45.6%',
#   '$241,261,119',
#   '54.4%',
#   '2001'],
#  ['263',
#   'Alvin and the Chipmunks: The Squeakquel',
#   '$443,140,005',
#   '$219,614,612',
#   '49.6%',
#   '$223,525,393',
#   '50.4%',
#   '2009'],
#  ['264',
#   'Les Misérables',
#   '$441,809,770',
#   '$148,809,770',
#   '33.7%',
#   '$293,000,000',
#   '66.3%',
#   '2012'],
#  ['265',
#   'The Exorcist',
#   '$441,306,145',
#   '$232,906,145',
#   '52.8%',
#   '$208,400,000',
#   '47.2%',
#   '1973'],
#  ['266',
#   'Mrs. Doubtfire',
#   '$441,286,195',
#   '$219,195,243',
#   '49.7%',
#   '$222,090,952',
#   '50.3%',
#   '1993'],
#  ['267',
#   'Terminator Genisys',
#   '$440,603,537',
#   '$89,760,956',
#   '20.4%',
#   '$350,842,581',
#   '79.6%',
#   '2015'],
#  ['268',
#   'Beauty and the Beast',
#   '$440,118,382',
#   '$218,967,620',
#   '49.8%',
#   '$221,150,762',
#   '50.2%',
#   '1991'],
#  ['269',
#   'Warcraft',
#   '$439,048,914',
#   '$47,365,290',
#   '10.8%',
#   '$391,683,624',
#   '89.2%',
#   '2016'],
#  ['270',
#   'A Star Is Born',
#   '$436,188,866',
#   '$215,288,866',
#   '49.4%',
#   '$220,900,000',
#   '50.6%',
#   '2018'],
#  ['271',
#   'The Greatest Showman',
#   '$434,993,183',
#   '$174,340,174',
#   '40.1%',
#   '$260,653,009',
#   '59.9%',
#   '2017'],
#  ['272',
#   'Terminator 3: Rise of the Machines',
#   '$433,371,112',
#   '$150,371,112',
#   '34.7%',
#   '$283,000,000',
#   '65.3%',
#   '2003'],
#  ['273',
#   'Pokémon Detective Pikachu',
#   '$433,005,346',
#   '$144,105,346',
#   '33.3%',
#   '$288,900,000',
#   '66.7%',
#   '2019'],
#  ['274',
#   'Die Another Day',
#   '$431,971,116',
#   '$160,942,139',
#   '37.3%',
#   '$271,028,977',
#   '62.7%',
#   '2002'],
#  ['275',
#   'The Secret Life of Pets 2',
#   '$430,051,293',
#   '$158,874,395',
#   '36.9%',
#   '$271,176,898',
#   '63.1%',
#   '2019'],
#  ['276',
#   'Cast Away',
#   '$429,632,142',
#   '$233,632,142',
#   '54.4%',
#   '$196,000,000',
#   '45.6%',
#   '2000'],
#  ['277',
#   'Rampage',
#   '$428,028,233',
#   '$101,028,233',
#   '23.6%',
#   '$327,000,000',
#   '76.4%',
#   '2018'],
#  ['278',
#   "The King's Speech",
#   '$427,374,317',
#   '$138,797,449',
#   '32.5%',
#   '$288,576,868',
#   '67.5%',
#   '2010'],
#  ['279',
#   'The Matrix Revolutions',
#   '$427,344,031',
#   '$139,313,948',
#   '32.6%',
#   '$288,030,083',
#   '67.4%',
#   '2003'],
#  ['280',
#   'The Intouchables',
#   '$426,588,510',
#   '$10,198,820',
#   '2.4%',
#   '$416,389,690',
#   '97.6%',
#   '2011'],
#  ['281',
#   'Django Unchained',
#   '$425,368,238',
#   '$162,805,434',
#   '38.3%',
#   '$262,562,804',
#   '61.7%',
#   '2012'],
#  ['282',
#   'Dances with Wolves',
#   '$424,208,848',
#   '$184,208,848',
#   '43.4%',
#   '$240,000,000',
#   '56.6%',
#   '1990'],
#  ['283',
#   'The Chronicles of Narnia: Prince Caspian',
#   '$419,665,568',
#   '$141,621,490',
#   '33.8%',
#   '$278,044,078',
#   '66.2%',
#   '2008'],
#  ['284',
#   'Sex and the City',
#   '$418,765,321',
#   '$152,647,258',
#   '36.4%',
#   '$266,118,063',
#   '63.6%',
#   '2008'],
#  ['285',
#   'The Captain',
#   '$416,953,262',
#   '$706,572',
#   '0.2%',
#   '$416,246,690',
#   '99.8%',
#   '2019'],
#  ['286',
#   'The Mummy',
#   '$415,933,406',
#   '$155,385,488',
#   '37.4%',
#   '$260,547,918',
#   '62.6%',
#   '1999'],
#  ['287',
#   'The Chronicles of Narnia: The Voyage of the Dawn Treader',
#   '$415,686,217',
#   '$104,386,950',
#   '25.1%',
#   '$311,299,267',
#   '74.9%',
#   '2010'],
#  ['288',
#   'Jason Bourne',
#   '$415,484,914',
#   '$162,434,410',
#   '39.1%',
#   '$253,050,504',
#   '60.9%',
#   '2016'],
#  ['289',
#   'The Wolverine',
#   '$414,828,246',
#   '$132,556,852',
#   '32%',
#   '$282,271,394',
#   '68%',
#   '2013'],
#  ['290',
#   'Kingsman: The Secret Service',
#   '$414,351,546',
#   '$128,261,724',
#   '31%',
#   '$286,089,822',
#   '69%',
#   '2015'],
#  ['291',
#   'Night at the Museum: Battle of the Smithsonian',
#   '$413,106,170',
#   '$177,243,721',
#   '42.9%',
#   '$235,862,449',
#   '57.1%',
#   '2009'],
#  ['292',
#   'Batman',
#   '$411,556,825',
#   '$251,348,343',
#   '61.1%',
#   '$160,208,482',
#   '38.9%',
#   '1989'],
#  ['293',
#   'The Bodyguard',
#   '$411,006,740',
#   '$122,006,740',
#   '29.7%',
#   '$289,000,000',
#   '70.3%',
#   '1992'],
#  ['294',
#   'Pacific Rim',
#   '$411,002,906',
#   '$101,802,906',
#   '24.8%',
#   '$309,200,000',
#   '75.2%',
#   '2013'],
#  ['295',
#   'Kingsman: The Golden Circle',
#   '$410,902,662',
#   '$100,234,838',
#   '24.4%',
#   '$310,667,824',
#   '75.6%',
#   '2017'],
#  ['296',
#   'The Mummy',
#   '$409,231,607',
#   '$80,227,895',
#   '19.6%',
#   '$329,003,712',
#   '80.4%',
#   '2017'],
#  ['297',
#   'Ice Age: Collision Course',
#   '$408,579,038',
#   '$64,063,008',
#   '15.7%',
#   '$344,516,030',
#   '84.3%',
#   '2016'],
#  ['298',
#   'Twilight',
#   '$408,424,673',
#   '$193,962,473',
#   '47.5%',
#   '$214,462,200',
#   '52.5%',
#   '2008'],
#  ['299',
#   'Signs',
#   '$408,247,917',
#   '$227,966,634',
#   '55.8%',
#   '$180,281,283',
#   '44.2%',
#   '2002'],
#  ['300',
#   'X2: X-Men United',
#   '$407,711,549',
#   '$214,949,694',
#   '52.7%',
#   '$192,761,855',
#   '47.3%',
#   '2003'],
#  ['301',
#   'Bad Boys for Life',
#   '$405,418,519',
#   '$197,418,519',
#   '48.7%',
#   '$208,000,000',
#   '51.3%',
#   '2020'],
#  ['302',
#   'Alita: Battle Angel',
#   '$404,852,543',
#   '$85,710,210',
#   '21.2%',
#   '$319,142,333',
#   '78.8%',
#   '2019'],
#  ['303',
#   'Toy Story',
#   '$404,265,438',
#   '$222,498,679',
#   '55%',
#   '$181,766,759',
#   '45%',
#   '1995'],
#  ['304',
#   'The Mummy: Tomb of the Dragon Emperor',
#   '$403,449,830',
#   '$102,491,776',
#   '25.4%',
#   '$300,958,054',
#   '74.6%',
#   '2008'],
#  ['305',
#   'Prometheus',
#   '$403,354,469',
#   '$126,477,084',
#   '31.4%',
#   '$276,877,385',
#   '68.6%',
#   '2012'],
#  ['306',
#   'Gone with the Wind',
#   '$402,352,579',
#   '$200,852,579',
#   '49.9%',
#   '$201,500,000',
#   '50.1%',
#   '1939'],
#  ['307',
#   'TRON: Legacy',
#   '$400,062,763',
#   '$172,062,763',
#   '43%',
#   '$228,000,000',
#   '57%',
#   '2010'],
#  ['308',
#   'Mission: Impossible III',
#   '$398,479,497',
#   '$134,029,801',
#   '33.6%',
#   '$264,449,696',
#   '66.4%',
#   '2005'],
#  ['309',
#   'Grease',
#   '$396,961,563',
#   '$189,969,103',
#   '47.9%',
#   '$206,992,460',
#   '52.1%',
#   '1978'],
#  ['310',
#   'Snow White and the Huntsman',
#   '$396,592,829',
#   '$155,332,381',
#   '39.2%',
#   '$241,260,448',
#   '60.8%',
#   '2012'],
#  ['311',
#   'Mamma Mia! Here We Go Again',
#   '$395,044,706',
#   '$120,634,935',
#   '30.5%',
#   '$274,409,771',
#   '69.5%',
#   '2018'],
#  ['312',
#   'Solo: A Star Wars Story',
#   '$392,924,807',
#   '$213,767,512',
#   '54.4%',
#   '$179,157,295',
#   '45.6%',
#   '2018'],
#  ['313',
#   'The Wolf of Wall Street',
#   '$392,000,694',
#   '$116,900,694',
#   '29.8%',
#   '$275,100,000',
#   '70.2%',
#   '2013'],
#  ['314',
#   'Superman Returns',
#   '$391,081,192',
#   '$200,081,192',
#   '51.2%',
#   '$191,000,000',
#   '48.8%',
#   '2006'],
#  ['315',
#   'Robin Hood: Prince of Thieves',
#   '$390,493,908',
#   '$165,493,908',
#   '42.4%',
#   '$225,000,000',
#   '57.6%',
#   '1991'],
#  ['316',
#   'Raiders of the Lost Ark',
#   '$390,133,212',
#   '$248,159,971',
#   '63.6%',
#   '$141,973,241',
#   '36.4%',
#   '1981'],
#  ['317',
#   'Independence Day: Resurgence',
#   '$389,681,935',
#   '$103,144,286',
#   '26.5%',
#   '$286,537,649',
#   '73.5%',
#   '2016'],
#  ['318',
#   'Back to the Future',
#   '$388,355,305',
#   '$211,159,762',
#   '54.4%',
#   '$177,195,543',
#   '45.6%',
#   '1985'],
#  ['319',
#   'Live Free or Die Hard',
#   '$388,156,011',
#   '$134,529,403',
#   '34.7%',
#   '$253,626,608',
#   '65.3%',
#   '2007'],
#  ['320',
#   'Monster Hunt',
#   '$387,053,506',
#   '$32,766',
#   '<0.1%',
#   '$387,020,740',
#   '100%',
#   '2015'],
#  ['321',
#   'Godzilla: King of the Monsters',
#   '$386,600,138',
#   '$110,500,138',
#   '28.6%',
#   '$276,100,000',
#   '71.4%',
#   '2019'],
#  ['322',
#   'Home',
#   '$386,041,607',
#   '$177,397,510',
#   '46%',
#   '$208,644,097',
#   '54%',
#   '2015'],
#  ['323',
#   'Star Trek',
#   '$385,680,446',
#   '$257,730,019',
#   '66.8%',
#   '$127,950,427',
#   '33.2%',
#   '2009'],
#  ['324',
#   'Happy Feet',
#   '$384,335,608',
#   '$198,000,317',
#   '51.5%',
#   '$186,335,291',
#   '48.5%',
#   '2006'],
#  ['325',
#   'Cars 3',
#   '$383,930,656',
#   '$152,901,115',
#   '39.8%',
#   '$231,029,541',
#   '60.2%',
#   '2017'],
#  ['326',
#   'Ice Age',
#   '$383,257,136',
#   '$176,387,405',
#   '46%',
#   '$206,869,731',
#   '54%',
#   '2002'],
#  ['327',
#   'Fifty Shades Darker',
#   '$381,545,846',
#   '$114,581,250',
#   '30%',
#   '$266,964,596',
#   '70%',
#   '2017'],
#  ['328',
#   'Monsters vs. Aliens',
#   '$381,509,870',
#   '$198,351,526',
#   '52%',
#   '$183,158,344',
#   '48%',
#   '2009'],
#  ['329',
#   'Godzilla',
#   '$379,014,294',
#   '$136,314,294',
#   '36%',
#   '$242,700,000',
#   '64%',
#   '1998'],
#  ['330',
#   'True Lies',
#   '$378,882,411',
#   '$146,282,411',
#   '38.6%',
#   '$232,600,000',
#   '61.4%',
#   '1994'],
#  ['331',
#   'Slumdog Millionaire',
#   '$378,060,798',
#   '$141,319,928',
#   '37.4%',
#   '$236,740,870',
#   '62.6%',
#   '2008'],
#  ['332',
#   'Taken 2',
#   '$376,141,306',
#   '$139,854,287',
#   '37.2%',
#   '$236,287,019',
#   '62.8%',
#   '2012'],
#  ['333',
#   'G.I. Joe: Retaliation',
#   '$375,740,705',
#   '$122,523,060',
#   '32.6%',
#   '$253,217,645',
#   '67.4%',
#   '2013'],
#  ['334',
#   'Spider-Man: Into the Spider-Verse',
#   '$375,540,831',
#   '$190,241,310',
#   '50.7%',
#   '$185,299,521',
#   '49.3%',
#   '2018'],
#  ['335',
#   'Mad Max: Fury Road',
#   '$375,209,362',
#   '$154,058,340',
#   '41.1%',
#   '$221,151,022',
#   '58.9%',
#   '2015'],
#  ['336',
#   'Shark Tale',
#   '$374,583,879',
#   '$160,861,908',
#   '42.9%',
#   '$213,721,971',
#   '57.1%',
#   '2004'],
#  ['337',
#   'Once Upon a Time... in Hollywood',
#   '$374,341,301',
#   '$142,502,728',
#   '38.1%',
#   '$231,838,573',
#   '61.9%',
#   '2019'],
#  ['338',
#   'What Women Want',
#   '$374,111,707',
#   '$182,811,707',
#   '48.9%',
#   '$191,300,000',
#   '51.1%',
#   '2000'],
#  ['339',
#   'The Adventures of Tintin',
#   '$373,993,951',
#   '$77,591,831',
#   '20.8%',
#   '$296,402,120',
#   '79.2%',
#   '2011'],
#  ['340',
#   'Penguins of Madagascar',
#   '$373,515,621',
#   '$83,850,911',
#   '22.4%',
#   '$289,664,710',
#   '77.6%',
#   '2014'],
#  ['341',
#   'Batman Begins',
#   '$373,413,297',
#   '$206,852,432',
#   '55.4%',
#   '$166,560,865',
#   '44.6%',
#   '2005'],
#  ['342',
#   'X-Men Origins: Wolverine',
#   '$373,062,864',
#   '$179,883,157',
#   '48.2%',
#   '$193,179,707',
#   '51.8%',
#   '2009'],
#  ['343',
#   'The Golden Compass',
#   '$372,234,864',
#   '$70,107,728',
#   '18.8%',
#   '$302,127,136',
#   '81.2%',
#   '2007'],
#  ['344',
#   'Fifty Shades Freed',
#   '$371,985,018',
#   '$100,407,760',
#   '27%',
#   '$271,577,258',
#   '73%',
#   '2018'],
#  ['345',
#   'Hitch',
#   '$371,594,210',
#   '$179,495,555',
#   '48.3%',
#   '$192,098,655',
#   '51.7%',
#   '2005'],
#  ['346',
#   'Terminator Salvation',
#   '$371,353,001',
#   '$125,322,469',
#   '33.8%',
#   '$246,030,532',
#   '66.2%',
#   '2009'],
#  ['347',
#   'Captain America: The First Avenger',
#   '$370,569,774',
#   '$176,654,505',
#   '47.7%',
#   '$193,915,269',
#   '52.3%',
#   '2011'],
#  ['348',
#   'Edge of Tomorrow',
#   '$370,541,256',
#   '$100,206,256',
#   '27%',
#   '$270,335,000',
#   '73%',
#   '2014'],
#  ['349',
#   "There's Something About Mary",
#   '$369,884,651',
#   '$176,484,651',
#   '47.7%',
#   '$193,400,000',
#   '52.3%',
#   '1998'],
#  ['350',
#   'Gone Girl',
#   '$369,330,363',
#   '$167,767,189',
#   '45.4%',
#   '$201,563,174',
#   '54.6%',
#   '2014'],
#  ['351',
#   'The Fugitive',
#   '$368,875,760',
#   '$183,875,760',
#   '49.8%',
#   '$185,000,000',
#   '50.2%',
#   '1993'],
#  ['352',
#   'Jurassic Park III',
#   '$368,780,809',
#   '$181,171,875',
#   '49.1%',
#   '$187,608,934',
#   '50.9%',
#   '2001'],
#  ['353',
#   'My Big Fat Greek Wedding',
#   '$368,744,044',
#   '$241,438,208',
#   '65.5%',
#   '$127,305,836',
#   '34.5%',
#   '2002'],
#  ['355',
#   'Die Hard with a Vengeance',
#   '$366,236,538',
#   '$100,012,499',
#   '27.3%',
#   '$266,224,039',
#   '72.7%',
#   '1995'],
#  ['356',
#   'Shazam!',
#   '$365,971,656',
#   '$140,371,656',
#   '38.4%',
#   '$225,600,000',
#   '61.6%',
#   '2019'],
#  ['357',
#   'The Nun',
#   '$365,550,119',
#   '$117,450,119',
#   '32.1%',
#   '$248,100,000',
#   '67.9%',
#   '2018'],
#  ['358',
#   'Alvin and the Chipmunks',
#   '$365,352,546',
#   '$217,326,974',
#   '59.5%',
#   '$148,025,572',
#   '40.5%',
#   '2007'],
#  ['359',
#   'Home Alone 2: Lost in New York',
#   '$365,154,932',
#   '$173,585,516',
#   '47.5%',
#   '$191,569,416',
#   '52.5%',
#   '1992'],
#  ['360',
#   'Notting Hill',
#   '$363,944,522',
#   '$116,089,678',
#   '31.9%',
#   '$247,854,844',
#   '68.1%',
#   '1999'],
#  ['361',
#   "A Bug's Life",
#   '$363,258,859',
#   '$162,798,565',
#   '44.8%',
#   '$200,460,294',
#   '55.2%',
#   '1998'],
#  ['362',
#   'Night at the Museum: Secret of the Tomb',
#   '$363,204,635',
#   '$113,746,621',
#   '31.3%',
#   '$249,458,014',
#   '68.7%',
#   '2014'],
#  ['363',
#   "Ocean's Twelve",
#   '$362,744,280',
#   '$125,544,280',
#   '34.6%',
#   '$237,200,000',
#   '65.4%',
#   '2004'],
#  ['364',
#   '1917',
#   '$362,407,149',
#   '$155,907,149',
#   '43%',
#   '$206,500,000',
#   '57%',
#   '2019'],
#  ['365',
#   'Planet of the Apes',
#   '$362,211,740',
#   '$180,011,740',
#   '49.7%',
#   '$182,200,000',
#   '50.3%',
#   '2001'],
#  ['366',
#   'The Hangover Part III',
#   '$362,000,072',
#   '$112,200,072',
#   '31%',
#   '$249,800,000',
#   '69%',
#   '2013'],
#  ['367',
#   'The World Is Not Enough',
#   '$361,832,400',
#   '$126,943,684',
#   '35.1%',
#   '$234,888,716',
#   '64.9%',
#   '1999'],
#  ['368',
#   'Monster Hunt 2',
#   '$361,682,618',
#   '$706,153',
#   '0.2%',
#   '$360,976,465',
#   '99.8%',
#   '2018'],
#  ['369',
#   'Fast & Furious',
#   '$360,364,265',
#   '$155,064,265',
#   '43%',
#   '$205,300,000',
#   '57%',
#   '2009'],
#  ['370',
#   'Noah',
#   '$359,200,044',
#   '$101,200,044',
#   '28.2%',
#   '$258,000,000',
#   '71.8%',
#   '2014'],
#  ['371',
#   'The Karate Kid',
#   '$359,126,022',
#   '$176,591,618',
#   '49.2%',
#   '$182,534,404',
#   '50.8%',
#   '2010'],
#  ['372',
#   'Your Name.',
#   '$358,922,706',
#   '$5,017,246',
#   '1.4%',
#   '$353,905,460',
#   '98.6%',
#   '2016'],
#  ['373',
#   'Hotel Transylvania',
#   '$358,375,603',
#   '$148,313,048',
#   '41.4%',
#   '$210,062,555',
#   '58.6%',
#   '2011'],
#  ['374',
#   'Minority Report',
#   '$358,372,926',
#   '$132,072,926',
#   '36.8%',
#   '$226,300,000',
#   '63.2%',
#   '2002'],
#  ['375',
#   'Top Gun',
#   '$356,830,601',
#   '$179,800,601',
#   '50.4%',
#   '$177,030,000',
#   '49.6%',
#   '1986'],
#  ['376',
#   'The Legend of Tarzan',
#   '$356,700,357',
#   '$126,643,061',
#   '35.5%',
#   '$230,057,296',
#   '64.5%',
#   '2016'],
#  ['377',
#   'American Beauty',
#   '$356,296,601',
#   '$130,096,601',
#   '36.5%',
#   '$226,200,000',
#   '63.5%',
#   '1999'],
#  ['378',
#   'Apollo 13',
#   '$355,237,933',
#   '$173,837,933',
#   '48.9%',
#   '$181,400,000',
#   '51.1%',
#   '1995'],
#  ['379',
#   'Rain Man',
#   '$354,825,435',
#   '$172,825,435',
#   '48.7%',
#   '$182,000,000',
#   '51.3%',
#   '1988'],
#  ['380',
#   'The Great Gatsby',
#   '$353,641,895',
#   '$144,840,419',
#   '41%',
#   '$208,801,476',
#   '59%',
#   '2013'],
#  ['381',
#   'Dumbo',
#   '$353,284,621',
#   '$114,766,307',
#   '32.5%',
#   '$238,518,314',
#   '67.5%',
#   '2019'],
#  ['382',
#   'I, Robot',
#   '$353,133,898',
#   '$144,801,023',
#   '41%',
#   '$208,332,875',
#   '59%',
#   '2004'],
#  ['383',
#   'Basic Instinct',
#   '$352,927,224',
#   '$117,727,224',
#   '33.4%',
#   '$235,200,000',
#   '66.6%',
#   '1992'],
#  ['384',
#   'Murder on the Orient Express',
#   '$352,789,811',
#   '$102,826,543',
#   '29.2%',
#   '$249,963,268',
#   '70.8%',
#   '2017'],
#  ['385',
#   'X-Men: First Class',
#   '$352,616,690',
#   '$146,408,305',
#   '41.5%',
#   '$206,208,385',
#   '58.5%',
#   '2011'],
#  ['386',
#   'The Angry Birds Movie',
#   '$352,333,929',
#   '$107,509,366',
#   '30.5%',
#   '$244,824,563',
#   '69.5%',
#   '2016'],
#  ['387',
#   'GoldenEye',
#   '$352,194,034',
#   '$106,429,941',
#   '30.2%',
#   '$245,764,093',
#   '69.8%',
#   '1995'],
#  ['388',
#   'Catch Me If You Can',
#   '$352,114,312',
#   '$164,615,351',
#   '46.8%',
#   '$187,498,961',
#   '53.2%',
#   '2002'],
#  ['389',
#   'Now You See Me',
#   '$351,723,989',
#   '$117,723,989',
#   '33.5%',
#   '$234,000,000',
#   '66.5%',
#   '2013'],
#  ['390',
#   'Hannibal',
#   '$351,692,268',
#   '$165,092,268',
#   '46.9%',
#   '$186,600,000',
#   '53.1%',
#   '2001'],
#  ['391',
#   'The Mask',
#   '$351,583,407',
#   '$119,938,730',
#   '34.1%',
#   '$231,644,677',
#   '65.9%',
#   '1994'],
#  ['392',
#   'Peter Rabbit',
#   '$351,266,433',
#   '$115,253,424',
#   '32.8%',
#   '$236,013,009',
#   '67.2%',
#   '2018'],
#  ['393',
#   'Speed',
#   '$350,448,145',
#   '$121,248,145',
#   '34.6%',
#   '$229,200,000',
#   '65.4%',
#   '1994'],
#  ['394',
#   'Dinosaur',
#   '$349,822,765',
#   '$137,748,063',
#   '39.4%',
#   '$212,074,702',
#   '60.6%',
#   '2000'],
#  ['395',
#   'Mary Poppins Returns',
#   '$349,537,494',
#   '$171,958,438',
#   '49.2%',
#   '$177,579,056',
#   '50.8%',
#   '2018'],
#  ['396',
#   'Deep Impact',
#   '$349,464,664',
#   '$140,464,664',
#   '40.2%',
#   '$209,000,000',
#   '59.8%',
#   '1998'],
#  ['397',
#   'The Lorax',
#   '$348,840,316',
#   '$214,030,500',
#   '61.4%',
#   '$134,809,816',
#   '38.6%',
#   '2012'],
#  ['398',
#   'The Maze Runner',
#   '$348,319,861',
#   '$102,427,862',
#   '29.4%',
#   '$245,891,999',
#   '70.6%',
#   '2014'],
#  ['399',
#   'Spirited Away',
#   '$347,742,810',
#   '$13,750,644',
#   '4%',
#   '$333,992,166',
#   '96%',
#   '2001'],
#  ['400',
#   'The Smurfs 2',
#   '$347,545,360',
#   '$71,017,784',
#   '20.4%',
#   '$276,527,576',
#   '79.6%',
#   '2013'],
#  ['401',
#   'National Treasure',
#   '$347,512,318',
#   '$173,008,894',
#   '49.8%',
#   '$174,503,424',
#   '50.2%',
#   '2004']]

# %%
url = "https://www.boxofficemojo.com/chart/ww_top_lifetime_gross/?offset=400&area=XWW"
r = requests.get(url)
soup = bs(r.content, "html.parser")
print(soup.prettify)
# Out:
# <bound method Tag.prettify of <!DOCTYPE doctype html>
# <html class="a-no-js" data-19ax5a9jf="dingo"><head><script>var aPageStart = (new Date()).getTime();</script><meta charset="utf-8"/><meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <meta charset="utf-8"/>
# <title dir="ltr">Top Lifetime Grosses - Box Office Mojo</title><meta content="Top Lifetime Grosses" name="title"/>
# <meta content="Box Office Mojo" property="og:site_name"/>
# <meta content="telephone=no" name="format-detection"/>
# <link href="https://m.media-amazon.com/images/G/01/boxofficemojo/v2/favicon._CB448965889_.ico" rel="icon" type="image/x-icon"/>
# <link href="https://images-na.ssl-images-amazon.com/images/I/51tax7M48-L._RC|516fcOUE-HL.css,01evdoiemkL.css,01K+Ps1DeEL.css,31pdJv9iSzL.css,01VszOUTO6L.css,11UGC+GXOPL.css,21LK7jaicML.css,11L58Qpo0GL.css,21kyTi1FabL.css,01ruG+gDPFL.css,01YhS3Cs-hL.css,21GwE3cR-yL.css,019SHZnt8RL.css,01wAWQRgXzL.css,21bWcRJYNIL.css,11WgRxUdJRL.css,01dU8+SPlFL.css,11ocrgKoE-L.css,01SHjPML6tL.css,111-D2qRjiL.css,01QrWuRrZ-L.css,310Imb6LqFL.css,01piEq-AdwL.css,11Z1a0FxSIL.css,01cbS3UK11L.css,21mOLw+nYYL.css,01L8Y-JFEhL.css_.css?AUIClients/AmazonUI#us.not-trident" rel="stylesheet"/>
# <link href="https://images-na.ssl-images-amazon.com/images/I/41jxT1zINDL.css?AUIClients/IMDbMojoSiteAssets" rel="stylesheet"/>
# <script>
# (function(f,h,Q,A){function G(a){v&&v.tag&&v.tag(q(":","aui",a))}function x(a,b){v&&v.count&&v.count("aui:"+a,0===b?0:b||(v.count("aui:"+a)||0)+1)}function l(a){try{return a.test(navigator.userAgent)}catch(b){return!1}}function y(a,b,c){a.addEventListener?a.addEventListener(b,c,!1):a.attachEvent&&a.attachEvent("on"+b,c)}function q(a,b,c,e){b=b&&c?b+a+c:b||c;return e?q(a,b,e):b}function H(a,b,c){try{Object.defineProperty(a,b,{value:c,writable:!1})}catch(e){a[b]=c}return c}function ta(a,b){var c=a.length,
# e=c,g=function(){e--||(R.push(b),S||(setTimeout(T,0),S=!0))};for(g();c--;)ca[a[c]]?g():(B[a[c]]=B[a[c]]||[]).push(g)}function ua(a,b,c,e,g){var d=h.createElement(a?"script":"link");y(d,"error",e);g&&y(d,"load",g);a?(d.type="text/javascript",d.async=!0,c&&/AUIClients|images[/]I/.test(b)&&d.setAttribute("crossorigin","anonymous"),d.src=b):(d.rel="stylesheet",d.href=b);h.getElementsByTagName("head")[0].appendChild(d)}function da(a,b){function c(c,e){function g(){ua(b,c,h,function(b){!I&&h?(h=!1,x("resource_retry"),
# g()):(x("resource_error"),a.log("Asset failed to load: "+c,I?"WARN":A));b&&b.stopPropagation?b.stopPropagation():f.event&&(f.event.cancelBubble=!0)},e)}if(ea[c])return!1;ea[c]=!0;x("resource_count");var h=!0;return!g()}if(b){var e=0,g=0;c.andConfirm=function(a,b){return c(a,function(){e++;b&&b.apply(this,arguments)})};c.confirm=function(){g++};c.getCsriCounters=function(){return{reqs:e,full:g}}}return c}function va(a,b,c){for(var e={name:a,guard:function(c){return b.guardFatal(a,c)},logError:function(c,
# d,e){b.logError(c,d,e,a)}},g=[],d=0;d<c.length;d++)J.hasOwnProperty(c[d])&&(g[d]=U.hasOwnProperty(c[d])?U[c[d]](J[c[d]],e):J[c[d]]);return g}function C(a,b,c,e,g){return function(d,h){function m(){var a=null;e?a=h:"function"===typeof h&&(p.start=D(),a=h.apply(f,va(d,k,l)),p.end=D());if(b){J[d]=a;a=d;for(ca[a]=!0;(B[a]||[]).length;)B[a].shift()();delete B[a]}p.done=!0}var k=g||this;"function"===typeof d&&(h=d,d=A);b&&(d=d?d.replace(fa,""):"__NONAME__",V.hasOwnProperty(d)&&k.error(q(", reregistered by ",
# q(" by ",d+" already registered",V[d]),k.attribution),d),V[d]=k.attribution);for(var l=[],n=0;n<a.length;n++)l[n]=a[n].replace(fa,"");var p=ga[d||"anon"+ ++wa]={depend:l,registered:D(),namespace:k.namespace};c?m():ta(l,k.guardFatal(d,m));return{decorate:function(a){U[d]=k.guardFatal(d,a)}}}}function ha(a){return function(){var b=Array.prototype.slice.call(arguments);return{execute:C(b,!1,a,!1,this),register:C(b,!0,a,!1,this)}}}function W(a,b){return function(c,e){e||(e=c,c=A);var g=this.attribution;
# return function(){z.push(b||{attribution:g,name:c,logLevel:a});var d=e.apply(this,arguments);z.pop();return d}}}function K(a,b){this.load={js:da(this,!0),css:da(this)};H(this,"namespace",b);H(this,"attribution",a)}function ia(){h.body?p.trigger("a-bodyBegin"):setTimeout(ia,20)}function E(a,b){a.className=X(a,b)+" "+b}function X(a,b){return(" "+a.className+" ").split(" "+b+" ").join(" ").replace(/^ | $/g,"")}function ja(a){try{return a()}catch(b){return!1}}function L(){if(M){var a={w:f.innerWidth||
# m.clientWidth,h:f.innerHeight||m.clientHeight};5<Math.abs(a.w-Y.w)||50<a.h-Y.h?(Y=a,N=4,(a=k.mobile||k.tablet?450<a.w&&a.w>a.h:1250<=a.w)?E(m,"a-ws"):m.className=X(m,"a-ws")):0<N&&(N--,ka=setTimeout(L,16))}}function xa(a){(M=a===A?!M:!!a)&&L()}function ya(){return M}function r(a,b){return"sw:"+(b||"")+":"+a+":"}function la(){ma.forEach(function(a){G(a)})}function n(a){ma.push(a)}function na(a,b,c,e){if(c){b=l(/Chrome/i)&&!l(/Edge/i)&&!l(/OPR/i)&&!a.capabilities.isAmazonApp&&!l(new RegExp(Z+"bwv"+
# Z+"b"));var g=r(e,"browser"),d=r(e,"prod_mshop"),f=r(e,"beta_mshop");!a.capabilities.isAmazonApp&&c.browser&&b&&(n(g+"supported"),c.browser.action(g,e));!b&&c.browser&&n(g+"unsupported");c.prodMshop&&n(d+"unsupported");c.betaMshop&&n(f+"unsupported")}}"use strict";var O=Q.now=Q.now||function(){return+new Q},D=function(a){return a&&a.now?a.now.bind(a):O}(f.performance),za=D(),t=f.AmazonUIPageJS||f.P;if(t&&t.when&&t.register)throw Error("A copy of P has already been loaded on this page.");var v=f.ue;
# G();G("aui_build_date:3.20.1-2020-02-28");var R=[],S=!1,T;T=function(){for(var a=setTimeout(T,0),b=O();R.length;)if(R.shift()(),50<O()-b)return;clearTimeout(a);S=!1};var ca={},B={},ea={},I=!1;y(f,"beforeunload",function(){I=!0;setTimeout(function(){I=!1},1E4)});var fa=/^prv:/,V={},J={},U={},ga={},wa=0,Z=String.fromCharCode(92),F,z=[],oa=f.onerror;f.onerror=function(a,b,c,e,g){g&&"object"===typeof g||(g=Error(a,b,c),g.columnNumber=e,g.stack=b||c||e?q(Z,g.message,"at "+q(":",b,c,e)):A);var d=z.pop()||
# {};g.attribution=q(":",g.attribution||d.attribution,d.name);g.logLevel=d.logLevel;g.attribution&&console&&console.log&&console.log([g.logLevel||"ERROR",a,"thrown by",g.attribution].join(" "));z=[];oa&&(d=[].slice.call(arguments),d[4]=g,oa.apply(f,d))};K.prototype={logError:function(a,b,c,e){b={message:b,logLevel:c||"ERROR",attribution:q(":",this.attribution,e)};if(f.ueLogError)return f.ueLogError(a||b,a?b:null),!0;console&&console.error&&(console.log(b),console.error(a));return!1},error:function(a,
# b,c,e){a=Error(q(":",e,a,c));a.attribution=q(":",this.attribution,b);throw a;},guardError:W(),guardFatal:W("FATAL"),guardCurrent:function(a){var b=z[z.length-1];return b?W(b.logLevel,b).call(this,a):a},log:function(a,b,c){return this.logError(null,a,b,c)},declare:C([],!0,!0,!0),register:C([],!0),execute:C([]),AUI_BUILD_DATE:"3.20.1-2020-02-28",when:ha(),now:ha(!0),trigger:function(a,b,c){var e=O();this.declare(a,{data:b,pageElapsedTime:e-(f.aPageStart||NaN),triggerTime:e});c&&c.instrument&&F.when("prv:a-logTrigger").execute(function(b){b(a)})},
# handleTriggers:function(){this.log("handleTriggers deprecated")},attributeErrors:function(a){return new K(a)},_namespace:function(a,b){return new K(a,b)}};var p=H(f,"AmazonUIPageJS",new K);F=p._namespace("PageJS","AmazonUI");F.declare("prv:p-debug",ga);p.declare("p-recorder-events",[]);p.declare("p-recorder-stop",function(){});H(f,"P",p);ia();if(h.addEventListener){var pa;h.addEventListener("DOMContentLoaded",pa=function(){p.trigger("a-domready");h.removeEventListener("DOMContentLoaded",pa,!1)},!1)}var m=
# h.documentElement,aa=function(){var a=["O","ms","Moz","Webkit"],b=h.createElement("div");return{testGradients:function(){b.style.cssText="background-image:-webkit-gradient(linear,left top,right bottom,from(#1E4),to(white));background-image:-webkit-linear-gradient(left top,#1E4,white);background-image:linear-gradient(left top,#1E4,white);";return~b.style.backgroundImage.indexOf("gradient")},test:function(c){var e=c.charAt(0).toUpperCase()+c.substr(1);c=(a.join(e+" ")+e+" "+c).split(" ");for(e=c.length;e--;)if(""===
# b.style[c[e]])return!0;return!1},testTransform3d:function(){var a=!1;f.matchMedia&&(a=f.matchMedia("(-webkit-transform-3d)").matches);return a}}}(),t=m.className,qa=/(^| )a-mobile( |$)/.test(t),ra=/(^| )a-tablet( |$)/.test(t),k={audio:function(){return!!h.createElement("audio").canPlayType},video:function(){return!!h.createElement("video").canPlayType},canvas:function(){return!!h.createElement("canvas").getContext},svg:function(){return!!h.createElementNS&&!!h.createElementNS("http://www.w3.org/2000/svg",
# "svg").createSVGRect},offline:function(){return navigator.hasOwnProperty&&navigator.hasOwnProperty("onLine")&&navigator.onLine},dragDrop:function(){return"draggable"in h.createElement("span")},geolocation:function(){return!!navigator.geolocation},history:function(){return!(!f.history||!f.history.pushState)},webworker:function(){return!!f.Worker},autofocus:function(){return"autofocus"in h.createElement("input")},inputPlaceholder:function(){return"placeholder"in h.createElement("input")},textareaPlaceholder:function(){return"placeholder"in
# h.createElement("textarea")},localStorage:function(){return"localStorage"in f&&null!==f.localStorage},orientation:function(){return"orientation"in f},touch:function(){return"ontouchend"in h},gradients:function(){return aa.testGradients()},hires:function(){var a=f.devicePixelRatio&&1.5<=f.devicePixelRatio||f.matchMedia&&f.matchMedia("(min-resolution:144dpi)").matches;x("hiRes"+(qa?"Mobile":ra?"Tablet":"Desktop"),a?1:0);return a},transform3d:function(){return aa.testTransform3d()},touchScrolling:function(){return l(/Windowshop|android|OS ([5-9]|[1-9][0-9]+)(_[0-9]{1,2})+ like Mac OS X|Chrome|Silk|Firefox|Trident.+?; Touch/i)},
# ios:function(){return l(/OS [1-9][0-9]*(_[0-9]*)+ like Mac OS X/i)&&!l(/trident|Edge/i)},android:function(){return l(/android.([1-9]|[L-Z])/i)&&!l(/trident|Edge/i)},mobile:function(){return qa},tablet:function(){return ra},rtl:function(){return"rtl"===m.dir}},u;for(u in k)k.hasOwnProperty(u)&&(k[u]=ja(k[u]));for(var ba="textShadow textStroke boxShadow borderRadius borderImage opacity transform transition".split(" "),P=0;P<ba.length;P++)k[ba[P]]=ja(function(){return aa.test(ba[P])});var M=!0,ka=0,
# Y={w:0,h:0},N=4;L();y(f,"resize",function(){clearTimeout(ka);N=4;L()});var sa={getItem:function(a){try{return f.localStorage.getItem(a)}catch(b){}},setItem:function(a,b){try{return f.localStorage.setItem(a,b)}catch(c){}}};m.className=X(m,"a-no-js");E(m,"a-js");!l(/OS [1-8](_[0-9]*)+ like Mac OS X/i)||f.navigator.standalone||l(/safari/i)||E(m,"a-ember");t=[];for(u in k)k.hasOwnProperty(u)&&k[u]&&t.push("a-"+u.replace(/([A-Z])/g,function(a){return"-"+a.toLowerCase()}));E(m,t.join(" "));m.setAttribute("data-aui-build-date",
# "3.20.1-2020-02-28");p.register("p-detect",function(){return{capabilities:k,localStorage:k.localStorage&&sa,toggleResponsiveGrid:xa,responsiveGridEnabled:ya}});l(/UCBrowser/i)||k.localStorage&&E(m,sa.getItem("a-font-class"));p.declare("a-event-revised-handling",!1);var w;try{w=navigator.serviceWorker}catch(a){G("sw:nav_err")}w&&(y(w,"message",function(a){a&&a.data&&x(a.data.k,a.data.v)}),w.controller&&w.controller.postMessage("MSG-RDY"));var ma=[];(function(a){var b=a.reg,c=a.unreg;w&&w.getRegistrations?
# (F.when("A","a-util").execute(function(a,b){na(a,b,c,"unregister")}),y(f,"load",function(){F.when("A","a-util").execute(function(a,c){na(a,c,b,"register");la()})})):(b&&(b.browser&&n(r("register","browser")+"unsupported"),b.prodMshop&&n(r("register","prod_mshop")+"unsupported"),b.betaMshop&&n(r("register","beta_mshop")+"unsupported")),c&&(c.browser&&n(r("unregister","browser")+"unsupported"),c.prodMshop&&n(r("unregister","prod_mshop")+"unsupported"),c.betaMshop&&n(r("unregister","beta_mshop")+"unsupported")),
# la())})({reg:{},unreg:{}});p.declare("a-fix-event-off",!1);x("pagejs:pkgExecTime",D()-za)})(window,document,Date);
#   (window.AmazonUIPageJS ? AmazonUIPageJS : P).load.js('https://images-na.ssl-images-amazon.com/images/I/61-6nKPKyWL._RC|11-BZEJ8lnL.js,61GQ9IdK7HL.js,21Of0-9HPCL.js,012FVc3131L.js,11S5WBtBslL.js,51CF7BmbF2L.js,11AHlQhPRjL.js,016iHgpF74L.js,11aNYFFS5hL.js,116tgw9TSaL.js,211-p4GRUCL.js,01PoLXBDXWL.js,618UAEWDpaL.js,01ezj5Rkz1L.js,11BOgvnnntL.js,31UWuPgtTtL.js,01rpauTep4L.js,01iyxuSGj4L.js,01nZw0IOzSL.js_.js?AUIClients/AmazonUI');
#   (window.AmazonUIPageJS ? AmazonUIPageJS : P).load.js('https://images-na.ssl-images-amazon.com/images/I/51voyzpfdCL.js?AUIClients/IMDbMojoSiteAssets');
# </script>
# </head><body class="mojo-page-id-cso a-m-us a-aui_157141-c a-aui_72554-c a-aui_dropdown_187959-c a-aui_pci_risk_banner_210084-c a-aui_perf_130093-c a-aui_tnr_v2_180836-c a-aui_ux_145937-c" id="body"><div id="a-page"><script data-a-state='{"key":"a-wlab-states"}' type="a-state">{}</script><div class="a-section a-spacing-none mojo-navigation mojo-header mojo-flex mojo-flex-h"><div class="a-section mojo-logo"><a class="a-link-normal" href="/?ref_=bo_nb_cso_mojologo"></a></div><div class="a-section a-spacing-none mojo-nav-elements mojo-flex mojo-flex-h mojo-flex-1"><div class="a-section a-spacing-none mojo-search-bar mojo-flex mojo-flex-h"><div class="a-section a-spacing-none mojo-search"><form action="/search">
# <input id="mojo-search-text-input" name="q" placeholder="Search for Titles" required="true" type="search"/>
# <input class="mojo-inline-button" id="mojo-search-button" type="submit" value=""/>
# </form>
# </div></div><div class="a-section a-spacing-none mojo-mobile-options"><span class="a-declarative" data-a-popover='{"closeButton":"false","inlineContent":"\u003cspan class=\"a-size-medium\"&gt;\u003ca href=\"https://pro.imdb.com/?ref_=mojo_nb_cso_pro&amp;amp;rf=mojo_nb_cso_pro\" class=\"a-touch-link a-box a-touch-link-noborder\"&gt;\u003cdiv class=\"a-box-inner\"&gt;\u003ci class=\"a-icon a-icon-touch-link\"&gt;\u003c\/i&gt;IMDbPro\u003c\/div&gt;\u003c\/a&gt;\u003ca href=\"https://www.facebook.com/BoxOfficeMojo/\" class=\"a-touch-link a-box a-touch-link-noborder\"&gt;\u003cdiv class=\"a-box-inner\"&gt;\u003ci class=\"a-icon a-icon-touch-link\"&gt;\u003c\/i&gt;Facebook\u003c\/div&gt;\u003c\/a&gt;\u003ca href=\"https://twitter.com/boxofficemojo\" class=\"a-touch-link a-box a-touch-link-noborder\"&gt;\u003cdiv class=\"a-box-inner\"&gt;\u003ci class=\"a-icon a-icon-touch-link\"&gt;\u003c\/i&gt;Twitter\u003c\/div&gt;\u003c\/a&gt;\u003ca href=\"https://help.imdb.com/article/imdbpro/industry-research/box-office-mojo-by-imdbpro-faq/GCWTV4MQKGWRAUAP?ref_=mojo_ftr_help\" class=\"a-touch-link a-box a-touch-link-noborder\"&gt;\u003cdiv class=\"a-box-inner\"&gt;\u003ci class=\"a-icon a-icon-touch-link\"&gt;\u003c\/i&gt;Help\u003c\/div&gt;\u003c\/a&gt;\u003c\/span&gt;"}' data-action="a-popover"><a class="a-popover-trigger a-declarative" href="javascript:void(0)"><span class="mobile-menu-popover-trigger"></span>
# <i class="a-icon a-icon-popover"></i></a></span></div><div class="a-section a-spacing-none mojo-options mojo-flex"><div class="a-popover-preload" id="a-popover-mojoRollover"><a class="a-link-normal mojo-rollover-image" href="https://pro.imdb.com/login/ap?u=%2Flogin%2Flwa&amp;imdbPageAction=signUp&amp;ref_=mojo_nb_cso_rollover&amp;rf=mojo_nb_cso_rollover"><img alt="" src="https://m.media-amazon.com/images/G/01/IMDbPro/images/MI_121919_NYNY2020_Engagement_rollover_2x._CB1578336809_.png"/></a></div><span class="a-declarative" data-a-popover='{"padding":"none","closeButton":"false","dataStrategy":"preload","name":"mojoRollover","width":"500","position":"triggerBottom","height":"200"}' data-action="a-popover"><a class="a-popover-trigger a-declarative" href="javascript:void(0)"><span class="imdb-pro-logo"></span><i class="a-icon a-icon-popover"></i></a></span><span class="mojo-logo-delimiter"></span><a class="a-link-normal mojo-fb-logo" href="https://www.facebook.com/BoxOfficeMojo/" rel="noopener" target="_blank"></a><a class="a-link-normal mojo-tw-logo" href="https://twitter.com/boxofficemojo" rel="noopener" target="_blank"></a></div></div><div class="a-section a-spacing-none mojo-link-bar mojo-flex mojo-flex-h"><div class="a-section a-spacing-none mojo-tab-container"><a class="a-size-medium a-link-normal mojo-navigation-tab" href="/date/?ref_=bo_nb_cso_tab">Domestic</a><a class="a-size-medium a-link-normal mojo-navigation-tab" href="/intl/?ref_=bo_nb_cso_tab">International</a><a class="a-size-medium a-link-normal mojo-navigation-tab" href="/year/world/?ref_=bo_nb_cso_tab">Worldwide</a><a class="a-size-medium a-link-normal mojo-navigation-tab" href="/calendar/?ref_=bo_nb_cso_tab">Calendar</a><a class="a-size-medium a-link-normal mojo-navigation-tab mojo-navigation-tab-active" href="/charts/overall/?ref_=bo_nb_cso_tab">All Time</a><a class="a-size-medium a-link-normal mojo-navigation-tab" href="/showdown/?ref_=bo_nb_cso_tab">Showdowns</a><a class="a-size-medium a-link-normal mojo-navigation-tab" href="/news/?ref_=bo_nb_cso_tab">News</a></div></div><div class="a-section a-spacing-none mojo-link-bar-secondary mojo-flex mojo-flex-h"><div class="a-section a-spacing-base mojo-tab-container"><a class="a-size-medium a-link-normal mojo-navigation-tab mojo-navigation-tab-active" href="/charts/overall/?ref_=bo_nb_cso_secondarytab"><h2 class="a-size-medium a-text-normal">Overall</h2></a><a class="a-size-medium a-link-normal mojo-navigation-tab" href="/charts/weekend/?ref_=bo_nb_cso_secondarytab">Weekend Records</a><a class="a-size-medium a-link-normal mojo-navigation-tab" href="/charts/daily/?ref_=bo_nb_cso_secondarytab">Daily Records</a><a class="a-size-medium a-link-normal mojo-navigation-tab" href="/charts/misc/?ref_=bo_nb_cso_secondarytab">Miscellaneous Records</a></div></div><div class="a-section a-spacing-none mojo-link-bar-fade"><span class="a-letter-space"></span></div></div><main>
# <div class="a-section mojo-body aok-relative"><div class="a-section a-spacing-none"><h1 class="mojo-gutter">Top Lifetime Grosses</h1><div class="a-section mojo-gutter-sides"></div><div class="mojo-refiner mojo-override-gutter">
# <div class="mojo-refinement mojo-refinement-dropdown">
# <span class="mojo-dropdown-clear">
# <form action="" autocomplete="off" class="a-spacing-none" method="post"><span class="a-dropdown-container"><select autocomplete="off" class="a-native-dropdown" id="area-navSelector" name="area-navSelector" tabindex="-1"><option value="/chart/top_lifetime_gross/">Domestic</option><option selected="" value="/chart/ww_top_lifetime_gross/?area=XWW">Worldwide</option></select><span class="a-button a-button-dropdown" tabindex="-1"><span class="a-button-inner"><span aria-hidden="true" class="a-button-text a-declarative" data-action="a-dropdown-button" role="button" tabindex="0"><span class="a-dropdown-prompt"></span></span><i class="a-icon a-icon-dropdown"></i></span></span></span></form></span>
# </div>
# </div>
# <div class="a-text-center mojo-pagination"><ul class="a-pagination"><li><a href="/chart/ww_top_lifetime_gross/?offset=200&amp;area=XWW">←<span class="a-letter-space"></span><span class="a-letter-space"></span>Previous page</a></li><li class="a-selected mojo-pagination-button-center"><a href="#">401-600 of 1,000</a></li><li class="a-last"><a href="/chart/ww_top_lifetime_gross/?offset=600&amp;area=XWW">Next page<span class="a-letter-space"></span><span class="a-letter-space"></span>→</a></li></ul></div><style>
# table.a-bordered.mojo-body-table-compact td,
# table.a-bordered.mojo-body-table-compact th {
#     padding: 5px;
# }
# table.mojo-body-table tr.mojo-group-label th {
#     background: linear-gradient(to bottom, #f8f8f8, #eee);
# }
# </style>
# <div class="a-section imdb-scroll-table mojo-gutter-sides" id="table"><div class="a-section imdb-scroll-table-inner"><table class="a-bordered a-horizontal-stripes a-size-base a-span12 mojo-body-table mojo-table-annotated"><tr><th class="a-text-right mojo-field-type-rank a-nowrap"><span title="Rank">Rank</span>
# </th><th class="a-text-left mojo-field-type-title a-nowrap"><span title="Title">Title</span>
# </th><th class="a-text-right mojo-field-type-money a-nowrap"><span title="Worldwide Lifetime Gross">Worldwide Lifetime Gross</span>
# </th><th class="a-text-right mojo-field-type-money a-nowrap"><span title="Domestic Lifetime Gross">Domestic Lifetime Gross</span>
# </th><th class="a-text-right mojo-field-type-percent a-nowrap"><span title="Domestic %">Domestic %</span>
# </th><th class="a-text-right mojo-field-type-money a-nowrap"><span title="Foreign Lifetime Gross">Foreign Lifetime Gross</span>
# </th><th class="a-text-right mojo-field-type-percent a-nowrap"><span title="Foreign %">Foreign %</span>
# </th><th class="a-text-left mojo-field-type-year a-nowrap"><span title="Year">Year</span>
# </th></tr><tr><td class="a-text-right mojo-header-column mojo-truncate mojo-field-type-rank">402</td><td class="a-text-left mojo-field-type-title"><a class="a-link-normal" href="/title/tt0266915/?ref_=bo_cso_table_1">Rush Hour 2</a></td><td class="a-text-right mojo-field-type-money">$347,325,802</td><td class="a-text-right mojo-field-type-money">$226,164,286</td><td class="a-text-right mojo-field-type-percent">65.1%</td><td class="a-text-right mojo-field-type-money">$121,161,516</td><td class="a-text-right mojo-field-type-percent">34.9%</td><td class="a-text-left mojo-field-type-year"><a class="a-link-normal" href="/year/world/2001/?ref_=bo_cso_table_1">2001</a></td></tr><tr><td class="a-text-right mojo-header-column mojo-truncate mojo-field-type-rank">403</td><td class="a-text-left mojo-field-type-title"><a class="a-link-normal" href="/title/tt1679335/?ref_=bo_cso_table_2">Trolls</a></td><td class="a-text-right mojo-field-type-money">$346,864,462</td><td class="a-text-right mojo-field-type-money">$153,707,064</td><td class="a-text-right mojo-field-type-percent">44.3%</td><td class="a-text-right mojo-field-type-money">$193,157,398</td><td class="a-text-right mojo-field-type-percent">55.7%</td><td class="a-text-left mojo-field-type-year"><a class="a-link-normal" href="/year/world/2016/?ref_=bo_cso_table_2">2016</a></td></tr><tr><td class="a-text-right mojo-header-column mojo-truncate mojo-field-type-rank">404</td><td class="a-text-left mojo-field-type-title"><a class="a-link-normal" href="/title/tt1293847/?ref_=bo_cso_table_3">xXx: Return of Xander Cage</a></td><td class="a-text-right mojo-field-type-money">$346,118,277</td><td class="a-text-right mojo-field-type-money">$44,898,413</td><td class="a-text-right mojo-field-type-percent">13%</td><td class="a-text-right mojo-field-type-money">$301,219,864</td><td class="a-text-right mojo-field-type-percent">87%</td><td class="a-text-left mojo-field-type-year"><a class="a-link-normal" href="/year/world/2017/?ref_=bo_cso_table_3">2017</a></td></tr><tr><td class="a-text-right mojo-header-column mojo-truncate mojo-field-type-rank">405</td><td class="a-text-left mojo-field-type-title"><a class="a-link-normal" href="/title/tt0114148/?ref_=bo_cso_table_4">Pocahontas</a></td><td class="a-text-right mojo-field-type-money">$346,079,773</td><td class="a-text-right mojo-field-type-money">$141,579,773</td><td class="a-text-right mojo-field-type-percent">40.9%</td><td class="a-text-right mojo-field-type-money">$204,500,000</td><td class="a-text-right mojo-field-type-percent">59.1%</td><td class="a-text-left mojo-field-type-year"><a class="a-link-normal" href="/year/world/1995/?ref_=bo_cso_table_4">1995</a></td></tr><tr><td class="a-text-right mojo-header-column mojo-truncate mojo-field-type-rank">406</td><td class="a-text-left mojo-field-type-title"><a class="a-link-normal" href="/title/tt0170016/?ref_=bo_cso_table_5">How the Grinch Stole Christmas</a></td><td class="a-text-right mojo-field-type-money">$345,141,403</td><td class="a-text-right mojo-field-type-money">$260,044,825</td><td class="a-text-right mojo-field-type-percent">75.3%</td><td class="a-text-right mojo-field-type-money">$85,096,578</td><td class="a-text-right mojo-field-type-percent">24.7%</td><td class="a-text-left mojo-field-type-year"><a class="a-link-normal" href="/year/world/2000/?ref_=bo_cso_table_5">2000</a></td></tr><tr><td class="a-text-right mojo-header-column mojo-truncate mojo-field-type-rank">407</td><td class="a-text-left mojo-field-type-title"><a class="a-link-normal" href="/title/tt2660888/?ref_=bo_cso_table_6">Star Trek Beyond</a></td><td class="a-text-right mojo-field-type-money">$343,471,816</td><td class="a-text-right mojo-field-type-money">$158,848,340</td><td class="a-text-right mojo-field-type-percent">46.2%</td><td class="a-text-right mojo-field-type-money">$184,623,476</td><td class="a-text-right mojo-field-type-percent">53.8%</td><td class="a-text-left mojo-field-type-year"><a class="a-link-normal" href=" ...
# <div class="a-section a-spacing-none mojo-navigation-frame"><div class="a-section a-spacing-none mojo-navigation mojo-footer"><a class="a-link-normal imdb-pro-logo" href="https://pro.imdb.com/?ref_=mojo_ft_cso_prologo&amp;rf=mojo_ft_cso_prologo"></a><p>
#             Latest Updates:
#             <a class="a-link-normal" href="/news/?ref_=bo_ft_cso_news">News</a> |
#             <a class="a-link-normal" href="/daily/?ref_=bo_ft_cso_daily">Daily</a> |
#             <a class="a-link-normal" href="/weekend/?ref_=bo_ft_cso_weekend">Weekend</a> |
#             <a class="a-link-normal" href="/charts/?ref_=bo_ft_cso_charts">All Time</a> |
#             <a class="a-link-normal" href="/intl/?ref_=bo_ft_cso_intl">International</a> |
#             <a class="a-link-normal" href="/showdown/?ref_=bo_ft_cso_showdown">Showdowns</a></p><p><a class="a-link-normal" href="https://help.imdb.com/article/imdbpro/industry-research/box-office-mojo-by-imdbpro-faq/GCWTV4MQKGWRAUAP?ref_=mojo_ftr_help" rel="noopener" target="_blank">Help</a></p><p>
#             BoxOfficeMojo.com by IMDbPro - an
#             <a class="a-link-normal" href="http://www.imdb.com/" rel="noopener" target="_blank">IMDb</a>
#             company.
#         </p><p>
#             © IMDb.com, Inc. or its affiliates. All rights reserved.
#             Box Office Mojo and IMDb are trademarks or registered trademarks of IMDb.com, Inc. or its affiliates.
#             <a class="a-link-normal" href="/conditions/?ref_=bo_ft_cso_conditions">Conditions of Use</a>
#              and
#              <a class="a-link-normal" href="/privacy/?ref_=bo_ft_cso_privacy">Privacy Policy</a>
#             under which this service is provided to you.
#         </p></div></div></div></body></html>>

# %%
movie_list3 = []
row_list = []
for record in soup.findAll("tr"):
    for data in record.findAll("td"):
        row_list.append(data.text)
    if row_list == []:
        pass
    else:
        movie_list3.append(row_list)
        row_list = []
movie_list3
# Out:
# [['402',
#   'Rush Hour 2',
#   '$347,325,802',
#   '$226,164,286',
#   '65.1%',
#   '$121,161,516',
#   '34.9%',
#   '2001'],
#  ['403',
#   'Trolls',
#   '$346,864,462',
#   '$153,707,064',
#   '44.3%',
#   '$193,157,398',
#   '55.7%',
#   '2016'],
#  ['404',
#   'xXx: Return of Xander Cage',
#   '$346,118,277',
#   '$44,898,413',
#   '13%',
#   '$301,219,864',
#   '87%',
#   '2017'],
#  ['405',
#   'Pocahontas',
#   '$346,079,773',
#   '$141,579,773',
#   '40.9%',
#   '$204,500,000',
#   '59.1%',
#   '1995'],
#  ['406',
#   'How the Grinch Stole Christmas',
#   '$345,141,403',
#   '$260,044,825',
#   '75.3%',
#   '$85,096,578',
#   '24.7%',
#   '2000'],
#  ['407',
#   'Star Trek Beyond',
#   '$343,471,816',
#   '$158,848,340',
#   '46.2%',
#   '$184,623,476',
#   '53.8%',
#   '2016'],
#  ['408',
#   'Alvin and the Chipmunks: Chipwrecked',
#   '$342,695,435',
#   '$133,110,742',
#   '38.8%',
#   '$209,584,693',
#   '61.2%',
#   '2011'],
#  ['409',
#   'Wanted',
#   '$342,463,063',
#   '$134,508,551',
#   '39.3%',
#   '$207,954,512',
#   '60.7%',
#   '2008'],
#  ['410',
#   'The Flintstones',
#   '$341,631,208',
#   '$130,531,208',
#   '38.2%',
#   '$211,100,000',
#   '61.8%',
#   '1994'],
#  ['411',
#   'A Quiet Place',
#   '$340,939,361',
#   '$188,024,361',
#   '55.2%',
#   '$152,915,000',
#   '44.8%',
#   '2018'],
#  ['412',
#   'Enchanted',
#   '$340,487,652',
#   '$127,807,262',
#   '37.5%',
#   '$212,680,390',
#   '62.5%',
#   '2007'],
#  ['413',
#   'Over the Hedge',
#   '$339,795,890',
#   '$155,019,340',
#   '45.6%',
#   '$184,776,550',
#   '54.4%',
#   '2006'],
#  ['414',
#   '300: Rise of an Empire',
#   '$337,580,051',
#   '$106,580,051',
#   '31.6%',
#   '$231,000,000',
#   '68.4%',
#   '2014'],
#  ['415',
#   'Batman Forever',
#   '$336,567,531',
#   '$184,069,126',
#   '54.7%',
#   '$152,498,405',
#   '45.3%',
#   '1995'],
#  ['416',
#   'Prince of Persia: The Sands of Time',
#   '$336,365,676',
#   '$90,759,676',
#   '27%',
#   '$245,606,000',
#   '73%',
#   '2009'],
#  ['417',
#   'Back to the Future Part II',
#   '$335,949,377',
#   '$119,000,002',
#   '35.4%',
#   '$216,949,375',
#   '64.6%',
#   '1989'],
#  ['418',
#   'The Curious Case of Benjamin Button',
#   '$335,802,786',
#   '$127,509,326',
#   '38%',
#   '$208,293,460',
#   '62%',
#   '2008'],
#  ['419',
#   'Journey 2: The Mysterious Island',
#   '$335,260,290',
#   '$103,860,290',
#   '31%',
#   '$231,400,000',
#   '69%',
#   '2012'],
#  ['420',
#   'The Rock',
#   '$335,062,621',
#   '$134,069,511',
#   '40%',
#   '$200,993,110',
#   '60%',
#   '1996'],
#  ['421',
#   'The Great Wall',
#   '$334,933,831',
#   '$45,540,830',
#   '13.6%',
#   '$289,393,001',
#   '86.4%',
#   '2016'],
#  ['422',
#   'Now You See Me 2',
#   '$334,897,606',
#   '$65,075,540',
#   '19.4%',
#   '$269,822,066',
#   '80.6%',
#   '2016'],
#  ['424',
#   'Fantastic Four',
#   '$333,535,934',
#   '$154,696,080',
#   '46.4%',
#   '$178,839,854',
#   '53.6%',
#   '2005'],
#  ['425',
#   'Indiana Jones and the Temple of Doom',
#   '$333,107,271',
#   '$179,870,271',
#   '54%',
#   '$153,237,000',
#   '46%',
#   '1984'],
#  ['426',
#   'Tomorrow Never Dies',
#   '$333,011,068',
#   '$125,304,276',
#   '37.6%',
#   '$207,706,792',
#   '62.4%',
#   '1997'],
#  ['427',
#   'The Good Dinosaur',
#   '$332,207,671',
#   '$123,087,120',
#   '37%',
#   '$209,120,551',
#   '63%',
#   '2015'],
#  ['428',
#   '22 Jump Street',
#   '$331,333,876',
#   '$191,719,337',
#   '57.9%',
#   '$139,614,539',
#   '42.1%',
#   '2014'],
#  ['429',
#   'Meet the Parents',
#   '$330,444,045',
#   '$166,244,045',
#   '50.3%',
#   '$164,200,000',
#   '49.7%',
#   '2000'],
#  ['430',
#   'Who Framed Roger Rabbit',
#   '$329,803,958',
#   '$156,452,370',
#   '47.4%',
#   '$173,351,588',
#   '52.6%',
#   '1988'],
#  ['431',
#   'Green Book',
#   '$329,719,448',
#   '$85,080,171',
#   '25.8%',
#   '$244,639,277',
#   '74.2%',
#   '2018'],
#  ['432',
#   'Black Swan',
#   '$329,398,046',
#   '$106,954,678',
#   '32.5%',
#   '$222,443,368',
#   '67.5%',
#   '2010'],
#  ['433',
#   'The Perfect Storm',
#   '$328,718,434',
#   '$182,618,434',
#   '55.6%',
#   '$146,100,000',
#   '44.4%',
#   '2000'],
#  ['434',
#   'Crocodile Dundee',
#   '$328,203,506',
#   '$174,803,506',
#   '53.3%',
#   '$153,400,000',
#   '46.7%',
#   '1986'],
#  ['435',
#   'The Devil Wears Prada',
#   '$327,893,740',
#   '$124,740,460',
#   '38%',
#   '$203,153,280',
#   '62%',
#   '2006'],
#  ['437',
#   'Se7en',
#   '$327,333,559',
#   '$100,125,643',
#   '30.6%',
#   '$227,207,916',
#   '69.4%',
#   '1995'],
#  ['438',
#   'John Wick: Chapter 3 - Parabellum',
#   '$326,709,727',
#   '$171,015,687',
#   '52.3%',
#   '$155,694,040',
#   '47.7%',
#   '2019'],
#  ['439',
#   'Taken 3',
#   '$326,479,141',
#   '$89,256,424',
#   '27.3%',
#   '$237,222,717',
#   '72.7%',
#   '2015'],
#  ['440',
#   'The Hunchback of Notre Dame',
#   '$325,338,851',
#   '$100,138,851',
#   '30.8%',
#   '$225,200,000',
#   '69.2%',
#   '1996'],
#  ['441',
#   'A Christmas Carol',
#   '$325,286,646',
#   '$137,855,863',
#   '42.4%',
#   '$187,430,783',
#   '57.6%',
#   '2009'],
#  ['442',
#   'The SpongeBob Movie: Sponge Out of Water',
#   '$325,186,032',
#   '$162,994,032',
#   '50.1%',
#   '$162,192,000',
#   '49.9%',
#   '2015'],
#  ['443',
#   "Schindler's List",
#   '$322,243,445',
#   '$96,898,818',
#   '30.1%',
#   '$225,344,627',
#   '69.9%',
#   '1993'],
#  ['444',
#   'Megamind',
#   '$321,885,765',
#   '$148,415,853',
#   '46.1%',
#   '$173,469,912',
#   '53.9%',
#   '2010'],
#  ['445',
#   'Lethal Weapon 3',
#   '$321,731,527',
#   '$144,731,527',
#   '45%',
#   '$177,000,000',
#   '55%',
#   '1992'],
#  ['446',
#   'The Ugly Truth',
#   '$321,682,600',
#   '$88,915,214',
#   '27.6%',
#   '$232,767,386',
#   '72.4%',
#   '2009'],
#  ['447',
#   'Robin Hood',
#   '$321,669,741',
#   '$105,269,730',
#   '32.7%',
#   '$216,400,011',
#   '67.3%',
#   '2010'],
#  ['448',
#   'Inglourious Basterds',
#   '$321,455,689',
#   '$120,540,719',
#   '37.5%',
#   '$200,914,970',
#   '62.5%',
#   '2009'],
#  ['449',
#   '101 Dalmatians',
#   '$320,689,294',
#   '$136,189,294',
#   '42.5%',
#   '$184,500,000',
#   '57.5%',
#   '1996'],
#  ['450',
#   'The Conjuring 2',
#   '$320,392,818',
#   '$102,470,008',
#   '32%',
#   '$217,922,810',
#   '68%',
#   '2016'],
#  ['451',
#   'Fatal Attraction',
#   '$320,145,693',
#   '$156,645,693',
#   '48.9%',
#   '$163,500,000',
#   '51.1%',
#   '1987'],
#  ['452',
#   'The Last Airbender',
#   '$319,713,881',
#   '$131,772,187',
#   '41.2%',
#   '$187,941,694',
#   '58.8%',
#   '2010'],
#  ['453',
#   'The Conjuring',
#   '$319,494,638',
#   '$137,400,141',
#   '43%',
#   '$182,094,497',
#   '57%',
#   '2013'],
#  ['454',
#   'The Proposal',
#   '$317,375,031',
#   '$163,958,031',
#   '51.7%',
#   '$153,417,000',
#   '48.3%',
#   '2009'],
#  ['455',
#   'A Beautiful Mind',
#   '$316,791,257',
#   '$170,742,341',
#   '53.9%',
#   '$146,048,916',
#   '46.1%',
#   '2001'],
#  ['456',
#   'Beverly Hills Cop',
#   '$316,360,478',
#   '$234,760,478',
#   '74.2%',
#   '$81,600,000',
#   '25.8%',
#   '1984'],
#  ['457',
#   'Air Force One',
#   '$315,156,409',
#   '$172,956,409',
#   '54.9%',
#   '$142,200,000',
#   '45.1%',
#   '1997'],
#  ['458',
#   'The Expendables 2',
#   '$314,975,955',
#   '$85,028,192',
#   '27%',
#   '$229,947,763',
#   '73%',
#   '2012'],
#  ['459',
#   'Chicken Little',
#   '$314,432,837',
#   '$135,386,665',
#   '43.1%',
#   '$179,046,172',
#   '56.9%',
#   '2005'],
#  ['460',
#   'As Good as It Gets',
#   '$314,178,011',
#   '$148,478,011',
#   '47.3%',
#   '$165,700,000',
#   '52.7%',
#   '1997'],
#  ['461',
#   'The Polar Express',
#   '$313,500,433',
#   '$187,224,490',
#   '59.7%',
#   '$126,275,943',
#   '40.3%',
#   '2004'],
#  ['462',
#   'Maze Runner: The Scorch Trials',
#   '$312,296,056',
#   '$81,697,192',
#   '26.2%',
#   '$230,598,864',
#   '73.8%',
#   '2015'],
#  ['463',
#   'Resident Evil: The Final Chapter',
#   '$312,242,626',
#   '$26,830,068',
#   '8.6%',
#   '$285,412,558',
#   '91.4%',
#   '2016'],
#  ['464',
#   'Austin Powers: The Spy Who Shagged Me',
#   '$312,016,928',
#   '$206,040,086',
#   '66%',
#   '$105,976,842',
#   '34%',
#   '1999'],
#  ['465',
#   'The Lego Batman Movie',
#   '$311,950,384',
#   '$175,750,384',
#   '56.3%',
#   '$136,200,000',
#   '43.7%',
#   '2017'],
#  ['466',
#   "Ocean's Thirteen",
#   '$311,312,624',
#   '$117,154,724',
#   '37.6%',
#   '$194,157,900',
#   '62.4%',
#   '2007'],
#  ['467',
#   'Little Fockers',
#   '$310,650,585',
#   '$148,438,600',
#   '47.8%',
#   '$162,211,985',
#   '52.2%',
#   '2010'],
#  ['468',
#   'Bolt',
#   '$309,979,994',
#   '$114,053,579',
#   '36.8%',
#   '$195,926,415',
#   '63.2%',
#   '2008'],
#  ['469',
#   'Ransom',
#   '$309,492,681',
#   '$136,492,681',
#   '44.1%',
#   '$173,000,000',
#   '55.9%',
#   '1996'],
#  ['470',
#   'Runaway Bride',
#   '$309,460,292',
#   '$152,257,509',
#   '49.2%',
#   '$157,202,783',
#   '50.8%',
#   '1999'],
#  ['471',
#   'The Blind Side',
#   '$309,208,309',
#   '$255,959,475',
#   '82.8%',
#   '$53,248,834',
#   '17.2%',
#   '2009'],
#  ['472',
#   'Knives Out',
#   '$307,644,122',
#   '$164,655,243',
#   '53.5%',
#   '$142,988,879',
#   '46.5%',
#   '2019'],
#  ['473',
#   'The Ex-File 3: The Return of The Exes',
#   '$307,592,427',
#   '$838,959',
#   '0.3%',
#   '$306,753,468',
#   '99.7%',
#   '2017'],
#  ['474',
#   'The Fault in Our Stars',
#   '$307,166,834',
#   '$124,872,350',
#   '40.6%',
#   '$182,294,484',
#   '59.4%',
#   '2014'],
#  ['475',
#   'The Pursuit of Happyness',
#   '$307,127,625',
#   '$163,566,459',
#   '53.3%',
#   '$143,561,166',
#   '46.7%',
#   '2006'],
#  ['476',
#   'Rise of the Guardians',
#   '$306,941,670',
#   '$103,412,758',
#   '33.7%',
#   '$203,528,912',
#   '66.3%',
#   '2012'],
#  ['477',
#   'Close Encounters of the Third Kind',
#   '$306,898,466',
#   '$135,189,114',
#   '44%',
#   '$171,709,352',
#   '56%',
#   '1977'],
#  ['478',
#   'Chicago',
#   '$306,776,732',
#   '$170,687,518',
#   '55.6%',
#   '$136,089,214',
#   '44.4%',
#   '2002'],
#  ['479',
#   'Annabelle: Creation',
#   '$306,515,884',
#   '$102,092,201',
#   '33.3%',
#   '$204,423,683',
#   '66.7%',
#   '2017'],
#  ['480',
#   'Wonder',
#   '$305,937,718',
#   '$132,422,809',
#   '43.3%',
#   '$173,514,909',
#   '56.7%',
#   '2017'],
#  ['481',
#   'Skyscraper',
#   '$304,868,961',
#   '$68,420,120',
#   '22.4%',
#   '$236,448,841',
#   '77.6%',
#   '2018'],
#  ['482',
#   'A Good Day to Die Hard',
#   '$304,654,182',
#   '$67,349,198',
#   '22.1%',
#   '$237,304,984',
#   '77.9%',
#   '2013'],
#  ['483',
#   'Mulan',
#   '$304,320,254',
#   '$120,620,254',
#   '39.6%',
#   '$183,700,000',
#   '60.4%',
#   '1998'],
#  ['484',
#   'Dangal',
#   '$303,723,636',
#   '$12,391,761',
#   '4.1%',
#   '$291,331,875',
#   '95.9%',
#   '2016'],
#  ['485',
#   'Passengers',
#   '$303,144,152',
#   '$100,014,699',
#   '33%',
#   '$203,129,453',
#   '67%',
#   '2016'],
#  ['486',
#   'Battleship',
#   '$303,025,485',
#   '$65,422,625',
#   '21.6%',
#   '$237,602,860',
#   '78.4%',
#   '2012'],
#  ['487',
#   'Liar Liar',
#   '$302,710,615',
#   '$181,410,615',
#   '59.9%',
#   '$121,300,000',
#   '40.1%',
#   '1997'],
#  ['488',
#   'G.I. Joe: The Rise of Cobra',
#   '$302,469,017',
#   '$150,201,498',
#   '49.7%',
#   '$152,267,519',
#   '50.3%',
#   '2009'],
#  ['489',
#   'Wrath of the Titans',
#   '$301,970,083',
#   '$83,670,083',
#   '27.7%',
#   '$218,300,000',
#   '72.3%',
#   '2012'],
#  ['490',
#   'Fantastic 4: Rise of the Silver Surfer',
#   '$301,913,131',
#   '$131,921,738',
#   '43.7%',
#   '$169,991,393',
#   '56.3%',
#   '2007'],
#  ['491',
#   'Hook',
#   '$300,854,823',
#   '$119,654,823',
#   '39.8%',
#   '$181,200,000',
#   '60.2%',
#   '1991'],
#  ['492',
#   'Rocky IV',
#   '$300,473,716',
#   '$127,873,716',
#   '42.6%',
#   '$172,600,000',
#   '57.4%',
#   '1985'],
#  ['493',
#   'Superman',
#   '$300,451,603',
#   '$134,451,603',
#   '44.8%',
#   '$166,000,000',
#   '55.2%',
#   '1978'],
#  ['494',
#   'Rambo: First Blood Part II',
#   '$300,400,432',
#   '$150,415,432',
#   '50.1%',
#   '$149,985,000',
#   '49.9%',
#   '1985'],
#  ['495',
#   'Resident Evil: Afterlife',
#   '$300,228,084',
#   '$60,128,566',
#   '20%',
#   '$240,099,518',
#   '80%',
#   '2010'],
#  ['496',
#   'Van Helsing',
#   '$300,157,638',
#   '$120,177,084',
#   '40%',
#   '$179,980,554',
#   '60%',
#   '2004'],
#  ['497',
#   'Stuart Little',
#   '$300,135,367',
#   '$140,035,367',
#   '46.7%',
#   '$160,100,000',
#   '53.3%',
#   '1999'],
#  ['498',
#   'Beverly Hills Cop II',
#   '$299,965,036',
#   '$153,665,036',
#   '51.2%',
#   '$146,300,000',
#   '48.8%',
#   '1987'],
#  ['499',
#   'Alice Through the Looking Glass',
#   '$299,457,024',
#   '$77,041,381',
#   '25.7%',
#   '$222,415,643',
#   '74.3%',
#   '2016'],
#  ['500',
#   "My Best Friend's Wedding",
#   '$299,288,605',
#   '$127,120,029',
#   '42.5%',
#   '$172,168,576',
#   '57.5%',
#   '1997'],
#  ['501',
#   'Real Steel',
#   '$299,268,508',
#   '$85,468,508',
#   '28.6%',
#   '$213,800,000',
#   '71.4%',
#   '2011'],
#  ['502',
#   'Horton Hears a Who!',
#   '$298,572,799',
#   '$154,529,439',
#   '51.8%',
#   '$144,043,360',
#   '48.2%',
#   '2008'],
#  ['503',
#   "Ocean's Eight",
#   '$297,718,711',
#   '$140,218,711',
#   '47.1%',
#   '$157,500,000',
#   '52.9%',
#   '2018'],
#  ['504',
#   'Insurgent',
#   '$297,002,527',
#   '$130,179,072',
#   '43.8%',
#   '$166,823,455',
#   '56.2%',
#   '2015'],
#  ['505',
#   "Look Who's Talking",
#   '$296,999,813',
#   '$140,088,813',
#   '47.2%',
#   '$156,911,000',
#   '52.8%',
#   '1989'],
#  ['506',
#   'Austin Powers in Goldmember',
#   '$296,938,801',
#   '$213,307,889',
#   '71.8%',
#   '$83,630,912',
#   '28.2%',
#   '2002'],
#  ['507',
#   "Miss Peregrine's Home for Peculiar Children",
#   '$296,482,446',
#   '$87,242,834',
#   '29.4%',
#   '$209,239,612',
#   '70.6%',
#   '2016'],
#  ['508',
#   'X-Men',
#   '$296,339,528',
#   '$157,299,718',
#   '53.1%',
#   '$139,039,810',
#   '46.9%',
#   '2000'],
#  ['509',
#   'Ferdinand',
#   '$296,069,199',
#   '$84,410,380',
#   '28.5%',
#   '$211,658,819',
#   '71.5%',
#   '2017'],
#  ['510',
#   'Ghostbusters',
#   '$295,743,767',
#   '$242,582,079',
#   '82%',
#   '$53,161,688',
#   '18%',
#   '1984'],
#  ['511',
#   'Shutter Island',
#   '$294,804,195',
#   '$128,012,934',
#   '43.4%',
#   '$166,791,261',
#   '56.6%',
#   '2010'],
#  ['512',
#   'Doctor Dolittle',
#   '$294,456,605',
#   '$144,156,605',
#   '49%',
#   '$150,300,000',
#   '51%',
#   '1998'],
#  ['513',
#   'Bee Movie',
#   '$293,514,336',
#   '$126,631,277',
#   '43.1%',
#   '$166,883,059',
#   '56.9%',
#   '2007'],
#  ['514',
#   'Salt',
#   '$293,503,354',
#   '$118,311,368',
#   '40.3%',
#   '$175,191,986',
#   '59.7%',
#   '2010'],
#  ['515',
#   'G-Force',
#   '$292,817,841',
#   '$119,436,770',
#   '40.8%',
#   '$173,381,071',
#   '59.2%',
#   '2009'],
#  ['516',
#   'The Departed',
#   '$291,465,034',
#   '$132,384,315',
#   '45.4%',
#   '$159,080,719',
#   '54.6%',
#   '2006'],
#  ['517',
#   'What Lies Beneath',
#   '$291,420,351',
#   '$155,464,351',
#   '53.4%',
#   '$135,956,000',
#   '46.6%',
#   '2000'],
#  ['518',
#   'Pacific Rim: Uprising',
#   '$290,930,148',
#   '$59,874,525',
#   '20.6%',
#   '$231,055,623',
#   '79.4%',
#   '2018'],
#  ['519',
#   'The Bourne Supremacy',
#   '$290,835,269',
#   '$176,241,941',
#   '60.6%',
#   '$114,593,328',
#   '39.4%',
#   '2004'],
#  ['520',
#   'Sex and the City 2',
#   '$290,745,055',
#   '$95,347,692',
#   '32.8%',
#   '$195,397,363',
#   '67.2%',
#   '2010'],
#  ['521',
#   'Shakespeare in Love',
#   '$289,317,794',
#   '$100,317,794',
#   '34.7%',
#   '$189,000,000',
#   '65.3%',
#   '1998'],
#  ['522',
#   'Divergent',
#   '$288,885,818',
#   '$150,947,895',
#   '52.2%',
#   '$137,937,923',
#   '47.8%',
#   '2014'],
#  ['523',
#   'Coming to America',
#   '$288,752,301',
#   '$128,152,301',
#   '44.4%',
#   '$160,600,000',
#   '55.6%',
#   '1988'],
#  ['524',
#   'Wedding Crashers',
#   '$288,467,645',
#   '$209,255,921',
#   '72.5%',
#   '$79,211,724',
#   '27.5%',
#   '2005'],
#  ['525',
#   'Bridesmaids',
#   '$288,383,523',
#   '$169,106,725',
#   '58.6%',
#   '$119,276,798',
#   '41.4%',
#   '2011'],
#  ['526',
#   'Maze Runner: The Death Cure',
#   '$288,175,335',
#   '$58,032,443',
#   '20.1%',
#   '$230,142,892',
#   '79.9%',
#   '2018'],
#  ['527',
#   'Casper',
#   '$287,928,194',
#   '$100,328,194',
#   '34.8%',
#   '$187,600,000',
#   '65.2%',
#   '1995'],
#  ['528',
#   'American Pie 2',
#   '$287,553,595',
#   '$145,103,595',
#   '50.5%',
#   '$142,450,000',
#   '49.5%',
#   '2001'],
#  ['529',
#   'Pitch Perfect 2',
#   '$287,144,079',
#   '$184,296,230',
#   '64.2%',
#   '$102,847,849',
#   '35.8%',
#   '2015'],
#  ['530',
#   'Knowing',
#   '$287,046,800',
#   '$79,957,634',
#   '27.9%',
#   '$207,089,166',
#   '72.1%',
#   '2007'],
#  ['531',
#   'The Green Mile',
#   '$286,801,374',
#   '$136,801,374',
#   '47.7%',
#   '$150,000,000',
#   '52.3%',
#   '1999'],
#  ['532',
#   'Oblivion',
#   '$286,168,572',
#   '$89,107,235',
#   '31.1%',
#   '$197,061,337',
#   '68.9%',
#   '2013'],
#  ['533',
#   'Elysium',
#   '$286,140,700',
#   '$93,050,117',
#   '32.5%',
#   '$193,090,583',
#   '67.5%',
#   '2013'],
#  ['534',
#   'Lethal Weapon 4',
#   '$285,444,603',
#   '$130,444,603',
#   '45.7%',
#   '$155,000,000',
#   '54.3%',
#   '1998'],
#  ['535',
#   'John Carter',
#   '$284,139,100',
#   '$73,078,100',
#   '25.7%',
#   '$211,061,000',
#   '74.3%',
#   '2012'],
#  ['536',
#   'Paddington',
#   '$282,839,394',
#   '$76,271,832',
#   '27%',
#   '$206,567,562',
#   '73%',
#   '2014'],
#  ['537',
#   'Turbo',
#   '$282,570,682',
#   '$83,028,128',
#   '29.4%',
#   '$199,542,554',
#   '70.6%',
#   '2013'],
#  ['538',
#   "Bridget Jones's Diary",
#   '$281,929,795',
#   '$71,543,427',
#   '25.4%',
#   '$210,386,368',
#   '74.6%',
#   '2001'],
#  ['539',
#   'The Tourist',
#   '$278,780,441',
#   '$67,631,157',
#   '24.3%',
#   '$211,149,284',
#   '75.7%',
#   '2010'],
#  ['540',
#   'Split',
#   '$278,454,358',
#   '$138,291,365',
#   '49.7%',
#   '$140,162,993',
#   '50.3%',
#   '2017'],
#  ['541',
#   'Scary Movie',
#   '$278,019,771',
#   '$157,019,771',
#   '56.5%',
#   '$121,000,000',
#   '43.5%',
#   '2000'],
#  ['542',
#   'xXx',
#   '$277,448,382',
#   '$142,109,382',
#   '51.2%',
#   '$135,339,000',
#   '48.8%',
#   '2002'],
#  ['543',
#   'The Bourne Legacy',
#   '$276,144,750',
#   '$113,203,870',
#   '41%',
#   '$162,940,880',
#   '59%',
#   '2012'],
#  ['544',
#   'Mr. Peabody & Sherman',
#   '$275,698,039',
#   '$111,506,430',
#   '40.4%',
#   '$164,191,609',
#   '59.6%',
#   '2014'],
#  ['545',
#   'Scooby-Doo',
#   '$275,650,703',
#   '$153,294,164',
#   '55.6%',
#   '$122,356,539',
#   '44.4%',
#   '2002'],
#  ['546',
#   'Lincoln',
#   '$275,293,450',
#   '$182,207,973',
#   '66.2%',
#   '$93,085,477',
#   '33.8%',
#   '2012'],
#  ['547',
#   'Lara Croft: Tomb Raider',
#   '$274,703,340',
#   '$131,168,070',
#   '47.8%',
#   '$143,535,270',
#   '52.2%',
#   '2001'],
#  ['548',
#   'Tomb Raider',
#   '$274,650,803',
#   '$58,250,803',
#   '21.2%',
#   '$216,400,000',
#   '78.8%',
#   '2018'],
#  ['549',
#   'The Expendables',
#   '$274,470,394',
#   '$103,068,524',
#   '37.6%',
#   '$171,401,870',
#   '62.4%',
#   '2010'],
#  ['550',
#   'Cloudy with a Chance of Meatballs 2',
#   '$274,325,949',
#   '$119,793,567',
#   '43.7%',
#   '$154,532,382',
#   '56.3%',
#   '2013'],
#  ['551',
#   'The Little Mermaid',
#   '$274,176,364',
#   '$111,543,479',
#   '40.7%',
#   '$162,632,885',
#   '59.3%',
#   '1989'],
#  ['552',
#   'The Nutty Professor',
#   '$273,961,019',
#   '$128,814,019',
#   '47%',
#   '$145,147,000',
#   '53%',
#   '1996'],
#  ['553',
#   'Jerry Maguire',
#   '$273,552,592',
#   '$153,952,592',
#   '56.3%',
#   '$119,600,000',
#   '43.7%',
#   '1996'],
#  ['554',
#   'Bad Boys II',
#   '$273,339,556',
#   '$138,608,444',
#   '50.7%',
#   '$134,731,112',
#   '49.3%',
#   '2003'],
#  ['555',
#   'Lilo & Stitch',
#   '$273,144,151',
#   '$145,794,338',
#   '53.4%',
#   '$127,349,813',
#   '46.6%',
#   '2002'],
#  ['556',
#   'The Silence of the Lambs',
#   '$272,753,884',
#   '$130,742,922',
#   '47.9%',
#   '$142,010,962',
#   '52.1%',
#   '1991'],
#  ['557',
#   'Grown Ups',
#   '$271,430,189',
#   '$162,001,186',
#   '59.7%',
#   '$109,429,003',
#   '40.3%',
#   '2010'],
#  ['558',
#   'Neighbors',
#   '$270,665,134',
#   '$150,157,400',
#   '55.5%',
#   '$120,507,734',
#   '44.5%',
#   '2014'],
#  ['559',
#   'The Firm',
#   '$270,248,367',
#   '$158,348,367',
#   '58.6%',
#   '$111,900,000',
#   '41.4%',
#   '1993'],
#  ['560',
#   "We're the Millers",
#   '$269,994,119',
#   '$150,394,119',
#   '55.7%',
#   '$119,600,000',
#   '44.3%',
#   '2012'],
#  ['561',
#   'Gran Torino',
#   '$269,958,228',
#   '$148,095,302',
#   '54.9%',
#   '$121,862,926',
#   '45.1%',
#   '2008'],
#  ['562',
#   '10,000 BC',
#   '$269,784,201',
#   '$94,784,201',
#   '35.1%',
#   '$175,000,000',
#   '64.9%',
#   '2008'],
#  ['563',
#   'American Gangster',
#   '$269,755,430',
#   '$130,164,645',
#   '48.2%',
#   '$139,590,785',
#   '51.8%',
#   '2007'],
#  ['564',
#   'Epic',
#   '$268,426,634',
#   '$107,518,682',
#   '40.1%',
#   '$160,907,952',
#   '59.9%',
#   '2013'],
#  ['565',
#   'Exodus: Gods and Kings',
#   '$268,175,631',
#   '$65,014,513',
#   '24.2%',
#   '$203,161,118',
#   '75.8%',
#   '2014'],
#  ['566',
#   'Bambi',
#   '$267,447,150',
#   '$102,247,150',
#   '38.2%',
#   '$165,200,000',
#   '61.8%',
#   '1942'],
#  ['567',
#   'The Princess and the Frog',
#   '$267,045,765',
#   '$104,400,899',
#   '39.1%',
#   '$162,644,866',
#   '60.9%',
#   '2009'],
#  ['568',
#   'Batman Returns',
#   '$266,903,053',
#   '$162,902,340',
#   '61%',
#   '$104,000,713',
#   '39%',
#   '1992'],
#  ['569',
#   'Indecent Proposal',
#   '$266,614,059',
#   '$106,614,059',
#   '40%',
#   '$160,000,000',
#   '60%',
#   '1993'],
#  ['570',
#   'Sonic the Hedgehog',
#   '$265,755,045',
#   '$128,555,045',
#   '48.4%',
#   '$137,200,000',
#   '51.6%',
#   '2020'],
#  ['571',
#   "Something's Gotta Give",
#   '$265,328,738',
#   '$124,728,738',
#   '47%',
#   '$140,600,000',
#   '53%',
#   '2003'],
#  ['572',
#   'Bridget Jones: The Edge of Reason',
#   '$265,126,918',
#   '$40,226,215',
#   '15.2%',
#   '$224,900,703',
#   '84.8%',
#   '2004'],
#  ['573',
#   'The Incredible Hulk',
#   '$264,770,996',
#   '$134,806,913',
#   '50.9%',
#   '$129,964,083',
#   '49.1%',
#   '2008'],
#  ['574',
#   'Waterworld',
#   '$264,218,220',
#   '$88,246,220',
#   '33.4%',
#   '$175,972,000',
#   '66.6%',
#   '1995'],
#  ['575',
#   'The Truman Show',
#   '$264,118,201',
#   '$125,618,201',
#   '47.6%',
#   '$138,500,000',
#   '52.4%',
#   '1998'],
#  ['576',
#   "Charlie's Angels",
#   '$264,105,545',
#   '$125,305,545',
#   '47.4%',
#   '$138,800,000',
#   '52.6%',
#   '2000'],
#  ['577',
#   'The Fifth Element',
#   '$264,029,966',
#   '$63,820,180',
#   '24.2%',
#   '$200,209,786',
#   '75.8%',
#   '1997'],
#  ['578',
#   'Jumanji',
#   '$262,821,940',
#   '$100,499,940',
#   '38.2%',
#   '$162,322,000',
#   '61.8%',
#   '1995'],
#  ['579',
#   'Borat: Cultural Learnings of America for Make Benefit Glorious Nation of Kazakhstan',
#   '$262,552,893',
#   '$128,505,958',
#   '48.9%',
#   '$134,046,935',
#   '51.1%',
#   '2006'],
#  ['580',
#   'Robots',
#   '$262,511,490',
#   '$128,200,012',
#   '48.8%',
#   '$134,311,478',
#   '51.2%',
#   '2005'],
#  ['581',
#   'Knight and Day',
#   '$261,989,769',
#   '$76,423,035',
#   '29.2%',
#   '$185,566,734',
#   '70.8%',
#   '2008'],
#  ['582',
#   'Total Recall',
#   '$261,317,921',
#   '$119,412,921',
#   '45.7%',
#   '$141,905,000',
#   '54.3%',
#   '1990'],
#  ['583',
#   'This Is It',
#   '$261,183,588',
#   '$72,091,016',
#   '27.6%',
#   '$189,092,572',
#   '72.4%',
#   '2009'],
#  ['584',
#   'Terminator: Dark Fate',
#   '$261,119,292',
#   '$62,253,077',
#   '23.8%',
#   '$198,866,215',
#   '76.2%',
#   '2019'],
#  ['585',
#   'The Lone Ranger',
#   '$260,502,115',
#   '$89,302,115',
#   '34.3%',
#   '$171,200,000',
#   '65.7%',
#   '2013'],
#  ['586',
#   'Super 8',
#   '$260,095,986',
#   '$127,004,179',
#   '48.8%',
#   '$133,091,807',
#   '51.2%',
#   '2011'],
#  ['587',
#   'Mojin - The Lost Legend',
#   '$259,368,448',
#   '$1,243,810',
#   '0.5%',
#   '$258,124,638',
#   '99.5%',
#   '2015'],
#  ['588',
#   'Blade Runner 2049',
#   '$259,239,658',
#   '$92,054,159',
#   '35.5%',
#   '$167,185,499',
#   '64.5%',
#   '2017'],
#  ['589',
#   "Charlie's Angels: Full Throttle",
#   '$259,175,788',
#   '$100,830,111',
#   '38.9%',
#   '$158,345,677',
#   '61.1%',
#   '2003'],
#  ['590',
#   'Rush Hour 3',
#   '$258,097,122',
#   '$140,125,968',
#   '54.3%',
#   '$117,971,154',
#   '45.7%',
#   '2007'],
#  ['591',
#   'The Full Monty',
#   '$257,938,649',
#   '$45,950,122',
#   '17.8%',
#   '$211,988,527',
#   '82.2%',
#   '1997'],
#  ['592',
#   'Kung Fu Yoga',
#   '$257,743,016',
#   '$362,657',
#   '0.1%',
#   '$257,380,359',
#   '99.9%',
#   '2017'],
#  ['593',
#   'Annabelle',
#   '$257,047,661',
#   '$84,273,813',
#   '32.8%',
#   '$172,773,848',
#   '67.2%',
#   '2014'],
#  ['594',
#   'The Village',
#   '$256,697,520',
#   '$114,197,520',
#   '44.5%',
#   '$142,500,000',
#   '55.5%',
#   '2003'],
#  ['595',
#   'Lost in Hong Kong',
#   '$256,283,912',
#   '$1,302,281',
#   '0.5%',
#   '$254,981,631',
#   '99.5%',
#   '2015'],
#  ['596',
#   'Erin Brockovich',
#   '$256,271,286',
#   '$125,595,205',
#   '49%',
#   '$130,676,081',
#   '51%',
#   '2000'],
#  ['598',
#   'Marley & Me',
#   '$255,743,093',
#   '$143,153,751',
#   '56%',
#   '$112,589,342',
#   '44%',
#   '2008'],
#  ['599',
#   'Halloween',
#   '$255,485,178',
#   '$159,342,015',
#   '62.4%',
#   '$96,143,163',
#   '37.6%',
#   '2018'],
#  ['600',
#   'Get Out',
#   '$255,413,717',
#   '$176,040,665',
#   '68.9%',
#   '$79,373,052',
#   '31.1%',
#   '2017'],
#  ['601',
#   'Us',
#   '$255,184,580',
#   '$175,084,580',
#   '68.6%',
#   '$80,100,000',
#   '31.4%',
#   '2019'],
#  ['602',
#   'Cliffhanger',
#   '$255,000,211',
#   '$84,049,211',
#   '33%',
#   '$170,951,000',
#   '67%',
#   '1993'],
#  ['603',
#   'Baahubali 2: The Conclusion',
#   '$254,158,390',
#   '$20,186,659',
#   '7.9%',
#   '$233,971,731',
#   '92.1%',
#   '2017'],
#  ['604',
#   'Babe',
#   '$254,134,910',
#   '$63,658,910',
#   '25%',
#   '$190,476,000',
#   '75%',
#   '1995']]

# %%
url = "https://www.boxofficemojo.com/chart/ww_top_lifetime_gross/?area=XWW&offset=600"
r = requests.get(url)
soup = bs(r.content, "html.parser")
print(soup.prettify)
# Out:
# <bound method Tag.prettify of <!DOCTYPE doctype html>
# <html class="a-no-js" data-19ax5a9jf="dingo"><head><script>var aPageStart = (new Date()).getTime();</script><meta charset="utf-8"/><meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <meta charset="utf-8"/>
# <title dir="ltr">Top Lifetime Grosses - Box Office Mojo</title><meta content="Top Lifetime Grosses" name="title"/>
# <meta content="Box Office Mojo" property="og:site_name"/>
# <meta content="telephone=no" name="format-detection"/>
# <link href="https://m.media-amazon.com/images/G/01/boxofficemojo/v2/favicon._CB448965889_.ico" rel="icon" type="image/x-icon"/>
# <link href="https://images-na.ssl-images-amazon.com/images/I/51tax7M48-L._RC|516fcOUE-HL.css,01evdoiemkL.css,01K+Ps1DeEL.css,31pdJv9iSzL.css,01VszOUTO6L.css,11UGC+GXOPL.css,21LK7jaicML.css,11L58Qpo0GL.css,21kyTi1FabL.css,01ruG+gDPFL.css,01YhS3Cs-hL.css,21GwE3cR-yL.css,019SHZnt8RL.css,01wAWQRgXzL.css,21bWcRJYNIL.css,11WgRxUdJRL.css,01dU8+SPlFL.css,11ocrgKoE-L.css,01SHjPML6tL.css,111-D2qRjiL.css,01QrWuRrZ-L.css,310Imb6LqFL.css,01piEq-AdwL.css,11Z1a0FxSIL.css,01cbS3UK11L.css,21mOLw+nYYL.css,01L8Y-JFEhL.css_.css?AUIClients/AmazonUI#us.not-trident" rel="stylesheet"/>
# <link href="https://images-na.ssl-images-amazon.com/images/I/41jxT1zINDL.css?AUIClients/IMDbMojoSiteAssets" rel="stylesheet"/>
# <script>
# (function(f,h,Q,A){function G(a){v&&v.tag&&v.tag(q(":","aui",a))}function x(a,b){v&&v.count&&v.count("aui:"+a,0===b?0:b||(v.count("aui:"+a)||0)+1)}function l(a){try{return a.test(navigator.userAgent)}catch(b){return!1}}function y(a,b,c){a.addEventListener?a.addEventListener(b,c,!1):a.attachEvent&&a.attachEvent("on"+b,c)}function q(a,b,c,e){b=b&&c?b+a+c:b||c;return e?q(a,b,e):b}function H(a,b,c){try{Object.defineProperty(a,b,{value:c,writable:!1})}catch(e){a[b]=c}return c}function ta(a,b){var c=a.length,
# e=c,g=function(){e--||(R.push(b),S||(setTimeout(T,0),S=!0))};for(g();c--;)ca[a[c]]?g():(B[a[c]]=B[a[c]]||[]).push(g)}function ua(a,b,c,e,g){var d=h.createElement(a?"script":"link");y(d,"error",e);g&&y(d,"load",g);a?(d.type="text/javascript",d.async=!0,c&&/AUIClients|images[/]I/.test(b)&&d.setAttribute("crossorigin","anonymous"),d.src=b):(d.rel="stylesheet",d.href=b);h.getElementsByTagName("head")[0].appendChild(d)}function da(a,b){function c(c,e){function g(){ua(b,c,h,function(b){!I&&h?(h=!1,x("resource_retry"),
# g()):(x("resource_error"),a.log("Asset failed to load: "+c,I?"WARN":A));b&&b.stopPropagation?b.stopPropagation():f.event&&(f.event.cancelBubble=!0)},e)}if(ea[c])return!1;ea[c]=!0;x("resource_count");var h=!0;return!g()}if(b){var e=0,g=0;c.andConfirm=function(a,b){return c(a,function(){e++;b&&b.apply(this,arguments)})};c.confirm=function(){g++};c.getCsriCounters=function(){return{reqs:e,full:g}}}return c}function va(a,b,c){for(var e={name:a,guard:function(c){return b.guardFatal(a,c)},logError:function(c,
# d,e){b.logError(c,d,e,a)}},g=[],d=0;d<c.length;d++)J.hasOwnProperty(c[d])&&(g[d]=U.hasOwnProperty(c[d])?U[c[d]](J[c[d]],e):J[c[d]]);return g}function C(a,b,c,e,g){return function(d,h){function m(){var a=null;e?a=h:"function"===typeof h&&(p.start=D(),a=h.apply(f,va(d,k,l)),p.end=D());if(b){J[d]=a;a=d;for(ca[a]=!0;(B[a]||[]).length;)B[a].shift()();delete B[a]}p.done=!0}var k=g||this;"function"===typeof d&&(h=d,d=A);b&&(d=d?d.replace(fa,""):"__NONAME__",V.hasOwnProperty(d)&&k.error(q(", reregistered by ",
# q(" by ",d+" already registered",V[d]),k.attribution),d),V[d]=k.attribution);for(var l=[],n=0;n<a.length;n++)l[n]=a[n].replace(fa,"");var p=ga[d||"anon"+ ++wa]={depend:l,registered:D(),namespace:k.namespace};c?m():ta(l,k.guardFatal(d,m));return{decorate:function(a){U[d]=k.guardFatal(d,a)}}}}function ha(a){return function(){var b=Array.prototype.slice.call(arguments);return{execute:C(b,!1,a,!1,this),register:C(b,!0,a,!1,this)}}}function W(a,b){return function(c,e){e||(e=c,c=A);var g=this.attribution;
# return function(){z.push(b||{attribution:g,name:c,logLevel:a});var d=e.apply(this,arguments);z.pop();return d}}}function K(a,b){this.load={js:da(this,!0),css:da(this)};H(this,"namespace",b);H(this,"attribution",a)}function ia(){h.body?p.trigger("a-bodyBegin"):setTimeout(ia,20)}function E(a,b){a.className=X(a,b)+" "+b}function X(a,b){return(" "+a.className+" ").split(" "+b+" ").join(" ").replace(/^ | $/g,"")}function ja(a){try{return a()}catch(b){return!1}}function L(){if(M){var a={w:f.innerWidth||
# m.clientWidth,h:f.innerHeight||m.clientHeight};5<Math.abs(a.w-Y.w)||50<a.h-Y.h?(Y=a,N=4,(a=k.mobile||k.tablet?450<a.w&&a.w>a.h:1250<=a.w)?E(m,"a-ws"):m.className=X(m,"a-ws")):0<N&&(N--,ka=setTimeout(L,16))}}function xa(a){(M=a===A?!M:!!a)&&L()}function ya(){return M}function r(a,b){return"sw:"+(b||"")+":"+a+":"}function la(){ma.forEach(function(a){G(a)})}function n(a){ma.push(a)}function na(a,b,c,e){if(c){b=l(/Chrome/i)&&!l(/Edge/i)&&!l(/OPR/i)&&!a.capabilities.isAmazonApp&&!l(new RegExp(Z+"bwv"+
# Z+"b"));var g=r(e,"browser"),d=r(e,"prod_mshop"),f=r(e,"beta_mshop");!a.capabilities.isAmazonApp&&c.browser&&b&&(n(g+"supported"),c.browser.action(g,e));!b&&c.browser&&n(g+"unsupported");c.prodMshop&&n(d+"unsupported");c.betaMshop&&n(f+"unsupported")}}"use strict";var O=Q.now=Q.now||function(){return+new Q},D=function(a){return a&&a.now?a.now.bind(a):O}(f.performance),za=D(),t=f.AmazonUIPageJS||f.P;if(t&&t.when&&t.register)throw Error("A copy of P has already been loaded on this page.");var v=f.ue;
# G();G("aui_build_date:3.20.1-2020-02-28");var R=[],S=!1,T;T=function(){for(var a=setTimeout(T,0),b=O();R.length;)if(R.shift()(),50<O()-b)return;clearTimeout(a);S=!1};var ca={},B={},ea={},I=!1;y(f,"beforeunload",function(){I=!0;setTimeout(function(){I=!1},1E4)});var fa=/^prv:/,V={},J={},U={},ga={},wa=0,Z=String.fromCharCode(92),F,z=[],oa=f.onerror;f.onerror=function(a,b,c,e,g){g&&"object"===typeof g||(g=Error(a,b,c),g.columnNumber=e,g.stack=b||c||e?q(Z,g.message,"at "+q(":",b,c,e)):A);var d=z.pop()||
# {};g.attribution=q(":",g.attribution||d.attribution,d.name);g.logLevel=d.logLevel;g.attribution&&console&&console.log&&console.log([g.logLevel||"ERROR",a,"thrown by",g.attribution].join(" "));z=[];oa&&(d=[].slice.call(arguments),d[4]=g,oa.apply(f,d))};K.prototype={logError:function(a,b,c,e){b={message:b,logLevel:c||"ERROR",attribution:q(":",this.attribution,e)};if(f.ueLogError)return f.ueLogError(a||b,a?b:null),!0;console&&console.error&&(console.log(b),console.error(a));return!1},error:function(a,
# b,c,e){a=Error(q(":",e,a,c));a.attribution=q(":",this.attribution,b);throw a;},guardError:W(),guardFatal:W("FATAL"),guardCurrent:function(a){var b=z[z.length-1];return b?W(b.logLevel,b).call(this,a):a},log:function(a,b,c){return this.logError(null,a,b,c)},declare:C([],!0,!0,!0),register:C([],!0),execute:C([]),AUI_BUILD_DATE:"3.20.1-2020-02-28",when:ha(),now:ha(!0),trigger:function(a,b,c){var e=O();this.declare(a,{data:b,pageElapsedTime:e-(f.aPageStart||NaN),triggerTime:e});c&&c.instrument&&F.when("prv:a-logTrigger").execute(function(b){b(a)})},
# handleTriggers:function(){this.log("handleTriggers deprecated")},attributeErrors:function(a){return new K(a)},_namespace:function(a,b){return new K(a,b)}};var p=H(f,"AmazonUIPageJS",new K);F=p._namespace("PageJS","AmazonUI");F.declare("prv:p-debug",ga);p.declare("p-recorder-events",[]);p.declare("p-recorder-stop",function(){});H(f,"P",p);ia();if(h.addEventListener){var pa;h.addEventListener("DOMContentLoaded",pa=function(){p.trigger("a-domready");h.removeEventListener("DOMContentLoaded",pa,!1)},!1)}var m=
# h.documentElement,aa=function(){var a=["O","ms","Moz","Webkit"],b=h.createElement("div");return{testGradients:function(){b.style.cssText="background-image:-webkit-gradient(linear,left top,right bottom,from(#1E4),to(white));background-image:-webkit-linear-gradient(left top,#1E4,white);background-image:linear-gradient(left top,#1E4,white);";return~b.style.backgroundImage.indexOf("gradient")},test:function(c){var e=c.charAt(0).toUpperCase()+c.substr(1);c=(a.join(e+" ")+e+" "+c).split(" ");for(e=c.length;e--;)if(""===
# b.style[c[e]])return!0;return!1},testTransform3d:function(){var a=!1;f.matchMedia&&(a=f.matchMedia("(-webkit-transform-3d)").matches);return a}}}(),t=m.className,qa=/(^| )a-mobile( |$)/.test(t),ra=/(^| )a-tablet( |$)/.test(t),k={audio:function(){return!!h.createElement("audio").canPlayType},video:function(){return!!h.createElement("video").canPlayType},canvas:function(){return!!h.createElement("canvas").getContext},svg:function(){return!!h.createElementNS&&!!h.createElementNS("http://www.w3.org/2000/svg",
# "svg").createSVGRect},offline:function(){return navigator.hasOwnProperty&&navigator.hasOwnProperty("onLine")&&navigator.onLine},dragDrop:function(){return"draggable"in h.createElement("span")},geolocation:function(){return!!navigator.geolocation},history:function(){return!(!f.history||!f.history.pushState)},webworker:function(){return!!f.Worker},autofocus:function(){return"autofocus"in h.createElement("input")},inputPlaceholder:function(){return"placeholder"in h.createElement("input")},textareaPlaceholder:function(){return"placeholder"in
# h.createElement("textarea")},localStorage:function(){return"localStorage"in f&&null!==f.localStorage},orientation:function(){return"orientation"in f},touch:function(){return"ontouchend"in h},gradients:function(){return aa.testGradients()},hires:function(){var a=f.devicePixelRatio&&1.5<=f.devicePixelRatio||f.matchMedia&&f.matchMedia("(min-resolution:144dpi)").matches;x("hiRes"+(qa?"Mobile":ra?"Tablet":"Desktop"),a?1:0);return a},transform3d:function(){return aa.testTransform3d()},touchScrolling:function(){return l(/Windowshop|android|OS ([5-9]|[1-9][0-9]+)(_[0-9]{1,2})+ like Mac OS X|Chrome|Silk|Firefox|Trident.+?; Touch/i)},
# ios:function(){return l(/OS [1-9][0-9]*(_[0-9]*)+ like Mac OS X/i)&&!l(/trident|Edge/i)},android:function(){return l(/android.([1-9]|[L-Z])/i)&&!l(/trident|Edge/i)},mobile:function(){return qa},tablet:function(){return ra},rtl:function(){return"rtl"===m.dir}},u;for(u in k)k.hasOwnProperty(u)&&(k[u]=ja(k[u]));for(var ba="textShadow textStroke boxShadow borderRadius borderImage opacity transform transition".split(" "),P=0;P<ba.length;P++)k[ba[P]]=ja(function(){return aa.test(ba[P])});var M=!0,ka=0,
# Y={w:0,h:0},N=4;L();y(f,"resize",function(){clearTimeout(ka);N=4;L()});var sa={getItem:function(a){try{return f.localStorage.getItem(a)}catch(b){}},setItem:function(a,b){try{return f.localStorage.setItem(a,b)}catch(c){}}};m.className=X(m,"a-no-js");E(m,"a-js");!l(/OS [1-8](_[0-9]*)+ like Mac OS X/i)||f.navigator.standalone||l(/safari/i)||E(m,"a-ember");t=[];for(u in k)k.hasOwnProperty(u)&&k[u]&&t.push("a-"+u.replace(/([A-Z])/g,function(a){return"-"+a.toLowerCase()}));E(m,t.join(" "));m.setAttribute("data-aui-build-date",
# "3.20.1-2020-02-28");p.register("p-detect",function(){return{capabilities:k,localStorage:k.localStorage&&sa,toggleResponsiveGrid:xa,responsiveGridEnabled:ya}});l(/UCBrowser/i)||k.localStorage&&E(m,sa.getItem("a-font-class"));p.declare("a-event-revised-handling",!1);var w;try{w=navigator.serviceWorker}catch(a){G("sw:nav_err")}w&&(y(w,"message",function(a){a&&a.data&&x(a.data.k,a.data.v)}),w.controller&&w.controller.postMessage("MSG-RDY"));var ma=[];(function(a){var b=a.reg,c=a.unreg;w&&w.getRegistrations?
# (F.when("A","a-util").execute(function(a,b){na(a,b,c,"unregister")}),y(f,"load",function(){F.when("A","a-util").execute(function(a,c){na(a,c,b,"register");la()})})):(b&&(b.browser&&n(r("register","browser")+"unsupported"),b.prodMshop&&n(r("register","prod_mshop")+"unsupported"),b.betaMshop&&n(r("register","beta_mshop")+"unsupported")),c&&(c.browser&&n(r("unregister","browser")+"unsupported"),c.prodMshop&&n(r("unregister","prod_mshop")+"unsupported"),c.betaMshop&&n(r("unregister","beta_mshop")+"unsupported")),
# la())})({reg:{},unreg:{}});p.declare("a-fix-event-off",!1);x("pagejs:pkgExecTime",D()-za)})(window,document,Date);
#   (window.AmazonUIPageJS ? AmazonUIPageJS : P).load.js('https://images-na.ssl-images-amazon.com/images/I/61-6nKPKyWL._RC|11-BZEJ8lnL.js,61GQ9IdK7HL.js,21Of0-9HPCL.js,012FVc3131L.js,11S5WBtBslL.js,51CF7BmbF2L.js,11AHlQhPRjL.js,016iHgpF74L.js,11aNYFFS5hL.js,116tgw9TSaL.js,211-p4GRUCL.js,01PoLXBDXWL.js,618UAEWDpaL.js,01ezj5Rkz1L.js,11BOgvnnntL.js,31UWuPgtTtL.js,01rpauTep4L.js,01iyxuSGj4L.js,01nZw0IOzSL.js_.js?AUIClients/AmazonUI');
#   (window.AmazonUIPageJS ? AmazonUIPageJS : P).load.js('https://images-na.ssl-images-amazon.com/images/I/51voyzpfdCL.js?AUIClients/IMDbMojoSiteAssets');
# </script>
# </head><body class="mojo-page-id-cso a-m-us a-aui_157141-c a-aui_72554-c a-aui_dropdown_187959-c a-aui_pci_risk_banner_210084-c a-aui_perf_130093-c a-aui_tnr_v2_180836-c a-aui_ux_145937-c" id="body"><div id="a-page"><script data-a-state='{"key":"a-wlab-states"}' type="a-state">{}</script><div class="a-section a-spacing-none mojo-navigation mojo-header mojo-flex mojo-flex-h"><div class="a-section mojo-logo"><a class="a-link-normal" href="/?ref_=bo_nb_cso_mojologo"></a></div><div class="a-section a-spacing-none mojo-nav-elements mojo-flex mojo-flex-h mojo-flex-1"><div class="a-section a-spacing-none mojo-search-bar mojo-flex mojo-flex-h"><div class="a-section a-spacing-none mojo-search"><form action="/search">
# <input id="mojo-search-text-input" name="q" placeholder="Search for Titles" required="true" type="search"/>
# <input class="mojo-inline-button" id="mojo-search-button" type="submit" value=""/>
# </form>
# </div></div><div class="a-section a-spacing-none mojo-mobile-options"><span class="a-declarative" data-a-popover='{"closeButton":"false","inlineContent":"\u003cspan class=\"a-size-medium\"&gt;\u003ca href=\"https://pro.imdb.com/?ref_=mojo_nb_cso_pro&amp;amp;rf=mojo_nb_cso_pro\" class=\"a-touch-link a-box a-touch-link-noborder\"&gt;\u003cdiv class=\"a-box-inner\"&gt;\u003ci class=\"a-icon a-icon-touch-link\"&gt;\u003c\/i&gt;IMDbPro\u003c\/div&gt;\u003c\/a&gt;\u003ca href=\"https://www.facebook.com/BoxOfficeMojo/\" class=\"a-touch-link a-box a-touch-link-noborder\"&gt;\u003cdiv class=\"a-box-inner\"&gt;\u003ci class=\"a-icon a-icon-touch-link\"&gt;\u003c\/i&gt;Facebook\u003c\/div&gt;\u003c\/a&gt;\u003ca href=\"https://twitter.com/boxofficemojo\" class=\"a-touch-link a-box a-touch-link-noborder\"&gt;\u003cdiv class=\"a-box-inner\"&gt;\u003ci class=\"a-icon a-icon-touch-link\"&gt;\u003c\/i&gt;Twitter\u003c\/div&gt;\u003c\/a&gt;\u003ca href=\"https://help.imdb.com/article/imdbpro/industry-research/box-office-mojo-by-imdbpro-faq/GCWTV4MQKGWRAUAP?ref_=mojo_ftr_help\" class=\"a-touch-link a-box a-touch-link-noborder\"&gt;\u003cdiv class=\"a-box-inner\"&gt;\u003ci class=\"a-icon a-icon-touch-link\"&gt;\u003c\/i&gt;Help\u003c\/div&gt;\u003c\/a&gt;\u003c\/span&gt;"}' data-action="a-popover"><a class="a-popover-trigger a-declarative" href="javascript:void(0)"><span class="mobile-menu-popover-trigger"></span>
# <i class="a-icon a-icon-popover"></i></a></span></div><div class="a-section a-spacing-none mojo-options mojo-flex"><div class="a-popover-preload" id="a-popover-mojoRollover"><a class="a-link-normal mojo-rollover-image" href="https://pro.imdb.com/login/ap?u=%2Flogin%2Flwa&amp;imdbPageAction=signUp&amp;ref_=mojo_nb_cso_rollover&amp;rf=mojo_nb_cso_rollover"><img alt="" src="https://m.media-amazon.com/images/G/01/IMDbPro/images/MI_121919_NYNY2020_Engagement_rollover_2x._CB1578336809_.png"/></a></div><span class="a-declarative" data-a-popover='{"padding":"none","closeButton":"false","dataStrategy":"preload","name":"mojoRollover","width":"500","position":"triggerBottom","height":"200"}' data-action="a-popover"><a class="a-popover-trigger a-declarative" href="javascript:void(0)"><span class="imdb-pro-logo"></span><i class="a-icon a-icon-popover"></i></a></span><span class="mojo-logo-delimiter"></span><a class="a-link-normal mojo-fb-logo" href="https://www.facebook.com/BoxOfficeMojo/" rel="noopener" target="_blank"></a><a class="a-link-normal mojo-tw-logo" href="https://twitter.com/boxofficemojo" rel="noopener" target="_blank"></a></div></div><div class="a-section a-spacing-none mojo-link-bar mojo-flex mojo-flex-h"><div class="a-section a-spacing-none mojo-tab-container"><a class="a-size-medium a-link-normal mojo-navigation-tab" href="/date/?ref_=bo_nb_cso_tab">Domestic</a><a class="a-size-medium a-link-normal mojo-navigation-tab" href="/intl/?ref_=bo_nb_cso_tab">International</a><a class="a-size-medium a-link-normal mojo-navigation-tab" href="/year/world/?ref_=bo_nb_cso_tab">Worldwide</a><a class="a-size-medium a-link-normal mojo-navigation-tab" href="/calendar/?ref_=bo_nb_cso_tab">Calendar</a><a class="a-size-medium a-link-normal mojo-navigation-tab mojo-navigation-tab-active" href="/charts/overall/?ref_=bo_nb_cso_tab">All Time</a><a class="a-size-medium a-link-normal mojo-navigation-tab" href="/showdown/?ref_=bo_nb_cso_tab">Showdowns</a><a class="a-size-medium a-link-normal mojo-navigation-tab" href="/news/?ref_=bo_nb_cso_tab">News</a></div></div><div class="a-section a-spacing-none mojo-link-bar-secondary mojo-flex mojo-flex-h"><div class="a-section a-spacing-base mojo-tab-container"><a class="a-size-medium a-link-normal mojo-navigation-tab mojo-navigation-tab-active" href="/charts/overall/?ref_=bo_nb_cso_secondarytab"><h2 class="a-size-medium a-text-normal">Overall</h2></a><a class="a-size-medium a-link-normal mojo-navigation-tab" href="/charts/weekend/?ref_=bo_nb_cso_secondarytab">Weekend Records</a><a class="a-size-medium a-link-normal mojo-navigation-tab" href="/charts/daily/?ref_=bo_nb_cso_secondarytab">Daily Records</a><a class="a-size-medium a-link-normal mojo-navigation-tab" href="/charts/misc/?ref_=bo_nb_cso_secondarytab">Miscellaneous Records</a></div></div><div class="a-section a-spacing-none mojo-link-bar-fade"><span class="a-letter-space"></span></div></div><main>
# <div class="a-section mojo-body aok-relative"><div class="a-section a-spacing-none"><h1 class="mojo-gutter">Top Lifetime Grosses</h1><div class="a-section mojo-gutter-sides"></div><div class="mojo-refiner mojo-override-gutter">
# <div class="mojo-refinement mojo-refinement-dropdown">
# <span class="mojo-dropdown-clear">
# <form action="" autocomplete="off" class="a-spacing-none" method="post"><span class="a-dropdown-container"><select autocomplete="off" class="a-native-dropdown" id="area-navSelector" name="area-navSelector" tabindex="-1"><option value="/chart/top_lifetime_gross/">Domestic</option><option selected="" value="/chart/ww_top_lifetime_gross/?area=XWW">Worldwide</option></select><span class="a-button a-button-dropdown" tabindex="-1"><span class="a-button-inner"><span aria-hidden="true" class="a-button-text a-declarative" data-action="a-dropdown-button" role="button" tabindex="0"><span class="a-dropdown-prompt"></span></span><i class="a-icon a-icon-dropdown"></i></span></span></span></form></span>
# </div>
# </div>
# <div class="a-text-center mojo-pagination"><ul class="a-pagination"><li><a href="/chart/ww_top_lifetime_gross/?offset=400&amp;area=XWW">←<span class="a-letter-space"></span><span class="a-letter-space"></span>Previous page</a></li><li class="a-selected mojo-pagination-button-center"><a href="#">601-800 of 1,000</a></li><li class="a-last"><a href="/chart/ww_top_lifetime_gross/?offset=800&amp;area=XWW">Next page<span class="a-letter-space"></span><span class="a-letter-space"></span>→</a></li></ul></div><style>
# table.a-bordered.mojo-body-table-compact td,
# table.a-bordered.mojo-body-table-compact th {
#     padding: 5px;
# }
# table.mojo-body-table tr.mojo-group-label th {
#     background: linear-gradient(to bottom, #f8f8f8, #eee);
# }
# </style>
# <div class="a-section imdb-scroll-table mojo-gutter-sides" id="table"><div class="a-section imdb-scroll-table-inner"><table class="a-bordered a-horizontal-stripes a-size-base a-span12 mojo-body-table mojo-table-annotated"><tr><th class="a-text-right mojo-field-type-rank a-nowrap"><span title="Rank">Rank</span>
# </th><th class="a-text-left mojo-field-type-title a-nowrap"><span title="Title">Title</span>
# </th><th class="a-text-right mojo-field-type-money a-nowrap"><span title="Worldwide Lifetime Gross">Worldwide Lifetime Gross</span>
# </th><th class="a-text-right mojo-field-type-money a-nowrap"><span title="Domestic Lifetime Gross">Domestic Lifetime Gross</span>
# </th><th class="a-text-right mojo-field-type-percent a-nowrap"><span title="Domestic %">Domestic %</span>
# </th><th class="a-text-right mojo-field-type-money a-nowrap"><span title="Foreign Lifetime Gross">Foreign Lifetime Gross</span>
# </th><th class="a-text-right mojo-field-type-percent a-nowrap"><span title="Foreign %">Foreign %</span>
# </th><th class="a-text-left mojo-field-type-year a-nowrap"><span title="Year">Year</span>
# </th></tr><tr><td class="a-text-right mojo-header-column mojo-truncate mojo-field-type-rank">605</td><td class="a-text-left mojo-field-type-title"><a class="a-link-normal" href="/title/tt2283336/?ref_=bo_cso_table_1">Men in Black: International</a></td><td class="a-text-right mojo-field-type-money">$253,890,701</td><td class="a-text-right mojo-field-type-money">$80,001,807</td><td class="a-text-right mojo-field-type-percent">31.5%</td><td class="a-text-right mojo-field-type-money">$173,888,894</td><td class="a-text-right mojo-field-type-percent">68.5%</td><td class="a-text-left mojo-field-type-year"><a class="a-link-normal" href="/year/world/2019/?ref_=bo_cso_table_1">2019</a></td></tr><tr><td class="a-text-right mojo-header-column mojo-truncate mojo-field-type-rank">606</td><td class="a-text-left mojo-field-type-title"><a class="a-link-normal" href="/title/tt0486946/?ref_=bo_cso_table_2">Wild Hogs</a></td><td class="a-text-right mojo-field-type-money">$253,625,427</td><td class="a-text-right mojo-field-type-money">$168,273,550</td><td class="a-text-right mojo-field-type-percent">66.4%</td><td class="a-text-right mojo-field-type-money">$85,351,877</td><td class="a-text-right mojo-field-type-percent">33.6%</td><td class="a-text-left mojo-field-type-year"><a class="a-link-normal" href="/year/world/2007/?ref_=bo_cso_table_2">2007</a></td></tr><tr><td class="a-text-right mojo-header-column mojo-truncate mojo-field-type-rank">607</td><td class="a-text-left mojo-field-type-title"><a class="a-link-normal" href="/title/tt0962726/?ref_=bo_cso_table_3">High School Musical 3</a></td><td class="a-text-right mojo-field-type-money">$252,909,177</td><td class="a-text-right mojo-field-type-money">$90,559,416</td><td class="a-text-right mojo-field-type-percent">35.8%</td><td class="a-text-right mojo-field-type-money">$162,349,761</td><td class="a-text-right mojo-field-type-percent">64.2%</td><td class="a-text-left mojo-field-type-year"><a class="a-link-normal" href="/year/world/2008/?ref_=bo_cso_table_3">2008</a></td></tr><tr><td class="a-text-right mojo-header-column mojo-truncate mojo-field-type-rank">608</td><td class="a-text-left mojo-field-type-title"><a class="a-link-normal" href="/title/tt0119282/?ref_=bo_cso_table_4">Hercules</a></td><td class="a-text-right mojo-field-type-money">$252,712,101</td><td class="a-text-right mojo-field-type-money">$99,112,101</td><td class="a-text-right mojo-field-type-percent">39.2%</td><td class="a-text-right mojo-field-type-money">$153,600,000</td><td class="a-text-right mojo-field-type-percent">60.8%</td><td class="a-text-left mojo-field-type-year"><a class="a-link-normal" href="/year/world/1997/?ref_=bo_cso_table_4">1997</a></td></tr><tr><td class="a-text-right mojo-header-column mojo-truncate mojo-field-type-rank">609</td><td class="a-text-left mojo-field-type-title"><a class="a-link-normal" href="/title/tt6565702/?ref_=bo_cso_table_5">X-Men: Dark Phoenix</a></td><td class="a-text-right mojo-field-type-money">$252,442,974</td><td class="a-text-right mojo-field-type-money">$65,845,974</td><td class="a-text-right mojo-field-type-percent">26.1%</td><td class="a-text-right mojo-field-type-money">$186,597,000</td><td class="a-text-right mojo-field-type-percent">73.9%</td><td class="a-text-left mojo-field-type-year"><a class="a-link-normal" href="/year/world/2019/?ref_=bo_cso_table_5">2019</a></td></tr><tr><td class="a-text-right mojo-header-column mojo-truncate mojo-field-type-rank">610</td><td class="a-text-left mojo-field-type-title"><a class="a-link-normal" href="/title/tt1403865/?ref_=bo_cso_table_6">True Grit</a></td><td class="a-text-right mojo-field-type-money">$252,276,927</td><td class="a-text-right mojo-field-type-money">$171,243,005</td><td class="a-text-right mojo-field-type-percent">67.9%</td><td class="a-text-right mojo-field-type-money">$81,033,922</td><td class="a-text-right mojo-field-type-percent">32.1%</td><td class="a-text-left mojo-field-type-year"><a class="a-link-normal" href="/year/ ...
# <div class="a-section a-spacing-none mojo-navigation-frame"><div class="a-section a-spacing-none mojo-navigation mojo-footer"><a class="a-link-normal imdb-pro-logo" href="https://pro.imdb.com/?ref_=mojo_ft_cso_prologo&amp;rf=mojo_ft_cso_prologo"></a><p>
#             Latest Updates:
#             <a class="a-link-normal" href="/news/?ref_=bo_ft_cso_news">News</a> |
#             <a class="a-link-normal" href="/daily/?ref_=bo_ft_cso_daily">Daily</a> |
#             <a class="a-link-normal" href="/weekend/?ref_=bo_ft_cso_weekend">Weekend</a> |
#             <a class="a-link-normal" href="/charts/?ref_=bo_ft_cso_charts">All Time</a> |
#             <a class="a-link-normal" href="/intl/?ref_=bo_ft_cso_intl">International</a> |
#             <a class="a-link-normal" href="/showdown/?ref_=bo_ft_cso_showdown">Showdowns</a></p><p><a class="a-link-normal" href="https://help.imdb.com/article/imdbpro/industry-research/box-office-mojo-by-imdbpro-faq/GCWTV4MQKGWRAUAP?ref_=mojo_ftr_help" rel="noopener" target="_blank">Help</a></p><p>
#             BoxOfficeMojo.com by IMDbPro - an
#             <a class="a-link-normal" href="http://www.imdb.com/" rel="noopener" target="_blank">IMDb</a>
#             company.
#         </p><p>
#             © IMDb.com, Inc. or its affiliates. All rights reserved.
#             Box Office Mojo and IMDb are trademarks or registered trademarks of IMDb.com, Inc. or its affiliates.
#             <a class="a-link-normal" href="/conditions/?ref_=bo_ft_cso_conditions">Conditions of Use</a>
#              and
#              <a class="a-link-normal" href="/privacy/?ref_=bo_ft_cso_privacy">Privacy Policy</a>
#             under which this service is provided to you.
#         </p></div></div></div></body></html>>

# %%
movie_list4 = []
row_list = []
for record in soup.findAll("tr"):
    for data in record.findAll("td"):
        row_list.append(data.text)
    if row_list == []:
        pass
    else:
        movie_list4.append(row_list)
        row_list = []
movie_list4
# Out:
# [['605',
#   'Men in Black: International',
#   '$253,890,701',
#   '$80,001,807',
#   '31.5%',
#   '$173,888,894',
#   '68.5%',
#   '2019'],
#  ['606',
#   'Wild Hogs',
#   '$253,625,427',
#   '$168,273,550',
#   '66.4%',
#   '$85,351,877',
#   '33.6%',
#   '2007'],
#  ['607',
#   'High School Musical 3',
#   '$252,909,177',
#   '$90,559,416',
#   '35.8%',
#   '$162,349,761',
#   '64.2%',
#   '2008'],
#  ['608',
#   'Hercules',
#   '$252,712,101',
#   '$99,112,101',
#   '39.2%',
#   '$153,600,000',
#   '60.8%',
#   '1997'],
#  ['609',
#   'X-Men: Dark Phoenix',
#   '$252,442,974',
#   '$65,845,974',
#   '26.1%',
#   '$186,597,000',
#   '73.9%',
#   '2019'],
#  ['610',
#   'True Grit',
#   '$252,276,927',
#   '$171,243,005',
#   '67.9%',
#   '$81,033,922',
#   '32.1%',
#   '2010'],
#  ['611',
#   'Bean',
#   '$251,212,670',
#   '$45,319,423',
#   '18%',
#   '$205,893,247',
#   '82%',
#   '1997'],
#  ['612',
#   'American Hustle',
#   '$251,171,807',
#   '$150,117,807',
#   '59.8%',
#   '$101,054,000',
#   '40.2%',
#   '2013'],
#  ['613',
#   'Enemy of the State',
#   '$250,849,789',
#   '$111,549,836',
#   '44.5%',
#   '$139,299,953',
#   '55.5%',
#   '1998'],
#  ['614',
#   "You've Got Mail",
#   '$250,821,495',
#   '$115,821,495',
#   '46.2%',
#   '$135,000,000',
#   '53.8%',
#   '1998'],
#  ['615',
#   'Eragon',
#   '$250,425,512',
#   '$75,030,163',
#   '30%',
#   '$175,395,349',
#   '70%',
#   '2006'],
#  ['616',
#   'Brother Bear',
#   '$250,397,798',
#   '$85,336,277',
#   '34.1%',
#   '$165,061,521',
#   '65.9%',
#   '2003'],
#  ['617',
#   'The Mask of Zorro',
#   '$250,288,523',
#   '$94,095,523',
#   '37.6%',
#   '$156,193,000',
#   '62.4%',
#   '1998'],
#  ['618',
#   'The Ring',
#   '$249,348,933',
#   '$129,128,133',
#   '51.8%',
#   '$120,220,800',
#   '48.2%',
#   '2002'],
#  ['619',
#   'The Blair Witch Project',
#   '$248,639,099',
#   '$140,539,099',
#   '56.5%',
#   '$108,100,000',
#   '43.5%',
#   '1999'],
#  ['620',
#   'Unbreakable',
#   '$248,118,121',
#   '$95,011,339',
#   '38.3%',
#   '$153,106,782',
#   '61.7%',
#   '2000'],
#  ['621',
#   'Journey to the West: The Demons Strike Back',
#   '$247,585,244',
#   '$880,346',
#   '0.4%',
#   '$246,704,898',
#   '99.6%',
#   '2017'],
#  ['622',
#   'Dumb and Dumber',
#   '$247,275,374',
#   '$127,175,374',
#   '51.4%',
#   '$120,100,000',
#   '48.6%',
#   '1994'],
#  ['623',
#   'Glass',
#   '$246,999,039',
#   '$111,048,468',
#   '45%',
#   '$135,950,571',
#   '55%',
#   '2019'],
#  ['624',
#   'Grown Ups 2',
#   '$246,984,278',
#   '$133,668,525',
#   '54.1%',
#   '$113,315,753',
#   '45.9%',
#   '2013'],
#  ['625',
#   'The Peanuts Movie',
#   '$246,233,113',
#   '$130,178,411',
#   '52.9%',
#   '$116,054,702',
#   '47.1%',
#   '2015'],
#  ['626',
#   'Back to the Future Part III',
#   '$246,144,250',
#   '$88,277,583',
#   '35.9%',
#   '$157,866,667',
#   '64.1%',
#   '1990'],
#  ['627',
#   'The Godfather',
#   '$246,120,974',
#   '$134,966,411',
#   '54.8%',
#   '$111,154,563',
#   '45.2%',
#   '1972'],
#  ['628',
#   'Rango',
#   '$245,724,603',
#   '$123,477,607',
#   '50.2%',
#   '$122,246,996',
#   '49.8%',
#   '2011'],
#  ['629',
#   'Four Weddings and a Funeral',
#   '$245,700,832',
#   '$52,700,832',
#   '21.4%',
#   '$193,000,000',
#   '78.6%',
#   '1994'],
#  ['630',
#   'Face/Off',
#   '$245,676,146',
#   '$112,276,146',
#   '45.7%',
#   '$133,400,000',
#   '54.3%',
#   '1997'],
#  ['631',
#   'Teenage Mutant Ninja Turtles: Out of the Shadows',
#   '$245,623,848',
#   '$82,051,601',
#   '33.4%',
#   '$163,572,247',
#   '66.6%',
#   '2016'],
#  ['632',
#   'Dark Shadows',
#   '$245,527,149',
#   '$79,727,149',
#   '32.5%',
#   '$165,800,000',
#   '67.5%',
#   '2012'],
#  ['633',
#   'Hulk',
#   '$245,285,165',
#   '$132,177,234',
#   '53.9%',
#   '$113,107,931',
#   '46.1%',
#   '2003'],
#  ['634',
#   'The Bravest',
#   '$245,179,562',
#   '$290,217',
#   '0.1%',
#   '$244,889,345',
#   '99.9%',
#   '2019'],
#  ['636',
#   'Love Actually',
#   '$244,931,766',
#   '$59,696,144',
#   '24.4%',
#   '$185,235,622',
#   '75.6%',
#   '2003'],
#  ['637',
#   'Pixels',
#   '$244,874,809',
#   '$78,747,585',
#   '32.2%',
#   '$166,127,224',
#   '67.8%',
#   '2015'],
#  ['638',
#   'Hercules',
#   '$244,819,862',
#   '$72,688,614',
#   '29.7%',
#   '$172,131,248',
#   '70.3%',
#   '2014'],
#  ['639',
#   'Rush Hour',
#   '$244,721,064',
#   '$141,186,864',
#   '57.7%',
#   '$103,534,200',
#   '42.3%',
#   '1998'],
#  ['640',
#   'Journey to the Center of the Earth',
#   '$244,232,688',
#   '$101,704,370',
#   '41.6%',
#   '$142,528,318',
#   '58.4%',
#   '2008'],
#  ['641',
#   'After Earth',
#   '$243,611,982',
#   '$60,522,097',
#   '24.8%',
#   '$183,089,885',
#   '75.2%',
#   '2013'],
#  ['642',
#   'A Few Good Men',
#   '$243,240,178',
#   '$141,340,178',
#   '58.1%',
#   '$101,900,000',
#   '41.9%',
#   '1992'],
#  ['643',
#   'Cloudy with a Chance of Meatballs',
#   '$243,006,126',
#   '$124,870,275',
#   '51.4%',
#   '$118,135,851',
#   '48.6%',
#   '2009'],
#  ['644',
#   '8 Mile',
#   '$242,875,078',
#   '$116,750,901',
#   '48.1%',
#   '$126,124,177',
#   '51.9%',
#   '2002'],
#  ['645',
#   "Daddy's Home",
#   '$242,786,137',
#   '$150,357,137',
#   '61.9%',
#   '$92,429,000',
#   '38.1%',
#   '2015'],
#  ['646',
#   'RoboCop',
#   '$242,688,965',
#   '$58,607,007',
#   '24.2%',
#   '$184,081,958',
#   '75.8%',
#   '2014'],
#  ['647',
#   'Eraser',
#   '$242,295,562',
#   '$101,295,562',
#   '41.8%',
#   '$141,000,000',
#   '58.2%',
#   '1996'],
#  ['648',
#   'Alien: Covenant',
#   '$240,891,763',
#   '$74,262,031',
#   '30.8%',
#   '$166,629,732',
#   '69.2%',
#   '2017'],
#  ['649',
#   'Sully',
#   '$240,797,623',
#   '$125,070,033',
#   '51.9%',
#   '$115,727,590',
#   '48.1%',
#   '2016'],
#  ['650',
#   "Assassin's Creed",
#   '$240,697,856',
#   '$54,647,948',
#   '22.7%',
#   '$186,049,908',
#   '77.3%',
#   '2016'],
#  ['651',
#   'Click',
#   '$240,685,326',
#   '$137,355,633',
#   '57.1%',
#   '$103,329,693',
#   '42.9%',
#   '2006'],
#  ['652',
#   'Die Hard 2',
#   '$240,247,433',
#   '$117,540,947',
#   '48.9%',
#   '$122,706,486',
#   '51.1%',
#   '1990'],
#  ['653',
#   'Resident Evil: Retribution',
#   '$240,159,255',
#   '$42,345,531',
#   '17.6%',
#   '$197,813,724',
#   '82.4%',
#   '2012'],
#  ['654',
#   'Crocodile Dundee II',
#   '$239,606,210',
#   '$109,306,210',
#   '45.6%',
#   '$130,300,000',
#   '54.4%',
#   '1988'],
#  ['655',
#   'Planes',
#   '$239,258,712',
#   '$90,288,712',
#   '37.7%',
#   '$148,970,000',
#   '62.3%',
#   '2013'],
#  ['656',
#   'Crazy Rich Asians',
#   '$238,532,921',
#   '$174,532,921',
#   '73.2%',
#   '$64,000,000',
#   '26.8%',
#   '2018'],
#  ['657',
#   'Batman & Robin',
#   '$238,235,915',
#   '$107,353,792',
#   '45.1%',
#   '$130,882,123',
#   '54.9%',
#   '1997'],
#  ['658',
#   "Gulliver's Travels",
#   '$237,382,724',
#   '$42,779,261',
#   '18%',
#   '$194,603,463',
#   '82%',
#   '2010'],
#  ['659',
#   'Gone in 60 Seconds',
#   '$237,202,299',
#   '$101,648,571',
#   '42.8%',
#   '$135,553,728',
#   '57.2%',
#   '2000'],
#  ['660',
#   'Saturday Night Fever',
#   '$237,113,184',
#   '$94,213,184',
#   '39.7%',
#   '$142,900,000',
#   '60.3%',
#   '1977'],
#  ['661',
#   'Silver Linings Playbook',
#   '$236,412,453',
#   '$132,092,958',
#   '55.9%',
#   '$104,319,495',
#   '44.1%',
#   '2012'],
#  ['662',
#   '2 Fast 2 Furious',
#   '$236,350,661',
#   '$127,154,901',
#   '53.8%',
#   '$109,195,760',
#   '46.2%',
#   '2003'],
#  ['663',
#   "Howl's Moving Castle",
#   '$236,212,992',
#   '$5,576,743',
#   '2.4%',
#   '$230,636,249',
#   '97.6%',
#   '2004'],
#  ['664',
#   'Hidden Figures',
#   '$235,956,898',
#   '$169,607,287',
#   '71.9%',
#   '$66,349,611',
#   '28.1%',
#   '2016'],
#  ['665',
#   'A.I. Artificial Intelligence',
#   '$235,926,552',
#   '$78,616,689',
#   '33.3%',
#   '$157,309,863',
#   '66.7%',
#   '2001'],
#  ['666',
#   'Dead Poets Society',
#   '$235,860,116',
#   '$95,860,116',
#   '40.6%',
#   '$140,000,000',
#   '59.4%',
#   '1988'],
#  ['667',
#   'Spy',
#   '$235,666,219',
#   '$110,825,712',
#   '47%',
#   '$124,840,507',
#   '53%',
#   '2015'],
#  ['668',
#   'American Pie',
#   '$235,483,004',
#   '$102,561,004',
#   '43.6%',
#   '$132,922,000',
#   '56.4%',
#   '1999'],
#  ['669',
#   'American Reunion',
#   '$234,989,584',
#   '$57,011,521',
#   '24.3%',
#   '$177,978,063',
#   '75.7%',
#   '2012'],
#  ['670',
#   'Big Daddy',
#   '$234,801,895',
#   '$163,479,795',
#   '69.6%',
#   '$71,322,100',
#   '30.4%',
#   '1999'],
#  ['671',
#   'Alvin and the Chipmunks: The Road Chip',
#   '$234,798,636',
#   '$85,886,987',
#   '36.6%',
#   '$148,911,649',
#   '63.4%',
#   '2015'],
#  ['672',
#   'The Imitation Game',
#   '$233,555,708',
#   '$91,125,683',
#   '39%',
#   '$142,430,025',
#   '61%',
#   '2014'],
#  ['673',
#   'The Day the Earth Stood Still',
#   '$233,093,859',
#   '$79,366,978',
#   '34%',
#   '$153,726,881',
#   '66%',
#   '2008'],
#  ['674',
#   'American Wedding',
#   '$232,722,935',
#   '$104,565,114',
#   '44.9%',
#   '$128,157,821',
#   '55.1%',
#   '2003'],
#  ['675',
#   'The Girl with the Dragon Tattoo',
#   '$232,617,430',
#   '$102,515,793',
#   '44.1%',
#   '$130,101,637',
#   '55.9%',
#   '2011'],
#  ['676',
#   'Juno',
#   '$232,372,681',
#   '$143,495,265',
#   '61.8%',
#   '$88,877,416',
#   '38.2%',
#   '2007'],
#  ['677',
#   'Argo',
#   '$232,325,503',
#   '$136,025,503',
#   '58.6%',
#   '$96,300,000',
#   '41.4%',
#   '2012'],
#  ['678',
#   "Mr. Bean's Holiday",
#   '$232,225,908',
#   '$33,302,167',
#   '14.3%',
#   '$198,923,741',
#   '85.7%',
#   '2007'],
#  ['679',
#   'The English Patient',
#   '$231,976,425',
#   '$78,676,425',
#   '33.9%',
#   '$153,300,000',
#   '66.1%',
#   '1996'],
#  ['680',
#   'Sister Act',
#   '$231,605,150',
#   '$139,605,150',
#   '60.3%',
#   '$92,000,000',
#   '39.7%',
#   '1992'],
#  ['681',
#   'Annabelle Comes Home',
#   '$231,252,591',
#   '$74,152,591',
#   '32.1%',
#   '$157,100,000',
#   '67.9%',
#   '2019'],
#  ['682',
#   'Constantine',
#   '$230,884,728',
#   '$75,976,178',
#   '32.9%',
#   '$154,908,550',
#   '67.1%',
#   '2005'],
#  ['683',
#   'Get Smart',
#   '$230,685,453',
#   '$130,319,208',
#   '56.5%',
#   '$100,366,245',
#   '43.5%',
#   '2008'],
#  ['684',
#   'Space Jam',
#   '$230,418,342',
#   '$90,418,342',
#   '39.2%',
#   '$140,000,000',
#   '60.8%',
#   '1996'],
#  ['685',
#   'Life Is Beautiful',
#   '$230,098,753',
#   '$57,563,264',
#   '25%',
#   '$172,535,489',
#   '75%',
#   '1998'],
#  ['686',
#   'The Heat',
#   '$229,930,771',
#   '$159,582,188',
#   '69.4%',
#   '$70,348,583',
#   '30.6%',
#   '2013'],
#  ['687',
#   'Ghostbusters',
#   '$229,147,509',
#   '$128,350,574',
#   '56%',
#   '$100,796,935',
#   '44%',
#   '2016'],
#  ['688',
#   'Ghost Rider',
#   '$228,738,393',
#   '$115,802,596',
#   '50.6%',
#   '$112,935,797',
#   '49.4%',
#   '2007'],
#  ['690',
#   'Goodbye Mr. Loser',
#   '$228,122,928',
#   '$1,293,626',
#   '0.6%',
#   '$226,829,302',
#   '99.4%',
#   '2015'],
#  ['691',
#   'Paddington 2',
#   '$227,978,523',
#   '$40,891,591',
#   '17.9%',
#   '$187,086,932',
#   '82.1%',
#   '2017'],
#  ['692',
#   'Sleepless in Seattle',
#   '$227,927,165',
#   '$126,808,165',
#   '55.6%',
#   '$101,119,000',
#   '44.4%',
#   '1993'],
#  ['693',
#   'Lethal Weapon 2',
#   '$227,853,986',
#   '$147,253,986',
#   '64.6%',
#   '$80,600,000',
#   '35.4%',
#   '1989'],
#  ['694',
#   'Parasite',
#   '$227,847,373',
#   '$51,479,136',
#   '22.6%',
#   '$176,368,237',
#   '77.4%',
#   '2019'],
#  ['695',
#   'The Green Hornet',
#   '$227,817,248',
#   '$98,780,042',
#   '43.4%',
#   '$129,037,206',
#   '56.6%',
#   '2011'],
#  ['696',
#   'Out of Africa',
#   '$227,542,205',
#   '$87,071,205',
#   '38.3%',
#   '$140,471,000',
#   '61.7%',
#   '1985'],
#  ['697',
#   'Youth',
#   '$227,091,290',
#   '$1,891,956',
#   '0.8%',
#   '$225,199,334',
#   '99.2%',
#   '2017'],
#  ['698',
#   'Baby Driver',
#   '$226,945,087',
#   '$107,825,862',
#   '47.5%',
#   '$119,119,225',
#   '52.5%',
#   '2017'],
#  ['699',
#   'Immortals',
#   '$226,904,017',
#   '$83,504,017',
#   '36.8%',
#   '$143,400,000',
#   '63.2%',
#   '2011'],
#  ['700',
#   'Taken',
#   '$226,837,760',
#   '$145,000,989',
#   '63.9%',
#   '$81,836,771',
#   '36.1%',
#   '2008'],
#  ['701',
#   'Percy Jackson & the Olympians: The Lightning Thief',
#   '$226,497,209',
#   '$88,768,303',
#   '39.2%',
#   '$137,728,906',
#   '60.8%',
#   '2010'],
#  ['702',
#   'Hansel & Gretel: Witch Hunters',
#   '$226,349,749',
#   '$55,703,475',
#   '24.6%',
#   '$170,646,274',
#   '75.4%',
#   '2013'],
#  ['703',
#   'Good Will Hunting',
#   '$225,933,435',
#   '$138,433,435',
#   '61.3%',
#   '$87,500,000',
#   '38.7%',
#   '1997'],
#  ['704',
#   'Valerian and the City of a Thousand Planets',
#   '$225,874,228',
#   '$41,189,488',
#   '18.2%',
#   '$184,684,740',
#   '81.8%',
#   '2017'],
#  ['705',
#   'Ford v Ferrari',
#   '$225,388,680',
#   '$117,504,827',
#   '52.1%',
#   '$107,883,853',
#   '47.9%',
#   '2019'],
#  ['706',
#   'Better Days',
#   '$225,320,294',
#   '$1,921,657',
#   '0.8%',
#   '$223,398,637',
#   '99.2%',
#   '2019'],
#  ['707',
#   'Jumper',
#   '$225,132,113',
#   '$80,172,128',
#   '35.6%',
#   '$144,959,985',
#   '64.4%',
#   '2008'],
#  ['708',
#   'The Social Network',
#   '$224,920,315',
#   '$96,962,694',
#   '43.1%',
#   '$127,957,621',
#   '56.9%',
#   '2010'],
#  ['709',
#   'Chicken Run',
#   '$224,834,564',
#   '$106,834,564',
#   '47.5%',
#   '$118,000,000',
#   '52.5%',
#   '2000'],
#  ['710',
#   'Con Air',
#   '$224,012,234',
#   '$101,117,573',
#   '45.1%',
#   '$122,894,661',
#   '54.9%',
#   '1997'],
#  ['711',
#   'Interview with the Vampire: The Vampire Chronicles',
#   '$223,664,608',
#   '$105,264,608',
#   '47.1%',
#   '$118,400,000',
#   '52.9%',
#   '1994'],
#  ['712',
#   'Flightplan',
#   '$223,387,299',
#   '$89,707,299',
#   '40.2%',
#   '$133,680,000',
#   '59.8%',
#   '2005'],
#  ['713',
#   'Yes Man',
#   '$223,241,637',
#   '$97,690,976',
#   '43.8%',
#   '$125,550,661',
#   '56.2%',
#   '2008'],
#  ['714',
#   'Non-Stop',
#   '$222,809,600',
#   '$92,168,600',
#   '41.4%',
#   '$130,641,000',
#   '58.6%',
#   '2014'],
#  ['715',
#   'Honey, I Shrunk the Kids',
#   '$222,724,172',
#   '$130,724,172',
#   '58.7%',
#   '$92,000,000',
#   '41.3%',
#   '1989'],
#  ['716',
#   'Fahrenheit 9/11',
#   '$222,446,882',
#   '$119,194,771',
#   '53.6%',
#   '$103,252,111',
#   '46.4%',
#   '2004'],
#  ['717',
#   'Wild Wild West',
#   '$222,104,681',
#   '$113,804,681',
#   '51.2%',
#   '$108,300,000',
#   '48.8%',
#   '1999'],
#  ['718',
#   'Elf',
#   '$221,671,773',
#   '$174,626,840',
#   '78.8%',
#   '$47,044,933',
#   '21.2%',
#   '2003'],
#  ['719',
#   'Geostorm',
#   '$221,600,160',
#   '$33,700,160',
#   '15.2%',
#   '$187,900,000',
#   '84.8%',
#   '2017'],
#  ['720',
#   'Presumed Innocent',
#   '$221,303,188',
#   '$86,303,188',
#   '39%',
#   '$135,000,000',
#   '61%',
#   '1990'],
#  ['721',
#   'Collateral',
#   '$220,926,695',
#   '$101,005,703',
#   '45.7%',
#   '$119,920,992',
#   '54.3%',
#   '2004'],
#  ['722',
#   'Scary Movie 3',
#   '$220,673,217',
#   '$110,003,217',
#   '49.8%',
#   '$110,670,000',
#   '50.2%',
#   '2003'],
#  ['723',
#   'Inferno',
#   '$220,021,259',
#   '$34,343,574',
#   '15.6%',
#   '$185,677,685',
#   '84.4%',
#   '2016'],
#  ['724',
#   'Knocked Up',
#   '$219,922,417',
#   '$148,768,917',
#   '67.6%',
#   '$71,153,500',
#   '32.4%',
#   '2007'],
#  ['725',
#   'Green Lantern',
#   '$219,851,172',
#   '$116,601,172',
#   '53%',
#   '$103,250,000',
#   '47%',
#   '2011'],
#  ['726',
#   'What Happens in Vegas',
#   '$219,375,562',
#   '$80,277,646',
#   '36.6%',
#   '$139,097,916',
#   '63.4%',
#   '2008'],
#  ['727',
#   "It's Complicated",
#   '$219,103,655',
#   '$112,735,375',
#   '51.4%',
#   '$106,368,280',
#   '48.6%',
#   '2009'],
#  ['728',
#   'The Terminal',
#   '$219,100,084',
#   '$77,872,883',
#   '35.5%',
#   '$141,227,201',
#   '64.5%',
#   '2004'],
#  ['729',
#   'Captain Phillips',
#   '$218,791,811',
#   '$107,100,855',
#   '49%',
#   '$111,690,956',
#   '51%',
#   '2013'],
#  ['730',
#   'The Prince of Egypt',
#   '$218,613,188',
#   '$101,413,188',
#   '46.4%',
#   '$117,200,000',
#   '53.6%',
#   '1998'],
#  ['731',
#   'Jack Reacher',
#   '$218,340,595',
#   '$80,070,736',
#   '36.7%',
#   '$138,269,859',
#   '63.3%',
#   '2012'],
#  ['732',
#   'Kingdom of Heaven',
#   '$218,122,627',
#   '$47,398,413',
#   '21.7%',
#   '$170,724,214',
#   '78.3%',
#   '2005'],
#  ['733',
#   'The Emoji Movie',
#   '$217,776,646',
#   '$86,089,513',
#   '39.5%',
#   '$131,687,133',
#   '60.5%',
#   '2017'],
#  ['734',
#   'Dirty Dancing',
#   '$217,688,008',
#   '$64,577,242',
#   '29.7%',
#   '$153,110,766',
#   '70.3%',
#   '1987'],
#  ['735',
#   'Dolittle',
#   '$217,430,985',
#   '$76,030,985',
#   '35%',
#   '$141,400,000',
#   '65%',
#   '2020'],
#  ['736',
#   'Dracula Untold',
#   '$217,124,280',
#   '$56,280,355',
#   '25.9%',
#   '$160,843,925',
#   '74.1%',
#   '2014'],
#  ['737',
#   'Central Intelligence',
#   '$216,972,543',
#   '$127,440,871',
#   '58.7%',
#   '$89,531,672',
#   '41.3%',
#   '2016'],
#  ['738',
#   'Million Dollar Baby',
#   '$216,763,646',
#   '$100,492,203',
#   '46.4%',
#   '$116,271,443',
#   '53.6%',
#   '2004'],
#  ['739',
#   'The Help',
#   '$216,639,112',
#   '$169,708,112',
#   '78.3%',
#   '$46,931,000',
#   '21.7%',
#   '2011'],
#  ['740',
#   'Twins',
#   '$216,614,388',
#   '$111,938,388',
#   '51.7%',
#   '$104,676,000',
#   '48.3%',
#   '1988'],
#  ['741',
#   "Valentine's Day",
#   '$216,485,654',
#   '$110,485,654',
#   '51%',
#   '$106,000,000',
#   '49%',
#   '2010'],
#  ['742',
#   'Bad Teacher',
#   '$216,197,492',
#   '$100,292,856',
#   '46.4%',
#   '$115,904,636',
#   '53.6%',
#   '2011'],
#  ['743',
#   'One Hundred and One Dalmatians',
#   '$216,026,182',
#   '$144,880,014',
#   '67.1%',
#   '$71,146,168',
#   '32.9%',
#   '1961'],
#  ['744',
#   'Clear and Present Danger',
#   '$215,887,717',
#   '$122,187,717',
#   '56.6%',
#   '$93,700,000',
#   '43.4%',
#   '1994'],
#  ['745',
#   'Ted 2',
#   '$215,863,606',
#   '$81,476,385',
#   '37.7%',
#   '$134,387,221',
#   '62.3%',
#   '2015'],
#  ['746',
#   "Bram Stoker's Dracula",
#   '$215,862,692',
#   '$82,522,790',
#   '38.2%',
#   '$133,339,902',
#   '61.8%',
#   '1992'],
#  ['747',
#   'Vertical Limit',
#   '$215,663,859',
#   '$69,243,859',
#   '32.1%',
#   '$146,420,000',
#   '67.9%',
#   '2000'],
#  ['748',
#   'Ghostbusters II',
#   '$215,394,738',
#   '$112,494,738',
#   '52.2%',
#   '$102,900,000',
#   '47.8%',
#   '1989'],
#  ['749',
#   'The Patriot',
#   '$215,294,342',
#   '$113,330,342',
#   '52.6%',
#   '$101,964,000',
#   '47.4%',
#   '2000'],
#  ['750',
#   "The Sorcerer's Apprentice",
#   '$215,283,742',
#   '$63,150,991',
#   '29.3%',
#   '$152,132,751',
#   '70.7%',
#   '2010'],
#  ['751',
#   'Just Go with It',
#   '$214,945,591',
#   '$103,028,109',
#   '47.9%',
#   '$111,917,482',
#   '52.1%',
#   '2011'],
#  ['752',
#   'The Expendables 3',
#   '$214,657,577',
#   '$39,322,544',
#   '18.3%',
#   '$175,335,033',
#   '81.7%',
#   '2014'],
#  ['753',
#   'Creed II',
#   '$214,215,889',
#   '$115,715,889',
#   '54%',
#   '$98,500,000',
#   '46%',
#   '2018'],
#  ['754',
#   'Pulp Fiction',
#   '$214,179,088',
#   '$107,928,762',
#   '50.4%',
#   '$106,250,326',
#   '49.6%',
#   '1994'],
#  ['755',
#   'Public Enemies',
#   '$214,104,620',
#   '$97,104,620',
#   '45.4%',
#   '$117,000,000',
#   '54.6%',
#   '2009'],
#  ['756',
#   'Smallfoot',
#   '$214,040,103',
#   '$83,240,103',
#   '38.9%',
#   '$130,800,000',
#   '61.1%',
#   '2018'],
#  ['757',
#   'The Bourne Identity',
#   '$214,034,224',
#   '$121,661,683',
#   '56.8%',
#   '$92,372,541',
#   '43.2%',
#   '2002'],
#  ['758',
#   'Disclosure',
#   '$214,015,089',
#   '$83,015,089',
#   '38.8%',
#   '$131,000,000',
#   '61.2%',
#   '1994'],
#  ['759',
#   'The Aviator',
#   '$213,719,942',
#   '$102,610,330',
#   '48%',
#   '$111,109,612',
#   '52%',
#   '2004'],
#  ['760',
#   'Crouching Tiger, Hidden Dragon',
#   '$213,525,736',
#   '$128,078,872',
#   '60%',
#   '$85,446,864',
#   '40%',
#   '2000'],
#  ['761',
#   'Braveheart',
#   '$213,216,216',
#   '$75,609,945',
#   '35.5%',
#   '$137,606,271',
#   '64.5%',
#   '1995'],
#  ['762',
#   'Into the Woods',
#   '$212,902,372',
#   '$128,002,372',
#   '60.1%',
#   '$84,900,000',
#   '39.9%',
#   '2014'],
#  ['763',
#   'Bedtime Stories',
#   '$212,874,864',
#   '$110,101,975',
#   '51.7%',
#   '$102,772,889',
#   '48.3%',
#   '2008'],
#  ['764',
#   'Miss Congeniality',
#   '$212,742,720',
#   '$106,807,667',
#   '50.2%',
#   '$105,935,053',
#   '49.8%',
#   '2000'],
#  ['765',
#   'Entrapment',
#   '$212,404,396',
#   '$87,704,396',
#   '41.3%',
#   '$124,700,000',
#   '58.7%',
#   '1999'],
#  ['766',
#   'Ace Ventura: When Nature Calls',
#   '$212,385,533',
#   '$108,385,533',
#   '51%',
#   '$104,000,000',
#   '49%',
#   '1995'],
#  ['767',
#   'End of Days',
#   '$211,989,043',
#   '$66,889,043',
#   '31.6%',
#   '$145,100,000',
#   '68.4%',
#   '1999'],
#  ['768',
#   "Bridget Jones's Baby",
#   '$211,952,420',
#   '$24,252,420',
#   '11.4%',
#   '$187,700,000',
#   '88.6%',
#   '2016'],
#  ['769',
#   'Battle Los Angeles',
#   '$211,819,354',
#   '$83,552,429',
#   '39.4%',
#   '$128,266,925',
#   '60.6%',
#   '2011'],
#  ['770',
#   'Fury',
#   '$211,817,906',
#   '$85,817,906',
#   '40.5%',
#   '$126,000,000',
#   '59.5%',
#   '2014'],
#  ['771',
#   'Australia',
#   '$211,787,511',
#   '$49,554,002',
#   '23.4%',
#   '$162,233,509',
#   '76.6%',
#   '2008'],
#  ['772',
#   'Due Date',
#   '$211,780,824',
#   '$100,539,043',
#   '47.5%',
#   '$111,241,781',
#   '52.5%',
#   '2010'],
#  ['773',
#   'Master and Commander: The Far Side of the World',
#   '$211,622,535',
#   '$93,927,920',
#   '44.4%',
#   '$117,694,615',
#   '55.6%',
#   '2003'],
#  ['774',
#   "Lemony Snicket's A Series of Unfortunate Events",
#   '$211,468,235',
#   '$118,634,549',
#   '56.1%',
#   '$92,833,686',
#   '43.9%',
#   '2004'],
#  ['775',
#   'District 9',
#   '$210,888,950',
#   '$115,646,235',
#   '54.8%',
#   '$95,242,715',
#   '45.2%',
#   '2009'],
#  ['776',
#   'The Jungle Book',
#   '$210,310,084',
#   '$141,843,612',
#   '67.4%',
#   '$68,466,472',
#   '32.6%',
#   '1967'],
#  ['777',
#   'Moonraker',
#   '$210,308,099',
#   '$70,308,099',
#   '33.4%',
#   '$140,000,000',
#   '66.6%',
#   '1979'],
#  ['778',
#   'The Others',
#   '$209,947,037',
#   '$96,522,687',
#   '46%',
#   '$113,424,350',
#   '54%',
#   '2001'],
#  ['779',
#   'Horrible Bosses',
#   '$209,838,559',
#   '$117,538,559',
#   '56%',
#   '$92,300,000',
#   '44%',
#   '2011'],
#  ['781',
#   'Red Dragon',
#   '$209,196,298',
#   '$93,149,898',
#   '44.5%',
#   '$116,046,400',
#   '55.5%',
#   '2002'],
#  ['782',
#   'Tomorrowland',
#   '$209,035,668',
#   '$93,436,322',
#   '44.7%',
#   '$115,599,346',
#   '55.3%',
#   '2015'],
#  ['783',
#   'Me Before You',
#   '$208,314,186',
#   '$56,245,075',
#   '27%',
#   '$152,069,111',
#   '73%',
#   '2016'],
#  ['784',
#   'Safe House',
#   '$208,076,205',
#   '$126,373,434',
#   '60.7%',
#   '$81,702,771',
#   '39.3%',
#   '2012'],
#  ['785',
#   'S.W.A.T.',
#   '$207,725,639',
#   '$116,934,650',
#   '56.3%',
#   '$90,790,989',
#   '43.7%',
#   '2003'],
#  ['786',
#   'Traffic',
#   '$207,515,725',
#   '$124,115,725',
#   '59.8%',
#   '$83,400,000',
#   '40.2%',
#   '2000'],
#  ['787',
#   'The Fast and the Furious',
#   '$207,284,863',
#   '$144,533,925',
#   '69.7%',
#   '$62,750,938',
#   '30.3%',
#   '2001'],
#  ['788',
#   'Paranormal Activity 3',
#   '$207,039,844',
#   '$104,028,807',
#   '50.2%',
#   '$103,011,037',
#   '49.8%',
#   '2011'],
#  ['789',
#   'Philadelphia',
#   '$206,678,440',
#   '$77,446,440',
#   '37.5%',
#   '$129,232,000',
#   '62.5%',
#   '1993'],
#  ['790',
#   'Sleepy Hollow',
#   '$206,071,502',
#   '$101,071,502',
#   '49%',
#   '$105,000,000',
#   '51%',
#   '1999'],
#  ['791',
#   'The Holiday',
#   '$205,841,885',
#   '$63,224,849',
#   '30.7%',
#   '$142,617,036',
#   '69.3%',
#   '2006'],
#  ['792',
#   'London Has Fallen',
#   '$205,754,447',
#   '$62,524,260',
#   '30.4%',
#   '$143,230,187',
#   '69.6%',
#   '2016'],
#  ['793',
#   "A Dog's Purpose",
#   '$205,736,628',
#   '$64,508,620',
#   '31.4%',
#   '$141,228,008',
#   '68.6%',
#   '2017'],
#  ['794',
#   'The Break-Up',
#   '$205,668,210',
#   '$118,703,275',
#   '57.7%',
#   '$86,964,935',
#   '42.3%',
#   '2006'],
#  ['795',
#   'Journey to the West',
#   '$205,637,183',
#   '$18,058',
#   '<0.1%',
#   '$205,619,125',
#   '100%',
#   '2013'],
#  ['796',
#   'JFK',
#   '$205,405,498',
#   '$70,405,498',
#   '34.3%',
#   '$135,000,000',
#   '65.7%',
#   '1991'],
#  ['797',
#   'White House Down',
#   '$205,366,737',
#   '$73,103,784',
#   '35.6%',
#   '$132,262,953',
#   '64.4%',
#   '2013'],
#  ['798',
#   'Fun with Dick and Jane',
#   '$204,681,899',
#   '$110,332,737',
#   '53.9%',
#   '$94,349,162',
#   '46.1%',
#   '2005'],
#  ['799',
#   'Eat Pray Love',
#   '$204,594,016',
#   '$80,574,010',
#   '39.4%',
#   '$124,020,006',
#   '60.6%',
#   '2010'],
#  ['800',
#   "You Don't Mess with the Zohan",
#   '$204,313,400',
#   '$100,018,837',
#   '49%',
#   '$104,294,563',
#   '51%',
#   '2008'],
#  ['801',
#   'King Arthur',
#   '$203,567,857',
#   '$51,882,244',
#   '25.5%',
#   '$151,685,613',
#   '74.5%',
#   '2004'],
#  ['802',
#   'Hairspray',
#   '$203,552,922',
#   '$118,871,849',
#   '58.4%',
#   '$84,681,073',
#   '41.6%',
#   '2007'],
#  ['803',
#   'Yogi Bear',
#   '$203,518,375',
#   '$100,246,011',
#   '49.3%',
#   '$103,272,364',
#   '50.7%',
#   '2010'],
#  ['804',
#   'Everest',
#   '$203,427,584',
#   '$43,482,270',
#   '21.4%',
#   '$159,945,314',
#   '78.6%',
#   '2015'],
#  ['805',
#   'Vanilla Sky',
#   '$203,388,341',
#   '$100,618,344',
#   '49.5%',
#   '$102,769,997',
#   '50.5%',
#   '2001'],
#  ['806',
#   'Arrival',
#   '$203,388,186',
#   '$100,546,139',
#   '49.4%',
#   '$102,842,047',
#   '50.6%',
#   '2016'],
#  ['807',
#   'Need for Speed',
#   '$203,277,636',
#   '$43,577,636',
#   '21.4%',
#   '$159,700,000',
#   '78.6%',
#   '2014']]

# %%
url = "https://www.boxofficemojo.com/chart/ww_top_lifetime_gross/?area=XWW&offset=800"
r = requests.get(url)
soup = bs(r.content, "html.parser")
print(soup.prettify)
# Out:
# <bound method Tag.prettify of <!DOCTYPE doctype html>
# <html class="a-no-js" data-19ax5a9jf="dingo"><head><script>var aPageStart = (new Date()).getTime();</script><meta charset="utf-8"/><meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <meta charset="utf-8"/>
# <title dir="ltr">Top Lifetime Grosses - Box Office Mojo</title><meta content="Top Lifetime Grosses" name="title"/>
# <meta content="Box Office Mojo" property="og:site_name"/>
# <meta content="telephone=no" name="format-detection"/>
# <link href="https://m.media-amazon.com/images/G/01/boxofficemojo/v2/favicon._CB448965889_.ico" rel="icon" type="image/x-icon"/>
# <link href="https://images-na.ssl-images-amazon.com/images/I/51tax7M48-L._RC|516fcOUE-HL.css,01evdoiemkL.css,01K+Ps1DeEL.css,31pdJv9iSzL.css,01VszOUTO6L.css,11UGC+GXOPL.css,21LK7jaicML.css,11L58Qpo0GL.css,21kyTi1FabL.css,01ruG+gDPFL.css,01YhS3Cs-hL.css,21GwE3cR-yL.css,019SHZnt8RL.css,01wAWQRgXzL.css,21bWcRJYNIL.css,11WgRxUdJRL.css,01dU8+SPlFL.css,11ocrgKoE-L.css,01SHjPML6tL.css,111-D2qRjiL.css,01QrWuRrZ-L.css,310Imb6LqFL.css,01piEq-AdwL.css,11Z1a0FxSIL.css,01cbS3UK11L.css,21mOLw+nYYL.css,01L8Y-JFEhL.css_.css?AUIClients/AmazonUI#us.not-trident" rel="stylesheet"/>
# <link href="https://images-na.ssl-images-amazon.com/images/I/41jxT1zINDL.css?AUIClients/IMDbMojoSiteAssets" rel="stylesheet"/>
# <script>
# (function(f,h,Q,A){function G(a){v&&v.tag&&v.tag(q(":","aui",a))}function x(a,b){v&&v.count&&v.count("aui:"+a,0===b?0:b||(v.count("aui:"+a)||0)+1)}function l(a){try{return a.test(navigator.userAgent)}catch(b){return!1}}function y(a,b,c){a.addEventListener?a.addEventListener(b,c,!1):a.attachEvent&&a.attachEvent("on"+b,c)}function q(a,b,c,e){b=b&&c?b+a+c:b||c;return e?q(a,b,e):b}function H(a,b,c){try{Object.defineProperty(a,b,{value:c,writable:!1})}catch(e){a[b]=c}return c}function ta(a,b){var c=a.length,
# e=c,g=function(){e--||(R.push(b),S||(setTimeout(T,0),S=!0))};for(g();c--;)ca[a[c]]?g():(B[a[c]]=B[a[c]]||[]).push(g)}function ua(a,b,c,e,g){var d=h.createElement(a?"script":"link");y(d,"error",e);g&&y(d,"load",g);a?(d.type="text/javascript",d.async=!0,c&&/AUIClients|images[/]I/.test(b)&&d.setAttribute("crossorigin","anonymous"),d.src=b):(d.rel="stylesheet",d.href=b);h.getElementsByTagName("head")[0].appendChild(d)}function da(a,b){function c(c,e){function g(){ua(b,c,h,function(b){!I&&h?(h=!1,x("resource_retry"),
# g()):(x("resource_error"),a.log("Asset failed to load: "+c,I?"WARN":A));b&&b.stopPropagation?b.stopPropagation():f.event&&(f.event.cancelBubble=!0)},e)}if(ea[c])return!1;ea[c]=!0;x("resource_count");var h=!0;return!g()}if(b){var e=0,g=0;c.andConfirm=function(a,b){return c(a,function(){e++;b&&b.apply(this,arguments)})};c.confirm=function(){g++};c.getCsriCounters=function(){return{reqs:e,full:g}}}return c}function va(a,b,c){for(var e={name:a,guard:function(c){return b.guardFatal(a,c)},logError:function(c,
# d,e){b.logError(c,d,e,a)}},g=[],d=0;d<c.length;d++)J.hasOwnProperty(c[d])&&(g[d]=U.hasOwnProperty(c[d])?U[c[d]](J[c[d]],e):J[c[d]]);return g}function C(a,b,c,e,g){return function(d,h){function m(){var a=null;e?a=h:"function"===typeof h&&(p.start=D(),a=h.apply(f,va(d,k,l)),p.end=D());if(b){J[d]=a;a=d;for(ca[a]=!0;(B[a]||[]).length;)B[a].shift()();delete B[a]}p.done=!0}var k=g||this;"function"===typeof d&&(h=d,d=A);b&&(d=d?d.replace(fa,""):"__NONAME__",V.hasOwnProperty(d)&&k.error(q(", reregistered by ",
# q(" by ",d+" already registered",V[d]),k.attribution),d),V[d]=k.attribution);for(var l=[],n=0;n<a.length;n++)l[n]=a[n].replace(fa,"");var p=ga[d||"anon"+ ++wa]={depend:l,registered:D(),namespace:k.namespace};c?m():ta(l,k.guardFatal(d,m));return{decorate:function(a){U[d]=k.guardFatal(d,a)}}}}function ha(a){return function(){var b=Array.prototype.slice.call(arguments);return{execute:C(b,!1,a,!1,this),register:C(b,!0,a,!1,this)}}}function W(a,b){return function(c,e){e||(e=c,c=A);var g=this.attribution;
# return function(){z.push(b||{attribution:g,name:c,logLevel:a});var d=e.apply(this,arguments);z.pop();return d}}}function K(a,b){this.load={js:da(this,!0),css:da(this)};H(this,"namespace",b);H(this,"attribution",a)}function ia(){h.body?p.trigger("a-bodyBegin"):setTimeout(ia,20)}function E(a,b){a.className=X(a,b)+" "+b}function X(a,b){return(" "+a.className+" ").split(" "+b+" ").join(" ").replace(/^ | $/g,"")}function ja(a){try{return a()}catch(b){return!1}}function L(){if(M){var a={w:f.innerWidth||
# m.clientWidth,h:f.innerHeight||m.clientHeight};5<Math.abs(a.w-Y.w)||50<a.h-Y.h?(Y=a,N=4,(a=k.mobile||k.tablet?450<a.w&&a.w>a.h:1250<=a.w)?E(m,"a-ws"):m.className=X(m,"a-ws")):0<N&&(N--,ka=setTimeout(L,16))}}function xa(a){(M=a===A?!M:!!a)&&L()}function ya(){return M}function r(a,b){return"sw:"+(b||"")+":"+a+":"}function la(){ma.forEach(function(a){G(a)})}function n(a){ma.push(a)}function na(a,b,c,e){if(c){b=l(/Chrome/i)&&!l(/Edge/i)&&!l(/OPR/i)&&!a.capabilities.isAmazonApp&&!l(new RegExp(Z+"bwv"+
# Z+"b"));var g=r(e,"browser"),d=r(e,"prod_mshop"),f=r(e,"beta_mshop");!a.capabilities.isAmazonApp&&c.browser&&b&&(n(g+"supported"),c.browser.action(g,e));!b&&c.browser&&n(g+"unsupported");c.prodMshop&&n(d+"unsupported");c.betaMshop&&n(f+"unsupported")}}"use strict";var O=Q.now=Q.now||function(){return+new Q},D=function(a){return a&&a.now?a.now.bind(a):O}(f.performance),za=D(),t=f.AmazonUIPageJS||f.P;if(t&&t.when&&t.register)throw Error("A copy of P has already been loaded on this page.");var v=f.ue;
# G();G("aui_build_date:3.20.1-2020-02-28");var R=[],S=!1,T;T=function(){for(var a=setTimeout(T,0),b=O();R.length;)if(R.shift()(),50<O()-b)return;clearTimeout(a);S=!1};var ca={},B={},ea={},I=!1;y(f,"beforeunload",function(){I=!0;setTimeout(function(){I=!1},1E4)});var fa=/^prv:/,V={},J={},U={},ga={},wa=0,Z=String.fromCharCode(92),F,z=[],oa=f.onerror;f.onerror=function(a,b,c,e,g){g&&"object"===typeof g||(g=Error(a,b,c),g.columnNumber=e,g.stack=b||c||e?q(Z,g.message,"at "+q(":",b,c,e)):A);var d=z.pop()||
# {};g.attribution=q(":",g.attribution||d.attribution,d.name);g.logLevel=d.logLevel;g.attribution&&console&&console.log&&console.log([g.logLevel||"ERROR",a,"thrown by",g.attribution].join(" "));z=[];oa&&(d=[].slice.call(arguments),d[4]=g,oa.apply(f,d))};K.prototype={logError:function(a,b,c,e){b={message:b,logLevel:c||"ERROR",attribution:q(":",this.attribution,e)};if(f.ueLogError)return f.ueLogError(a||b,a?b:null),!0;console&&console.error&&(console.log(b),console.error(a));return!1},error:function(a,
# b,c,e){a=Error(q(":",e,a,c));a.attribution=q(":",this.attribution,b);throw a;},guardError:W(),guardFatal:W("FATAL"),guardCurrent:function(a){var b=z[z.length-1];return b?W(b.logLevel,b).call(this,a):a},log:function(a,b,c){return this.logError(null,a,b,c)},declare:C([],!0,!0,!0),register:C([],!0),execute:C([]),AUI_BUILD_DATE:"3.20.1-2020-02-28",when:ha(),now:ha(!0),trigger:function(a,b,c){var e=O();this.declare(a,{data:b,pageElapsedTime:e-(f.aPageStart||NaN),triggerTime:e});c&&c.instrument&&F.when("prv:a-logTrigger").execute(function(b){b(a)})},
# handleTriggers:function(){this.log("handleTriggers deprecated")},attributeErrors:function(a){return new K(a)},_namespace:function(a,b){return new K(a,b)}};var p=H(f,"AmazonUIPageJS",new K);F=p._namespace("PageJS","AmazonUI");F.declare("prv:p-debug",ga);p.declare("p-recorder-events",[]);p.declare("p-recorder-stop",function(){});H(f,"P",p);ia();if(h.addEventListener){var pa;h.addEventListener("DOMContentLoaded",pa=function(){p.trigger("a-domready");h.removeEventListener("DOMContentLoaded",pa,!1)},!1)}var m=
# h.documentElement,aa=function(){var a=["O","ms","Moz","Webkit"],b=h.createElement("div");return{testGradients:function(){b.style.cssText="background-image:-webkit-gradient(linear,left top,right bottom,from(#1E4),to(white));background-image:-webkit-linear-gradient(left top,#1E4,white);background-image:linear-gradient(left top,#1E4,white);";return~b.style.backgroundImage.indexOf("gradient")},test:function(c){var e=c.charAt(0).toUpperCase()+c.substr(1);c=(a.join(e+" ")+e+" "+c).split(" ");for(e=c.length;e--;)if(""===
# b.style[c[e]])return!0;return!1},testTransform3d:function(){var a=!1;f.matchMedia&&(a=f.matchMedia("(-webkit-transform-3d)").matches);return a}}}(),t=m.className,qa=/(^| )a-mobile( |$)/.test(t),ra=/(^| )a-tablet( |$)/.test(t),k={audio:function(){return!!h.createElement("audio").canPlayType},video:function(){return!!h.createElement("video").canPlayType},canvas:function(){return!!h.createElement("canvas").getContext},svg:function(){return!!h.createElementNS&&!!h.createElementNS("http://www.w3.org/2000/svg",
# "svg").createSVGRect},offline:function(){return navigator.hasOwnProperty&&navigator.hasOwnProperty("onLine")&&navigator.onLine},dragDrop:function(){return"draggable"in h.createElement("span")},geolocation:function(){return!!navigator.geolocation},history:function(){return!(!f.history||!f.history.pushState)},webworker:function(){return!!f.Worker},autofocus:function(){return"autofocus"in h.createElement("input")},inputPlaceholder:function(){return"placeholder"in h.createElement("input")},textareaPlaceholder:function(){return"placeholder"in
# h.createElement("textarea")},localStorage:function(){return"localStorage"in f&&null!==f.localStorage},orientation:function(){return"orientation"in f},touch:function(){return"ontouchend"in h},gradients:function(){return aa.testGradients()},hires:function(){var a=f.devicePixelRatio&&1.5<=f.devicePixelRatio||f.matchMedia&&f.matchMedia("(min-resolution:144dpi)").matches;x("hiRes"+(qa?"Mobile":ra?"Tablet":"Desktop"),a?1:0);return a},transform3d:function(){return aa.testTransform3d()},touchScrolling:function(){return l(/Windowshop|android|OS ([5-9]|[1-9][0-9]+)(_[0-9]{1,2})+ like Mac OS X|Chrome|Silk|Firefox|Trident.+?; Touch/i)},
# ios:function(){return l(/OS [1-9][0-9]*(_[0-9]*)+ like Mac OS X/i)&&!l(/trident|Edge/i)},android:function(){return l(/android.([1-9]|[L-Z])/i)&&!l(/trident|Edge/i)},mobile:function(){return qa},tablet:function(){return ra},rtl:function(){return"rtl"===m.dir}},u;for(u in k)k.hasOwnProperty(u)&&(k[u]=ja(k[u]));for(var ba="textShadow textStroke boxShadow borderRadius borderImage opacity transform transition".split(" "),P=0;P<ba.length;P++)k[ba[P]]=ja(function(){return aa.test(ba[P])});var M=!0,ka=0,
# Y={w:0,h:0},N=4;L();y(f,"resize",function(){clearTimeout(ka);N=4;L()});var sa={getItem:function(a){try{return f.localStorage.getItem(a)}catch(b){}},setItem:function(a,b){try{return f.localStorage.setItem(a,b)}catch(c){}}};m.className=X(m,"a-no-js");E(m,"a-js");!l(/OS [1-8](_[0-9]*)+ like Mac OS X/i)||f.navigator.standalone||l(/safari/i)||E(m,"a-ember");t=[];for(u in k)k.hasOwnProperty(u)&&k[u]&&t.push("a-"+u.replace(/([A-Z])/g,function(a){return"-"+a.toLowerCase()}));E(m,t.join(" "));m.setAttribute("data-aui-build-date",
# "3.20.1-2020-02-28");p.register("p-detect",function(){return{capabilities:k,localStorage:k.localStorage&&sa,toggleResponsiveGrid:xa,responsiveGridEnabled:ya}});l(/UCBrowser/i)||k.localStorage&&E(m,sa.getItem("a-font-class"));p.declare("a-event-revised-handling",!1);var w;try{w=navigator.serviceWorker}catch(a){G("sw:nav_err")}w&&(y(w,"message",function(a){a&&a.data&&x(a.data.k,a.data.v)}),w.controller&&w.controller.postMessage("MSG-RDY"));var ma=[];(function(a){var b=a.reg,c=a.unreg;w&&w.getRegistrations?
# (F.when("A","a-util").execute(function(a,b){na(a,b,c,"unregister")}),y(f,"load",function(){F.when("A","a-util").execute(function(a,c){na(a,c,b,"register");la()})})):(b&&(b.browser&&n(r("register","browser")+"unsupported"),b.prodMshop&&n(r("register","prod_mshop")+"unsupported"),b.betaMshop&&n(r("register","beta_mshop")+"unsupported")),c&&(c.browser&&n(r("unregister","browser")+"unsupported"),c.prodMshop&&n(r("unregister","prod_mshop")+"unsupported"),c.betaMshop&&n(r("unregister","beta_mshop")+"unsupported")),
# la())})({reg:{},unreg:{}});p.declare("a-fix-event-off",!1);x("pagejs:pkgExecTime",D()-za)})(window,document,Date);
#   (window.AmazonUIPageJS ? AmazonUIPageJS : P).load.js('https://images-na.ssl-images-amazon.com/images/I/61-6nKPKyWL._RC|11-BZEJ8lnL.js,61GQ9IdK7HL.js,21Of0-9HPCL.js,012FVc3131L.js,11S5WBtBslL.js,51CF7BmbF2L.js,11AHlQhPRjL.js,016iHgpF74L.js,11aNYFFS5hL.js,116tgw9TSaL.js,211-p4GRUCL.js,01PoLXBDXWL.js,618UAEWDpaL.js,01ezj5Rkz1L.js,11BOgvnnntL.js,31UWuPgtTtL.js,01rpauTep4L.js,01iyxuSGj4L.js,01nZw0IOzSL.js_.js?AUIClients/AmazonUI');
#   (window.AmazonUIPageJS ? AmazonUIPageJS : P).load.js('https://images-na.ssl-images-amazon.com/images/I/51voyzpfdCL.js?AUIClients/IMDbMojoSiteAssets');
# </script>
# </head><body class="mojo-page-id-cso a-m-us a-aui_157141-c a-aui_72554-c a-aui_dropdown_187959-c a-aui_pci_risk_banner_210084-c a-aui_perf_130093-c a-aui_tnr_v2_180836-c a-aui_ux_145937-c" id="body"><div id="a-page"><script data-a-state='{"key":"a-wlab-states"}' type="a-state">{}</script><div class="a-section a-spacing-none mojo-navigation mojo-header mojo-flex mojo-flex-h"><div class="a-section mojo-logo"><a class="a-link-normal" href="/?ref_=bo_nb_cso_mojologo"></a></div><div class="a-section a-spacing-none mojo-nav-elements mojo-flex mojo-flex-h mojo-flex-1"><div class="a-section a-spacing-none mojo-search-bar mojo-flex mojo-flex-h"><div class="a-section a-spacing-none mojo-search"><form action="/search">
# <input id="mojo-search-text-input" name="q" placeholder="Search for Titles" required="true" type="search"/>
# <input class="mojo-inline-button" id="mojo-search-button" type="submit" value=""/>
# </form>
# </div></div><div class="a-section a-spacing-none mojo-mobile-options"><span class="a-declarative" data-a-popover='{"closeButton":"false","inlineContent":"\u003cspan class=\"a-size-medium\"&gt;\u003ca href=\"https://pro.imdb.com/?ref_=mojo_nb_cso_pro&amp;amp;rf=mojo_nb_cso_pro\" class=\"a-touch-link a-box a-touch-link-noborder\"&gt;\u003cdiv class=\"a-box-inner\"&gt;\u003ci class=\"a-icon a-icon-touch-link\"&gt;\u003c\/i&gt;IMDbPro\u003c\/div&gt;\u003c\/a&gt;\u003ca href=\"https://www.facebook.com/BoxOfficeMojo/\" class=\"a-touch-link a-box a-touch-link-noborder\"&gt;\u003cdiv class=\"a-box-inner\"&gt;\u003ci class=\"a-icon a-icon-touch-link\"&gt;\u003c\/i&gt;Facebook\u003c\/div&gt;\u003c\/a&gt;\u003ca href=\"https://twitter.com/boxofficemojo\" class=\"a-touch-link a-box a-touch-link-noborder\"&gt;\u003cdiv class=\"a-box-inner\"&gt;\u003ci class=\"a-icon a-icon-touch-link\"&gt;\u003c\/i&gt;Twitter\u003c\/div&gt;\u003c\/a&gt;\u003ca href=\"https://help.imdb.com/article/imdbpro/industry-research/box-office-mojo-by-imdbpro-faq/GCWTV4MQKGWRAUAP?ref_=mojo_ftr_help\" class=\"a-touch-link a-box a-touch-link-noborder\"&gt;\u003cdiv class=\"a-box-inner\"&gt;\u003ci class=\"a-icon a-icon-touch-link\"&gt;\u003c\/i&gt;Help\u003c\/div&gt;\u003c\/a&gt;\u003c\/span&gt;"}' data-action="a-popover"><a class="a-popover-trigger a-declarative" href="javascript:void(0)"><span class="mobile-menu-popover-trigger"></span>
# <i class="a-icon a-icon-popover"></i></a></span></div><div class="a-section a-spacing-none mojo-options mojo-flex"><div class="a-popover-preload" id="a-popover-mojoRollover"><a class="a-link-normal mojo-rollover-image" href="https://pro.imdb.com/login/ap?u=%2Flogin%2Flwa&amp;imdbPageAction=signUp&amp;ref_=mojo_nb_cso_rollover&amp;rf=mojo_nb_cso_rollover"><img alt="" src="https://m.media-amazon.com/images/G/01/IMDbPro/images/MI_121919_NYNY2020_Engagement_rollover_2x._CB1578336809_.png"/></a></div><span class="a-declarative" data-a-popover='{"padding":"none","closeButton":"false","dataStrategy":"preload","name":"mojoRollover","width":"500","position":"triggerBottom","height":"200"}' data-action="a-popover"><a class="a-popover-trigger a-declarative" href="javascript:void(0)"><span class="imdb-pro-logo"></span><i class="a-icon a-icon-popover"></i></a></span><span class="mojo-logo-delimiter"></span><a class="a-link-normal mojo-fb-logo" href="https://www.facebook.com/BoxOfficeMojo/" rel="noopener" target="_blank"></a><a class="a-link-normal mojo-tw-logo" href="https://twitter.com/boxofficemojo" rel="noopener" target="_blank"></a></div></div><div class="a-section a-spacing-none mojo-link-bar mojo-flex mojo-flex-h"><div class="a-section a-spacing-none mojo-tab-container"><a class="a-size-medium a-link-normal mojo-navigation-tab" href="/date/?ref_=bo_nb_cso_tab">Domestic</a><a class="a-size-medium a-link-normal mojo-navigation-tab" href="/intl/?ref_=bo_nb_cso_tab">International</a><a class="a-size-medium a-link-normal mojo-navigation-tab" href="/year/world/?ref_=bo_nb_cso_tab">Worldwide</a><a class="a-size-medium a-link-normal mojo-navigation-tab" href="/calendar/?ref_=bo_nb_cso_tab">Calendar</a><a class="a-size-medium a-link-normal mojo-navigation-tab mojo-navigation-tab-active" href="/charts/overall/?ref_=bo_nb_cso_tab">All Time</a><a class="a-size-medium a-link-normal mojo-navigation-tab" href="/showdown/?ref_=bo_nb_cso_tab">Showdowns</a><a class="a-size-medium a-link-normal mojo-navigation-tab" href="/news/?ref_=bo_nb_cso_tab">News</a></div></div><div class="a-section a-spacing-none mojo-link-bar-secondary mojo-flex mojo-flex-h"><div class="a-section a-spacing-base mojo-tab-container"><a class="a-size-medium a-link-normal mojo-navigation-tab mojo-navigation-tab-active" href="/charts/overall/?ref_=bo_nb_cso_secondarytab"><h2 class="a-size-medium a-text-normal">Overall</h2></a><a class="a-size-medium a-link-normal mojo-navigation-tab" href="/charts/weekend/?ref_=bo_nb_cso_secondarytab">Weekend Records</a><a class="a-size-medium a-link-normal mojo-navigation-tab" href="/charts/daily/?ref_=bo_nb_cso_secondarytab">Daily Records</a><a class="a-size-medium a-link-normal mojo-navigation-tab" href="/charts/misc/?ref_=bo_nb_cso_secondarytab">Miscellaneous Records</a></div></div><div class="a-section a-spacing-none mojo-link-bar-fade"><span class="a-letter-space"></span></div></div><main>
# <div class="a-section mojo-body aok-relative"><div class="a-section a-spacing-none"><h1 class="mojo-gutter">Top Lifetime Grosses</h1><div class="a-section mojo-gutter-sides"></div><div class="mojo-refiner mojo-override-gutter">
# <div class="mojo-refinement mojo-refinement-dropdown">
# <span class="mojo-dropdown-clear">
# <form action="" autocomplete="off" class="a-spacing-none" method="post"><span class="a-dropdown-container"><select autocomplete="off" class="a-native-dropdown" id="area-navSelector" name="area-navSelector" tabindex="-1"><option value="/chart/top_lifetime_gross/">Domestic</option><option selected="" value="/chart/ww_top_lifetime_gross/?area=XWW">Worldwide</option></select><span class="a-button a-button-dropdown" tabindex="-1"><span class="a-button-inner"><span aria-hidden="true" class="a-button-text a-declarative" data-action="a-dropdown-button" role="button" tabindex="0"><span class="a-dropdown-prompt"></span></span><i class="a-icon a-icon-dropdown"></i></span></span></span></form></span>
# </div>
# </div>
# <div class="a-text-center mojo-pagination"><ul class="a-pagination"><li><a href="/chart/ww_top_lifetime_gross/?area=XWW&amp;offset=600">←<span class="a-letter-space"></span><span class="a-letter-space"></span>Previous page</a></li><li class="a-selected mojo-pagination-button-center"><a href="#">801-1,000 of 1,000</a></li><li class="a-disabled a-last">Next page<span class="a-letter-space"></span><span class="a-letter-space"></span>→</li></ul></div><style>
# table.a-bordered.mojo-body-table-compact td,
# table.a-bordered.mojo-body-table-compact th {
#     padding: 5px;
# }
# table.mojo-body-table tr.mojo-group-label th {
#     background: linear-gradient(to bottom, #f8f8f8, #eee);
# }
# </style>
# <div class="a-section imdb-scroll-table mojo-gutter-sides" id="table"><div class="a-section imdb-scroll-table-inner"><table class="a-bordered a-horizontal-stripes a-size-base a-span12 mojo-body-table mojo-table-annotated"><tr><th class="a-text-right mojo-field-type-rank a-nowrap"><span title="Rank">Rank</span>
# </th><th class="a-text-left mojo-field-type-title a-nowrap"><span title="Title">Title</span>
# </th><th class="a-text-right mojo-field-type-money a-nowrap"><span title="Worldwide Lifetime Gross">Worldwide Lifetime Gross</span>
# </th><th class="a-text-right mojo-field-type-money a-nowrap"><span title="Domestic Lifetime Gross">Domestic Lifetime Gross</span>
# </th><th class="a-text-right mojo-field-type-percent a-nowrap"><span title="Domestic %">Domestic %</span>
# </th><th class="a-text-right mojo-field-type-money a-nowrap"><span title="Foreign Lifetime Gross">Foreign Lifetime Gross</span>
# </th><th class="a-text-right mojo-field-type-percent a-nowrap"><span title="Foreign %">Foreign %</span>
# </th><th class="a-text-left mojo-field-type-year a-nowrap"><span title="Year">Year</span>
# </th></tr><tr><td class="a-text-right mojo-header-column mojo-truncate mojo-field-type-rank">808</td><td class="a-text-left mojo-field-type-title"><a class="a-link-normal" href="/title/tt0876563/?ref_=bo_cso_table_1">Ponyo</a></td><td class="a-text-right mojo-field-type-money">$203,204,882</td><td class="a-text-right mojo-field-type-money">$15,743,471</td><td class="a-text-right mojo-field-type-percent">7.8%</td><td class="a-text-right mojo-field-type-money">$187,461,411</td><td class="a-text-right mojo-field-type-percent">92.2%</td><td class="a-text-left mojo-field-type-year"><a class="a-link-normal" href="/year/world/2008/?ref_=bo_cso_table_1">2008</a></td></tr><tr><td class="a-text-right mojo-header-column mojo-truncate mojo-field-type-rank">809</td><td class="a-text-left mojo-field-type-title"><a class="a-link-normal" href="/title/tt0356634/?ref_=bo_cso_table_2">Garfield</a></td><td class="a-text-right mojo-field-type-money">$203,172,417</td><td class="a-text-right mojo-field-type-money">$75,369,589</td><td class="a-text-right mojo-field-type-percent">37.1%</td><td class="a-text-right mojo-field-type-money">$127,802,828</td><td class="a-text-right mojo-field-type-percent">62.9%</td><td class="a-text-left mojo-field-type-year"><a class="a-link-normal" href="/year/world/2004/?ref_=bo_cso_table_2">2004</a></td></tr><tr><td class="a-text-right mojo-header-column mojo-truncate mojo-field-type-rank">810</td><td class="a-text-left mojo-field-type-title"><a class="a-link-normal" href="/title/tt1620981/?ref_=bo_cso_table_3">The Addams Family</a></td><td class="a-text-right mojo-field-type-money">$203,044,905</td><td class="a-text-right mojo-field-type-money">$100,044,905</td><td class="a-text-right mojo-field-type-percent">49.3%</td><td class="a-text-right mojo-field-type-money">$103,000,000</td><td class="a-text-right mojo-field-type-percent">50.7%</td><td class="a-text-left mojo-field-type-year"><a class="a-link-normal" href="/year/world/2019/?ref_=bo_cso_table_3">2019</a></td></tr><tr><td class="a-text-right mojo-header-column mojo-truncate mojo-field-type-rank">811</td><td class="a-text-left mojo-field-type-title"><a class="a-link-normal" href="/title/tt3281548/?ref_=bo_cso_table_4">Little Women</a></td><td class="a-text-right mojo-field-type-money">$203,038,887</td><td class="a-text-right mojo-field-type-money">$107,638,887</td><td class="a-text-right mojo-field-type-percent">53%</td><td class="a-text-right mojo-field-type-money">$95,400,000</td><td class="a-text-right mojo-field-type-percent">47%</td><td class="a-text-left mojo-field-type-year"><a class="a-link-normal" href="/year/world/2019/?ref_=bo_cso_table_4">2019</a></td></tr><tr><td class="a-text-right mojo-header-column mojo-truncate mojo-field-type-rank">812</td><td class="a-text-left mojo-field-type-title"><a class="a-link-normal" href="/title/tt0129290/?ref_=bo_cso_table_5">Patch Adams</a></td><td class="a-text-right mojo-field-type-money">$202,292,902</td><td class="a-text-right mojo-field-type-money">$135,026,902</td><td class="a-text-right mojo-field-type-percent">66.8%</td><td class="a-text-right mojo-field-type-money">$67,266,000</td><td class="a-text-right mojo-field-type-percent">33.2%</td><td class="a-text-left mojo-field-type-year"><a class="a-link-normal" href="/year/world/1998/?ref_=bo_cso_table_5">1998</a></td></tr><tr><td class="a-text-right mojo-header-column mojo-truncate mojo-field-type-rank">813</td><td class="a-text-left mojo-field-type-title"><a class="a-link-normal" href="/title/tt0100758/?ref_=bo_cso_table_6">Teenage Mutant Ninja Turtles</a></td><td class="a-text-right mojo-field-type-money">$201,965,915</td><td class="a-text-right mojo-field-type-money">$135,265,915</td><td class="a-text-right mojo-field-type-percent">67%</td><td class="a-text-right mojo-field-type-money">$66,700,000</td><td class="a-text-right mojo-field-type-percent">33%</td><td class="a-text-left mojo-field-type-year"><a class="a-link-normal" href="/year/world/1990/?ref_=bo_ ...
# <div class="a-section a-spacing-none mojo-navigation-frame"><div class="a-section a-spacing-none mojo-navigation mojo-footer"><a class="a-link-normal imdb-pro-logo" href="https://pro.imdb.com/?ref_=mojo_ft_cso_prologo&amp;rf=mojo_ft_cso_prologo"></a><p>
#             Latest Updates:
#             <a class="a-link-normal" href="/news/?ref_=bo_ft_cso_news">News</a> |
#             <a class="a-link-normal" href="/daily/?ref_=bo_ft_cso_daily">Daily</a> |
#             <a class="a-link-normal" href="/weekend/?ref_=bo_ft_cso_weekend">Weekend</a> |
#             <a class="a-link-normal" href="/charts/?ref_=bo_ft_cso_charts">All Time</a> |
#             <a class="a-link-normal" href="/intl/?ref_=bo_ft_cso_intl">International</a> |
#             <a class="a-link-normal" href="/showdown/?ref_=bo_ft_cso_showdown">Showdowns</a></p><p><a class="a-link-normal" href="https://help.imdb.com/article/imdbpro/industry-research/box-office-mojo-by-imdbpro-faq/GCWTV4MQKGWRAUAP?ref_=mojo_ftr_help" rel="noopener" target="_blank">Help</a></p><p>
#             BoxOfficeMojo.com by IMDbPro - an
#             <a class="a-link-normal" href="http://www.imdb.com/" rel="noopener" target="_blank">IMDb</a>
#             company.
#         </p><p>
#             © IMDb.com, Inc. or its affiliates. All rights reserved.
#             Box Office Mojo and IMDb are trademarks or registered trademarks of IMDb.com, Inc. or its affiliates.
#             <a class="a-link-normal" href="/conditions/?ref_=bo_ft_cso_conditions">Conditions of Use</a>
#              and
#              <a class="a-link-normal" href="/privacy/?ref_=bo_ft_cso_privacy">Privacy Policy</a>
#             under which this service is provided to you.
#         </p></div></div></div></body></html>>

# %%
movie_list5 = []
row_list = []
for record in soup.findAll("tr"):
    for data in record.findAll("td"):
        row_list.append(data.text)
    if row_list == []:
        pass
    else:
        movie_list5.append(row_list)
        row_list = []
movie_list5
# Out:
# [['808',
#   'Ponyo',
#   '$203,204,882',
#   '$15,743,471',
#   '7.8%',
#   '$187,461,411',
#   '92.2%',
#   '2008'],
#  ['809',
#   'Garfield',
#   '$203,172,417',
#   '$75,369,589',
#   '37.1%',
#   '$127,802,828',
#   '62.9%',
#   '2004'],
#  ['810',
#   'The Addams Family',
#   '$203,044,905',
#   '$100,044,905',
#   '49.3%',
#   '$103,000,000',
#   '50.7%',
#   '2019'],
#  ['811',
#   'Little Women',
#   '$203,038,887',
#   '$107,638,887',
#   '53%',
#   '$95,400,000',
#   '47%',
#   '2019'],
#  ['812',
#   'Patch Adams',
#   '$202,292,902',
#   '$135,026,902',
#   '66.8%',
#   '$67,266,000',
#   '33.2%',
#   '1998'],
#  ['813',
#   'Teenage Mutant Ninja Turtles',
#   '$201,965,915',
#   '$135,265,915',
#   '67%',
#   '$66,700,000',
#   '33%',
#   '1990'],
#  ['814',
#   'Kindergarten Cop',
#   '$201,957,688',
#   '$91,457,688',
#   '45.3%',
#   '$110,500,000',
#   '54.7%',
#   '1990'],
#  ['815',
#   'Straight Outta Compton',
#   '$201,634,991',
#   '$161,197,785',
#   '80%',
#   '$40,437,206',
#   '20%',
#   '2015'],
#  ['816',
#   '21 Jump Street',
#   '$201,585,328',
#   '$138,447,667',
#   '68.7%',
#   '$63,137,661',
#   '31.3%',
#   '2012'],
#  ['817',
#   'Valkyrie',
#   '$201,545,517',
#   '$83,077,833',
#   '41.2%',
#   '$118,467,684',
#   '58.8%',
#   '2008'],
#  ['818',
#   'Open Season',
#   '$200,811,689',
#   '$85,105,259',
#   '42.4%',
#   '$115,706,430',
#   '57.6%',
#   '2006'],
#  ['819',
#   'Cats & Dogs',
#   '$200,687,492',
#   '$93,385,515',
#   '46.5%',
#   '$107,301,977',
#   '53.5%',
#   '2001'],
#  ['820',
#   'The Hunt for Red October',
#   '$200,512,643',
#   '$122,012,643',
#   '60.8%',
#   '$78,500,000',
#   '39.2%',
#   '1990'],
#  ['821',
#   'Percy Jackson: Sea of Monsters',
#   '$199,850,315',
#   '$68,559,554',
#   '34.3%',
#   '$131,290,761',
#   '65.7%',
#   '2013'],
#  ['822',
#   'Two Weeks Notice',
#   '$199,043,242',
#   '$93,354,851',
#   '46.9%',
#   '$105,688,391',
#   '53.1%',
#   '2002'],
#  ['823',
#   'RED',
#   '$199,006,387',
#   '$90,380,162',
#   '45.4%',
#   '$108,626,225',
#   '54.6%',
#   '2010'],
#  ['824',
#   'City of Angels',
#   '$198,685,114',
#   '$78,685,114',
#   '39.6%',
#   '$120,000,000',
#   '60.4%',
#   '1998'],
#  ['825',
#   'The Pacifier',
#   '$198,636,868',
#   '$113,086,868',
#   '56.9%',
#   '$85,550,000',
#   '43.1%',
#   '2005'],
#  ['826',
#   '50 First Dates',
#   '$198,520,934',
#   '$120,908,074',
#   '60.9%',
#   '$77,612,860',
#   '39.1%',
#   '2004'],
#  ['827',
#   'Total Recall',
#   '$198,467,168',
#   '$58,877,969',
#   '29.7%',
#   '$139,589,199',
#   '70.3%',
#   '2012'],
#  ['828',
#   'The Island',
#   '$198,326,350',
#   '$670,883',
#   '0.3%',
#   '$197,655,467',
#   '99.7%',
#   '2018'],
#  ['829',
#   'The Impossible',
#   '$198,087,212',
#   '$19,019,882',
#   '9.6%',
#   '$179,067,330',
#   '90.4%',
#   '2012'],
#  ['830',
#   'Lost in Thailand',
#   '$197,757,387',
#   '$57,387',
#   '<0.1%',
#   '$197,700,000',
#   '100%',
#   '2012'],
#  ['831',
#   'Christopher Robin',
#   '$197,744,377',
#   '$99,215,042',
#   '50.2%',
#   '$98,529,335',
#   '49.8%',
#   '2018'],
#  ['832',
#   'Jack the Giant Slayer',
#   '$197,687,603',
#   '$65,187,603',
#   '33%',
#   '$132,500,000',
#   '67%',
#   '2013'],
#  ['833',
#   'Smurfs: The Lost Village',
#   '$197,183,546',
#   '$45,020,282',
#   '22.8%',
#   '$152,163,264',
#   '77.2%',
#   '2017'],
#  ['834',
#   'Spy Kids 3-D: Game Over',
#   '$197,101,678',
#   '$111,761,982',
#   '56.7%',
#   '$85,339,696',
#   '43.3%',
#   '2003'],
#  ['835',
#   'Panic Room',
#   '$197,079,546',
#   '$96,397,334',
#   '48.9%',
#   '$100,682,212',
#   '51.1%',
#   '2002'],
#  ['836',
#   'The Other Woman',
#   '$196,710,396',
#   '$83,911,193',
#   '42.7%',
#   '$112,799,203',
#   '57.3%',
#   '2014'],
#  ['837',
#   'Stargate',
#   '$196,567,262',
#   '$71,567,262',
#   '36.4%',
#   '$125,000,000',
#   '63.6%',
#   '1994'],
#  ['838',
#   'Beowulf',
#   '$196,393,745',
#   '$82,280,579',
#   '41.9%',
#   '$114,113,166',
#   '58.1%',
#   '2007'],
#  ['839',
#   'The Vow',
#   '$196,114,570',
#   '$125,014,030',
#   '63.8%',
#   '$71,100,540',
#   '36.2%',
#   '2012'],
#  ['840',
#   'Anger Management',
#   '$195,745,823',
#   '$135,645,823',
#   '69.3%',
#   '$60,100,000',
#   '30.7%',
#   '2003'],
#  ['841',
#   'Tropic Thunder',
#   '$195,702,811',
#   '$110,515,313',
#   '56.5%',
#   '$85,187,498',
#   '43.5%',
#   '2008'],
#  ['842',
#   'The Shape of Water',
#   '$195,333,312',
#   '$63,859,435',
#   '32.7%',
#   '$131,473,877',
#   '67.3%',
#   '2017'],
#  ['843',
#   'The Pelican Brief',
#   '$195,268,056',
#   '$100,768,056',
#   '51.6%',
#   '$94,500,000',
#   '48.4%',
#   '1993'],
#  ['844',
#   'The BFG',
#   '$195,243,411',
#   '$55,483,770',
#   '28.4%',
#   '$139,759,641',
#   '71.6%',
#   '2016'],
#  ['845',
#   'Rocketman',
#   '$195,179,299',
#   '$96,368,160',
#   '49.4%',
#   '$98,811,139',
#   '50.6%',
#   '2019'],
#  ['846',
#   'The Intern',
#   '$194,564,672',
#   '$75,764,672',
#   '38.9%',
#   '$118,800,000',
#   '61.1%',
#   '2015'],
#  ['847',
#   'Downton Abbey',
#   '$194,111,262',
#   '$96,854,135',
#   '49.9%',
#   '$97,257,127',
#   '50.1%',
#   '2019'],
#  ['848',
#   'Wallace & Gromit: The Curse of the Were-Rabbit',
#   '$194,111,171',
#   '$56,110,897',
#   '28.9%',
#   '$138,000,274',
#   '71.1%',
#   '2005'],
#  ['849',
#   'Gnomeo & Juliet',
#   '$193,967,670',
#   '$99,967,670',
#   '51.5%',
#   '$94,000,000',
#   '48.5%',
#   '2011'],
#  ['850',
#   'The Sum of All Fears',
#   '$193,921,372',
#   '$118,907,036',
#   '61.3%',
#   '$75,014,336',
#   '38.7%',
#   '2002'],
#  ['851',
#   'Gangs of New York',
#   '$193,772,504',
#   '$77,812,000',
#   '40.2%',
#   '$115,960,504',
#   '59.8%',
#   '2002'],
#  ['852',
#   'The Monkey King 2',
#   '$193,678,298',
#   '$709,982',
#   '0.4%',
#   '$192,968,316',
#   '99.6%',
#   '2016'],
#  ['853',
#   'Paranormal Activity',
#   '$193,355,800',
#   '$107,918,810',
#   '55.8%',
#   '$85,436,990',
#   '44.2%',
#   '2009'],
#  ['854',
#   'The Equalizer',
#   '$192,330,738',
#   '$101,530,738',
#   '52.8%',
#   '$90,800,000',
#   '47.2%',
#   '2014'],
#  ['855',
#   'The Lego Movie 2: The Second Part',
#   '$192,306,508',
#   '$105,806,508',
#   '55%',
#   '$86,500,000',
#   '45%',
#   '2019'],
#  ['856',
#   'The Addams Family',
#   '$191,502,426',
#   '$113,502,426',
#   '59.3%',
#   '$78,000,000',
#   '40.7%',
#   '1991'],
#  ['857',
#   'The Longest Yard',
#   '$191,466,556',
#   '$158,119,460',
#   '82.6%',
#   '$33,347,096',
#   '17.4%',
#   '2005'],
#  ['858',
#   'Cheaper by the Dozen',
#   '$190,538,630',
#   '$138,614,544',
#   '72.8%',
#   '$51,924,086',
#   '27.2%',
#   '2003'],
#  ['859',
#   'The Equalizer 2',
#   '$190,400,157',
#   '$102,084,362',
#   '53.6%',
#   '$88,315,795',
#   '46.4%',
#   '2018'],
#  ['860',
#   'Hollow Man',
#   '$190,213,455',
#   '$73,209,340',
#   '38.5%',
#   '$117,004,115',
#   '61.5%',
#   '2000'],
#  ['861',
#   'Outbreak',
#   '$189,859,560',
#   '$67,659,560',
#   '35.6%',
#   '$122,200,000',
#   '64.4%',
#   '1995'],
#  ['862',
#   'The Santa Clause',
#   '$189,833,357',
#   '$144,833,357',
#   '76.3%',
#   '$45,000,000',
#   '23.7%',
#   '1994'],
#  ['863',
#   'Abominable',
#   '$189,812,578',
#   '$60,716,390',
#   '32%',
#   '$129,096,188',
#   '68%',
#   '2019'],
#  ['864',
#   'The White Storm 2: Drug Lords',
#   '$189,396,380',
#   '$609,461',
#   '0.3%',
#   '$188,786,919',
#   '99.7%',
#   '2019'],
#  ['865',
#   'The X Files',
#   '$189,176,423',
#   '$83,898,313',
#   '44.4%',
#   '$105,278,110',
#   '55.6%',
#   '1998'],
#  ['866',
#   'Breakup Buddies',
#   '$189,017,596',
#   '$777,896',
#   '0.4%',
#   '$188,239,700',
#   '99.6%',
#   '2014'],
#  ['867',
#   'Rambo III',
#   '$189,015,611',
#   '$53,715,611',
#   '28.4%',
#   '$135,300,000',
#   '71.6%',
#   '1988'],
#  ['868',
#   'Birds of Prey: And the Fantabulous Emancipation of One Harley Quinn',
#   '$188,586,416',
#   '$78,786,416',
#   '41.8%',
#   '$109,800,000',
#   '58.2%',
#   '2020'],
#  ['869',
#   'The Secret Life of Walter Mitty',
#   '$188,133,322',
#   '$58,236,838',
#   '31%',
#   '$129,896,484',
#   '69%',
#   '2013'],
#  ['871',
#   'Jaws 2',
#   '$187,884,007',
#   '$81,766,007',
#   '43.5%',
#   '$106,118,000',
#   '56.5%',
#   '1978'],
#  ['872',
#   '12 Years a Slave',
#   '$187,733,202',
#   '$56,671,993',
#   '30.2%',
#   '$131,061,209',
#   '69.8%',
#   '2013'],
#  ['873',
#   'Heat',
#   '$187,436,818',
#   '$67,436,818',
#   '36%',
#   '$120,000,000',
#   '64%',
#   '1995'],
#  ['874',
#   "Mr. Popper's Penguins",
#   '$187,361,754',
#   '$68,224,452',
#   '36.4%',
#   '$119,137,302',
#   '63.6%',
#   '2011'],
#  ['875',
#   'The Grudge',
#   '$187,281,115',
#   '$110,359,362',
#   '58.9%',
#   '$76,921,753',
#   '41.1%',
#   '2004'],
#  ['876',
#   'I Now Pronounce You Chuck & Larry',
#   '$187,134,117',
#   '$120,059,556',
#   '64.2%',
#   '$67,074,561',
#   '35.8%',
#   '2007'],
#  ['877',
#   'The Horse Whisperer',
#   '$186,883,563',
#   '$75,383,563',
#   '40.3%',
#   '$111,500,000',
#   '59.7%',
#   '1998'],
#  ['878',
#   'Weathering with You',
#   '$186,880,688',
#   '$7,778,682',
#   '4.2%',
#   '$179,102,006',
#   '95.8%',
#   '2019'],
#  ['879',
#   'Walk the Line',
#   '$186,797,986',
#   '$119,519,402',
#   '64%',
#   '$67,278,584',
#   '36%',
#   '2005'],
#  ['881',
#   'The Jungle Book 2',
#   '$186,303,759',
#   '$47,901,582',
#   '25.7%',
#   '$138,402,177',
#   '74.3%',
#   '2003'],
#  ['882',
#   'The Final Destination',
#   '$186,167,139',
#   '$66,477,700',
#   '35.7%',
#   '$119,689,439',
#   '64.3%',
#   '2009'],
#  ['883',
#   'Atlantis: The Lost Empire',
#   '$186,053,725',
#   '$84,056,472',
#   '45.2%',
#   '$101,997,253',
#   '54.8%',
#   '2001'],
#  ['884',
#   'Inside Man',
#   '$186,003,591',
#   '$88,513,495',
#   '47.6%',
#   '$97,490,096',
#   '52.4%',
#   '2006'],
#  ['885',
#   'The Waterboy',
#   '$185,991,646',
#   '$161,491,646',
#   '86.8%',
#   '$24,500,000',
#   '13.2%',
#   '1998'],
#  ['886',
#   'Hugo',
#   '$185,770,160',
#   '$73,864,507',
#   '39.8%',
#   '$111,905,653',
#   '60.2%',
#   '2011'],
#  ['887',
#   'Pitch Perfect 3',
#   '$185,400,345',
#   '$104,897,530',
#   '56.6%',
#   '$80,502,815',
#   '43.4%',
#   '2017'],
#  ['888',
#   'Watchmen',
#   '$185,382,813',
#   '$107,509,799',
#   '58%',
#   '$77,873,014',
#   '42%',
#   '2009'],
#  ['889',
#   'The Birdcage',
#   '$185,260,553',
#   '$124,060,553',
#   '67%',
#   '$61,200,000',
#   '33%',
#   '1996'],
#  ['890',
#   'Moulin Rouge!',
#   '$184,928,135',
#   '$57,386,607',
#   '31%',
#   '$127,541,528',
#   '69%',
#   '2001'],
#  ['891',
#   'Snow White and the Seven Dwarfs',
#   '$184,925,486',
#   '$184,925,486',
#   '100%',
#   '$0',
#   '-',
#   '1937'],
#  ['892',
#   'Hop',
#   '$183,953,723',
#   '$108,085,305',
#   '58.8%',
#   '$75,868,418',
#   '41.2%',
#   '2011'],
#  ['893',
#   'Bad Moms',
#   '$183,936,074',
#   '$113,257,297',
#   '61.6%',
#   '$70,678,777',
#   '38.4%',
#   '2016'],
#  ['894',
#   'Jupiter Ascending',
#   '$183,887,723',
#   '$47,387,723',
#   '25.8%',
#   '$136,500,000',
#   '74.2%',
#   '2015'],
#  ['895',
#   '102 Dalmatians',
#   '$183,611,771',
#   '$66,957,026',
#   '36.5%',
#   '$116,654,745',
#   '63.5%',
#   '2000'],
#  ['897',
#   'Storks',
#   '$183,388,953',
#   '$72,679,278',
#   '39.6%',
#   '$110,709,675',
#   '60.4%',
#   '2016'],
#  ['898',
#   'Paul Blart: Mall Cop',
#   '$183,348,429',
#   '$146,336,178',
#   '79.8%',
#   '$37,012,251',
#   '20.2%',
#   '2009'],
#  ['899',
#   "Wayne's World",
#   '$183,097,323',
#   '$121,697,323',
#   '66.5%',
#   '$61,400,000',
#   '33.5%',
#   '1992'],
#  ['900',
#   'Maverick',
#   '$183,031,272',
#   '$101,631,272',
#   '55.5%',
#   '$81,400,000',
#   '44.5%',
#   '1994'],
#  ['901',
#   'Mirror Mirror',
#   '$183,018,522',
#   '$64,935,167',
#   '35.5%',
#   '$118,083,355',
#   '64.5%',
#   '2012'],
#  ['902',
#   'The Man in the Iron Mask',
#   '$182,968,902',
#   '$56,968,902',
#   '31.1%',
#   '$126,000,000',
#   '68.9%',
#   '1998'],
#  ['903',
#   'Cape Fear',
#   '$182,291,969',
#   '$79,091,969',
#   '43.4%',
#   '$103,200,000',
#   '56.6%',
#   '1991'],
#  ['904',
#   'The Haunted Mansion',
#   '$182,290,266',
#   '$75,847,266',
#   '41.6%',
#   '$106,443,000',
#   '58.4%',
#   '2003'],
#  ['906',
#   'While You Were Sleeping',
#   '$182,057,016',
#   '$81,057,016',
#   '44.5%',
#   '$101,000,000',
#   '55.5%',
#   '1995'],
#  ['907',
#   'The Bridges of Madison County',
#   '$182,016,617',
#   '$71,516,617',
#   '39.3%',
#   '$110,500,000',
#   '60.7%',
#   '1995'],
#  ['909',
#   'Poseidon',
#   '$181,674,817',
#   '$60,674,817',
#   '33.4%',
#   '$121,000,000',
#   '66.6%',
#   '2006'],
#  ['910',
#   'The First Wives Club',
#   '$181,489,203',
#   '$105,489,203',
#   '58.1%',
#   '$76,000,000',
#   '41.9%',
#   '1996'],
#  ['911',
#   'Scooby-Doo 2: Monsters Unleashed',
#   '$181,216,833',
#   '$84,216,833',
#   '46.5%',
#   '$97,000,000',
#   '53.5%',
#   '2004'],
#  ['912',
#   'Hot Shots!',
#   '$181,096,164',
#   '$69,467,617',
#   '38.4%',
#   '$111,628,547',
#   '61.6%',
#   '1991'],
#  ['913',
#   'Road to Perdition',
#   '$181,001,478',
#   '$104,454,762',
#   '57.7%',
#   '$76,546,716',
#   '42.3%',
#   '2002'],
#  ['914',
#   'Kill Bill: Vol. 1',
#   '$180,899,045',
#   '$70,099,045',
#   '38.8%',
#   '$110,800,000',
#   '61.2%',
#   '2003'],
#  ['915',
#   "The Hitman's Bodyguard",
#   '$180,650,747',
#   '$75,468,583',
#   '41.8%',
#   '$105,182,164',
#   '58.2%',
#   '2017'],
#  ['916',
#   'The Scorpion King',
#   '$180,630,907',
#   '$91,047,077',
#   '50.4%',
#   '$89,583,830',
#   '49.6%',
#   '2002'],
#  ['917',
#   'Sweet Home Alabama',
#   '$180,622,424',
#   '$127,223,418',
#   '70.4%',
#   '$53,399,006',
#   '29.6%',
#   '2002'],
#  ['918',
#   "Daddy's Home 2",
#   '$180,613,180',
#   '$104,029,443',
#   '57.6%',
#   '$76,583,737',
#   '42.4%',
#   '2017'],
#  ['919',
#   'Deja Vu',
#   '$180,557,550',
#   '$64,038,616',
#   '35.5%',
#   '$116,518,934',
#   '64.5%',
#   '2006'],
#  ['920',
#   'Hacksaw Ridge',
#   '$180,450,918',
#   '$67,209,615',
#   '37.2%',
#   '$113,241,303',
#   '62.8%',
#   '2016'],
#  ['921',
#   'The Post',
#   '$179,769,457',
#   '$81,903,458',
#   '45.6%',
#   '$97,865,999',
#   '54.4%',
#   '2017'],
#  ['922',
#   'Dangerous Minds',
#   '$179,519,401',
#   '$84,919,401',
#   '47.3%',
#   '$94,600,000',
#   '52.7%',
#   '1995'],
#  ['923',
#   'The Dictator',
#   '$179,379,533',
#   '$59,650,222',
#   '33.2%',
#   '$119,729,311',
#   '66.8%',
#   '2012'],
#  ['924',
#   'The League of Extraordinary Gentlemen',
#   '$179,265,204',
#   '$66,465,204',
#   '37.1%',
#   '$112,800,000',
#   '62.9%',
#   '2003'],
#  ['925',
#   'Allegiant',
#   '$179,246,868',
#   '$66,184,051',
#   '36.9%',
#   '$113,062,817',
#   '63.1%',
#   '2016'],
#  ['926',
#   'Daredevil',
#   '$179,179,718',
#   '$102,543,518',
#   '57.2%',
#   '$76,636,200',
#   '42.8%',
#   '2003'],
#  ['927',
#   'City Slickers',
#   '$179,033,791',
#   '$124,033,791',
#   '69.3%',
#   '$55,000,000',
#   '30.7%',
#   '1991'],
#  ['928',
#   "He's Just Not That Into You",
#   '$178,866,158',
#   '$93,953,653',
#   '52.5%',
#   '$84,912,505',
#   '47.5%',
#   '2009'],
#  ['929',
#   'Eagle Eye',
#   '$178,767,383',
#   '$101,440,743',
#   '56.7%',
#   '$77,326,640',
#   '43.3%',
#   '2008'],
#  ['930',
#   'Along Came Polly',
#   '$178,311,729',
#   '$88,097,164',
#   '49.4%',
#   '$90,214,565',
#   '50.6%',
#   '2004'],
#  ['931',
#   'Flushed Away',
#   '$178,281,554',
#   '$64,665,672',
#   '36.3%',
#   '$113,615,882',
#   '63.7%',
#   '2006'],
#  ['932',
#   'Scary Movie 4',
#   '$178,262,620',
#   '$90,710,620',
#   '50.9%',
#   '$87,552,000',
#   '49.1%',
#   '2006'],
#  ['933',
#   "Dante's Peak",
#   '$178,127,760',
#   '$67,127,760',
#   '37.7%',
#   '$111,000,000',
#   '62.3%',
#   '1997'],
#  ['934',
#   'Brokeback Mountain',
#   '$178,062,759',
#   '$83,043,761',
#   '46.6%',
#   '$95,018,998',
#   '53.4%',
#   '2005'],
#  ['935',
#   'Patriot Games',
#   '$178,051,587',
#   '$83,351,587',
#   '46.8%',
#   '$94,700,000',
#   '53.2%',
#   '1992'],
#  ['936',
#   'Flubber',
#   '$177,977,226',
#   '$92,977,226',
#   '52.2%',
#   '$85,000,000',
#   '47.8%',
#   '1997'],
#  ['937',
#   'Baywatch',
#   '$177,856,751',
#   '$58,060,186',
#   '32.6%',
#   '$119,796,565',
#   '67.4%',
#   '2017'],
#  ['938',
#   'Double Jeopardy',
#   '$177,841,558',
#   '$116,741,558',
#   '65.6%',
#   '$61,100,000',
#   '34.4%',
#   '1999'],
#  ['939',
#   'War Horse',
#   '$177,584,879',
#   '$79,884,879',
#   '45%',
#   '$97,700,000',
#   '55%',
#   '2011'],
#  ['940',
#   'Paranormal Activity 2',
#   '$177,512,032',
#   '$84,752,907',
#   '47.7%',
#   '$92,759,125',
#   '52.3%',
#   '2010'],
#  ['941',
#   'How to Lose a Guy in 10 Days',
#   '$177,502,387',
#   '$105,813,373',
#   '59.6%',
#   '$71,689,014',
#   '40.4%',
#   '2003'],
#  ['942',
#   'Alien vs. Predator',
#   '$177,427,090',
#   '$80,282,231',
#   '45.2%',
#   '$97,144,859',
#   '54.8%',
#   '2004'],
#  ['943',
#   'Hero',
#   '$177,395,557',
#   '$53,710,019',
#   '30.3%',
#   '$123,685,538',
#   '69.7%',
#   '2002'],
#  ['944',
#   'The 40-Year-Old Virgin',
#   '$177,378,645',
#   '$109,449,237',
#   '61.7%',
#   '$67,929,408',
#   '38.3%',
#   '2005'],
#  ['945',
#   "Lee Daniels' The Butler",
#   '$177,313,795',
#   '$116,632,095',
#   '65.8%',
#   '$60,681,700',
#   '34.2%',
#   '2013'],
#  ['946',
#   'The Haunting',
#   '$177,311,151',
#   '$91,411,151',
#   '51.6%',
#   '$85,900,000',
#   '48.4%',
#   '1999'],
#  ['947',
#   'The Descendants',
#   '$177,243,185',
#   '$82,584,160',
#   '46.6%',
#   '$94,659,025',
#   '53.4%',
#   '2011'],
#  ['948',
#   'The A-Team',
#   '$177,238,796',
#   '$77,222,099',
#   '43.6%',
#   '$100,016,697',
#   '56.4%',
#   '2010'],
#  ['949', 'Tootsie', '$177,200,000', '$177,200,000', '100%', '$0', '-', '1982'],
#  ['950',
#   'In the Line of Fire',
#   '$176,997,168',
#   '$102,314,823',
#   '57.8%',
#   '$74,682,345',
#   '42.2%',
#   '1993'],
#  ['951',
#   'Analyze This',
#   '$176,885,658',
#   '$106,885,658',
#   '60.4%',
#   '$70,000,000',
#   '39.6%',
#   '1999'],
#  ['952',
#   'Looper',
#   '$176,506,819',
#   '$66,486,205',
#   '37.7%',
#   '$110,020,614',
#   '62.3%',
#   '2012'],
#  ['954',
#   'Dr. Dolittle 2',
#   '$176,104,344',
#   '$112,952,899',
#   '64.1%',
#   '$63,151,445',
#   '35.9%',
#   '2001'],
#  ['955',
#   'The Italian Job',
#   '$176,070,171',
#   '$106,128,601',
#   '60.3%',
#   '$69,941,570',
#   '39.7%',
#   '2003'],
#  ['956',
#   'The Bucket List',
#   '$175,372,502',
#   '$93,466,502',
#   '53.3%',
#   '$81,906,000',
#   '46.7%',
#   '2007'],
#  ['957',
#   'Sleeping with the Enemy',
#   '$174,999,005',
#   '$101,599,005',
#   '58.1%',
#   '$73,400,000',
#   '41.9%',
#   '1991'],
#  ['958',
#   'Cowboys & Aliens',
#   '$174,822,325',
#   '$100,240,551',
#   '57.3%',
#   '$74,581,774',
#   '42.7%',
#   '2011'],
#  ['959',
#   'The Mule',
#   '$174,804,407',
#   '$103,804,407',
#   '59.4%',
#   '$71,000,000',
#   '40.6%',
#   '2018'],
#  ['960',
#   'George of the Jungle',
#   '$174,463,257',
#   '$105,263,257',
#   '60.3%',
#   '$69,200,000',
#   '39.7%',
#   '1997'],
#  ['961',
#   'Evan Almighty',
#   '$174,440,724',
#   '$100,462,298',
#   '57.6%',
#   '$73,978,426',
#   '42.4%',
#   '2007'],
#  ['962',
#   'Identity Thief',
#   '$173,965,010',
#   '$134,506,920',
#   '77.3%',
#   '$39,458,090',
#   '22.7%',
#   '2013'],
#  ['963',
#   'The Nutcracker and the Four Realms',
#   '$173,961,069',
#   '$54,858,851',
#   '31.5%',
#   '$119,102,218',
#   '68.5%',
#   '2018'],
#  ['964',
#   "Big Momma's House",
#   '$173,959,438',
#   '$117,559,438',
#   '67.6%',
#   '$56,400,000',
#   '32.4%',
#   '2000'],
#  ['965',
#   'In Time',
#   '$173,930,596',
#   '$37,520,095',
#   '21.6%',
#   '$136,410,501',
#   '78.4%',
#   '2011'],
#  ['966',
#   'Amélie',
#   '$173,924,742',
#   '$33,225,499',
#   '19.1%',
#   '$140,699,243',
#   '80.9%',
#   '2001'],
#  ['967',
#   'Operation Mekong',
#   '$173,839,072',
#   '$800,012',
#   '0.5%',
#   '$173,039,060',
#   '99.5%',
#   '2016'],
#  ['968',
#   'Anchorman 2: The Legend Continues',
#   '$173,649,931',
#   '$127,352,707',
#   '73.3%',
#   '$46,297,224',
#   '26.7%',
#   '2013'],
#  ['969',
#   'Creed',
#   '$173,567,581',
#   '$109,767,581',
#   '63.2%',
#   '$63,800,000',
#   '36.8%',
#   '2015'],
#  ['970',
#   'Gemini Man',
#   '$173,469,516',
#   '$48,546,770',
#   '28%',
#   '$124,922,746',
#   '72%',
#   '2019'],
#  ['971',
#   'The Girl on the Train',
#   '$173,185,859',
#   '$75,395,035',
#   '43.5%',
#   '$97,790,824',
#   '56.5%',
#   '2016'],
#  ['972',
#   'Scream',
#   '$173,046,663',
#   '$103,046,663',
#   '59.6%',
#   '$70,000,000',
#   '40.4%',
#   '1996'],
#  ['973',
#   'Cold Mountain',
#   '$173,013,509',
#   '$95,636,509',
#   '55.3%',
#   '$77,377,000',
#   '44.7%',
#   '2003'],
#  ['974',
#   'Black Hawk Down',
#   '$172,989,651',
#   '$108,638,745',
#   '62.8%',
#   '$64,350,906',
#   '37.2%',
#   '2001'],
#  ['975',
#   'The Grand Budapest Hotel',
#   '$172,936,941',
#   '$59,301,324',
#   '34.3%',
#   '$113,635,617',
#   '65.7%',
#   '2014'],
#  ['976',
#   'The Santa Clause 2',
#   '$172,855,065',
#   '$139,236,327',
#   '80.6%',
#   '$33,618,738',
#   '19.4%',
#   '2002'],
#  ['977',
#   'Cloverfield',
#   '$172,394,180',
#   '$80,048,433',
#   '46.4%',
#   '$92,345,747',
#   '53.6%',
#   '2008'],
#  ['978',
#   'Scream 2',
#   '$172,363,301',
#   '$101,363,301',
#   '58.8%',
#   '$71,000,000',
#   '41.2%',
#   '1997'],
#  ['979',
#   'Couples Retreat',
#   '$171,844,840',
#   '$109,204,945',
#   '63.6%',
#   '$62,639,895',
#   '36.4%',
#   '2009'],
#  ['980',
#   'Antz',
#   '$171,757,863',
#   '$90,757,863',
#   '52.8%',
#   '$81,000,000',
#   '47.2%',
#   '1998'],
#  ['981',
#   'Blood Diamond',
#   '$171,720,398',
#   '$57,377,916',
#   '33.4%',
#   '$114,342,482',
#   '66.6%',
#   '2006'],
#  ['982',
#   'Jackass 3D',
#   '$171,685,792',
#   '$117,229,692',
#   '68.3%',
#   '$54,456,100',
#   '31.7%',
#   '2010'],
#  ['983',
#   'No Country for Old Men',
#   '$171,627,166',
#   '$74,283,625',
#   '43.3%',
#   '$97,343,541',
#   '56.7%',
#   '2007'],
#  ['984',
#   'John Wick: Chapter 2',
#   '$171,539,887',
#   '$92,029,184',
#   '53.6%',
#   '$79,510,703',
#   '46.4%',
#   '2017'],
#  ['985',
#   'Cocktail',
#   '$171,504,781',
#   '$78,222,753',
#   '45.6%',
#   '$93,282,028',
#   '54.4%',
#   '1988'],
#  ['987',
#   'Mr. Deeds',
#   '$171,269,535',
#   '$126,293,452',
#   '73.7%',
#   '$44,976,083',
#   '26.3%',
#   '2002'],
#  ['988',
#   'Contact',
#   '$171,120,329',
#   '$100,920,329',
#   '59%',
#   '$70,200,000',
#   '41%',
#   '1997'],
#  ['989',
#   'Superbad',
#   '$170,812,526',
#   '$121,463,226',
#   '71.1%',
#   '$49,349,300',
#   '28.9%',
#   '2007'],
#  ['990',
#   'Spies in Disguise',
#   '$170,744,862',
#   '$66,435,069',
#   '38.9%',
#   '$104,309,793',
#   '61.1%',
#   '2019'],
#  ['991',
#   'The Other Guys',
#   '$170,458,922',
#   '$119,219,978',
#   '69.9%',
#   '$51,238,944',
#   '30.1%',
#   '2010'],
#  ['992',
#   'The Specialist',
#   '$170,362,582',
#   '$57,362,582',
#   '33.7%',
#   '$113,000,000',
#   '66.3%',
#   '1994'],
#  ['993',
#   'Olympus Has Fallen',
#   '$170,270,201',
#   '$98,925,640',
#   '58.1%',
#   '$71,344,561',
#   '41.9%',
#   '2013'],
#  ['994',
#   'Starsky & Hutch',
#   '$170,268,750',
#   '$88,237,754',
#   '51.8%',
#   '$82,030,996',
#   '48.2%',
#   '2004'],
#  ['995',
#   'Shall We Dance',
#   '$170,128,460',
#   '$57,890,460',
#   '34%',
#   '$112,238,000',
#   '66%',
#   '2004'],
#  ['996',
#   'Stuart Little 2',
#   '$169,956,806',
#   '$64,956,806',
#   '38.2%',
#   '$105,000,000',
#   '61.8%',
#   '2002'],
#  ['997',
#   'Zookeeper',
#   '$169,852,759',
#   '$80,360,843',
#   '47.3%',
#   '$89,491,916',
#   '52.7%',
#   '2011'],
#  ['998',
#   'Dumb and Dumber To',
#   '$169,837,010',
#   '$86,208,010',
#   '50.8%',
#   '$83,629,000',
#   '49.2%',
#   '2014'],
#  ['999',
#   'Ghost in the Shell',
#   '$169,801,921',
#   '$40,563,557',
#   '23.9%',
#   '$129,238,364',
#   '76.1%',
#   '2017'],
#  ['1,000',
#   'Seven Pounds',
#   '$169,748,929',
#   '$69,951,824',
#   '41.2%',
#   '$99,797,105',
#   '58.8%',
#   '2008'],
#  ['1,001',
#   'Meet the Robinsons',
#   '$169,333,034',
#   '$97,822,171',
#   '57.8%',
#   '$71,510,863',
#   '42.2%',
#   '2007'],
#  ['1,002',
#   "The Emperor's New Groove",
#   '$169,327,687',
#   '$89,302,687',
#   '52.7%',
#   '$80,025,000',
#   '47.3%',
#   '2000'],
#  ['1,003',
#   '12 Monkeys',
#   '$168,839,459',
#   '$57,141,459',
#   '33.8%',
#   '$111,698,000',
#   '66.2%',
#   '1995'],
#  ['1,004',
#   'Dodgeball: A True Underdog Story',
#   '$168,423,227',
#   '$114,326,736',
#   '67.9%',
#   '$54,096,491',
#   '32.1%',
#   '2004'],
#  ['1,005',
#   'Hellboy II: The Golden Army',
#   '$168,319,243',
#   '$75,986,503',
#   '45.1%',
#   '$92,332,740',
#   '54.9%',
#   '2008'],
#  ['1,006',
#   'Insidious: The Last Key',
#   '$167,885,588',
#   '$67,745,330',
#   '40.4%',
#   '$100,140,258',
#   '59.6%',
#   '2018'],
#  ['1,007',
#   'Fantastic Four',
#   '$167,882,881',
#   '$56,117,548',
#   '33.4%',
#   '$111,765,333',
#   '66.6%',
#   '2015'],
#  ['1,008',
#   'Unstoppable',
#   '$167,805,466',
#   '$81,562,942',
#   '48.6%',
#   '$86,242,524',
#   '51.4%',
#   '2010'],
#  ['1,009',
#   'Three Men and a Baby',
#   '$167,780,960',
#   '$167,780,960',
#   '100%',
#   '$0',
#   '-',
#   '1987'],
#  ['1,010',
#   'Magic Mike',
#   '$167,739,368',
#   '$113,721,571',
#   '67.8%',
#   '$54,017,797',
#   '32.2%',
#   '2012'],
#  ['1,011',
#   'Alexander',
#   '$167,298,192',
#   '$34,297,191',
#   '20.5%',
#   '$133,001,001',
#   '79.5%',
#   '2004'],
#  ['1,012',
#   'Up in the Air',
#   '$166,842,739',
#   '$83,823,381',
#   '50.2%',
#   '$83,019,358',
#   '49.8%',
#   '2009'],
#  ['1,013',
#   'Nutty Professor II: The Klumps',
#   '$166,339,890',
#   '$123,309,890',
#   '74.1%',
#   '$43,030,000',
#   '25.9%',
#   '2000'],
#  ['1,014',
#   'Sleepers',
#   '$165,615,285',
#   '$53,315,285',
#   '32.2%',
#   '$112,300,000',
#   '67.8%',
#   '1996']]

# %%
highest_grossing = movie_list1 + movie_list2 + movie_list3 + movie_list4 + movie_list5
len(highest_grossing)
highest_grossing
# Out:
# [['1',
#   'Avengers: Endgame',
#   '$2,797,800,564',
#   '$858,373,000',
#   '30.7%',
#   '$1,939,427,564',
#   '69.3%',
#   '2019'],
#  ['2',
#   'Avatar',
#   '$2,790,439,000',
#   '$760,507,625',
#   '27.2%',
#   '$2,029,931,375',
#   '72.8%',
#   '2009'],
#  ['3',
#   'Titanic',
#   '$2,194,439,542',
#   '$659,363,944',
#   '30%',
#   '$1,535,075,598',
#   '70%',
#   '1997'],
#  ['4',
#   'Star Wars: Episode VII - The Force Awakens',
#   '$2,068,223,624',
#   '$936,662,225',
#   '45.3%',
#   '$1,131,561,399',
#   '54.7%',
#   '2015'],
#  ['5',
#   'Avengers: Infinity War',
#   '$2,048,359,754',
#   '$678,815,482',
#   '33.1%',
#   '$1,369,544,272',
#   '66.9%',
#   '2018'],
#  ['6',
#   'Jurassic World',
#   '$1,670,400,637',
#   '$652,270,625',
#   '39%',
#   '$1,018,130,012',
#   '61%',
#   '2015'],
#  ['7',
#   'The Lion King',
#   '$1,656,943,394',
#   '$543,638,043',
#   '32.8%',
#   '$1,113,305,351',
#   '67.2%',
#   '2019'],
#  ['8',
#   'The Avengers',
#   '$1,518,812,988',
#   '$623,357,910',
#   '41%',
#   '$895,455,078',
#   '59%',
#   '2012'],
#  ['9',
#   'Furious 7',
#   '$1,515,047,671',
#   '$353,007,020',
#   '23.3%',
#   '$1,162,040,651',
#   '76.7%',
#   '2015'],
#  ['10',
#   'Frozen II',
#   '$1,448,800,077',
#   '$477,020,655',
#   '32.9%',
#   '$971,779,422',
#   '67.1%',
#   '2019'],
#  ['11',
#   'Avengers: Age of Ultron',
#   '$1,402,805,868',
#   '$459,005,868',
#   '32.7%',
#   '$943,800,000',
#   '67.3%',
#   '2015'],
#  ['12',
#   'Black Panther',
#   '$1,346,913,161',
#   '$700,059,566',
#   '52%',
#   '$646,853,595',
#   '48%',
#   '2018'],
#  ['13',
#   'Harry Potter and the Deathly Hallows: Part 2',
#   '$1,341,932,398',
#   '$381,409,310',
#   '28.4%',
#   '$960,523,088',
#   '71.6%',
#   '2011'],
#  ['14',
#   'Star Wars: Episode VIII - The Last Jedi',
#   '$1,332,539,889',
#   '$620,181,382',
#   '46.5%',
#   '$712,358,507',
#   '53.5%',
#   '2017'],
#  ['15',
#   'Jurassic World: Fallen Kingdom',
#   '$1,308,467,944',
#   '$417,719,760',
#   '31.9%',
#   '$890,748,184',
#   '68.1%',
#   '2018'],
#  ['16',
#   'Frozen',
#   '$1,280,802,282',
#   '$400,738,009',
#   '31.3%',
#   '$880,064,273',
#   '68.7%',
#   '2013'],
#  ['17',
#   'Beauty and the Beast',
#   '$1,263,521,126',
#   '$504,014,165',
#   '39.9%',
#   '$759,506,961',
#   '60.1%',
#   '2017'],
#  ['18',
#   'Incredibles 2',
#   '$1,242,805,359',
#   '$608,581,744',
#   '49%',
#   '$634,223,615',
#   '51%',
#   '2018'],
#  ['19',
#   'The Fate of the Furious',
#   '$1,236,005,118',
#   '$226,008,385',
#   '18.3%',
#   '$1,009,996,733',
#   '81.7%',
#   '2017'],
#  ['20',
#   'Iron Man 3',
#   '$1,214,811,252',
#   '$409,013,994',
#   '33.7%',
#   '$805,797,258',
#   '66.3%',
#   '2013'],
#  ['21',
#   'Minions',
#   '$1,159,398,397',
#   '$336,045,770',
#   '29%',
#   '$823,352,627',
#   '71%',
#   '2015'],
#  ['22',
#   'Captain America: Civil War',
#   '$1,153,296,293',
#   '$408,084,349',
#   '35.4%',
#   '$745,211,944',
#   '64.6%',
#   '2016'],
#  ['23',
#   'Aquaman',
#   '$1,148,461,807',
#   '$335,061,807',
#   '29.2%',
#   '$813,400,000',
#   '70.8%',
#   '2018'],
#  ['24',
#   'The Lord of the Rings: The Return of the King',
#   '$1,142,219,401',
#   '$377,845,905',
#   '33.1%',
#   '$764,373,496',
#   '66.9%',
#   '2003'],
#  ['25',
#   'Spider-Man: Far from Home',
#   '$1,131,927,996',
#   '$390,532,085',
#   '34.5%',
#   '$741,395,911',
#   '65.5%',
#   '2019'],
#  ['26',
#   'Captain Marvel',
#   '$1,128,274,794',
#   '$426,829,839',
#   '37.8%',
#   '$701,444,955',
#   '62.2%',
#   '2019'],
#  ['27',
#   'Transformers: Dark of the Moon',
#   '$1,123,794,079',
#   '$352,390,543',
#   '31.4%',
#   '$771,403,536',
#   '68.6%',
#   '2011'],
#  ['28',
#   'Skyfall',
#   '$1,108,561,013',
#   '$304,360,277',
#   '27.5%',
#   '$804,200,736',
#   '72.5%',
#   '2012'],
#  ['29',
#   'Transformers: Age of Extinction',
#   '$1,104,054,072',
#   '$245,439,076',
#   '22.2%',
#   '$858,614,996',
#   '77.8%',
#   '2014'],
#  ['30',
#   'The Dark Knight Rises',
#   '$1,081,041,287',
#   '$448,139,099',
#   '41.4%',
#   '$632,902,188',
#   '58.6%',
#   '2012'],
#  ['31',
#   'Joker',
#   '$1,073,940,971',
#   '$335,440,971',
#   '31.2%',
#   '$738,500,000',
#   '68.8%',
#   '2019'],
#  ['32',
#   'Toy Story 4',
#   '$1,073,394,593',
#   '$434,038,008',
#   '40.4%',
#   '$639,356,585',
#   '59.6%',
#   '2019'],
#  ['33',
#   'Star Wars: Episode IX - The Rise of Skywalker',
#   '$1,073,260,762',
#   '$514,684,482',
#   '48%',
#   '$558,576,280',
#   '52%',
#   '2019'],
#  ['34',
#   'Toy Story 3',
#   '$1,066,969,703',
#   '$415,004,880',
#   '38.9%',
#   '$651,964,823',
#   '61.1%',
#   '2010'],
#  ['35',
#   "Pirates of the Caribbean: Dead Man's Chest",
#   '$1,066,179,725',
#   '$423,315,812',
#   '39.7%',
#   '$642,863,913',
#   '60.3%',
#   '2006'],
#  ['36',
#   'Rogue One: A Star Wars Story',
#   '$1,056,057,273',
#   '$532,177,324',
#   '50.4%',
#   '$523,879,949',
#   '49.6%',
#   '2016'],
#  ['37',
#   'Aladdin',
#   '$1,050,693,953',
#   '$355,559,216',
#   '33.8%',
#   '$695,134,737',
#   '66.2%',
#   '2019'],
#  ['38',
#   'Pirates of the Caribbean: On Stranger Tides',
#   '$1,045,713,802',
#   '$241,071,802',
#   '23%',
#   '$804,642,000',
#   '77%',
#   '2011'],
#  ['39',
#   'Despicable Me 3',
#   '$1,034,799,409',
#   '$264,624,300',
#   '25.6%',
#   '$770,175,109',
#   '74.4%',
#   '2017'],
#  ['40',
#   'Jurassic Park',
#   '$1,032,020,521',
#   '$402,828,120',
#   '39%',
#   '$629,192,401',
#   '61%',
#   '1993'],
#  ['41',
#   'Finding Dory',
#   '$1,028,570,889',
#   '$486,295,561',
#   '47.3%',
#   '$542,275,328',
#   '52.7%',
#   '2016'],
#  ['42',
#   'Star Wars: Episode I - The Phantom Menace',
#   '$1,027,082,707',
#   '$474,544,677',
#   '46.2%',
#   '$552,538,030',
#   '53.8%',
#   '1999'],
#  ['43',
#   'Alice in Wonderland',
#   '$1,025,467,110',
#   '$334,191,110',
#   '32.6%',
#   '$691,276,000',
#   '67.4%',
#   '2010'],
#  ['44',
#   'Zootopia',
#   '$1,023,784,195',
#   '$341,268,248',
#   '33.3%',
#   '$682,515,947',
#   '66.7%',
#   '2016'],
#  ['45',
#   'The Hobbit: An Unexpected Journey',
#   '$1,017,003,568',
#   '$303,003,568',
#   '29.8%',
#   '$714,000,000',
#   '70.2%',
#   '2012'],
#  ['46',
#   'The Dark Knight',
#   '$1,004,934,033',
#   '$535,234,033',
#   '53.3%',
#   '$469,700,000',
#   '46.7%',
#   '2008'],
#  ['47',
#   "Harry Potter and the Sorcerer's Stone",
#   '$978,087,613',
#   '$318,087,620',
#   '32.5%',
#   '$659,999,993',
#   '67.5%',
#   '2001'],
#  ['48',
#   'Harry Potter and the Deathly Hallows: Part 1',
#   '$976,920,103',
#   '$296,347,721',
#   '30.3%',
#   '$680,572,382',
#   '69.7%',
#   '2010'],
#  ['49',
#   'Despicable Me 2',
#   '$970,766,005',
#   '$368,065,385',
#   '37.9%',
#   '$602,700,620',
#   '62.1%',
#   '2013'],
#  ['50',
#   'The Lion King',
#   '$968,511,805',
#   '$422,783,777',
#   '43.6%',
#   '$545,728,028',
#   '56.4%',
#   '1994'],
#  ['51',
#   'The Jungle Book',
#   '$966,550,600',
#   '$364,001,123',
#   '37.7%',
#   '$602,549,477',
#   '62.3%',
#   '2016'],
#  ['52',
#   'Jumanji: Welcome to the Jungle',
#   '$962,102,237',
#   '$404,540,171',
#   '42%',
#   '$557,562,066',
#   '58%',
#   '2017'],
#  ['53',
#   "Pirates of the Caribbean: At World's End",
#   '$960,996,492',
#   '$309,420,425',
#   '32.2%',
#   '$651,576,067',
#   '67.8%',
#   '2007'],
#  ['54',
#   'The Hobbit: The Desolation of Smaug',
#   '$958,366,855',
#   '$258,366,855',
#   '27%',
#   '$700,000,000',
#   '73%',
#   '2013'],
#  ['55',
#   'The Hobbit: The Battle of the Five Armies',
#   '$956,019,788',
#   '$255,119,788',
#   '26.7%',
#   '$700,900,000',
#   '73.3%',
#   '2014'],
#  ['56',
#   'The Lord of the Rings: The Two Towers',
#   '$951,208,089',
#   '$342,551,365',
#   '36%',
#   '$608,656,724',
#   '64%',
#   '2002'],
#  ['57',
#   'Harry Potter and the Order of the Phoenix',
#   '$942,044,510',
#   '$292,353,413',
#   '31%',
#   '$649,691,097',
#   '69%',
#   '2007'],
#  ['58',
#   'Finding Nemo',
#   '$940,343,261',
#   '$380,843,261',
#   '40.5%',
#   '$559,500,000',
#   '59.5%',
#   '2003'],
#  ['59',
#   'Harry Potter and the Half-Blood Prince',
#   '$934,326,396',
#   '$302,305,431',
#   '32.4%',
#   '$632,020,965',
#   '67.6%',
#   '2009'],
#  ['60',
#   'Shrek 2',
#   '$928,760,770',
#   '$441,226,247',
#   '47.5%',
#   '$487,534,523',
#   '52.5%',
#   '2004'],
#  ['61',
#   'Bohemian Rhapsody',
#   '$903,655,259',
#   '$216,428,042',
#   '24%',
#   '$687,227,217',
#   '76%',
#   '2018'],
#  ['62',
#   'Harry Potter and the Goblet of Fire',
#   '$896,346,229',
#   '$290,417,905',
#   '32.4%',
#   '$605,928,324',
#   '67.6%',
#   '2005'],
#  ['63',
#   'Spider-Man 3',
#   '$894,983,373',
#   '$336,530,303',
#   '37.6%',
#   '$558,453,070',
#   '62.4%',
#   '2007'],
#  ['64',
#   'The Lord of the Rings: The Fellowship of the Ring',
#   '$887,832,826',
#   '$315,544,750',
#   '35.5%',
#   '$572,288,076',
#   '64.5%',
#   '2001'],
#  ['65',
#   'Ice Age: Dawn of the Dinosaurs',
#   '$886,686,817',
#   '$196,573,705',
#   '22.2%',
#   '$690,113,112',
#   '77.8%',
#   '2009'],
#  ['66',
#   'Spectre',
#   '$880,674,609',
#   '$200,074,609',
#   '22.7%',
#   '$680,600,000',
#   '77.3%',
#   '2015'],
#  ['67',
#   'Spider-Man: Homecoming',
#   '$880,166,924',
#   '$334,201,140',
#   '38%',
#   '$545,965,784',
#   '62%',
#   '2017'],
#  ['68',
#   'Harry Potter and the Chamber of Secrets',
#   '$879,465,594',
#   '$262,450,136',
#   '29.8%',
#   '$617,015,458',
#   '70.2%',
#   '2002'],
#  ['69',
#   'Ice Age: Continental Drift',
#   '$877,244,782',
#   '$161,321,843',
#   '18.4%',
#   '$715,922,939',
#   '81.6%',
#   '2012'],
#  ['70',
#   'The Secret Life of Pets',
#   '$875,457,937',
#   '$368,384,330',
#   '42.1%',
#   '$507,073,607',
#   '57.9%',
#   '2016'],
#  ['71',
#   'Batman v Superman: Dawn of Justice',
#   '$873,634,919',
#   '$330,360,194',
#   '37.8%',
#   '$543,274,725',
#   '62.2%',
#   '2016'],
#  ['72',
#   'Wolf Warrior 2',
#   '$870,325,439',
#   '$2,721,100',
#   '0.3%',
#   '$867,604,339',
#   '99.7%',
#   '2017'],
#  ['73',
#   'Star Wars: Episode III - Revenge of the Sith',
#   '$868,390,560',
#   '$380,270,577',
#   '43.8%',
#   '$488,119,983',
#   '56.2%',
#   '2005'],
#  ['74',
#   'The Hunger Games: Catching Fire',
#   '$865,011,746',
#   '$424,668,047',
#   '49.1%',
#   '$440,343,699',
#   '50.9%',
#   '2013'],
#  ['75',
#   'Guardians of the Galaxy Vol. 2',
#   '$863,756,051',
#   '$389,813,101',
#   '45.1%',
#   '$473,942,950',
#   '54.9%',
#   '2017'],
#  ['76',
#   'Inside Out',
#   '$857,611,174',
#   '$356,461,711',
#   '41.6%',
#   '$501,149,463',
#   '58.4%',
#   '2015'],
#  ['77',
#   'Venom',
#   '$856,085,151',
#   '$213,515,506',
#   '24.9%',
#   '$642,569,645',
#   '75.1%',
#   '2018'],
#  ['78',
#   'Thor: Ragnarok',
#   '$853,977,126',
#   '$315,058,289',
#   '36.9%',
#   '$538,918,837',
#   '63.1%',
#   '2017'],
#  ['79',
#   'Transformers: Revenge of the Fallen',
#   '$836,303,693',
#   '$402,111,870',
#   '48.1%',
#   '$434,191,823',
#   '51.9%',
#   '2009'],
#  ['80',
#   'Inception',
#   '$829,895,144',
#   '$292,576,195',
#   '35.2%',
#   '$537,318,949',
#   '64.8%',
#   '2010'],
#  ['81',
#   'The Twilight Saga: Breaking Dawn - Part 2',
#   '$829,746,820',
#   '$292,324,737',
#   '35.2%',
#   '$537,422,083',
#   '64.8%',
#   '2012'],
#  ['82',
#   'Spider-Man',
#   '$825,025,036',
#   '$407,022,860',
#   '49.3%',
#   '$418,002,176',
#   '50.7%',
#   '2002'],
#  ['83',
#   'Wonder Woman',
#   '$821,847,012',
#   '$412,563,408',
#   '50.2%',
#   '$409,283,604',
#   '49.8%',
#   '2017'],
#  ['84',
#   'Independence Day',
#   '$817,400,891',
#   '$306,169,268',
#   '37.5%',
#   '$511,231,623',
#   '62.5%',
#   '1996'],
#  ['85',
#   'Fantastic Beasts and Where to Find Them',
#   '$814,037,575',
#   '$234,037,575',
#   '28.8%',
#   '$580,000,000',
#   '71.2%',
#   '2016'],
#  ['86',
#   'Shrek the Third',
#   '$813,367,380',
#   '$322,719,944',
#   '39.7%',
#   '$490,647,436',
#   '60.3%',
#   '2007'],
#  ['87',
#   'Coco',
#   '$807,082,196',
#   '$209,726,015',
#   '26%',
#   '$597,356,181',
#   '74%',
#   '2017'],
#  ['88',
#   'Harry Potter and the Prisoner of Azkaban',
#   '$796,093,802',
#   '$249,975,996',
#   '31.4%',
#   '$546,117,806',
#   '68.6%',
#   '2004'],
#  ['89',
#   'Pirates of the Caribbean: Dead Men Tell No Tales',
#   '$794,861,794',
#   '$172,558,876',
#   '21.7%',
#   '$622,302,918',
#   '78.3%',
#   '2017'],
#  ['90',
#   'E.T. the Extra-Terrestrial',
#   '$793,482,178',
#   '$435,110,554',
#   '54.8%',
#   '$358,371,624',
#   '45.2%',
#   '1982'],
#  ['91',
#   '2012',
#   '$791,217,826',
#   '$166,112,167',
#   '21%',
#   '$625,105,659',
#   '79%',
#   '2009'],
#  ['92',
#   'Mission: Impossible - Fallout',
#   '$791,115,104',
#   '$220,159,104',
#   '27.8%',
#   '$570,956,000',
#   '72.2%',
#   '2018'],
#  ['93',
#   'Jumanji: The Next Level',
#   '$790,929,476',
#   '$313,787,152',
#   '39.7%',
#   '$477,142,324',
#   '60.3%',
#   '2019'],
#  ['94',
#   'Indiana Jones and the Kingdom of the Crystal Skull',
#   '$790,653,942',
#   '$317,101,119',
#   '40.1%',
#   '$473,552,823',
#   '59.9%',
#   '2008'],
#  ['95',
#   'Spider-Man 2',
#   '$788,976,453',
#   '$373,585,825',
#   '47.4%',
#   '$415,390,628',
#   '52.6%',
#   '2004'],
#  ['96',
#   'Fast & Furious 6',
#   '$788,679,850',
#   '$238,679,850',
#   '30.3%',
#   '$550,000,000',
#   '69.7%',
#   '2013'],
#  ['97',
#   'Deadpool 2',
#   '$785,794,179',
#   '$324,591,735',
#   '41.3%',
#   '$461,202,444',
#   '58.7%',
#   '2018'],
#  ['98',
#   'Deadpool',
#   '$782,612,155',
#   '$363,070,709',
#   '46.4%',
#   '$419,541,446',
#   '53.6%',
#   '2016'],
#  ['99',
#   'Star Wars: Episode IV - A New Hope',
#   '$775,512,064',
#   '$460,998,507',
#   '59.4%',
#   '$314,513,557',
#   '40.6%',
#   '1977'],
#  ['100',
#   'Guardians of the Galaxy',
#   '$772,776,600',
#   '$333,176,600',
#   '43.1%',
#   '$439,600,000',
#   '56.9%',
#   '2014'],
#  ['101',
#   'The Da Vinci Code',
#   '$760,006,945',
#   '$217,536,138',
#   '28.6%',
#   '$542,470,807',
#   '71.4%',
#   '2006'],
#  ['102',
#   'Fast & Furious Presents: Hobbs & Shaw',
#   '$759,056,935',
#   '$173,956,935',
#   '22.9%',
#   '$585,100,000',
#   '77.1%',
#   '2019'],
#  ['103',
#   'Maleficent',
#   '$758,410,378',
#   '$241,410,378',
#   '31.8%',
#   '$517,000,000',
#   '68.2%',
#   '2014'],
#  ['104',
#   'The Amazing Spider-Man',
#   '$757,930,663',
#   '$262,030,663',
#   '34.6%',
#   '$495,900,000',
#   '65.4%',
#   '2012'],
#  ['105',
#   'The Hunger Games: Mockingjay - Part 1',
#   '$755,356,711',
#   '$337,135,885',
#   '44.6%',
#   '$418,220,826',
#   '55.4%',
#   '2014'],
#  ['106',
#   'Shrek Forever After',
#   '$752,600,867',
#   '$238,736,787',
#   '31.7%',
#   '$513,864,080',
#   '68.3%',
#   '2010'],
#  ['107',
#   "Madagascar 3: Europe's Most Wanted",
#   '$746,921,274',
#   '$216,391,482',
#   '29%',
#   '$530,529,792',
#   '71%',
#   '2012'],
#  ['108',
#   'Suicide Squad',
#   '$746,846,894',
#   '$325,100,054',
#   '43.5%',
#   '$421,746,840',
#   '56.5%',
#   '2016'],
#  ['109',
#   'X-Men: Days of Future Past',
#   '$746,045,700',
#   '$233,921,534',
#   '31.4%',
#   '$512,124,166',
#   '68.6%',
#   '2014'],
#  ['110',
#   'The Chronicles of Narnia: The Lion, the Witch and the Wardrobe',
#   '$745,013,115',
#   '$291,710,957',
#   '39.2%',
#   '$453,302,158',
#   '60.8%',
#   '2005'],
#  ['111',
#   'Monsters University',
#   '$743,559,607',
#   '$268,492,764',
#   '36.1%',
#   '$475,066,843',
#   '63.9%',
#   '2013'],
#  ['112',
#   'The Matrix Reloaded',
#   '$741,846,459',
#   '$281,576,461',
#   '38%',
#   '$460,269,998',
#   '62%',
#   '2003'],
#  ['113',
#   'Up',
#   '$735,099,082',
#   '$293,004,164',
#   '39.9%',
#   '$442,094,918',
#   '60.1%',
#   '2009'],
#  ['114',
#   'Ne Zha',
#   '$726,063,471',
#   '$3,695,533',
#   '0.5%',
#   '$722,367,938',
#   '99.5%',
#   '2019'],
#  ['115',
#   'Gravity',
#   '$723,192,705',
#   '$274,092,705',
#   '37.9%',
#   '$449,100,000',
#   '62.1%',
#   '2013'],
#  ['116',
#   'Captain America: The Winter Soldier',
#   '$714,421,503',
#   '$259,766,572',
#   '36.4%',
#   '$454,654,931',
#   '63.6%',
#   '2014'],
#  ['117',
#   'The Twilight Saga: Breaking Dawn - Part 1',
#   '$712,205,856',
#   '$281,287,133',
#   '39.5%',
#   '$430,918,723',
#   '60.5%',
#   '2011'],
#  ['118',
#   'The Twilight Saga: New Moon',
#   '$711,020,081',
#   '$297,816,253',
#   '41.9%',
#   '$413,203,828',
#   '58.1%',
#   '2009'],
#  ['119',
#   'Dawn of the Planet of the Apes',
#   '$710,644,566',
#   '$208,545,589',
#   '29.4%',
#   '$502,098,977',
#   '70.6%',
#   '2014'],
#  ['120',
#   'Transformers',
#   '$709,709,780',
#   '$319,246,193',
#   '45%',
#   '$390,463,587',
#   '55%',
#   '2007'],
#  ['121',
#   'The Amazing Spider-Man 2',
#   '$708,982,323',
#   '$202,853,933',
#   '28.6%',
#   '$506,128,390',
#   '71.4%',
#   '2014'],
#  ['122',
#   'It',
#   '$701,796,444',
#   '$328,828,874',
#   '46.9%',
#   '$372,967,570',
#   '53.1%',
#   '2017'],
#  ['123',
#   'The Wandering Earth',
#   '$699,760,773',
#   '$5,875,487',
#   '0.8%',
#   '$693,885,286',
#   '99.2%',
#   '2019'],
#  ['124',
#   'The Twilight Saga: Eclipse',
#   '$698,491,347',
#   '$300,531,751',
#   '43%',
#   '$397,959,596',
#   '57%',
#   '2010'],
#  ['125',
#   'Mission: Impossible - Ghost Protocol',
#   '$694,713,380',
#   '$209,397,903',
#   '30.1%',
#   '$485,315,477',
#   '69.9%',
#   '2011'],
#  ['126',
#   'The Hunger Games',
#   '$694,394,724',
#   '$408,010,692',
#   '58.8%',
#   '$286,384,032',
#   '41.2%',
#   '2012'],
#  ['127',
#   'Moana',
#   '$690,845,539',
#   '$248,757,044',
#   '36%',
#   '$442,088,495',
#   '64%',
#   '2016'],
#  ['128',
#   'Mission: Impossible - Rogue Nation',
#   '$682,714,267',
#   '$195,042,377',
#   '28.6%',
#   '$487,671,890',
#   '71.4%',
#   '2015'],
#  ['129',
#   'Forrest Gump',
#   '$678,194,565',
#   '$330,455,270',
#   '48.7%',
#   '$347,739,295',
#   '51.3%',
#   '1994'],
#  ['130',
#   'Doctor Strange',
#   '$677,718,395',
#   '$232,641,920',
#   '34.3%',
#   '$445,076,475',
#   '65.7%',
#   '2016'],
#  ['131',
#   'Interstellar',
#   '$677,471,339',
#   '$188,020,017',
#   '27.8%',
#   '$489,451,322',
#   '72.2%',
#   '2014'],
#  ['132',
#   'The Sixth Sense',
#   '$672,806,292',
#   '$293,506,292',
#   '43.6%',
#   '$379,300,000',
#   '56.4%',
#   '1999'],
#  ['133',
#   'Man of Steel',
#   '$668,045,518',
#   '$291,045,518',
#   '43.6%',
#   '$377,000,000',
#   '56.4%',
#   '2013'],
#  ['134',
#   'Ice Age: The Meltdown',
#   '$667,094,506',
#   '$195,330,621',
#   '29.3%',
#   '$471,763,885',
#   '70.7%',
#   '2006'],
#  ['135',
#   'Kung Fu Panda 2',
#   '$665,692,281',
#   '$165,249,063',
#   '24.8%',
#   '$500,443,218',
#   '75.2%',
#   '2011'],
#  ['136',
#   'The Hunger Games: Mockingjay - Part 2',
#   '$658,344,137',
#   '$281,723,902',
#   '42.8%',
#   '$376,620,235',
#   '57.2%',
#   '2015'],
#  ['137',
#   'Justice League',
#   '$657,924,295',
#   '$229,024,295',
#   '34.8%',
#   '$428,900,000',
#   '65.2%',
#   '2017'],
#  ['138',
#   'Big Hero 6',
#   '$657,827,828',
#   '$222,527,828',
#   '33.8%',
#   '$435,300,000',
#   '66.2%',
#   '2014'],
#  ['139',
#   'Fantastic Beasts: The Crimes of Grindelwald',
#   '$654,855,901',
#   '$159,555,901',
#   '24.4%',
#   '$495,300,000',
#   '75.6%',
#   '2018'],
#  ['140',
#   'Pirates of the Caribbean: The Curse of the Black Pearl',
#   '$654,264,015',
#   '$305,413,918',
#   '46.7%',
#   '$348,850,097',
#   '53.3%',
#   '2003'],
#  ['141',
#   'Star Wars: Episode II - Attack of the Clones',
#   '$653,779,970',
#   '$310,676,740',
#   '47.5%',
#   '$343,103,230',
#   '52.5%',
#   '2002'],
#  ['142',
#   'Thor: The Dark World',
#   '$644,783,140',
#   '$206,362,140',
#   '32%',
#   '$438,421,000',
#   '68%',
#   '2013'],
#  ['143',
#   'Sing',
#   '$634,151,679',
#   '$270,395,425',
#   '42.6%',
#   '$363,756,254',
#   '57.4%',
#   '2016'],
#  ['144',
#   'Monsters, Inc.',
#   '$632,316,649',
#   '$289,916,256',
#   '45.8%',
#   '$342,400,393',
#   '54.2%',
#   '2001'],
#  ['145',
#   'Kung Fu Panda',
#   '$631,746,197',
#   '$215,434,591',
#   '34.1%',
#   '$416,311,606',
#   '65.9%',
#   '2008'],
#  ['146',
#   'The Incredibles',
#   '$631,606,713',
#   '$261,441,092',
#   '41.4%',
#   '$370,165,621',
#   '58.6%',
#   '2004'],
#  ['147',
#   'The Martian',
#   '$630,161,890',
#   '$228,433,663',
#   '36.2%',
#   '$401,728,227',
#   '63.8%',
#   '2015'],
#  ['148',
#   'Hancock',
#   '$629,443,428',
#   '$227,946,274',
#   '36.2%',
#   '$401,497,154',
#   '63.8%',
#   '2008'],
#  ['149',
#   'Fast Five',
#   '$626,137,675',
#   '$209,837,675',
#   '33.5%',
#   '$416,300,000',
#   '66.5%',
#   '2011'],
#  ['150',
#   'Men in Black 3',
#   '$624,026,776',
#   '$179,020,854',
#   '28.7%',
#   '$445,005,922',
#   '71.3%',
#   '2012'],
#  ['151',
#   'Iron Man 2',
#   '$623,933,331',
#   '$312,433,331',
#   '50.1%',
#   '$311,500,000',
#   '49.9%',
#   '2010'],
#  ['152',
#   'Ratatouille',
#   '$623,726,085',
#   '$206,445,654',
#   '33.1%',
#   '$417,280,431',
#   '66.9%',
#   '2007'],
#  ['153',
#   'Ant-Man and the Wasp',
#   '$622,674,139',
#   '$216,648,740',
#   '34.8%',
#   '$406,025,399',
#   '65.2%',
#   '2018'],
#  ['154',
#   'How to Train Your Dragon 2',
#   '$621,537,519',
#   '$177,002,924',
#   '28.5%',
#   '$444,534,595',
#   '71.5%',
#   '2014'],
#  ['155',
#   'Logan',
#   '$619,021,436',
#   '$226,277,068',
#   '36.6%',
#   '$392,744,368',
#   '63.4%',
#   '2017'],
#  ['156',
#   'The Lost World: Jurassic Park',
#   '$618,638,999',
#   '$229,086,679',
#   '37%',
#   '$389,552,320',
#   '63%',
#   '1997'],
#  ['157',
#   'Casino Royale',
#   '$616,501,619',
#   '$167,445,960',
#   '27.2%',
#   '$449,055,659',
#   '72.8%',
#   '2006'],
#  ['158',
#   'The Passion of the Christ',
#   '$612,054,428',
#   '$370,782,930',
#   '60.6%',
#   '$241,271,498',
#   '39.4%',
#   '2004'],
#  ['159',
#   'Mamma Mia!',
#   '$609,896,805',
#   '$144,169,664',
#   '23.6%',
#   '$465,727,141',
#   '76.4%',
#   '2008'],
#  ['160',
#   'Life of Pi',
#   '$609,016,565',
#   '$124,987,023',
#   '20.5%',
#   '$484,029,542',
#   '79.5%',
#   '2012'],
#  ['161',
#   'Transformers: The Last Knight',
#   '$605,425,157',
#   '$130,168,683',
#   '21.5%',
#   '$475,256,474',
#   '78.5%',
#   '2017'],
#  ['162',
#   'Madagascar: Escape 2 Africa',
#   '$603,900,354',
#   '$180,010,950',
#   '29.8%',
#   '$423,889,404',
#   '70.2%',
#   '2008'],
#  ['163',
#   'War of the Worlds',
#   '$603,873,119',
#   '$234,280,354',
#   '38.8%',
#   '$369,592,765',
#   '61.2%',
#   '2005'],
#  ['164',
#   'Tangled',
#   '$592,304,396',
#   '$200,821,936',
#   '33.9%',
#   '$391,482,460',
#   '66.1%',
#   '2010'],
#  ['165',
#   'Quantum of Solace',
#   '$589,580,482',
#   '$168,368,427',
#   '28.6%',
#   '$421,212,055',
#   '71.4%',
#   '2008'],
#  ['166',
#   'Men in Black',
#   '$589,390,539',
#   '$250,690,539',
#   '42.5%',
#   '$338,700,000',
#   '57.5%',
#   '1997'],
#  ['167',
#   'The Croods',
#   '$587,204,668',
#   '$187,168,425',
#   '31.9%',
#   '$400,036,243',
#   '68.1%',
#   '2013'],
#  ['168',
#   'The Hangover Part II',
#   '$586,764,305',
#   '$254,464,305',
#   '43.4%',
#   '$332,300,000',
#   '56.6%',
#   '2011'],
#  ['169',
#   'I Am Legend',
#   '$585,410,052',
#   '$256,393,010',
#   '43.8%',
#   '$329,017,042',
#   '56.2%',
#   '2007'],
#  ['170',
#   'Iron Man',
#   '$585,366,247',
#   '$318,604,126',
#   '54.4%',
#   '$266,762,121',
#   '45.6%',
#   '2008'],
#  ['171',
#   'Ready Player One',
#   '$582,890,172',
#   '$137,690,172',
#   '23.6%',
#   '$445,200,000',
#   '76.4%',
#   '2018'],
#  ['172',
#   'Operation Red Sea',
#   '$579,330,426',
#   '$1,543,547',
#   '0.3%',
#   '$577,786,879',
#   '99.7%',
#   '2018'],
#  ['173',
#   'Night at the Museum',
#   '$574,480,841',
#   '$250,863,268',
#   '43.7%',
#   '$323,617,573',
#   '56.3%',
#   '2006'],
#  ['174',
#   'Fifty Shades of Grey',
#   '$569,651,467',
#   '$166,167,230',
#   '29.2%',
#   '$403,484,237',
#   '70.8%',
#   '2015'],
#  ['175',
#   'Kong: Skull Island',
#   '$566,652,812',
#   '$168,052,812',
#   '29.7%',
#   '$398,600,000',
#   '70.3%',
#   '2017'],
#  ['176',
#   'The Smurfs',
#   '$563,749,323',
#   '$142,614,158',
#   '25.3%',
#   '$421,135,165',
#   '74.7%',
#   '2011'],
#  ['177',
#   'King Kong',
#   '$562,363,449',
#   '$218,080,025',
#   '38.8%',
#   '$344,283,424',
#   '61.2%',
#   '2005'],
#  ['178',
#   'Cars 2',
#   '$559,852,396',
#   '$191,452,396',
#   '34.2%',
#   '$368,400,000',
#   '65.8%',
#   '2011'],
#  ['179',
#   'Puss in Boots',
#   '$554,987,477',
#   '$149,260,504',
#   '26.9%',
#   '$405,726,973',
#   '73.1%',
#   '2011'],
#  ['180',
#   'The Mermaid',
#   '$553,810,228',
#   '$3,232,685',
#   '0.6%',
#   '$550,577,543',
#   '99.4%',
#   '2016'],
#  ['181',
#   'Armageddon',
#   '$553,709,788',
#   '$201,578,182',
#   '36.4%',
#   '$352,131,606',
#   '63.6%',
#   '1998'],
#  ['182',
#   'The Day After Tomorrow',
#   '$552,639,571',
#   '$186,740,799',
#   '33.8%',
#   '$365,898,772',
#   '66.2%',
#   '2004'],
#  ['183',
#   'Ted',
#   '$549,368,315',
#   '$218,815,487',
#   '39.8%',
#   '$330,552,828',
#   '60.2%',
#   '2012'],
#  ['184',
#   'Star Wars: Episode V - The Empire Strikes Back',
#   '$547,897,454',
#   '$290,271,960',
#   '53%',
#   '$257,625,494',
#   '47%',
#   '1980'],
#  ['185',
#   'American Sniper',
#   '$547,426,372',
#   '$350,126,372',
#   '64%',
#   '$197,300,000',
#   '36%',
#   '2014'],
#  ['186',
#   'Mission: Impossible II',
#   '$546,388,108',
#   '$215,409,889',
#   '39.4%',
#   '$330,978,219',
#   '60.6%',
#   '2000'],
#  ['187',
#   'Detective Chinatown 2',
#   '$544,185,156',
#   '$1,983,984',
#   '0.4%',
#   '$542,201,172',
#   '99.6%',
#   '2018'],
#  ['188',
#   'X-Men: Apocalypse',
#   '$543,934,105',
#   '$155,442,489',
#   '28.6%',
#   '$388,491,616',
#   '71.4%',
#   '2016'],
#  ['189',
#   'Sherlock Holmes: A Game of Shadows',
#   '$543,848,418',
#   '$186,848,418',
#   '34.4%',
#   '$357,000,000',
#   '65.6%',
#   '2011'],
#  ['190',
#   'Despicable Me',
#   '$543,113,985',
#   '$251,513,985',
#   '46.3%',
#   '$291,600,000',
#   '53.7%',
#   '2010'],
#  ['191',
#   'Cinderella',
#   '$542,351,353',
#   '$201,151,353',
#   '37.1%',
#   '$341,200,000',
#   '62.9%',
#   '2015'],
#  ['192',
#   'Madagascar',
#   '$542,063,846',
#   '$193,595,521',
#   '35.7%',
#   '$348,468,325',
#   '64.3%',
#   '2005'],
#  ['193',
#   'World War Z',
#   '$540,007,876',
#   '$202,359,711',
#   '37.5%',
#   '$337,648,165',
#   '62.5%',
#   '2013'],
#  ['194',
#   'Brave',
#   '$538,983,207',
#   '$237,283,207',
#   '44%',
#   '$301,700,000',
#   '56%',
#   '2012'],
#  ['195',
#   'The Simpsons Movie',
#   '$536,414,270',
#   '$183,135,014',
#   '34.1%',
#   '$353,279,256',
#   '65.9%',
#   '2007'],
#  ['196',
#   'The Revenant',
#   '$532,950,503',
#   '$183,637,894',
#   '34.5%',
#   '$349,312,609',
#   '65.5%',
#   '2015'],
#  ['197',
#   'The Meg',
#   '$530,243,742',
#   '$145,443,742',
#   '27.4%',
#   '$384,800,000',
#   '72.6%',
#   '2018'],
#  ['198',
#   'Ralph Breaks the Internet',
#   '$529,323,962',
#   '$201,091,711',
#   '38%',
#   '$328,232,251',
#   '62%',
#   '2018'],
#  ['199',
#   'Hotel Transylvania 3: Summer Vacation',
#   '$528,583,774',
#   '$167,510,016',
#   '31.7%',
#   '$361,073,758',
#   '68.3%',
#   '2018'],
#  ['200',
#   'The Boss Baby',
#   '$527,965,936',
#   '$175,003,033',
#   '33.2%',
#   '$352,962,903',
#   '66.8%',
#   '2017'],
#  ['201',
#   'Dunkirk',
#   '$526,940,665',
#   '$189,740,665',
#   '36%',
#   '$337,200,000',
#   '64%',
#   '2017'],
#  ['202',
#   'Godzilla',
#   '$524,976,069',
#   '$200,676,069',
#   '38.2%',
#   '$324,300,000',
#   '61.8%',
#   '2014'],
#  ['203',
#   'Sherlock Holmes',
#   '$524,028,679',
#   '$209,028,679',
#   '39.9%',
#   '$315,000,000',
#   '60.1%',
#   '2009'],
#  ['204',
#   'Meet the Fockers',
#   '$522,657,936',
#   '$279,261,160',
#   '53.4%',
#   '$243,396,776',
#   '46.6%',
#   '2004'],
#  ['205',
#   'How to Train Your Dragon: The Hidden World',
#   '$521,799,505',
#   '$160,799,505',
#   '30.8%',
#   '$361,000,000',
#   '69.2%',
#   '2019'],
#  ['206',
#   'WALL·E',
#   '$521,311,860',
#   '$223,808,164',
#   '42.9%',
#   '$297,503,696',
#   '57.1%',
#   '2008'],
#  ['207',
#   'Kung Fu Panda 3',
#   '$521,170,825',
#   '$143,528,619',
#   '27.5%',
#   '$377,642,206',
#   '72.5%',
#   '2016'],
#  ['208',
#   'Terminator 2: Judgment Day',
#   '$520,884,847',
#   '$205,881,154',
#   '39.5%',
#   '$315,003,693',
#   '60.5%',
#   '1991'],
#  ['209',
#   'Ant-Man',
#   '$519,311,965',
#   '$180,202,163',
#   '34.7%',
#   '$339,109,802',
#   '65.3%',
#   '2015'],
#  ['210',
#   "Dr. Seuss' The Grinch",
#   '$511,595,957',
#   '$270,620,950',
#   '52.9%',
#   '$240,975,007',
#   '47.1%',
#   '2018'],
#  ['211',
#   'Ghost',
#   '$505,809,505',
#   '$217,631,306',
#   '43%',
#   '$288,178,199',
#   '57%',
#   '1990'],
#  ['212',
#   'Aladdin',
#   '$504,050,219',
#   '$217,350,219',
#   '43.1%',
#   '$286,700,000',
#   '56.9%',
#   '1992'],
#  ['213',
#   'Rio 2',
#   '$498,781,117',
#   '$131,538,435',
#   '26.4%',
#   '$367,242,682',
#   '73.6%',
#   '2014'],
#  ['214',
#   'Troy',
#   '$497,409,852',
#   '$133,378,256',
#   '26.8%',
#   '$364,031,596',
#   '73.2%',
#   '2004'],
#  ['215',
#   'Toy Story 2',
#   '$497,374,776',
#   '$245,852,179',
#   '49.4%',
#   '$251,522,597',
#   '50.6%',
#   '1999'],
#  ['216',
#   'How to Train Your Dragon',
#   '$494,878,759',
#   '$217,581,231',
#   '44%',
#   '$277,297,528',
#   '56%',
#   '2010'],
#  ['217',
#   'Twister',
#   '$494,471,524',
#   '$241,721,524',
#   '48.9%',
#   '$252,750,000',
#   '51.1%',
#   '1996'],
#  ['218',
#   'Oz the Great and Powerful',
#   '$493,311,825',
#   '$234,911,825',
#   '47.6%',
#   '$258,400,000',
#   '52.4%',
#   '2013'],
#  ['219',
#   'Clash of the Titans',
#   '$493,214,993',
#   '$163,214,888',
#   '33.1%',
#   '$330,000,105',
#   '66.9%',
#   '2010'],
#  ['220',
#   'Maleficent: Mistress of Evil',
#   '$491,730,089',
#   '$113,929,605',
#   '23.2%',
#   '$377,800,484',
#   '76.8%',
#   '2019'],
#  ['221',
#   'War for the Planet of the Apes',
#   '$490,719,763',
#   '$146,880,162',
#   '29.9%',
#   '$343,839,601',
#   '70.1%',
#   '2017'],
#  ['222',
#   'Mr. & Mrs. Smith',
#   '$487,287,646',
#   '$186,336,279',
#   '38.2%',
#   '$300,951,367',
#   '61.8%',
#   '2005'],
#  ['223',
#   'Angels & Demons',
#   '$485,930,816',
#   '$133,375,846',
#   '27.4%',
#   '$352,554,970',
#   '72.6%',
#   '2009'],
#  ['224',
#   'Teenage Mutant Ninja Turtles',
#   '$485,004,754',
#   '$191,204,754',
#   '39.4%',
#   '$293,800,000',
#   '60.6%',
#   '2014'],
#  ['225',
#   'Bruce Almighty',
#   '$484,592,874',
#   '$242,829,261',
#   '50.1%',
#   '$241,763,613',
#   '49.9%',
#   '2003'],
#  ['226',
#   'Shrek',
#   '$484,409,218',
#   '$267,665,011',
#   '55.3%',
#   '$216,744,207',
#   '44.7%',
#   '2001'],
#  ['227',
#   'Rio',
#   '$483,866,518',
#   '$143,619,809',
#   '29.7%',
#   '$340,246,709',
#   '70.3%',
#   '2011'],
#  ['228',
#   'Saving Private Ryan',
#   '$482,349,603',
#   '$217,049,603',
#   '45%',
#   '$265,300,000',
#   '55%',
#   '1998'],
#  ['229',
#   'Rise of the Planet of the Apes',
#   '$481,800,873',
#   '$176,760,185',
#   '36.7%',
#   '$305,040,688',
#   '63.3%',
#   '2011'],
#  ['230',
#   'Home Alone',
#   '$477,063,114',
#   '$285,761,243',
#   '59.9%',
#   '$191,301,871',
#   '40.1%',
#   '1990'],
#  ['231',
#   'Star Wars: Episode VI - Return of the Jedi',
#   '$475,347,111',
#   '$309,306,177',
#   '65.1%',
#   '$166,040,934',
#   '34.9%',
#   '1983'],
#  ['232',
#   'Charlie and the Chocolate Factory',
#   '$474,968,763',
#   '$206,459,076',
#   '43.5%',
#   '$268,509,687',
#   '56.5%',
#   '2005'],
#  ['233',
#   'Hotel Transylvania 2',
#   '$474,800,000',
#   '$169,700,110',
#   '35.7%',
#   '$305,099,890',
#   '64.3%',
#   '2015'],
#  ['234',
#   'Indiana Jones and the Last Crusade',
#   '$474,310,887',
#   '$197,171,806',
#   '41.6%',
#   '$277,139,081',
#   '58.4%',
#   '1989'],
#  ['235',
#   'San Andreas',
#   '$473,990,832',
#   '$155,190,832',
#   '32.7%',
#   '$318,800,000',
#   '67.3%',
#   '2015'],
#  ['236',
#   'It Chapter Two',
#   '$473,093,228',
#   '$211,593,228',
#   '44.7%',
#   '$261,500,000',
#   '55.3%',
#   '2019'],
#  ['237',
#   'Wreck-It Ralph',
#   '$471,222,889',
#   '$189,422,889',
#   '40.2%',
#   '$281,800,000',
#   '59.8%',
#   '2012'],
#  ['238',
#   'Jaws',
#   '$471,203,004',
#   '$260,000,000',
#   '55.2%',
#   '$211,203,004',
#   '44.8%',
#   '1975'],
#  ['239',
#   'The Hangover',
#   '$469,310,836',
#   '$277,322,503',
#   '59.1%',
#   '$191,988,333',
#   '40.9%',
#   '2009'],
#  ['240',
#   'The Lego Movie',
#   '$468,060,692',
#   '$257,760,692',
#   '55.1%',
#   '$210,300,000',
#   '44.9%',
#   '2014'],
#  ['241',
#   'Bumblebee',
#   '$467,989,645',
#   '$127,195,589',
#   '27.2%',
#   '$340,794,056',
#   '72.8%',
#   '2018'],
#  ['242',
#   'Star Trek Into Darkness',
#   '$467,365,246',
#   '$228,778,661',
#   '49%',
#   '$238,586,585',
#   '51%',
#   '2013'],
#  ['243',
#   'The Matrix',
#   '$465,343,787',
#   '$171,479,930',
#   '36.8%',
#   '$293,863,857',
#   '63.2%',
#   '1999'],
#  ['244',
#   'Pretty Woman',
#   '$463,406,268',
#   '$178,406,268',
#   '38.5%',
#   '$285,000,000',
#   '61.5%',
#   '1990'],
#  ['245',
#   'Cars',
#   '$461,983,149',
#   '$244,082,982',
#   '52.8%',
#   '$217,900,167',
#   '47.2%',
#   '2006'],
#  ['246',
#   'Gladiator',
#   '$460,583,960',
#   '$187,705,427',
#   '40.8%',
#   '$272,878,533',
#   '59.2%',
#   '2000'],
#  ['247',
#   'X-Men: The Last Stand',
#   '$460,435,291',
#   '$234,362,462',
#   '50.9%',
#   '$226,072,829',
#   '49.1%',
#   '2006'],
#  ['248',
#   'National Treasure: Book of Secrets',
#   '$459,242,249',
#   '$219,964,115',
#   '47.9%',
#   '$239,278,134',
#   '52.1%',
#   '2007'],
#  ['249',
#   'Lucy',
#   '$458,863,600',
#   '$126,663,600',
#   '27.6%',
#   '$332,200,000',
#   '72.4%',
#   '2014'],
#  ['250',
#   'Mission: Impossible',
#   '$457,731,198',
#   '$180,981,856',
#   '39.5%',
#   '$276,749,342',
#   '60.5%',
#   '1996'],
#  ['251',
#   '300',
#   '$456,068,181',
#   '$210,614,939',
#   '46.2%',
#   '$245,453,242',
#   '53.8%',
#   '2007'],
#  ['252',
#   'The Last Samurai',
#   '$454,627,263',
#   '$111,127,263',
#   '24.4%',
#   '$343,500,000',
#   '75.6%',
#   '2003'],
#  ['253',
#   'Dying to Survive',
#   '$451,183,391',
#   '$6,752',
#   '-',
#   '$451,176,639',
#   '100%',
#   '2018'],
#  ['254',
#   "Ocean's Eleven",
#   '$450,717,150',
#   '$183,417,150',
#   '40.7%',
#   '$267,300,000',
#   '59.3%',
#   '2001'],
#  ['255',
#   'My People, My Country',
#   '$450,064,993',
#   '$2,356,683',
#   '0.5%',
#   '$447,708,310',
#   '99.5%',
#   '2019'],
#  ['256',
#   'Thor',
#   '$449,326,618',
#   '$181,030,624',
#   '40.3%',
#   '$268,295,994',
#   '59.7%',
#   '2011'],
#  ['257',
#   'Pearl Harbor',
#   '$449,220,945',
#   '$198,542,554',
#   '44.2%',
#   '$250,678,391',
#   '55.8%',
#   '2001'],
#  ['258',
#   'Tarzan',
#   '$448,191,819',
#   '$171,091,819',
#   '38.2%',
#   '$277,100,000',
#   '61.8%',
#   '1999'],
#  ['259',
#   'La La Land',
#   '$446,171,671',
#   '$151,101,803',
#   '33.9%',
#   '$295,069,868',
#   '66.1%',
#   '2016'],
#  ['260',
#   'Men in Black II',
#   '$445,135,288',
#   '$193,735,288',
#   '43.5%',
#   '$251,400,000',
#   '56.5%',
#   '2002'],
#  ['261',
#   'The Bourne Ultimatum',
#   '$444,100,035',
#   '$227,471,070',
#   '51.2%',
#   '$216,628,965',
#   '48.8%',
#   '2007'],
#  ['262',
#   'The Mummy Returns',
#   '$443,280,904',
#   '$202,019,785',
#   '45.6%',
#   '$241,261,119',
#   '54.4%',
#   '2001'],
#  ['263',
#   'Alvin and the Chipmunks: The Squeakquel',
#   '$443,140,005',
#   '$219,614,612',
#   '49.6%',
#   '$223,525,393',
#   '50.4%',
#   '2009'],
#  ['264',
#   'Les Misérables',
#   '$441,809,770',
#   '$148,809,770',
#   '33.7%',
#   '$293,000,000',
#   '66.3%',
#   '2012'],
#  ['265',
#   'The Exorcist',
#   '$441,306,145',
#   '$232,906,145',
#   '52.8%',
#   '$208,400,000',
#   '47.2%',
#   '1973'],
#  ['266',
#   'Mrs. Doubtfire',
#   '$441,286,195',
#   '$219,195,243',
#   '49.7%',
#   '$222,090,952',
#   '50.3%',
#   '1993'],
#  ['267',
#   'Terminator Genisys',
#   '$440,603,537',
#   '$89,760,956',
#   '20.4%',
#   '$350,842,581',
#   '79.6%',
#   '2015'],
#  ['268',
#   'Beauty and the Beast',
#   '$440,118,382',
#   '$218,967,620',
#   '49.8%',
#   '$221,150,762',
#   '50.2%',
#   '1991'],
#  ['269',
#   'Warcraft',
#   '$439,048,914',
#   '$47,365,290',
#   '10.8%',
#   '$391,683,624',
#   '89.2%',
#   '2016'],
#  ['270',
#   'A Star Is Born',
#   '$436,188,866',
#   '$215,288,866',
#   '49.4%',
#   '$220,900,000',
#   '50.6%',
#   '2018'],
#  ['271',
#   'The Greatest Showman',
#   '$434,993,183',
#   '$174,340,174',
#   '40.1%',
#   '$260,653,009',
#   '59.9%',
#   '2017'],
#  ['272',
#   'Terminator 3: Rise of the Machines',
#   '$433,371,112',
#   '$150,371,112',
#   '34.7%',
#   '$283,000,000',
#   '65.3%',
#   '2003'],
#  ['273',
#   'Pokémon Detective Pikachu',
#   '$433,005,346',
#   '$144,105,346',
#   '33.3%',
#   '$288,900,000',
#   '66.7%',
#   '2019'],
#  ['274',
#   'Die Another Day',
#   '$431,971,116',
#   '$160,942,139',
#   '37.3%',
#   '$271,028,977',
#   '62.7%',
#   '2002'],
#  ['275',
#   'The Secret Life of Pets 2',
#   '$430,051,293',
#   '$158,874,395',
#   '36.9%',
#   '$271,176,898',
#   '63.1%',
#   '2019'],
#  ['276',
#   'Cast Away',
#   '$429,632,142',
#   '$233,632,142',
#   '54.4%',
#   '$196,000,000',
#   '45.6%',
#   '2000'],
#  ['277',
#   'Rampage',
#   '$428,028,233',
#   '$101,028,233',
#   '23.6%',
#   '$327,000,000',
#   '76.4%',
#   '2018'],
#  ['278',
#   "The King's Speech",
#   '$427,374,317',
#   '$138,797,449',
#   '32.5%',
#   '$288,576,868',
#   '67.5%',
#   '2010'],
#  ['279',
#   'The Matrix Revolutions',
#   '$427,344,031',
#   '$139,313,948',
#   '32.6%',
#   '$288,030,083',
#   '67.4%',
#   '2003'],
#  ['280',
#   'The Intouchables',
#   '$426,588,510',
#   '$10,198,820',
#   '2.4%',
#   '$416,389,690',
#   '97.6%',
#   '2011'],
#  ['281',
#   'Django Unchained',
#   '$425,368,238',
#   '$162,805,434',
#   '38.3%',
#   '$262,562,804',
#   '61.7%',
#   '2012'],
#  ['282',
#   'Dances with Wolves',
#   '$424,208,848',
#   '$184,208,848',
#   '43.4%',
#   '$240,000,000',
#   '56.6%',
#   '1990'],
#  ['283',
#   'The Chronicles of Narnia: Prince Caspian',
#   '$419,665,568',
#   '$141,621,490',
#   '33.8%',
#   '$278,044,078',
#   '66.2%',
#   '2008'],
#  ['284',
#   'Sex and the City',
#   '$418,765,321',
#   '$152,647,258',
#   '36.4%',
#   '$266,118,063',
#   '63.6%',
#   '2008'],
#  ['285',
#   'The Captain',
#   '$416,953,262',
#   '$706,572',
#   '0.2%',
#   '$416,246,690',
#   '99.8%',
#   '2019'],
#  ['286',
#   'The Mummy',
#   '$415,933,406',
#   '$155,385,488',
#   '37.4%',
#   '$260,547,918',
#   '62.6%',
#   '1999'],
#  ['287',
#   'The Chronicles of Narnia: The Voyage of the Dawn Treader',
#   '$415,686,217',
#   '$104,386,950',
#   '25.1%',
#   '$311,299,267',
#   '74.9%',
#   '2010'],
#  ['288',
#   'Jason Bourne',
#   '$415,484,914',
#   '$162,434,410',
#   '39.1%',
#   '$253,050,504',
#   '60.9%',
#   '2016'],
#  ['289',
#   'The Wolverine',
#   '$414,828,246',
#   '$132,556,852',
#   '32%',
#   '$282,271,394',
#   '68%',
#   '2013'],
#  ['290',
#   'Kingsman: The Secret Service',
#   '$414,351,546',
#   '$128,261,724',
#   '31%',
#   '$286,089,822',
#   '69%',
#   '2015'],
#  ['291',
#   'Night at the Museum: Battle of the Smithsonian',
#   '$413,106,170',
#   '$177,243,721',
#   '42.9%',
#   '$235,862,449',
#   '57.1%',
#   '2009'],
#  ['292',
#   'Batman',
#   '$411,556,825',
#   '$251,348,343',
#   '61.1%',
#   '$160,208,482',
#   '38.9%',
#   '1989'],
#  ['293',
#   'The Bodyguard',
#   '$411,006,740',
#   '$122,006,740',
#   '29.7%',
#   '$289,000,000',
#   '70.3%',
#   '1992'],
#  ['294',
#   'Pacific Rim',
#   '$411,002,906',
#   '$101,802,906',
#   '24.8%',
#   '$309,200,000',
#   '75.2%',
#   '2013'],
#  ['295',
#   'Kingsman: The Golden Circle',
#   '$410,902,662',
#   '$100,234,838',
#   '24.4%',
#   '$310,667,824',
#   '75.6%',
#   '2017'],
#  ['296',
#   'The Mummy',
#   '$409,231,607',
#   '$80,227,895',
#   '19.6%',
#   '$329,003,712',
#   '80.4%',
#   '2017'],
#  ['297',
#   'Ice Age: Collision Course',
#   '$408,579,038',
#   '$64,063,008',
#   '15.7%',
#   '$344,516,030',
#   '84.3%',
#   '2016'],
#  ['298',
#   'Twilight',
#   '$408,424,673',
#   '$193,962,473',
#   '47.5%',
#   '$214,462,200',
#   '52.5%',
#   '2008'],
#  ['299',
#   'Signs',
#   '$408,247,917',
#   '$227,966,634',
#   '55.8%',
#   '$180,281,283',
#   '44.2%',
#   '2002'],
#  ['300',
#   'X2: X-Men United',
#   '$407,711,549',
#   '$214,949,694',
#   '52.7%',
#   '$192,761,855',
#   '47.3%',
#   '2003'],
#  ['301',
#   'Bad Boys for Life',
#   '$405,418,519',
#   '$197,418,519',
#   '48.7%',
#   '$208,000,000',
#   '51.3%',
#   '2020'],
#  ['302',
#   'Alita: Battle Angel',
#   '$404,852,543',
#   '$85,710,210',
#   '21.2%',
#   '$319,142,333',
#   '78.8%',
#   '2019'],
#  ['303',
#   'Toy Story',
#   '$404,265,438',
#   '$222,498,679',
#   '55%',
#   '$181,766,759',
#   '45%',
#   '1995'],
#  ['304',
#   'The Mummy: Tomb of the Dragon Emperor',
#   '$403,449,830',
#   '$102,491,776',
#   '25.4%',
#   '$300,958,054',
#   '74.6%',
#   '2008'],
#  ['305',
#   'Prometheus',
#   '$403,354,469',
#   '$126,477,084',
#   '31.4%',
#   '$276,877,385',
#   '68.6%',
#   '2012'],
#  ['306',
#   'Gone with the Wind',
#   '$402,352,579',
#   '$200,852,579',
#   '49.9%',
#   '$201,500,000',
#   '50.1%',
#   '1939'],
#  ['307',
#   'TRON: Legacy',
#   '$400,062,763',
#   '$172,062,763',
#   '43%',
#   '$228,000,000',
#   '57%',
#   '2010'],
#  ['308',
#   'Mission: Impossible III',
#   '$398,479,497',
#   '$134,029,801',
#   '33.6%',
#   '$264,449,696',
#   '66.4%',
#   '2005'],
#  ['309',
#   'Grease',
#   '$396,961,563',
#   '$189,969,103',
#   '47.9%',
#   '$206,992,460',
#   '52.1%',
#   '1978'],
#  ['310',
#   'Snow White and the Huntsman',
#   '$396,592,829',
#   '$155,332,381',
#   '39.2%',
#   '$241,260,448',
#   '60.8%',
#   '2012'],
#  ['311',
#   'Mamma Mia! Here We Go Again',
#   '$395,044,706',
#   '$120,634,935',
#   '30.5%',
#   '$274,409,771',
#   '69.5%',
#   '2018'],
#  ['312',
#   'Solo: A Star Wars Story',
#   '$392,924,807',
#   '$213,767,512',
#   '54.4%',
#   '$179,157,295',
#   '45.6%',
#   '2018'],
#  ['313',
#   'The Wolf of Wall Street',
#   '$392,000,694',
#   '$116,900,694',
#   '29.8%',
#   '$275,100,000',
#   '70.2%',
#   '2013'],
#  ['314',
#   'Superman Returns',
#   '$391,081,192',
#   '$200,081,192',
#   '51.2%',
#   '$191,000,000',
#   '48.8%',
#   '2006'],
#  ['315',
#   'Robin Hood: Prince of Thieves',
#   '$390,493,908',
#   '$165,493,908',
#   '42.4%',
#   '$225,000,000',
#   '57.6%',
#   '1991'],
#  ['316',
#   'Raiders of the Lost Ark',
#   '$390,133,212',
#   '$248,159,971',
#   '63.6%',
#   '$141,973,241',
#   '36.4%',
#   '1981'],
#  ['317',
#   'Independence Day: Resurgence',
#   '$389,681,935',
#   '$103,144,286',
#   '26.5%',
#   '$286,537,649',
#   '73.5%',
#   '2016'],
#  ['318',
#   'Back to the Future',
#   '$388,355,305',
#   '$211,159,762',
#   '54.4%',
#   '$177,195,543',
#   '45.6%',
#   '1985'],
#  ['319',
#   'Live Free or Die Hard',
#   '$388,156,011',
#   '$134,529,403',
#   '34.7%',
#   '$253,626,608',
#   '65.3%',
#   '2007'],
#  ['320',
#   'Monster Hunt',
#   '$387,053,506',
#   '$32,766',
#   '<0.1%',
#   '$387,020,740',
#   '100%',
#   '2015'],
#  ['321',
#   'Godzilla: King of the Monsters',
#   '$386,600,138',
#   '$110,500,138',
#   '28.6%',
#   '$276,100,000',
#   '71.4%',
#   '2019'],
#  ['322',
#   'Home',
#   '$386,041,607',
#   '$177,397,510',
#   '46%',
#   '$208,644,097',
#   '54%',
#   '2015'],
#  ['323',
#   'Star Trek',
#   '$385,680,446',
#   '$257,730,019',
#   '66.8%',
#   '$127,950,427',
#   '33.2%',
#   '2009'],
#  ['324',
#   'Happy Feet',
#   '$384,335,608',
#   '$198,000,317',
#   '51.5%',
#   '$186,335,291',
#   '48.5%',
#   '2006'],
#  ['325',
#   'Cars 3',
#   '$383,930,656',
#   '$152,901,115',
#   '39.8%',
#   '$231,029,541',
#   '60.2%',
#   '2017'],
#  ['326',
#   'Ice Age',
#   '$383,257,136',
#   '$176,387,405',
#   '46%',
#   '$206,869,731',
#   '54%',
#   '2002'],
#  ['327',
#   'Fifty Shades Darker',
#   '$381,545,846',
#   '$114,581,250',
#   '30%',
#   '$266,964,596',
#   '70%',
#   '2017'],
#  ['328',
#   'Monsters vs. Aliens',
#   '$381,509,870',
#   '$198,351,526',
#   '52%',
#   '$183,158,344',
#   '48%',
#   '2009'],
#  ['329',
#   'Godzilla',
#   '$379,014,294',
#   '$136,314,294',
#   '36%',
#   '$242,700,000',
#   '64%',
#   '1998'],
#  ['330',
#   'True Lies',
#   '$378,882,411',
#   '$146,282,411',
#   '38.6%',
#   '$232,600,000',
#   '61.4%',
#   '1994'],
#  ['331',
#   'Slumdog Millionaire',
#   '$378,060,798',
#   '$141,319,928',
#   '37.4%',
#   '$236,740,870',
#   '62.6%',
#   '2008'],
#  ['332',
#   'Taken 2',
#   '$376,141,306',
#   '$139,854,287',
#   '37.2%',
#   '$236,287,019',
#   '62.8%',
#   '2012'],
#  ['333',
#   'G.I. Joe: Retaliation',
#   '$375,740,705',
#   '$122,523,060',
#   '32.6%',
#   '$253,217,645',
#   '67.4%',
#   '2013'],
#  ['334',
#   'Spider-Man: Into the Spider-Verse',
#   '$375,540,831',
#   '$190,241,310',
#   '50.7%',
#   '$185,299,521',
#   '49.3%',
#   '2018'],
#  ['335',
#   'Mad Max: Fury Road',
#   '$375,209,362',
#   '$154,058,340',
#   '41.1%',
#   '$221,151,022',
#   '58.9%',
#   '2015'],
#  ['336',
#   'Shark Tale',
#   '$374,583,879',
#   '$160,861,908',
#   '42.9%',
#   '$213,721,971',
#   '57.1%',
#   '2004'],
#  ['337',
#   'Once Upon a Time... in Hollywood',
#   '$374,341,301',
#   '$142,502,728',
#   '38.1%',
#   '$231,838,573',
#   '61.9%',
#   '2019'],
#  ['338',
#   'What Women Want',
#   '$374,111,707',
#   '$182,811,707',
#   '48.9%',
#   '$191,300,000',
#   '51.1%',
#   '2000'],
#  ['339',
#   'The Adventures of Tintin',
#   '$373,993,951',
#   '$77,591,831',
#   '20.8%',
#   '$296,402,120',
#   '79.2%',
#   '2011'],
#  ['340',
#   'Penguins of Madagascar',
#   '$373,515,621',
#   '$83,850,911',
#   '22.4%',
#   '$289,664,710',
#   '77.6%',
#   '2014'],
#  ['341',
#   'Batman Begins',
#   '$373,413,297',
#   '$206,852,432',
#   '55.4%',
#   '$166,560,865',
#   '44.6%',
#   '2005'],
#  ['342',
#   'X-Men Origins: Wolverine',
#   '$373,062,864',
#   '$179,883,157',
#   '48.2%',
#   '$193,179,707',
#   '51.8%',
#   '2009'],
#  ['343',
#   'The Golden Compass',
#   '$372,234,864',
#   '$70,107,728',
#   '18.8%',
#   '$302,127,136',
#   '81.2%',
#   '2007'],
#  ['344',
#   'Fifty Shades Freed',
#   '$371,985,018',
#   '$100,407,760',
#   '27%',
#   '$271,577,258',
#   '73%',
#   '2018'],
#  ['345',
#   'Hitch',
#   '$371,594,210',
#   '$179,495,555',
#   '48.3%',
#   '$192,098,655',
#   '51.7%',
#   '2005'],
#  ['346',
#   'Terminator Salvation',
#   '$371,353,001',
#   '$125,322,469',
#   '33.8%',
#   '$246,030,532',
#   '66.2%',
#   '2009'],
#  ['347',
#   'Captain America: The First Avenger',
#   '$370,569,774',
#   '$176,654,505',
#   '47.7%',
#   '$193,915,269',
#   '52.3%',
#   '2011'],
#  ['348',
#   'Edge of Tomorrow',
#   '$370,541,256',
#   '$100,206,256',
#   '27%',
#   '$270,335,000',
#   '73%',
#   '2014'],
#  ['349',
#   "There's Something About Mary",
#   '$369,884,651',
#   '$176,484,651',
#   '47.7%',
#   '$193,400,000',
#   '52.3%',
#   '1998'],
#  ['350',
#   'Gone Girl',
#   '$369,330,363',
#   '$167,767,189',
#   '45.4%',
#   '$201,563,174',
#   '54.6%',
#   '2014'],
#  ['351',
#   'The Fugitive',
#   '$368,875,760',
#   '$183,875,760',
#   '49.8%',
#   '$185,000,000',
#   '50.2%',
#   '1993'],
#  ['352',
#   'Jurassic Park III',
#   '$368,780,809',
#   '$181,171,875',
#   '49.1%',
#   '$187,608,934',
#   '50.9%',
#   '2001'],
#  ['353',
#   'My Big Fat Greek Wedding',
#   '$368,744,044',
#   '$241,438,208',
#   '65.5%',
#   '$127,305,836',
#   '34.5%',
#   '2002'],
#  ['355',
#   'Die Hard with a Vengeance',
#   '$366,236,538',
#   '$100,012,499',
#   '27.3%',
#   '$266,224,039',
#   '72.7%',
#   '1995'],
#  ['356',
#   'Shazam!',
#   '$365,971,656',
#   '$140,371,656',
#   '38.4%',
#   '$225,600,000',
#   '61.6%',
#   '2019'],
#  ['357',
#   'The Nun',
#   '$365,550,119',
#   '$117,450,119',
#   '32.1%',
#   '$248,100,000',
#   '67.9%',
#   '2018'],
#  ['358',
#   'Alvin and the Chipmunks',
#   '$365,352,546',
#   '$217,326,974',
#   '59.5%',
#   '$148,025,572',
#   '40.5%',
#   '2007'],
#  ['359',
#   'Home Alone 2: Lost in New York',
#   '$365,154,932',
#   '$173,585,516',
#   '47.5%',
#   '$191,569,416',
#   '52.5%',
#   '1992'],
#  ['360',
#   'Notting Hill',
#   '$363,944,522',
#   '$116,089,678',
#   '31.9%',
#   '$247,854,844',
#   '68.1%',
#   '1999'],
#  ['361',
#   "A Bug's Life",
#   '$363,258,859',
#   '$162,798,565',
#   '44.8%',
#   '$200,460,294',
#   '55.2%',
#   '1998'],
#  ['362',
#   'Night at the Museum: Secret of the Tomb',
#   '$363,204,635',
#   '$113,746,621',
#   '31.3%',
#   '$249,458,014',
#   '68.7%',
#   '2014'],
#  ['363',
#   "Ocean's Twelve",
#   '$362,744,280',
#   '$125,544,280',
#   '34.6%',
#   '$237,200,000',
#   '65.4%',
#   '2004'],
#  ['364',
#   '1917',
#   '$362,407,149',
#   '$155,907,149',
#   '43%',
#   '$206,500,000',
#   '57%',
#   '2019'],
#  ['365',
#   'Planet of the Apes',
#   '$362,211,740',
#   '$180,011,740',
#   '49.7%',
#   '$182,200,000',
#   '50.3%',
#   '2001'],
#  ['366',
#   'The Hangover Part III',
#   '$362,000,072',
#   '$112,200,072',
#   '31%',
#   '$249,800,000',
#   '69%',
#   '2013'],
#  ['367',
#   'The World Is Not Enough',
#   '$361,832,400',
#   '$126,943,684',
#   '35.1%',
#   '$234,888,716',
#   '64.9%',
#   '1999'],
#  ['368',
#   'Monster Hunt 2',
#   '$361,682,618',
#   '$706,153',
#   '0.2%',
#   '$360,976,465',
#   '99.8%',
#   '2018'],
#  ['369',
#   'Fast & Furious',
#   '$360,364,265',
#   '$155,064,265',
#   '43%',
#   '$205,300,000',
#   '57%',
#   '2009'],
#  ['370',
#   'Noah',
#   '$359,200,044',
#   '$101,200,044',
#   '28.2%',
#   '$258,000,000',
#   '71.8%',
#   '2014'],
#  ['371',
#   'The Karate Kid',
#   '$359,126,022',
#   '$176,591,618',
#   '49.2%',
#   '$182,534,404',
#   '50.8%',
#   '2010'],
#  ['372',
#   'Your Name.',
#   '$358,922,706',
#   '$5,017,246',
#   '1.4%',
#   '$353,905,460',
#   '98.6%',
#   '2016'],
#  ['373',
#   'Hotel Transylvania',
#   '$358,375,603',
#   '$148,313,048',
#   '41.4%',
#   '$210,062,555',
#   '58.6%',
#   '2011'],
#  ['374',
#   'Minority Report',
#   '$358,372,926',
#   '$132,072,926',
#   '36.8%',
#   '$226,300,000',
#   '63.2%',
#   '2002'],
#  ['375',
#   'Top Gun',
#   '$356,830,601',
#   '$179,800,601',
#   '50.4%',
#   '$177,030,000',
#   '49.6%',
#   '1986'],
#  ['376',
#   'The Legend of Tarzan',
#   '$356,700,357',
#   '$126,643,061',
#   '35.5%',
#   '$230,057,296',
#   '64.5%',
#   '2016'],
#  ['377',
#   'American Beauty',
#   '$356,296,601',
#   '$130,096,601',
#   '36.5%',
#   '$226,200,000',
#   '63.5%',
#   '1999'],
#  ['378',
#   'Apollo 13',
#   '$355,237,933',
#   '$173,837,933',
#   '48.9%',
#   '$181,400,000',
#   '51.1%',
#   '1995'],
#  ['379',
#   'Rain Man',
#   '$354,825,435',
#   '$172,825,435',
#   '48.7%',
#   '$182,000,000',
#   '51.3%',
#   '1988'],
#  ['380',
#   'The Great Gatsby',
#   '$353,641,895',
#   '$144,840,419',
#   '41%',
#   '$208,801,476',
#   '59%',
#   '2013'],
#  ['381',
#   'Dumbo',
#   '$353,284,621',
#   '$114,766,307',
#   '32.5%',
#   '$238,518,314',
#   '67.5%',
#   '2019'],
#  ['382',
#   'I, Robot',
#   '$353,133,898',
#   '$144,801,023',
#   '41%',
#   '$208,332,875',
#   '59%',
#   '2004'],
#  ['383',
#   'Basic Instinct',
#   '$352,927,224',
#   '$117,727,224',
#   '33.4%',
#   '$235,200,000',
#   '66.6%',
#   '1992'],
#  ['384',
#   'Murder on the Orient Express',
#   '$352,789,811',
#   '$102,826,543',
#   '29.2%',
#   '$249,963,268',
#   '70.8%',
#   '2017'],
#  ['385',
#   'X-Men: First Class',
#   '$352,616,690',
#   '$146,408,305',
#   '41.5%',
#   '$206,208,385',
#   '58.5%',
#   '2011'],
#  ['386',
#   'The Angry Birds Movie',
#   '$352,333,929',
#   '$107,509,366',
#   '30.5%',
#   '$244,824,563',
#   '69.5%',
#   '2016'],
#  ['387',
#   'GoldenEye',
#   '$352,194,034',
#   '$106,429,941',
#   '30.2%',
#   '$245,764,093',
#   '69.8%',
#   '1995'],
#  ['388',
#   'Catch Me If You Can',
#   '$352,114,312',
#   '$164,615,351',
#   '46.8%',
#   '$187,498,961',
#   '53.2%',
#   '2002'],
#  ['389',
#   'Now You See Me',
#   '$351,723,989',
#   '$117,723,989',
#   '33.5%',
#   '$234,000,000',
#   '66.5%',
#   '2013'],
#  ['390',
#   'Hannibal',
#   '$351,692,268',
#   '$165,092,268',
#   '46.9%',
#   '$186,600,000',
#   '53.1%',
#   '2001'],
#  ['391',
#   'The Mask',
#   '$351,583,407',
#   '$119,938,730',
#   '34.1%',
#   '$231,644,677',
#   '65.9%',
#   '1994'],
#  ['392',
#   'Peter Rabbit',
#   '$351,266,433',
#   '$115,253,424',
#   '32.8%',
#   '$236,013,009',
#   '67.2%',
#   '2018'],
#  ['393',
#   'Speed',
#   '$350,448,145',
#   '$121,248,145',
#   '34.6%',
#   '$229,200,000',
#   '65.4%',
#   '1994'],
#  ['394',
#   'Dinosaur',
#   '$349,822,765',
#   '$137,748,063',
#   '39.4%',
#   '$212,074,702',
#   '60.6%',
#   '2000'],
#  ['395',
#   'Mary Poppins Returns',
#   '$349,537,494',
#   '$171,958,438',
#   '49.2%',
#   '$177,579,056',
#   '50.8%',
#   '2018'],
#  ['396',
#   'Deep Impact',
#   '$349,464,664',
#   '$140,464,664',
#   '40.2%',
#   '$209,000,000',
#   '59.8%',
#   '1998'],
#  ['397',
#   'The Lorax',
#   '$348,840,316',
#   '$214,030,500',
#   '61.4%',
#   '$134,809,816',
#   '38.6%',
#   '2012'],
#  ['398',
#   'The Maze Runner',
#   '$348,319,861',
#   '$102,427,862',
#   '29.4%',
#   '$245,891,999',
#   '70.6%',
#   '2014'],
#  ['399',
#   'Spirited Away',
#   '$347,742,810',
#   '$13,750,644',
#   '4%',
#   '$333,992,166',
#   '96%',
#   '2001'],
#  ['400',
#   'The Smurfs 2',
#   '$347,545,360',
#   '$71,017,784',
#   '20.4%',
#   '$276,527,576',
#   '79.6%',
#   '2013'],
#  ['401',
#   'National Treasure',
#   '$347,512,318',
#   '$173,008,894',
#   '49.8%',
#   '$174,503,424',
#   '50.2%',
#   '2004'],
#  ['402',
# ...
#   '$188,133,322',
#   '$58,236,838',
#   '31%',
#   '$129,896,484',
#   '69%',
#   '2013'],
#  ['871',
#   'Jaws 2',
#   '$187,884,007',
#   '$81,766,007',
#   '43.5%',
#   '$106,118,000',
#   '56.5%',
#   '1978'],
#  ['872',
#   '12 Years a Slave',
#   '$187,733,202',
#   '$56,671,993',
#   '30.2%',
#   '$131,061,209',
#   '69.8%',
#   '2013'],
#  ['873',
#   'Heat',
#   '$187,436,818',
#   '$67,436,818',
#   '36%',
#   '$120,000,000',
#   '64%',
#   '1995'],
#  ['874',
#   "Mr. Popper's Penguins",
#   '$187,361,754',
#   '$68,224,452',
#   '36.4%',
#   '$119,137,302',
#   '63.6%',
#   '2011'],
#  ['875',
#   'The Grudge',
#   '$187,281,115',
#   '$110,359,362',
#   '58.9%',
#   '$76,921,753',
#   '41.1%',
#   '2004'],
#  ['876',
#   'I Now Pronounce You Chuck & Larry',
#   '$187,134,117',
#   '$120,059,556',
#   '64.2%',
#   '$67,074,561',
#   '35.8%',
#   '2007'],
#  ['877',
#   'The Horse Whisperer',
#   '$186,883,563',
#   '$75,383,563',
#   '40.3%',
#   '$111,500,000',
#   '59.7%',
#   '1998'],
#  ['878',
#   'Weathering with You',
#   '$186,880,688',
#   '$7,778,682',
#   '4.2%',
#   '$179,102,006',
#   '95.8%',
#   '2019'],
#  ['879',
#   'Walk the Line',
#   '$186,797,986',
#   '$119,519,402',
#   '64%',
#   '$67,278,584',
#   '36%',
#   '2005'],
#  ['881',
#   'The Jungle Book 2',
#   '$186,303,759',
#   '$47,901,582',
#   '25.7%',
#   '$138,402,177',
#   '74.3%',
#   '2003'],
#  ['882',
#   'The Final Destination',
#   '$186,167,139',
#   '$66,477,700',
#   '35.7%',
#   '$119,689,439',
#   '64.3%',
#   '2009'],
#  ['883',
#   'Atlantis: The Lost Empire',
#   '$186,053,725',
#   '$84,056,472',
#   '45.2%',
#   '$101,997,253',
#   '54.8%',
#   '2001'],
#  ['884',
#   'Inside Man',
#   '$186,003,591',
#   '$88,513,495',
#   '47.6%',
#   '$97,490,096',
#   '52.4%',
#   '2006'],
#  ['885',
#   'The Waterboy',
#   '$185,991,646',
#   '$161,491,646',
#   '86.8%',
#   '$24,500,000',
#   '13.2%',
#   '1998'],
#  ['886',
#   'Hugo',
#   '$185,770,160',
#   '$73,864,507',
#   '39.8%',
#   '$111,905,653',
#   '60.2%',
#   '2011'],
#  ['887',
#   'Pitch Perfect 3',
#   '$185,400,345',
#   '$104,897,530',
#   '56.6%',
#   '$80,502,815',
#   '43.4%',
#   '2017'],
#  ['888',
#   'Watchmen',
#   '$185,382,813',
#   '$107,509,799',
#   '58%',
#   '$77,873,014',
#   '42%',
#   '2009'],
#  ['889',
#   'The Birdcage',
#   '$185,260,553',
#   '$124,060,553',
#   '67%',
#   '$61,200,000',
#   '33%',
#   '1996'],
#  ['890',
#   'Moulin Rouge!',
#   '$184,928,135',
#   '$57,386,607',
#   '31%',
#   '$127,541,528',
#   '69%',
#   '2001'],
#  ['891',
#   'Snow White and the Seven Dwarfs',
#   '$184,925,486',
#   '$184,925,486',
#   '100%',
#   '$0',
#   '-',
#   '1937'],
#  ['892',
#   'Hop',
#   '$183,953,723',
#   '$108,085,305',
#   '58.8%',
#   '$75,868,418',
#   '41.2%',
#   '2011'],
#  ['893',
#   'Bad Moms',
#   '$183,936,074',
#   '$113,257,297',
#   '61.6%',
#   '$70,678,777',
#   '38.4%',
#   '2016'],
#  ['894',
#   'Jupiter Ascending',
#   '$183,887,723',
#   '$47,387,723',
#   '25.8%',
#   '$136,500,000',
#   '74.2%',
#   '2015'],
#  ['895',
#   '102 Dalmatians',
#   '$183,611,771',
#   '$66,957,026',
#   '36.5%',
#   '$116,654,745',
#   '63.5%',
#   '2000'],
#  ['897',
#   'Storks',
#   '$183,388,953',
#   '$72,679,278',
#   '39.6%',
#   '$110,709,675',
#   '60.4%',
#   '2016'],
#  ['898',
#   'Paul Blart: Mall Cop',
#   '$183,348,429',
#   '$146,336,178',
#   '79.8%',
#   '$37,012,251',
#   '20.2%',
#   '2009'],
#  ['899',
#   "Wayne's World",
#   '$183,097,323',
#   '$121,697,323',
#   '66.5%',
#   '$61,400,000',
#   '33.5%',
#   '1992'],
#  ['900',
#   'Maverick',
#   '$183,031,272',
#   '$101,631,272',
#   '55.5%',
#   '$81,400,000',
#   '44.5%',
#   '1994'],
#  ['901',
#   'Mirror Mirror',
#   '$183,018,522',
#   '$64,935,167',
#   '35.5%',
#   '$118,083,355',
#   '64.5%',
#   '2012'],
#  ['902',
#   'The Man in the Iron Mask',
#   '$182,968,902',
#   '$56,968,902',
#   '31.1%',
#   '$126,000,000',
#   '68.9%',
#   '1998'],
#  ['903',
#   'Cape Fear',
#   '$182,291,969',
#   '$79,091,969',
#   '43.4%',
#   '$103,200,000',
#   '56.6%',
#   '1991'],
#  ['904',
#   'The Haunted Mansion',
#   '$182,290,266',
#   '$75,847,266',
#   '41.6%',
#   '$106,443,000',
#   '58.4%',
#   '2003'],
#  ['906',
#   'While You Were Sleeping',
#   '$182,057,016',
#   '$81,057,016',
#   '44.5%',
#   '$101,000,000',
#   '55.5%',
#   '1995'],
#  ['907',
#   'The Bridges of Madison County',
#   '$182,016,617',
#   '$71,516,617',
#   '39.3%',
#   '$110,500,000',
#   '60.7%',
#   '1995'],
#  ['909',
#   'Poseidon',
#   '$181,674,817',
#   '$60,674,817',
#   '33.4%',
#   '$121,000,000',
#   '66.6%',
#   '2006'],
#  ['910',
#   'The First Wives Club',
#   '$181,489,203',
#   '$105,489,203',
#   '58.1%',
#   '$76,000,000',
#   '41.9%',
#   '1996'],
#  ['911',
#   'Scooby-Doo 2: Monsters Unleashed',
#   '$181,216,833',
#   '$84,216,833',
#   '46.5%',
#   '$97,000,000',
#   '53.5%',
#   '2004'],
#  ['912',
#   'Hot Shots!',
#   '$181,096,164',
#   '$69,467,617',
#   '38.4%',
#   '$111,628,547',
#   '61.6%',
#   '1991'],
#  ['913',
#   'Road to Perdition',
#   '$181,001,478',
#   '$104,454,762',
#   '57.7%',
#   '$76,546,716',
#   '42.3%',
#   '2002'],
#  ['914',
#   'Kill Bill: Vol. 1',
#   '$180,899,045',
#   '$70,099,045',
#   '38.8%',
#   '$110,800,000',
#   '61.2%',
#   '2003'],
#  ['915',
#   "The Hitman's Bodyguard",
#   '$180,650,747',
#   '$75,468,583',
#   '41.8%',
#   '$105,182,164',
#   '58.2%',
#   '2017'],
#  ['916',
#   'The Scorpion King',
#   '$180,630,907',
#   '$91,047,077',
#   '50.4%',
#   '$89,583,830',
#   '49.6%',
#   '2002'],
#  ['917',
#   'Sweet Home Alabama',
#   '$180,622,424',
#   '$127,223,418',
#   '70.4%',
#   '$53,399,006',
#   '29.6%',
#   '2002'],
#  ['918',
#   "Daddy's Home 2",
#   '$180,613,180',
#   '$104,029,443',
#   '57.6%',
#   '$76,583,737',
#   '42.4%',
#   '2017'],
#  ['919',
#   'Deja Vu',
#   '$180,557,550',
#   '$64,038,616',
#   '35.5%',
#   '$116,518,934',
#   '64.5%',
#   '2006'],
#  ['920',
#   'Hacksaw Ridge',
#   '$180,450,918',
#   '$67,209,615',
#   '37.2%',
#   '$113,241,303',
#   '62.8%',
#   '2016'],
#  ['921',
#   'The Post',
#   '$179,769,457',
#   '$81,903,458',
#   '45.6%',
#   '$97,865,999',
#   '54.4%',
#   '2017'],
#  ['922',
#   'Dangerous Minds',
#   '$179,519,401',
#   '$84,919,401',
#   '47.3%',
#   '$94,600,000',
#   '52.7%',
#   '1995'],
#  ['923',
#   'The Dictator',
#   '$179,379,533',
#   '$59,650,222',
#   '33.2%',
#   '$119,729,311',
#   '66.8%',
#   '2012'],
#  ['924',
#   'The League of Extraordinary Gentlemen',
#   '$179,265,204',
#   '$66,465,204',
#   '37.1%',
#   '$112,800,000',
#   '62.9%',
#   '2003'],
#  ['925',
#   'Allegiant',
#   '$179,246,868',
#   '$66,184,051',
#   '36.9%',
#   '$113,062,817',
#   '63.1%',
#   '2016'],
#  ['926',
#   'Daredevil',
#   '$179,179,718',
#   '$102,543,518',
#   '57.2%',
#   '$76,636,200',
#   '42.8%',
#   '2003'],
#  ['927',
#   'City Slickers',
#   '$179,033,791',
#   '$124,033,791',
#   '69.3%',
#   '$55,000,000',
#   '30.7%',
#   '1991'],
#  ['928',
#   "He's Just Not That Into You",
#   '$178,866,158',
#   '$93,953,653',
#   '52.5%',
#   '$84,912,505',
#   '47.5%',
#   '2009'],
#  ['929',
#   'Eagle Eye',
#   '$178,767,383',
#   '$101,440,743',
#   '56.7%',
#   '$77,326,640',
#   '43.3%',
#   '2008'],
#  ['930',
#   'Along Came Polly',
#   '$178,311,729',
#   '$88,097,164',
#   '49.4%',
#   '$90,214,565',
#   '50.6%',
#   '2004'],
#  ['931',
#   'Flushed Away',
#   '$178,281,554',
#   '$64,665,672',
#   '36.3%',
#   '$113,615,882',
#   '63.7%',
#   '2006'],
#  ['932',
#   'Scary Movie 4',
#   '$178,262,620',
#   '$90,710,620',
#   '50.9%',
#   '$87,552,000',
#   '49.1%',
#   '2006'],
#  ['933',
#   "Dante's Peak",
#   '$178,127,760',
#   '$67,127,760',
#   '37.7%',
#   '$111,000,000',
#   '62.3%',
#   '1997'],
#  ['934',
#   'Brokeback Mountain',
#   '$178,062,759',
#   '$83,043,761',
#   '46.6%',
#   '$95,018,998',
#   '53.4%',
#   '2005'],
#  ['935',
#   'Patriot Games',
#   '$178,051,587',
#   '$83,351,587',
#   '46.8%',
#   '$94,700,000',
#   '53.2%',
#   '1992'],
#  ['936',
#   'Flubber',
#   '$177,977,226',
#   '$92,977,226',
#   '52.2%',
#   '$85,000,000',
#   '47.8%',
#   '1997'],
#  ['937',
#   'Baywatch',
#   '$177,856,751',
#   '$58,060,186',
#   '32.6%',
#   '$119,796,565',
#   '67.4%',
#   '2017'],
#  ['938',
#   'Double Jeopardy',
#   '$177,841,558',
#   '$116,741,558',
#   '65.6%',
#   '$61,100,000',
#   '34.4%',
#   '1999'],
#  ['939',
#   'War Horse',
#   '$177,584,879',
#   '$79,884,879',
#   '45%',
#   '$97,700,000',
#   '55%',
#   '2011'],
#  ['940',
#   'Paranormal Activity 2',
#   '$177,512,032',
#   '$84,752,907',
#   '47.7%',
#   '$92,759,125',
#   '52.3%',
#   '2010'],
#  ['941',
#   'How to Lose a Guy in 10 Days',
#   '$177,502,387',
#   '$105,813,373',
#   '59.6%',
#   '$71,689,014',
#   '40.4%',
#   '2003'],
#  ['942',
#   'Alien vs. Predator',
#   '$177,427,090',
#   '$80,282,231',
#   '45.2%',
#   '$97,144,859',
#   '54.8%',
#   '2004'],
#  ['943',
#   'Hero',
#   '$177,395,557',
#   '$53,710,019',
#   '30.3%',
#   '$123,685,538',
#   '69.7%',
#   '2002'],
#  ['944',
#   'The 40-Year-Old Virgin',
#   '$177,378,645',
#   '$109,449,237',
#   '61.7%',
#   '$67,929,408',
#   '38.3%',
#   '2005'],
#  ['945',
#   "Lee Daniels' The Butler",
#   '$177,313,795',
#   '$116,632,095',
#   '65.8%',
#   '$60,681,700',
#   '34.2%',
#   '2013'],
#  ['946',
#   'The Haunting',
#   '$177,311,151',
#   '$91,411,151',
#   '51.6%',
#   '$85,900,000',
#   '48.4%',
#   '1999'],
#  ['947',
#   'The Descendants',
#   '$177,243,185',
#   '$82,584,160',
#   '46.6%',
#   '$94,659,025',
#   '53.4%',
#   '2011'],
#  ['948',
#   'The A-Team',
#   '$177,238,796',
#   '$77,222,099',
#   '43.6%',
#   '$100,016,697',
#   '56.4%',
#   '2010'],
#  ['949', 'Tootsie', '$177,200,000', '$177,200,000', '100%', '$0', '-', '1982'],
#  ['950',
#   'In the Line of Fire',
#   '$176,997,168',
#   '$102,314,823',
#   '57.8%',
#   '$74,682,345',
#   '42.2%',
#   '1993'],
#  ['951',
#   'Analyze This',
#   '$176,885,658',
#   '$106,885,658',
#   '60.4%',
#   '$70,000,000',
#   '39.6%',
#   '1999'],
#  ['952',
#   'Looper',
#   '$176,506,819',
#   '$66,486,205',
#   '37.7%',
#   '$110,020,614',
#   '62.3%',
#   '2012'],
#  ['954',
#   'Dr. Dolittle 2',
#   '$176,104,344',
#   '$112,952,899',
#   '64.1%',
#   '$63,151,445',
#   '35.9%',
#   '2001'],
#  ['955',
#   'The Italian Job',
#   '$176,070,171',
#   '$106,128,601',
#   '60.3%',
#   '$69,941,570',
#   '39.7%',
#   '2003'],
#  ['956',
#   'The Bucket List',
#   '$175,372,502',
#   '$93,466,502',
#   '53.3%',
#   '$81,906,000',
#   '46.7%',
#   '2007'],
#  ['957',
#   'Sleeping with the Enemy',
#   '$174,999,005',
#   '$101,599,005',
#   '58.1%',
#   '$73,400,000',
#   '41.9%',
#   '1991'],
#  ['958',
#   'Cowboys & Aliens',
#   '$174,822,325',
#   '$100,240,551',
#   '57.3%',
#   '$74,581,774',
#   '42.7%',
#   '2011'],
#  ['959',
#   'The Mule',
#   '$174,804,407',
#   '$103,804,407',
#   '59.4%',
#   '$71,000,000',
#   '40.6%',
#   '2018'],
#  ['960',
#   'George of the Jungle',
#   '$174,463,257',
#   '$105,263,257',
#   '60.3%',
#   '$69,200,000',
#   '39.7%',
#   '1997'],
#  ['961',
#   'Evan Almighty',
#   '$174,440,724',
#   '$100,462,298',
#   '57.6%',
#   '$73,978,426',
#   '42.4%',
#   '2007'],
#  ['962',
#   'Identity Thief',
#   '$173,965,010',
#   '$134,506,920',
#   '77.3%',
#   '$39,458,090',
#   '22.7%',
#   '2013'],
#  ['963',
#   'The Nutcracker and the Four Realms',
#   '$173,961,069',
#   '$54,858,851',
#   '31.5%',
#   '$119,102,218',
#   '68.5%',
#   '2018'],
#  ['964',
#   "Big Momma's House",
#   '$173,959,438',
#   '$117,559,438',
#   '67.6%',
#   '$56,400,000',
#   '32.4%',
#   '2000'],
#  ['965',
#   'In Time',
#   '$173,930,596',
#   '$37,520,095',
#   '21.6%',
#   '$136,410,501',
#   '78.4%',
#   '2011'],
#  ['966',
#   'Amélie',
#   '$173,924,742',
#   '$33,225,499',
#   '19.1%',
#   '$140,699,243',
#   '80.9%',
#   '2001'],
#  ['967',
#   'Operation Mekong',
#   '$173,839,072',
#   '$800,012',
#   '0.5%',
#   '$173,039,060',
#   '99.5%',
#   '2016'],
#  ['968',
#   'Anchorman 2: The Legend Continues',
#   '$173,649,931',
#   '$127,352,707',
#   '73.3%',
#   '$46,297,224',
#   '26.7%',
#   '2013'],
#  ['969',
#   'Creed',
#   '$173,567,581',
#   '$109,767,581',
#   '63.2%',
#   '$63,800,000',
#   '36.8%',
#   '2015'],
#  ['970',
#   'Gemini Man',
#   '$173,469,516',
#   '$48,546,770',
#   '28%',
#   '$124,922,746',
#   '72%',
#   '2019'],
#  ['971',
#   'The Girl on the Train',
#   '$173,185,859',
#   '$75,395,035',
#   '43.5%',
#   '$97,790,824',
#   '56.5%',
#   '2016'],
#  ['972',
#   'Scream',
#   '$173,046,663',
#   '$103,046,663',
#   '59.6%',
#   '$70,000,000',
#   '40.4%',
#   '1996'],
#  ['973',
#   'Cold Mountain',
#   '$173,013,509',
#   '$95,636,509',
#   '55.3%',
#   '$77,377,000',
#   '44.7%',
#   '2003'],
#  ['974',
#   'Black Hawk Down',
#   '$172,989,651',
#   '$108,638,745',
#   '62.8%',
#   '$64,350,906',
#   '37.2%',
#   '2001'],
#  ['975',
#   'The Grand Budapest Hotel',
#   '$172,936,941',
#   '$59,301,324',
#   '34.3%',
#   '$113,635,617',
#   '65.7%',
#   '2014'],
#  ['976',
#   'The Santa Clause 2',
#   '$172,855,065',
#   '$139,236,327',
#   '80.6%',
#   '$33,618,738',
#   '19.4%',
#   '2002'],
#  ['977',
#   'Cloverfield',
#   '$172,394,180',
#   '$80,048,433',
#   '46.4%',
#   '$92,345,747',
#   '53.6%',
#   '2008'],
#  ['978',
#   'Scream 2',
#   '$172,363,301',
#   '$101,363,301',
#   '58.8%',
#   '$71,000,000',
#   '41.2%',
#   '1997'],
#  ['979',
#   'Couples Retreat',
#   '$171,844,840',
#   '$109,204,945',
#   '63.6%',
#   '$62,639,895',
#   '36.4%',
#   '2009'],
#  ['980',
#   'Antz',
#   '$171,757,863',
#   '$90,757,863',
#   '52.8%',
#   '$81,000,000',
#   '47.2%',
#   '1998'],
#  ['981',
#   'Blood Diamond',
#   '$171,720,398',
#   '$57,377,916',
#   '33.4%',
#   '$114,342,482',
#   '66.6%',
#   '2006'],
#  ['982',
#   'Jackass 3D',
#   '$171,685,792',
#   '$117,229,692',
#   '68.3%',
#   '$54,456,100',
#   '31.7%',
#   '2010'],
#  ['983',
#   'No Country for Old Men',
#   '$171,627,166',
#   '$74,283,625',
#   '43.3%',
#   '$97,343,541',
#   '56.7%',
#   '2007'],
#  ['984',
#   'John Wick: Chapter 2',
#   '$171,539,887',
#   '$92,029,184',
#   '53.6%',
#   '$79,510,703',
#   '46.4%',
#   '2017'],
#  ['985',
#   'Cocktail',
#   '$171,504,781',
#   '$78,222,753',
#   '45.6%',
#   '$93,282,028',
#   '54.4%',
#   '1988'],
#  ['987',
#   'Mr. Deeds',
#   '$171,269,535',
#   '$126,293,452',
#   '73.7%',
#   '$44,976,083',
#   '26.3%',
#   '2002'],
#  ['988',
#   'Contact',
#   '$171,120,329',
#   '$100,920,329',
#   '59%',
#   '$70,200,000',
#   '41%',
#   '1997'],
#  ['989',
#   'Superbad',
#   '$170,812,526',
#   '$121,463,226',
#   '71.1%',
#   '$49,349,300',
#   '28.9%',
#   '2007'],
#  ['990',
#   'Spies in Disguise',
#   '$170,744,862',
#   '$66,435,069',
#   '38.9%',
#   '$104,309,793',
#   '61.1%',
#   '2019'],
#  ['991',
#   'The Other Guys',
#   '$170,458,922',
#   '$119,219,978',
#   '69.9%',
#   '$51,238,944',
#   '30.1%',
#   '2010'],
#  ['992',
#   'The Specialist',
#   '$170,362,582',
#   '$57,362,582',
#   '33.7%',
#   '$113,000,000',
#   '66.3%',
#   '1994'],
#  ['993',
#   'Olympus Has Fallen',
#   '$170,270,201',
#   '$98,925,640',
#   '58.1%',
#   '$71,344,561',
#   '41.9%',
#   '2013'],
#  ['994',
#   'Starsky & Hutch',
#   '$170,268,750',
#   '$88,237,754',
#   '51.8%',
#   '$82,030,996',
#   '48.2%',
#   '2004'],
#  ['995',
#   'Shall We Dance',
#   '$170,128,460',
#   '$57,890,460',
#   '34%',
#   '$112,238,000',
#   '66%',
#   '2004'],
#  ['996',
#   'Stuart Little 2',
#   '$169,956,806',
#   '$64,956,806',
#   '38.2%',
#   '$105,000,000',
#   '61.8%',
#   '2002'],
#  ['997',
#   'Zookeeper',
#   '$169,852,759',
#   '$80,360,843',
#   '47.3%',
#   '$89,491,916',
#   '52.7%',
#   '2011'],
#  ['998',
#   'Dumb and Dumber To',
#   '$169,837,010',
#   '$86,208,010',
#   '50.8%',
#   '$83,629,000',
#   '49.2%',
#   '2014'],
#  ['999',
#   'Ghost in the Shell',
#   '$169,801,921',
#   '$40,563,557',
#   '23.9%',
#   '$129,238,364',
#   '76.1%',
#   '2017'],
#  ['1,000',
#   'Seven Pounds',
#   '$169,748,929',
#   '$69,951,824',
#   '41.2%',
#   '$99,797,105',
#   '58.8%',
#   '2008'],
#  ['1,001',
#   'Meet the Robinsons',
#   '$169,333,034',
#   '$97,822,171',
#   '57.8%',
#   '$71,510,863',
#   '42.2%',
#   '2007'],
#  ['1,002',
#   "The Emperor's New Groove",
#   '$169,327,687',
#   '$89,302,687',
#   '52.7%',
#   '$80,025,000',
#   '47.3%',
#   '2000'],
#  ['1,003',
#   '12 Monkeys',
#   '$168,839,459',
#   '$57,141,459',
#   '33.8%',
#   '$111,698,000',
#   '66.2%',
#   '1995'],
#  ['1,004',
#   'Dodgeball: A True Underdog Story',
#   '$168,423,227',
#   '$114,326,736',
#   '67.9%',
#   '$54,096,491',
#   '32.1%',
#   '2004'],
#  ['1,005',
#   'Hellboy II: The Golden Army',
#   '$168,319,243',
#   '$75,986,503',
#   '45.1%',
#   '$92,332,740',
#   '54.9%',
#   '2008'],
#  ['1,006',
#   'Insidious: The Last Key',
#   '$167,885,588',
#   '$67,745,330',
#   '40.4%',
#   '$100,140,258',
#   '59.6%',
#   '2018'],
#  ['1,007',
#   'Fantastic Four',
#   '$167,882,881',
#   '$56,117,548',
#   '33.4%',
#   '$111,765,333',
#   '66.6%',
#   '2015'],
#  ['1,008',
#   'Unstoppable',
#   '$167,805,466',
#   '$81,562,942',
#   '48.6%',
#   '$86,242,524',
#   '51.4%',
#   '2010'],
#  ['1,009',
#   'Three Men and a Baby',
#   '$167,780,960',
#   '$167,780,960',
#   '100%',
#   '$0',
#   '-',
#   '1987'],
#  ['1,010',
#   'Magic Mike',
#   '$167,739,368',
#   '$113,721,571',
#   '67.8%',
#   '$54,017,797',
#   '32.2%',
#   '2012'],
#  ['1,011',
#   'Alexander',
#   '$167,298,192',
#   '$34,297,191',
#   '20.5%',
#   '$133,001,001',
#   '79.5%',
#   '2004'],
#  ['1,012',
#   'Up in the Air',
#   '$166,842,739',
#   '$83,823,381',
#   '50.2%',
#   '$83,019,358',
#   '49.8%',
#   '2009'],
#  ['1,013',
#   'Nutty Professor II: The Klumps',
#   '$166,339,890',
#   '$123,309,890',
#   '74.1%',
#   '$43,030,000',
#   '25.9%',
#   '2000'],
#  ['1,014',
#   'Sleepers',
#   '$165,615,285',
#   '$53,315,285',
#   '32.2%',
#   '$112,300,000',
#   '67.8%',
#   '1996']]

# %%
for header in soup.findAll("th"):
    print(header.text)
# Out:
# Rank
#
# Title
#
# Worldwide Lifetime Gross
#
# Domestic Lifetime Gross
#
# Domestic %
#
# Foreign Lifetime Gross
#
# Foreign %
#
# Year

# %%
https://www.boxofficemojo.com/chart/ww_top_lifetime_gross/?area=XWW&offset=200
